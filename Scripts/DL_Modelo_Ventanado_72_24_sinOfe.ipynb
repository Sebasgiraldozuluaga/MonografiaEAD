# %% [markdown]
# #### Cargas las librerías

# %%
# Load Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
import os
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf

from evaluation._mae import MAE
from evaluation._smape import sMAPE
from evaluation._mape import MAPE
from evaluation._rmse import RMSE
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### Cargar dataset

# %%
s_path=Path.cwd()
s_prt_path=s_path.parent

file=os.path.join(s_prt_path,'datasets\XM_H_sinOfe.csv')
df_Data= pd.read_csv(file, index_col=0)
# df_Data.reset_index(inplace=True)

# %%
df_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52584 entries, 01/01/2013 0:00 to 31/12/2018 23:00
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PrecioB    52584 non-null  float64
#  1   Demanda    52584 non-null  float64
#  2   DispTer    52584 non-null  int64
#  3   DispNoTer  52584 non-null  int64
#  4   VolUtil    52584 non-null  int64
#  5   Aportes    52584 non-null  int64
#  6   day_cls    52584 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Funciones necesarias para las ejecuciones

# %% [markdown]
# ##### División de datos

# %%
# Dividir los datos en train, validación y test
def split_data(data, indexTotal, train_fraq, test_len=8760):

    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(data)-test_len

    test_data = data[test_slice:]
    indexTest=indexTotal[test_slice:]

    train_val_data = data[:test_slice]
    index_val_data=indexTotal[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    indexTrain=index_val_data[:train_size]

    val_data = train_val_data[train_size:]
    indexVal=index_val_data[train_size:]
    
    return train_data, val_data, test_data, indexTrain, indexVal, indexTest

# %% [markdown]
# ##### Construcción del dataset

# %%
# Crear los datos para entrar al modelo, definición de ventanas
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
    """ Create a windowed tensorflow dataset
    
    """

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
    
    #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    #ds = ds.shuffle(shuffle_buffer)
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    
    return ds

# Construcción del dataset usando las ventanas
def build_dataset(traindata,valdata,testdata,train_fraq=0.8, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
    """If multi variate then first column is always the column from which the target is contstructed.
    """
    
    tf.random.set_seed(23)
    
    
    train_ds = window_dataset(traindata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(valdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(testdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    
    
    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# ##### Parámetros y ejecución

# %%
# Definición de parámetros para la ejecución del modelo
def get_params(multivar=True):
    lr = 3e-4
    n_steps=72
    n_horizon=24
    if multivar:
        n_features=7
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

# Almacenamiento de los datos de las ejecuciones
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}

# Ejecuciones de los modelos con función de ventanado
def run_model(traindata,valdata,testdata,model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    
    train_ds, val_ds, test_ds = build_dataset(traindata,valdata,testdata,n_steps=n_steps, n_horizon=n_horizon, multi_var=True)

    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    # Define el early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=40)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=[early_stopping])

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    
    return test_ds

# %% [markdown]
# #### Modelos

# %% [markdown]
# ##### DNN

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 504)               0
#
#  dense (Dense)               (None, 128)               64640
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 84248 (329.09 KB)
# Trainable params: 84248 (329.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### LSTM

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 72, 72)            23040
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55640 (217.34 KB)
# Trainable params: 55640 (217.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### GRU

# %%
def gru_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.GRU(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.GRU(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='gru')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

gru = gru_model(*get_params(multivar=True))
gru.summary()
# Out:
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 72, 72)            17496
#
#  gru_1 (GRU)                 (None, 48)                17568
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 44432 (173.56 KB)
# Trainable params: 44432 (173.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### CNN_LSTM

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 67, 64)            2752
#
#  max_pooling1d (MaxPooling1  (None, 33, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 31, 64)            12352
#
#  max_pooling1d_1 (MaxPoolin  (None, 15, 64)            0
#  g1D)
#
#  lstm (LSTM)                 (None, 15, 72)            39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 87160 (340.47 KB)
# Trainable params: 87160 (340.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Escalamiento de los datos y división del dataset

# %%
#scale
scaler = MinMaxScaler(feature_range=(0, 1))
scalerP=MinMaxScaler(feature_range=(0, 1))

vec_precio=scalerP.fit_transform(df_Data.values[:,0].reshape(-1,1))

indexTotal=df_Data.index

multivar_df = scaler.fit_transform(df_Data)
train_multi, val_multi, test_multi, indexTrain, indexVal, indexTest = split_data(multivar_df,indexTotal, train_fraq=0.65, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
print('Precio',vec_precio.shape)
print('Todo',df_Data.shape)
# Out:
# Multivarate Datasets
# Train Data Shape: (28485, 7)
# Val Data Shape: (15339, 7)
# Test Data Shape: (8760, 7)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False
# Precio (52584, 1)
# Todo (52584, 7)

# %% [markdown]
# ##### Obtener dataset para el modelo utilizando la función de ventanado

# %%
n_steps=72
n_horizon=24

train_ds, val_ds, test_ds = build_dataset(train_multi, val_multi, test_multi,n_steps=n_steps, n_horizon=n_horizon,multi_var=True)
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Example sample shapes
# x =  (256, 72, 7)
# y =  (256, 24, 1)

# %% [markdown]
# ##### Ejecución de modelo con datos del ventanado

# %%
model_configs_v=dict()
nepochs=100

print('Ejecutando la dnn')
run_model(train_multi, val_multi, test_multi,"dnn", dnn_model, model_configs_v, epochs=nepochs)

print('Ejecutando la lstm')
run_model(train_multi, val_multi, test_multi,"lstm", lstm_model, model_configs_v, epochs=nepochs)

print('Ejecutando la gru')
run_model(train_multi, val_multi, test_multi,"gru", gru_model, model_configs_v, epochs=nepochs)

print('Ejecutando la cnn_lstm')
run_model(train_multi, val_multi, test_multi,"cnn_lstm", lstm_cnn_model, model_configs_v, epochs=nepochs)
# Out:
# Ejecutando la dnn
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 17s 965ms/step - loss: 0.0645 - mae: 0.2748 - mape: 9579.2773 - val_loss: 0.0028 - val_mae: 0.0604 - val_mape: 278.4319
# Epoch 2/100
# 5/5 [==============================] - 3s 589ms/step - loss: 0.0103 - mae: 0.1082 - mape: 2151.0842 - val_loss: 7.2259e-04 - val_mae: 0.0286 - val_mape: 112.4742
# Epoch 3/100
# 5/5 [==============================] - 2s 443ms/step - loss: 0.0068 - mae: 0.0786 - mape: 598.1594 - val_loss: 7.7256e-04 - val_mae: 0.0291 - val_mape: 126.3599
# Epoch 4/100
# 5/5 [==============================] - 3s 535ms/step - loss: 0.0057 - mae: 0.0705 - mape: 1781.4985 - val_loss: 8.2973e-04 - val_mae: 0.0319 - val_mape: 156.1055
# Epoch 5/100
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0047 - mae: 0.0634 - mape: 3389.4573 - val_loss: 7.7412e-04 - val_mae: 0.0313 - val_mape: 163.0503
# Epoch 6/100
# 5/5 [==============================] - 2s 437ms/step - loss: 0.0038 - mae: 0.0556 - mape: 4990.6885 - val_loss: 6.2032e-04 - val_mae: 0.0282 - val_mape: 151.2858
# Epoch 7/100
# 5/5 [==============================] - 2s 504ms/step - loss: 0.0029 - mae: 0.0473 - mape: 1632.6519 - val_loss: 6.2188e-04 - val_mae: 0.0281 - val_mape: 147.5042
# Epoch 8/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.0025 - mae: 0.0437 - mape: 1440.3761 - val_loss: 4.5196e-04 - val_mae: 0.0237 - val_mape: 121.8618
# Epoch 9/100
# 5/5 [==============================] - 3s 547ms/step - loss: 0.0021 - mae: 0.0378 - mape: 1846.1642 - val_loss: 3.5623e-04 - val_mae: 0.0214 - val_mape: 112.6492
# Epoch 10/100
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0019 - mae: 0.0354 - mape: 1517.7427 - val_loss: 3.3123e-04 - val_mae: 0.0209 - val_mape: 113.8645
# Epoch 11/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0017 - mae: 0.0330 - mape: 921.2877 - val_loss: 3.3998e-04 - val_mae: 0.0214 - val_mape: 119.2953
# Epoch 12/100
# 5/5 [==============================] - 2s 512ms/step - loss: 0.0017 - mae: 0.0328 - mape: 801.3671 - val_loss: 3.7538e-04 - val_mae: 0.0230 - val_mape: 129.5018
# Epoch 13/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0016 - mae: 0.0318 - mape: 1350.7220 - val_loss: 4.1562e-04 - val_mae: 0.0246 - val_mape: 138.7981
# Epoch 14/100
# 5/5 [==============================] - 2s 443ms/step - loss: 0.0014 - mae: 0.0312 - mape: 1655.7625 - val_loss: 4.5040e-04 - val_mae: 0.0259 - val_mape: 146.9023
# Epoch 15/100
# 5/5 [==============================] - 2s 442ms/step - loss: 0.0015 - mae: 0.0309 - mape: 1287.7229 - val_loss: 4.5380e-04 - val_mae: 0.0262 - val_mape: 150.6213
# Epoch 16/100
# 5/5 [==============================] - 2s 407ms/step - loss: 0.0015 - mae: 0.0332 - mape: 1977.6971 - val_loss: 4.9903e-04 - val_mae: 0.0277 - val_mape: 157.3614
# Epoch 17/100
# 5/5 [==============================] - 2s 507ms/step - loss: 0.0017 - mae: 0.0335 - mape: 1101.9490 - val_loss: 5.7916e-04 - val_mae: 0.0297 - val_mape: 166.2158
# Epoch 18/100
# 5/5 [==============================] - 2s 403ms/step - loss: 0.0017 - mae: 0.0363 - mape: 2493.9062 - val_loss: 5.4180e-04 - val_mae: 0.0293 - val_mape: 166.2665
# Epoch 19/100
# 5/5 [==============================] - 2s 533ms/step - loss: 0.0020 - mae: 0.0368 - mape: 1212.8317 - val_loss: 4.9625e-04 - val_mae: 0.0273 - val_mape: 158.2425
# Epoch 20/100
# 5/5 [==============================] - 2s 523ms/step - loss: 0.0016 - mae: 0.0337 - mape: 1561.6438 - val_loss: 7.2064e-04 - val_mae: 0.0346 - val_mape: 189.4768
# Epoch 21/100
# 5/5 [==============================] - 2s 480ms/step - loss: 0.0016 - mae: 0.0331 - mape: 1586.9924 - val_loss: 5.4735e-04 - val_mae: 0.0294 - val_mape: 168.6744
# Epoch 22/100
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0014 - mae: 0.0318 - mape: 1703.3324 - val_loss: 6.8565e-04 - val_mae: 0.0337 - val_mape: 186.4147
# Epoch 23/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0013 - mae: 0.0297 - mape: 2242.5669 - val_loss: 5.9211e-04 - val_mae: 0.0309 - val_mape: 175.0735
# Epoch 24/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0015 - mae: 0.0305 - mape: 1453.9055 - val_loss: 5.7633e-04 - val_mae: 0.0304 - val_mape: 173.0017
# Epoch 25/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0012 - mae: 0.0289 - mape: 1774.6014 - val_loss: 5.5652e-04 - val_mae: 0.0297 - val_mape: 170.0805
# Epoch 26/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0011 - mae: 0.0285 - mape: 1741.5586 - val_loss: 5.4746e-04 - val_mae: 0.0295 - val_mape: 168.4903
# Epoch 27/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0011 - mae: 0.0276 - mape: 1914.2153 - val_loss: 5.6794e-04 - val_mae: 0.0301 - val_mape: 170.3509
# Epoch 28/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0011 - mae: 0.0278 - mape: 1800.0454 - val_loss: 5.8519e-04 - val_mae: 0.0307 - val_mape: 171.8120
# Epoch 29/100
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0011 - mae: 0.0275 - mape: 1462.7041 - val_loss: 5.3702e-04 - val_mae: 0.0293 - val_mape: 165.7680
# Epoch 30/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0011 - mae: 0.0285 - mape: 1784.7665 - val_loss: 5.0280e-04 - val_mae: 0.0281 - val_mape: 160.9155
# Epoch 31/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0011 - mae: 0.0264 - mape: 1297.3510 - val_loss: 5.0596e-04 - val_mae: 0.0283 - val_mape: 160.7717
# Epoch 32/100
# 5/5 [==============================] - 0s 107ms/step - loss: 0.0011 - mae: 0.0274 - mape: 1669.5878 - val_loss: 5.4319e-04 - val_mae: 0.0295 - val_mape: 165.5255
# Epoch 33/100
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0011 - mae: 0.0274 - mape: 1592.3278 - val_loss: 4.7789e-04 - val_mae: 0.0274 - val_mape: 157.4580
# Epoch 34/100
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0012 - mae: 0.0302 - mape: 1957.0258 - val_loss: 4.8704e-04 - val_mae: 0.0277 - val_mape: 158.4266
# Epoch 35/100
# 5/5 [==============================] - 0s 106ms/step - loss: 0.0014 - mae: 0.0296 - mape: 1610.6219 - val_loss: 5.6742e-04 - val_mae: 0.0302 - val_mape: 167.7223
# Epoch 36/100
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0014 - mae: 0.0338 - mape: 1681.7037 - val_loss: 4.3846e-04 - val_mae: 0.0259 - val_mape: 151.7336
# Epoch 37/100
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0015 - mae: 0.0307 - mape: 1440.4602 - val_loss: 4.3394e-04 - val_mae: 0.0256 - val_mape: 150.3601
# Epoch 38/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0015 - mae: 0.0378 - mape: 1496.4071 - val_loss: 4.5723e-04 - val_mae: 0.0264 - val_mape: 153.1068
# Epoch 39/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0016 - mae: 0.0326 - mape: 1484.8584 - val_loss: 5.0010e-04 - val_mae: 0.0279 - val_mape: 159.0070
# Epoch 40/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0015 - mae: 0.0352 - mape: 1756.3824 - val_loss: 4.8389e-04 - val_mae: 0.0274 - val_mape: 160.4904
# Epoch 41/100
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0011 - mae: 0.0272 - mape: 1307.5859 - val_loss: 5.8013e-04 - val_mae: 0.0307 - val_mape: 170.8977
# Epoch 42/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0012 - mae: 0.0288 - mape: 1455.7993 - val_loss: 5.2378e-04 - val_mae: 0.0289 - val_mape: 164.6301
# Epoch 43/100
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0012 - mae: 0.0271 - mape: 1435.4548 - val_loss: 4.8486e-04 - val_mae: 0.0276 - val_mape: 160.2950
# Epoch 44/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0011 - mae: 0.0282 - mape: 1442.4510 - val_loss: 4.8472e-04 - val_mae: 0.0277 - val_mape: 160.9574
# Epoch 45/100
# 5/5 [==============================] - 0s 94ms/step - loss: 9.5195e-04 - mae: 0.0260 - mape: 1717.1671 - val_loss: 6.6092e-04 - val_mae: 0.0330 - val_mape: 180.7243
# Epoch 46/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0011 - mae: 0.0262 - mape: 1274.9377 - val_loss: 5.1250e-04 - val_mae: 0.0286 - val_mape: 163.7801
# Epoch 47/100
# 5/5 [==============================] - 0s 105ms/step - loss: 8.5829e-04 - mae: 0.0243 - mape: 1426.4414 - val_loss: 4.8127e-04 - val_mae: 0.0276 - val_mape: 160.1203
# Epoch 48/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0010 - mae: 0.0254 - mape: 1600.1930 - val_loss: 5.1002e-04 - val_mae: 0.0286 - val_mape: 163.2950
# Epoch 49/100
# 5/5 [==============================] - 0s 96ms/step - loss: 9.7852e-04 - mae: 0.0246 - mape: 1609.5933 - val_loss: 5.4183e-04 - val_mae: 0.0295 - val_mape: 166.5924
# Epoch 50/100
# 5/5 [==============================] - 1s 118ms/step - loss: 8.5613e-04 - mae: 0.0238 - mape: 1569.3809 - val_loss: 5.5326e-04 - val_mae: 0.0298 - val_mape: 167.6774
# Ejecutando la lstm
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 15s 720ms/step - loss: 0.0078 - mae: 0.0871 - mape: 894.8829 - val_loss: 5.1483e-04 - val_mae: 0.0228 - val_mape: 97.2232
# Epoch 2/100
# 5/5 [==============================] - 2s 428ms/step - loss: 0.0059 - mae: 0.0672 - mape: 513.7784 - val_loss: 8.3412e-04 - val_mae: 0.0336 - val_mape: 178.4063
# Epoch 3/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0049 - mae: 0.0628 - mape: 2239.3647 - val_loss: 0.0017 - val_mae: 0.0512 - val_mape: 276.4630
# Epoch 4/100
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0046 - mae: 0.0654 - mape: 2759.0059 - val_loss: 0.0023 - val_mae: 0.0615 - val_mape: 331.9022
# Epoch 5/100
# 5/5 [==============================] - 2s 404ms/step - loss: 0.0046 - mae: 0.0667 - mape: 1848.3850 - val_loss: 0.0021 - val_mae: 0.0600 - val_mape: 323.7219
# Epoch 6/100
# 5/5 [==============================] - 2s 353ms/step - loss: 0.0040 - mae: 0.0623 - mape: 4162.5864 - val_loss: 0.0018 - val_mae: 0.0554 - val_mape: 299.6420
# Epoch 7/100
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0037 - mae: 0.0585 - mape: 4672.1592 - val_loss: 0.0016 - val_mae: 0.0535 - val_mape: 287.2869
# Epoch 8/100
# 5/5 [==============================] - 2s 411ms/step - loss: 0.0031 - mae: 0.0552 - mape: 3061.4922 - val_loss: 0.0015 - val_mae: 0.0528 - val_mape: 278.2292
# Epoch 9/100
# 5/5 [==============================] - 2s 335ms/step - loss: 0.0025 - mae: 0.0507 - mape: 1456.2793 - val_loss: 0.0011 - val_mae: 0.0445 - val_mape: 233.7831
# Epoch 10/100
# 5/5 [==============================] - 2s 398ms/step - loss: 0.0053 - mae: 0.0492 - mape: 2024.9297 - val_loss: 5.1584e-04 - val_mae: 0.0264 - val_mape: 149.5150
# Epoch 11/100
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0033 - mae: 0.0476 - mape: 1584.8781 - val_loss: 4.4923e-04 - val_mae: 0.0239 - val_mape: 134.7467
# Epoch 12/100
# 5/5 [==============================] - 2s 337ms/step - loss: 0.0032 - mae: 0.0453 - mape: 1537.4775 - val_loss: 6.4959e-04 - val_mae: 0.0313 - val_mape: 175.8236
# Epoch 13/100
# 5/5 [==============================] - 2s 413ms/step - loss: 0.0027 - mae: 0.0443 - mape: 1686.4327 - val_loss: 0.0014 - val_mae: 0.0484 - val_mape: 259.4066
# Epoch 14/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0027 - mae: 0.0517 - mape: 1991.3297 - val_loss: 0.0020 - val_mae: 0.0597 - val_mape: 309.4941
# Epoch 15/100
# 5/5 [==============================] - 2s 360ms/step - loss: 0.0027 - mae: 0.0556 - mape: 3308.6885 - val_loss: 0.0015 - val_mae: 0.0516 - val_mape: 268.8271
# Epoch 16/100
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0024 - mae: 0.0479 - mape: 2884.6597 - val_loss: 7.6646e-04 - val_mae: 0.0352 - val_mape: 191.7888
# Epoch 17/100
# 5/5 [==============================] - 2s 341ms/step - loss: 0.0018 - mae: 0.0376 - mape: 2149.6958 - val_loss: 5.3855e-04 - val_mae: 0.0285 - val_mape: 158.8922
# Epoch 18/100
# 5/5 [==============================] - 2s 392ms/step - loss: 0.0014 - mae: 0.0336 - mape: 1724.1044 - val_loss: 4.4252e-04 - val_mae: 0.0253 - val_mape: 141.6463
# Epoch 19/100
# 5/5 [==============================] - 2s 347ms/step - loss: 0.0011 - mae: 0.0306 - mape: 1520.4510 - val_loss: 2.9489e-04 - val_mae: 0.0196 - val_mape: 111.6241
# Epoch 20/100
# 5/5 [==============================] - 2s 344ms/step - loss: 0.0011 - mae: 0.0287 - mape: 1699.1606 - val_loss: 2.6093e-04 - val_mae: 0.0185 - val_mape: 106.5956
# Epoch 21/100
# 5/5 [==============================] - 2s 360ms/step - loss: 0.0010 - mae: 0.0276 - mape: 1356.1843 - val_loss: 2.7321e-04 - val_mae: 0.0196 - val_mape: 114.1948
# Epoch 22/100
# 5/5 [==============================] - 2s 398ms/step - loss: 9.4066e-04 - mae: 0.0268 - mape: 2060.2556 - val_loss: 2.8168e-04 - val_mae: 0.0202 - val_mape: 117.4290
# Epoch 23/100
# 5/5 [==============================] - 2s 419ms/step - loss: 9.3757e-04 - mae: 0.0275 - mape: 1401.5264 - val_loss: 2.4092e-04 - val_mae: 0.0184 - val_mape: 107.6001
# Epoch 24/100
# 5/5 [==============================] - 2s 384ms/step - loss: 9.2752e-04 - mae: 0.0264 - mape: 1392.6780 - val_loss: 2.1863e-04 - val_mae: 0.0173 - val_mape: 100.7258
# Epoch 25/100
# 5/5 [==============================] - 2s 389ms/step - loss: 8.9370e-04 - mae: 0.0266 - mape: 1992.8829 - val_loss: 2.1646e-04 - val_mae: 0.0174 - val_mape: 102.0495
# Epoch 26/100
# 5/5 [==============================] - 2s 382ms/step - loss: 8.6140e-04 - mae: 0.0258 - mape: 1173.5470 - val_loss: 2.0970e-04 - val_mae: 0.0165 - val_mape: 93.5180
# Epoch 27/100
# 5/5 [==============================] - 2s 474ms/step - loss: 7.8469e-04 - mae: 0.0242 - mape: 1024.4401 - val_loss: 2.5517e-04 - val_mae: 0.0193 - val_mape: 111.9786
# Epoch 28/100
# 5/5 [==============================] - 3s 532ms/step - loss: 7.8734e-04 - mae: 0.0252 - mape: 1579.1561 - val_loss: 2.0261e-04 - val_mae: 0.0165 - val_mape: 95.9584
# Epoch 29/100
# 5/5 [==============================] - 2s 406ms/step - loss: 7.0883e-04 - mae: 0.0229 - mape: 843.4352 - val_loss: 2.0499e-04 - val_mae: 0.0169 - val_mape: 99.2080
# Epoch 30/100
# 5/5 [==============================] - 2s 416ms/step - loss: 7.2350e-04 - mae: 0.0233 - mape: 1373.2321 - val_loss: 1.8853e-04 - val_mae: 0.0160 - val_mape: 93.7357
# Epoch 31/100
# 5/5 [==============================] - 2s 445ms/step - loss: 7.0882e-04 - mae: 0.0224 - mape: 1538.8583 - val_loss: 1.8103e-04 - val_mae: 0.0156 - val_mape: 90.4520
# Epoch 32/100
# 5/5 [==============================] - 2s 382ms/step - loss: 6.1964e-04 - mae: 0.0215 - mape: 1712.5099 - val_loss: 1.7972e-04 - val_mae: 0.0156 - val_mape: 92.0160
# Epoch 33/100
# 5/5 [==============================] - 2s 370ms/step - loss: 6.9349e-04 - mae: 0.0214 - mape: 1619.9039 - val_loss: 1.8152e-04 - val_mae: 0.0158 - val_mape: 93.4485
# Epoch 34/100
# 5/5 [==============================] - 2s 409ms/step - loss: 6.4954e-04 - mae: 0.0218 - mape: 1328.1842 - val_loss: 1.7049e-04 - val_mae: 0.0151 - val_mape: 88.9839
# Epoch 35/100
# 5/5 [==============================] - 2s 365ms/step - loss: 6.7530e-04 - mae: 0.0214 - mape: 1245.5994 - val_loss: 1.6779e-04 - val_mae: 0.0148 - val_mape: 84.5277
# Epoch 36/100
# 5/5 [==============================] - 2s 379ms/step - loss: 6.0354e-04 - mae: 0.0209 - mape: 1277.6278 - val_loss: 1.7186e-04 - val_mae: 0.0152 - val_mape: 89.7364
# Epoch 37/100
# 5/5 [==============================] - 2s 389ms/step - loss: 6.5228e-04 - mae: 0.0218 - mape: 1172.7617 - val_loss: 1.6835e-04 - val_mae: 0.0150 - val_mape: 87.8506
# Epoch 38/100
# 5/5 [==============================] - 2s 356ms/step - loss: 5.7684e-04 - mae: 0.0203 - mape: 1225.4406 - val_loss: 1.6673e-04 - val_mae: 0.0148 - val_mape: 85.7988
# Epoch 39/100
# 5/5 [==============================] - 2s 372ms/step - loss: 6.1421e-04 - mae: 0.0202 - mape: 1290.8329 - val_loss: 1.6548e-04 - val_mae: 0.0148 - val_mape: 87.0833
# Epoch 40/100
# 5/5 [==============================] - 2s 362ms/step - loss: 6.0354e-04 - mae: 0.0208 - mape: 1563.6240 - val_loss: 1.6570e-04 - val_mae: 0.0149 - val_mape: 88.2752
# Epoch 41/100
# 5/5 [==============================] - 2s 360ms/step - loss: 6.4542e-04 - mae: 0.0211 - mape: 1612.4155 - val_loss: 1.6845e-04 - val_mae: 0.0148 - val_mape: 84.6331
# Epoch 42/100
# 5/5 [==============================] - 2s 420ms/step - loss: 6.2520e-04 - mae: 0.0204 - mape: 1119.6028 - val_loss: 1.7391e-04 - val_mae: 0.0154 - val_mape: 92.1010
# Epoch 43/100
# 5/5 [==============================] - 2s 392ms/step - loss: 6.3785e-04 - mae: 0.0209 - mape: 1451.4750 - val_loss: 1.7115e-04 - val_mae: 0.0150 - val_mape: 86.7276
# Epoch 44/100
# 5/5 [==============================] - 2s 406ms/step - loss: 5.5631e-04 - mae: 0.0195 - mape: 1268.1267 - val_loss: 1.6791e-04 - val_mae: 0.0149 - val_mape: 88.5884
# Epoch 45/100
# 5/5 [==============================] - 2s 417ms/step - loss: 5.6826e-04 - mae: 0.0197 - mape: 1266.7196 - val_loss: 1.7128e-04 - val_mae: 0.0151 - val_mape: 88.9366
# Epoch 46/100
# 5/5 [==============================] - 2s 383ms/step - loss: 5.7670e-04 - mae: 0.0198 - mape: 1150.9417 - val_loss: 1.7682e-04 - val_mae: 0.0153 - val_mape: 88.0993
# Epoch 47/100
# 5/5 [==============================] - 2s 343ms/step - loss: 6.0775e-04 - mae: 0.0203 - mape: 1089.4200 - val_loss: 1.8106e-04 - val_mae: 0.0157 - val_mape: 95.0306
# Epoch 48/100
# 5/5 [==============================] - 2s 380ms/step - loss: 5.3606e-04 - mae: 0.0207 - mape: 1502.1849 - val_loss: 1.8114e-04 - val_mae: 0.0155 - val_mape: 89.4028
# Epoch 49/100
# 5/5 [==============================] - 2s 354ms/step - loss: 5.7168e-04 - mae: 0.0197 - mape: 1137.4265 - val_loss: 1.8073e-04 - val_mae: 0.0155 - val_mape: 90.4163
# Epoch 50/100
# 5/5 [==============================] - 2s 383ms/step - loss: 5.4547e-04 - mae: 0.0195 - mape: 1081.1560 - val_loss: 1.8866e-04 - val_mae: 0.0161 - val_mape: 97.3161
# Epoch 51/100
# 5/5 [==============================] - 2s 385ms/step - loss: 5.7052e-04 - mae: 0.0205 - mape: 1225.5151 - val_loss: 1.8073e-04 - val_mae: 0.0155 - val_mape: 92.7317
# Epoch 52/100
# 5/5 [==============================] - 2s 380ms/step - loss: 5.1028e-04 - mae: 0.0191 - mape: 1319.4286 - val_loss: 1.8867e-04 - val_mae: 0.0158 - val_mape: 91.1802
# Epoch 53/100
# 5/5 [==============================] - 2s 371ms/step - loss: 5.3528e-04 - mae: 0.0200 - mape: 1108.9517 - val_loss: 1.8208e-04 - val_mae: 0.0156 - val_mape: 94.0436
# Epoch 54/100
# 5/5 [==============================] - 2s 421ms/step - loss: 4.9728e-04 - mae: 0.0195 - mape: 1585.1632 - val_loss: 1.8773e-04 - val_mae: 0.0159 - val_mape: 94.3263
# Epoch 55/100
# 5/5 [==============================] - 2s 370ms/step - loss: 5.6574e-04 - mae: 0.0191 - mape: 1533.9320 - val_loss: 1.9078e-04 - val_mae: 0.0160 - val_mape: 95.4788
# Epoch 56/100
# 5/5 [==============================] - 2s 428ms/step - loss: 5.1345e-04 - mae: 0.0194 - mape: 1498.2297 - val_loss: 1.9341e-04 - val_mae: 0.0161 - val_mape: 95.4685
# Epoch 57/100
# 5/5 [==============================] - 2s 402ms/step - loss: 5.0697e-04 - mae: 0.0191 - mape: 1091.0970 - val_loss: 1.9191e-04 - val_mae: 0.0161 - val_mape: 96.0720
# Epoch 58/100
# 5/5 [==============================] - 2s 364ms/step - loss: 5.5331e-04 - mae: 0.0189 - mape: 1652.3313 - val_loss: 1.9202e-04 - val_mae: 0.0161 - val_mape: 96.0874
# Epoch 59/100
# 5/5 [==============================] - 2s 430ms/step - loss: 5.0427e-04 - mae: 0.0191 - mape: 1195.5625 - val_loss: 1.9687e-04 - val_mae: 0.0164 - val_mape: 100.3220
# Epoch 60/100
# 5/5 [==============================] - 2s 446ms/step - loss: 5.2457e-04 - mae: 0.0207 - mape: 1569.6367 - val_loss: 2.0644e-04 - val_mae: 0.0164 - val_mape: 93.8066
# Epoch 61/100
# 5/5 [==============================] - 2s 374ms/step - loss: 6.0087e-04 - mae: 0.0216 - mape: 1065.5305 - val_loss: 2.0019e-04 - val_mae: 0.0165 - val_mape: 99.6766
# Epoch 62/100
# 5/5 [==============================] - 2s 436ms/step - loss: 5.1785e-04 - mae: 0.0198 - mape: 1386.4384 - val_loss: 2.0486e-04 - val_mae: 0.0167 - val_mape: 100.3898
# Epoch 63/100
# 5/5 [==============================] - 2s 416ms/step - loss: 5.0114e-04 - mae: 0.0190 - mape: 1537.9674 - val_loss: 2.0792e-04 - val_mae: 0.0169 - val_mape: 100.8581
# Epoch 64/100
# 5/5 [==============================] - 2s 396ms/step - loss: 5.2344e-04 - mae: 0.0192 - mape: 1130.7291 - val_loss: 2.0748e-04 - val_mae: 0.0168 - val_mape: 100.7295
# Epoch 65/100
# 5/5 [==============================] - 2s 368ms/step - loss: 5.3806e-04 - mae: 0.0196 - mape: 1258.1521 - val_loss: 2.0923e-04 - val_mae: 0.0169 - val_mape: 100.3062
# Epoch 66/100
# 5/5 [==============================] - 2s 399ms/step - loss: 5.1742e-04 - mae: 0.0193 - mape: 1401.8114 - val_loss: 2.0934e-04 - val_mae: 0.0169 - val_mape: 100.7344
# Epoch 67/100
# 5/5 [==============================] - 2s 394ms/step - loss: 5.9017e-04 - mae: 0.0206 - mape: 2320.8103 - val_loss: 2.1194e-04 - val_mae: 0.0170 - val_mape: 101.0493
# Epoch 68/100
# 5/5 [==============================] - 2s 413ms/step - loss: 5.9487e-04 - mae: 0.0207 - mape: 1237.2710 - val_loss: 2.1428e-04 - val_mae: 0.0171 - val_mape: 101.4691
# Epoch 69/100
# 5/5 [==============================] - 2s 449ms/step - loss: 7.0482e-04 - mae: 0.0225 - mape: 1289.9187 - val_loss: 2.2066e-04 - val_mae: 0.0173 - val_mape: 102.1972
# Epoch 70/100
# 5/5 [==============================] - 2s 447ms/step - loss: 6.7969e-04 - mae: 0.0222 - mape: 1545.0353 - val_loss: 2.2164e-04 - val_mae: 0.0175 - val_mape: 104.8724
# Epoch 71/100
# 5/5 [==============================] - 2s 451ms/step - loss: 5.9279e-04 - mae: 0.0214 - mape: 1164.7216 - val_loss: 2.3422e-04 - val_mae: 0.0177 - val_mape: 103.4671
# Epoch 72/100
# 5/5 [==============================] - 2s 443ms/step - loss: 5.7468e-04 - mae: 0.0199 - mape: 1458.4417 - val_loss: 2.4139e-04 - val_mae: 0.0185 - val_mape: 111.4442
# Epoch 73/100
# 5/5 [==============================] - 2s 467ms/step - loss: 5.6174e-04 - mae: 0.0211 - mape: 1523.2441 - val_loss: 2.4054e-04 - val_mae: 0.0180 - val_mape: 105.3946
# Epoch 74/100
# 5/5 [==============================] - 2s 464ms/step - loss: 5.1687e-04 - mae: 0.0189 - mape: 1390.2300 - val_loss: 2.3596e-04 - val_mae: 0.0181 - val_mape: 109.6216
# Epoch 75/100
# 5/5 [==============================] - 2s 365ms/step - loss: 4.7790e-04 - mae: 0.0184 - mape: 1190.3722 - val_loss: 2.3556e-04 - val_mae: 0.0181 - val_mape: 109.5811
# Epoch 76/100
# 5/5 [==============================] - 2s 406ms/step - loss: 4.7108e-04 - mae: 0.0182 - mape: 1394.2225 - val_loss: 2.3508e-04 - val_mae: 0.0180 - val_mape: 108.5559
# Epoch 77/100
# 5/5 [==============================] - 2s 412ms/step - loss: 4.3241e-04 - mae: 0.0174 - mape: 1316.7125 - val_loss: 2.3441e-04 - val_mae: 0.0181 - val_mape: 110.4529
# Epoch 78/100
# 5/5 [==============================] - 2s 373ms/step - loss: 4.8971e-04 - mae: 0.0181 - mape: 1237.4213 - val_loss: 2.3619e-04 - val_mae: 0.0180 - val_mape: 108.6713
# Epoch 79/100
# 5/5 [==============================] - 2s 385ms/step - loss: 4.4855e-04 - mae: 0.0176 - mape: 1277.8601 - val_loss: 2.3526e-04 - val_mae: 0.0180 - val_mape: 108.8405
# Ejecutando la gru
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 7s 521ms/step - loss: 0.0084 - mae: 0.0924 - mape: 982.9933 - val_loss: 5.6144e-04 - val_mae: 0.0247 - val_mape: 88.4388
# Epoch 2/100
# 5/5 [==============================] - 2s 343ms/step - loss: 0.0066 - mae: 0.0741 - mape: 363.0000 - val_loss: 4.8128e-04 - val_mae: 0.0232 - val_mape: 105.7032
# Epoch 3/100
# 5/5 [==============================] - 2s 352ms/step - loss: 0.0054 - mae: 0.0639 - mape: 221.9633 - val_loss: 7.6690e-04 - val_mae: 0.0315 - val_mape: 168.9202
# Epoch 4/100
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0047 - mae: 0.0611 - mape: 1105.9304 - val_loss: 0.0014 - val_mae: 0.0468 - val_mape: 251.2746
# Epoch 5/100
# 5/5 [==============================] - 2s 336ms/step - loss: 0.0045 - mae: 0.0643 - mape: 138.8090 - val_loss: 0.0017 - val_mae: 0.0536 - val_mape: 284.3615
# Epoch 6/100
# 5/5 [==============================] - 2s 303ms/step - loss: 0.0043 - mae: 0.0639 - mape: 3039.5117 - val_loss: 0.0016 - val_mae: 0.0520 - val_mape: 275.3431
# Epoch 7/100
# 5/5 [==============================] - 2s 339ms/step - loss: 0.0039 - mae: 0.0600 - mape: 2751.9182 - val_loss: 0.0014 - val_mae: 0.0499 - val_mape: 263.8860
# Epoch 8/100
# 5/5 [==============================] - 2s 346ms/step - loss: 0.0035 - mae: 0.0571 - mape: 3319.7722 - val_loss: 0.0015 - val_mae: 0.0506 - val_mape: 265.2974
# Epoch 9/100
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0033 - mae: 0.0561 - mape: 3803.9380 - val_loss: 0.0014 - val_mae: 0.0491 - val_mape: 255.9937
# Epoch 10/100
# 5/5 [==============================] - 2s 414ms/step - loss: 0.0030 - mae: 0.0532 - mape: 2356.6145 - val_loss: 0.0012 - val_mae: 0.0452 - val_mape: 236.2516
# Epoch 11/100
# 5/5 [==============================] - 2s 345ms/step - loss: 0.0026 - mae: 0.0487 - mape: 3134.3699 - val_loss: 0.0010 - val_mae: 0.0420 - val_mape: 218.9568
# Epoch 12/100
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0022 - mae: 0.0445 - mape: 2938.6226 - val_loss: 8.5699e-04 - val_mae: 0.0380 - val_mape: 200.0774
# Epoch 13/100
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0016 - mae: 0.0385 - mape: 2315.4065 - val_loss: 6.9621e-04 - val_mae: 0.0336 - val_mape: 182.0530
# Epoch 14/100
# 5/5 [==============================] - 2s 339ms/step - loss: 0.0013 - mae: 0.0341 - mape: 2774.5967 - val_loss: 5.2817e-04 - val_mae: 0.0286 - val_mape: 161.9986
# Epoch 15/100
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0011 - mae: 0.0290 - mape: 2387.7188 - val_loss: 4.6951e-04 - val_mae: 0.0268 - val_mape: 154.0937
# Epoch 16/100
# 5/5 [==============================] - 2s 322ms/step - loss: 9.9613e-04 - mae: 0.0276 - mape: 1966.7213 - val_loss: 4.5484e-04 - val_mae: 0.0263 - val_mape: 152.1069
# Epoch 17/100
# 5/5 [==============================] - 2s 348ms/step - loss: 0.0011 - mae: 0.0279 - mape: 2327.0891 - val_loss: 4.8681e-04 - val_mae: 0.0274 - val_mape: 157.8064
# Epoch 18/100
# 5/5 [==============================] - 1s 297ms/step - loss: 0.0011 - mae: 0.0279 - mape: 1634.9153 - val_loss: 4.5914e-04 - val_mae: 0.0265 - val_mape: 152.9623
# Epoch 19/100
# 5/5 [==============================] - 2s 351ms/step - loss: 0.0017 - mae: 0.0347 - mape: 1764.2329 - val_loss: 4.4779e-04 - val_mae: 0.0260 - val_mape: 149.0346
# Epoch 20/100
# 5/5 [==============================] - 2s 325ms/step - loss: 0.0013 - mae: 0.0313 - mape: 2193.8030 - val_loss: 7.7356e-04 - val_mae: 0.0360 - val_mape: 191.6776
# Epoch 21/100
# 5/5 [==============================] - 2s 368ms/step - loss: 0.0011 - mae: 0.0302 - mape: 1865.1771 - val_loss: 3.8631e-04 - val_mae: 0.0240 - val_mape: 139.6413
# Epoch 22/100
# 5/5 [==============================] - 2s 353ms/step - loss: 8.8615e-04 - mae: 0.0255 - mape: 1475.1675 - val_loss: 5.1016e-04 - val_mae: 0.0288 - val_mape: 158.1922
# Epoch 23/100
# 5/5 [==============================] - 2s 291ms/step - loss: 9.9081e-04 - mae: 0.0293 - mape: 1864.5924 - val_loss: 3.4163e-04 - val_mae: 0.0227 - val_mape: 130.8644
# Epoch 24/100
# 5/5 [==============================] - 2s 337ms/step - loss: 9.1529e-04 - mae: 0.0257 - mape: 1579.7721 - val_loss: 2.6289e-04 - val_mae: 0.0191 - val_mape: 113.9509
# Epoch 25/100
# 5/5 [==============================] - 2s 321ms/step - loss: 7.8112e-04 - mae: 0.0239 - mape: 1983.0266 - val_loss: 3.8042e-04 - val_mae: 0.0243 - val_mape: 137.2804
# Epoch 26/100
# 5/5 [==============================] - 2s 352ms/step - loss: 7.3629e-04 - mae: 0.0234 - mape: 1434.8855 - val_loss: 3.4390e-04 - val_mae: 0.0229 - val_mape: 132.3396
# Epoch 27/100
# 5/5 [==============================] - 2s 300ms/step - loss: 7.4514e-04 - mae: 0.0232 - mape: 1490.5334 - val_loss: 4.3937e-04 - val_mae: 0.0265 - val_mape: 148.0972
# Epoch 28/100
# 5/5 [==============================] - 2s 345ms/step - loss: 6.7764e-04 - mae: 0.0229 - mape: 1593.6578 - val_loss: 3.2346e-04 - val_mae: 0.0221 - val_mape: 127.6947
# Epoch 29/100
# 5/5 [==============================] - 2s 315ms/step - loss: 7.5342e-04 - mae: 0.0223 - mape: 1507.2526 - val_loss: 2.8093e-04 - val_mae: 0.0203 - val_mape: 118.8795
# Epoch 30/100
# 5/5 [==============================] - 2s 324ms/step - loss: 7.5481e-04 - mae: 0.0226 - mape: 1488.1671 - val_loss: 3.0960e-04 - val_mae: 0.0215 - val_mape: 124.1411
# Epoch 31/100
# 5/5 [==============================] - 2s 317ms/step - loss: 8.1808e-04 - mae: 0.0224 - mape: 2100.7698 - val_loss: 2.8947e-04 - val_mae: 0.0207 - val_mape: 120.5576
# Epoch 32/100
# 5/5 [==============================] - 2s 307ms/step - loss: 6.9339e-04 - mae: 0.0221 - mape: 1593.3557 - val_loss: 3.3959e-04 - val_mae: 0.0228 - val_mape: 129.4526
# Epoch 33/100
# 5/5 [==============================] - 2s 341ms/step - loss: 8.2908e-04 - mae: 0.0227 - mape: 1740.7395 - val_loss: 2.7825e-04 - val_mae: 0.0202 - val_mape: 118.2076
# Epoch 34/100
# 5/5 [==============================] - 2s 305ms/step - loss: 7.0314e-04 - mae: 0.0220 - mape: 1215.0284 - val_loss: 2.8333e-04 - val_mae: 0.0205 - val_mape: 118.4804
# Epoch 35/100
# 5/5 [==============================] - 2s 368ms/step - loss: 7.0914e-04 - mae: 0.0220 - mape: 1094.2469 - val_loss: 2.5993e-04 - val_mae: 0.0194 - val_mape: 114.1476
# Epoch 36/100
# 5/5 [==============================] - 2s 301ms/step - loss: 7.1207e-04 - mae: 0.0223 - mape: 1264.3319 - val_loss: 3.1359e-04 - val_mae: 0.0218 - val_mape: 123.9904
# Epoch 37/100
# 5/5 [==============================] - 2s 324ms/step - loss: 7.2480e-04 - mae: 0.0222 - mape: 1132.4136 - val_loss: 2.6006e-04 - val_mae: 0.0194 - val_mape: 113.8534
# Epoch 38/100
# 5/5 [==============================] - 2s 352ms/step - loss: 6.4186e-04 - mae: 0.0213 - mape: 1147.8988 - val_loss: 3.4804e-04 - val_mae: 0.0232 - val_mape: 130.1829
# Epoch 39/100
# 5/5 [==============================] - 2s 338ms/step - loss: 7.2114e-04 - mae: 0.0220 - mape: 1446.3279 - val_loss: 2.5523e-04 - val_mae: 0.0192 - val_mape: 112.9725
# Epoch 40/100
# 5/5 [==============================] - 2s 348ms/step - loss: 6.3230e-04 - mae: 0.0212 - mape: 1240.4822 - val_loss: 2.7828e-04 - val_mae: 0.0203 - val_mape: 116.6450
# Epoch 41/100
# 5/5 [==============================] - 2s 317ms/step - loss: 6.1632e-04 - mae: 0.0209 - mape: 1448.1588 - val_loss: 2.1955e-04 - val_mae: 0.0175 - val_mape: 104.5272
# Epoch 42/100
# 5/5 [==============================] - 2s 322ms/step - loss: 6.2966e-04 - mae: 0.0206 - mape: 1920.3265 - val_loss: 2.7952e-04 - val_mae: 0.0203 - val_mape: 117.3686
# Epoch 43/100
# 5/5 [==============================] - 2s 334ms/step - loss: 6.8698e-04 - mae: 0.0214 - mape: 1421.3170 - val_loss: 2.6785e-04 - val_mae: 0.0198 - val_mape: 115.7357
# Epoch 44/100
# 5/5 [==============================] - 2s 337ms/step - loss: 6.5156e-04 - mae: 0.0213 - mape: 1384.5375 - val_loss: 2.2635e-04 - val_mae: 0.0178 - val_mape: 105.5913
# Epoch 45/100
# 5/5 [==============================] - 2s 297ms/step - loss: 5.6988e-04 - mae: 0.0204 - mape: 1187.3416 - val_loss: 1.9779e-04 - val_mae: 0.0164 - val_mape: 98.7007
# Epoch 46/100
# 5/5 [==============================] - 2s 349ms/step - loss: 6.8392e-04 - mae: 0.0207 - mape: 1246.2639 - val_loss: 2.6681e-04 - val_mae: 0.0197 - val_mape: 115.3916
# Epoch 47/100
# 5/5 [==============================] - 2s 334ms/step - loss: 6.4355e-04 - mae: 0.0212 - mape: 979.2822 - val_loss: 2.8186e-04 - val_mae: 0.0203 - val_mape: 119.2812
# Epoch 48/100
# 5/5 [==============================] - 2s 315ms/step - loss: 6.3702e-04 - mae: 0.0217 - mape: 1261.0778 - val_loss: 2.5135e-04 - val_mae: 0.0189 - val_mape: 111.6173
# Epoch 49/100
# 5/5 [==============================] - 2s 352ms/step - loss: 5.8725e-04 - mae: 0.0205 - mape: 921.9016 - val_loss: 2.0732e-04 - val_mae: 0.0168 - val_mape: 101.4088
# Epoch 50/100
# 5/5 [==============================] - 2s 314ms/step - loss: 5.9034e-04 - mae: 0.0198 - mape: 1183.1871 - val_loss: 2.8629e-04 - val_mae: 0.0206 - val_mape: 118.9319
# Epoch 51/100
# 5/5 [==============================] - 2s 374ms/step - loss: 6.6985e-04 - mae: 0.0214 - mape: 1062.7159 - val_loss: 2.6374e-04 - val_mae: 0.0196 - val_mape: 115.3299
# Epoch 52/100
# 5/5 [==============================] - 2s 321ms/step - loss: 6.2472e-04 - mae: 0.0210 - mape: 1259.4822 - val_loss: 2.4367e-04 - val_mae: 0.0186 - val_mape: 109.3813
# Epoch 53/100
# 5/5 [==============================] - 2s 323ms/step - loss: 5.4048e-04 - mae: 0.0201 - mape: 1220.6807 - val_loss: 1.9687e-04 - val_mae: 0.0163 - val_mape: 98.5245
# Epoch 54/100
# 5/5 [==============================] - 2s 322ms/step - loss: 5.5469e-04 - mae: 0.0201 - mape: 1183.4846 - val_loss: 2.1687e-04 - val_mae: 0.0172 - val_mape: 103.7992
# Epoch 55/100
# 5/5 [==============================] - 2s 307ms/step - loss: 6.1138e-04 - mae: 0.0209 - mape: 1437.0325 - val_loss: 2.3547e-04 - val_mae: 0.0182 - val_mape: 109.0376
# Epoch 56/100
# 5/5 [==============================] - 2s 341ms/step - loss: 5.6625e-04 - mae: 0.0211 - mape: 1401.7125 - val_loss: 2.8833e-04 - val_mae: 0.0206 - val_mape: 119.1065
# Epoch 57/100
# 5/5 [==============================] - 2s 296ms/step - loss: 5.9720e-04 - mae: 0.0206 - mape: 1267.3043 - val_loss: 2.0787e-04 - val_mae: 0.0168 - val_mape: 101.8177
# Epoch 58/100
# 5/5 [==============================] - 2s 351ms/step - loss: 6.1176e-04 - mae: 0.0199 - mape: 1646.8212 - val_loss: 2.4030e-04 - val_mae: 0.0184 - val_mape: 109.7855
# Epoch 59/100
# 5/5 [==============================] - 2s 321ms/step - loss: 6.6349e-04 - mae: 0.0213 - mape: 957.7094 - val_loss: 2.6648e-04 - val_mae: 0.0197 - val_mape: 116.6151
# Epoch 60/100
# 5/5 [==============================] - 2s 350ms/step - loss: 5.9719e-04 - mae: 0.0215 - mape: 1686.5598 - val_loss: 2.5953e-04 - val_mae: 0.0193 - val_mape: 114.4891
# Epoch 61/100
# 5/5 [==============================] - 2s 312ms/step - loss: 6.4718e-04 - mae: 0.0215 - mape: 1092.0963 - val_loss: 2.1390e-04 - val_mae: 0.0171 - val_mape: 103.8885
# Epoch 62/100
# 5/5 [==============================] - 2s 335ms/step - loss: 6.7560e-04 - mae: 0.0207 - mape: 1110.4966 - val_loss: 2.7130e-04 - val_mae: 0.0199 - val_mape: 116.8920
# Epoch 63/100
# 5/5 [==============================] - 2s 315ms/step - loss: 6.2726e-04 - mae: 0.0211 - mape: 1556.3673 - val_loss: 2.3602e-04 - val_mae: 0.0182 - val_mape: 109.8435
# Epoch 64/100
# 5/5 [==============================] - 2s 323ms/step - loss: 5.5624e-04 - mae: 0.0199 - mape: 1081.7629 - val_loss: 3.4696e-04 - val_mae: 0.0230 - val_mape: 128.8015
# Epoch 65/100
# 5/5 [==============================] - 2s 322ms/step - loss: 5.1297e-04 - mae: 0.0196 - mape: 1150.2227 - val_loss: 2.1209e-04 - val_mae: 0.0170 - val_mape: 103.0570
# Epoch 66/100
# 5/5 [==============================] - 2s 327ms/step - loss: 5.2268e-04 - mae: 0.0190 - mape: 1957.4045 - val_loss: 2.3423e-04 - val_mae: 0.0180 - val_mape: 109.0111
# Epoch 67/100
# 5/5 [==============================] - 2s 343ms/step - loss: 4.7291e-04 - mae: 0.0185 - mape: 1265.7017 - val_loss: 2.5259e-04 - val_mae: 0.0189 - val_mape: 113.0446
# Epoch 68/100
# 5/5 [==============================] - 2s 304ms/step - loss: 4.8497e-04 - mae: 0.0182 - mape: 1460.9448 - val_loss: 2.5121e-04 - val_mae: 0.0189 - val_mape: 112.7262
# Epoch 69/100
# 5/5 [==============================] - 2s 346ms/step - loss: 6.0011e-04 - mae: 0.0192 - mape: 1000.9967 - val_loss: 2.6354e-04 - val_mae: 0.0194 - val_mape: 114.6875
# Epoch 70/100
# 5/5 [==============================] - 2s 317ms/step - loss: 5.8308e-04 - mae: 0.0192 - mape: 1149.3845 - val_loss: 2.3023e-04 - val_mae: 0.0178 - val_mape: 107.5659
# Epoch 71/100
# 5/5 [==============================] - 2s 332ms/step - loss: 4.3534e-04 - mae: 0.0183 - mape: 1243.0029 - val_loss: 2.1956e-04 - val_mae: 0.0173 - val_mape: 105.5028
# Epoch 72/100
# 5/5 [==============================] - 2s 309ms/step - loss: 5.2050e-04 - mae: 0.0186 - mape: 1101.0399 - val_loss: 2.5660e-04 - val_mae: 0.0191 - val_mape: 113.7820
# Epoch 73/100
# 5/5 [==============================] - 2s 369ms/step - loss: 5.1983e-04 - mae: 0.0187 - mape: 1487.5094 - val_loss: 2.7777e-04 - val_mae: 0.0201 - val_mape: 117.9705
# Epoch 74/100
# 5/5 [==============================] - 2s 346ms/step - loss: 5.7061e-04 - mae: 0.0199 - mape: 1569.6819 - val_loss: 2.2135e-04 - val_mae: 0.0174 - val_mape: 105.7370
# Epoch 75/100
# 5/5 [==============================] - 2s 329ms/step - loss: 5.5286e-04 - mae: 0.0199 - mape: 1138.8677 - val_loss: 2.1182e-04 - val_mae: 0.0169 - val_mape: 103.6018
# Epoch 76/100
# 5/5 [==============================] - 2s 362ms/step - loss: 5.5275e-04 - mae: 0.0193 - mape: 1075.8865 - val_loss: 2.3776e-04 - val_mae: 0.0182 - val_mape: 110.0108
# Epoch 77/100
# 5/5 [==============================] - 2s 301ms/step - loss: 6.6653e-04 - mae: 0.0217 - mape: 1127.7534 - val_loss: 2.2933e-04 - val_mae: 0.0178 - val_mape: 108.6509
# Epoch 78/100
# 5/5 [==============================] - 2s 343ms/step - loss: 5.2957e-04 - mae: 0.0208 - mape: 1091.3910 - val_loss: 2.6066e-04 - val_mae: 0.0192 - val_mape: 114.9178
# Epoch 79/100
# 5/5 [==============================] - 2s 310ms/step - loss: 6.0460e-04 - mae: 0.0201 - mape: 1412.6490 - val_loss: 2.2871e-04 - val_mae: 0.0177 - val_mape: 107.1253
# Epoch 80/100
# 5/5 [==============================] - 2s 348ms/step - loss: 5.6660e-04 - mae: 0.0196 - mape: 1169.9297 - val_loss: 2.6362e-04 - val_mae: 0.0194 - val_mape: 116.0920
# Epoch 81/100
# 5/5 [==============================] - 2s 331ms/step - loss: 5.2706e-04 - mae: 0.0193 - mape: 1189.8141 - val_loss: 2.4326e-04 - val_mae: 0.0184 - val_mape: 112.2029
# Epoch 82/100
# 5/5 [==============================] - 2s 301ms/step - loss: 4.6353e-04 - mae: 0.0183 - mape: 1168.8492 - val_loss: 3.0848e-04 - val_mae: 0.0214 - val_mape: 122.4768
# Epoch 83/100
# 5/5 [==============================] - 2s 373ms/step - loss: 4.4149e-04 - mae: 0.0182 - mape: 1285.5249 - val_loss: 2.2224e-04 - val_mae: 0.0174 - val_mape: 106.5369
# Epoch 84/100
# 5/5 [==============================] - 2s 299ms/step - loss: 5.0137e-04 - mae: 0.0184 - mape: 1385.7860 - val_loss: 2.2779e-04 - val_mae: 0.0177 - val_mape: 107.9236
# Epoch 85/100
# 5/5 [==============================] - 2s 318ms/step - loss: 5.3655e-04 - mae: 0.0188 - mape: 1241.1737 - val_loss: 2.4320e-04 - val_mae: 0.0184 - val_mape: 111.5714
# Epoch 86/100
# 5/5 [==============================] - 2s 327ms/step - loss: 4.7000e-04 - mae: 0.0179 - mape: 1437.0397 - val_loss: 2.6911e-04 - val_mae: 0.0196 - val_mape: 116.1667
# Epoch 87/100
# 5/5 [==============================] - 2s 336ms/step - loss: 5.0521e-04 - mae: 0.0181 - mape: 1372.1862 - val_loss: 2.4161e-04 - val_mae: 0.0183 - val_mape: 111.3505
# Epoch 88/100
# 5/5 [==============================] - 2s 310ms/step - loss: 4.2346e-04 - mae: 0.0171 - mape: 1342.6362 - val_loss: 2.6322e-04 - val_mae: 0.0193 - val_mape: 115.3808
# Epoch 89/100
# 5/5 [==============================] - 2s 300ms/step - loss: 4.4463e-04 - mae: 0.0179 - mape: 1193.1465 - val_loss: 2.5843e-04 - val_mae: 0.0191 - val_mape: 114.5586
# Epoch 90/100
# 5/5 [==============================] - 2s 308ms/step - loss: 4.4149e-04 - mae: 0.0175 - mape: 1324.3444 - val_loss: 2.6853e-04 - val_mae: 0.0196 - val_mape: 115.3700
# Epoch 91/100
# 5/5 [==============================] - 2s 330ms/step - loss: 4.9611e-04 - mae: 0.0180 - mape: 1239.8506 - val_loss: 2.2919e-04 - val_mae: 0.0177 - val_mape: 107.6995
# Epoch 92/100
# 5/5 [==============================] - 2s 332ms/step - loss: 3.9743e-04 - mae: 0.0170 - mape: 1315.3384 - val_loss: 2.4972e-04 - val_mae: 0.0187 - val_mape: 111.6764
# Epoch 93/100
# 5/5 [==============================] - 2s 323ms/step - loss: 4.8300e-04 - mae: 0.0181 - mape: 1380.6155 - val_loss: 2.4381e-04 - val_mae: 0.0184 - val_mape: 110.4026
# Ejecutando la cnn_lstm
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 6s 462ms/step - loss: 0.0067 - mae: 0.0762 - mape: 149.4177 - val_loss: 8.8056e-04 - val_mae: 0.0330 - val_mape: 172.5589
# Epoch 2/100
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0051 - mae: 0.0640 - mape: 3538.8992 - val_loss: 0.0020 - val_mae: 0.0571 - val_mape: 306.0193
# Epoch 3/100
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0049 - mae: 0.0675 - mape: 4160.2734 - val_loss: 0.0023 - val_mae: 0.0637 - val_mape: 341.0734
# Epoch 4/100
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0045 - mae: 0.0659 - mape: 1682.8002 - val_loss: 0.0020 - val_mae: 0.0602 - val_mape: 322.1572
# Epoch 5/100
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0042 - mae: 0.0632 - mape: 1968.6191 - val_loss: 0.0019 - val_mae: 0.0590 - val_mape: 313.6038
# Epoch 6/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0038 - mae: 0.0611 - mape: 2664.3523 - val_loss: 0.0019 - val_mae: 0.0586 - val_mape: 308.0160
# Epoch 7/100
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0034 - mae: 0.0589 - mape: 2996.4163 - val_loss: 0.0015 - val_mae: 0.0522 - val_mape: 273.6709
# Epoch 8/100
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0025 - mae: 0.0510 - mape: 3135.2375 - val_loss: 0.0011 - val_mae: 0.0431 - val_mape: 229.6615
# Epoch 9/100
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0018 - mae: 0.0431 - mape: 3417.4316 - val_loss: 6.2529e-04 - val_mae: 0.0310 - val_mape: 177.4602
# Epoch 10/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0016 - mae: 0.0332 - mape: 1616.0620 - val_loss: 4.4013e-04 - val_mae: 0.0251 - val_mape: 146.0678
# Epoch 11/100
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0016 - mae: 0.0341 - mape: 1766.9683 - val_loss: 5.2024e-04 - val_mae: 0.0285 - val_mape: 163.4825
# Epoch 12/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0020 - mae: 0.0438 - mape: 1211.7377 - val_loss: 4.5668e-04 - val_mae: 0.0263 - val_mape: 153.1807
# Epoch 13/100
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0033 - mae: 0.0458 - mape: 1412.0178 - val_loss: 4.5083e-04 - val_mae: 0.0248 - val_mape: 142.4260
# Epoch 14/100
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0026 - mae: 0.0413 - mape: 860.5909 - val_loss: 8.0084e-04 - val_mae: 0.0362 - val_mape: 203.6290
# Epoch 15/100
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0014 - mae: 0.0375 - mape: 2069.1909 - val_loss: 0.0018 - val_mae: 0.0573 - val_mape: 288.7068
# Epoch 16/100
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0017 - mae: 0.0466 - mape: 2960.8760 - val_loss: 8.3732e-04 - val_mae: 0.0375 - val_mape: 209.4724
# Epoch 17/100
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0014 - mae: 0.0338 - mape: 2251.1763 - val_loss: 5.9313e-04 - val_mae: 0.0303 - val_mape: 171.9776
# Epoch 18/100
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0011 - mae: 0.0300 - mape: 1880.5240 - val_loss: 5.1566e-04 - val_mae: 0.0286 - val_mape: 163.0551
# Epoch 19/100
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0010 - mae: 0.0279 - mape: 2161.6296 - val_loss: 3.8762e-04 - val_mae: 0.0239 - val_mape: 137.8770
# Epoch 20/100
# 5/5 [==============================] - 1s 189ms/step - loss: 9.6296e-04 - mae: 0.0262 - mape: 1839.2159 - val_loss: 4.2194e-04 - val_mae: 0.0255 - val_mape: 144.6353
# Epoch 21/100
# 5/5 [==============================] - 1s 178ms/step - loss: 8.7412e-04 - mae: 0.0262 - mape: 1803.1864 - val_loss: 3.2108e-04 - val_mae: 0.0216 - val_mape: 122.0467
# Epoch 22/100
# 5/5 [==============================] - 1s 237ms/step - loss: 9.0135e-04 - mae: 0.0247 - mape: 1445.9794 - val_loss: 2.5321e-04 - val_mae: 0.0187 - val_mape: 105.1671
# Epoch 23/100
# 5/5 [==============================] - 1s 189ms/step - loss: 8.6148e-04 - mae: 0.0244 - mape: 765.4874 - val_loss: 2.8635e-04 - val_mae: 0.0202 - val_mape: 115.5600
# Epoch 24/100
# 5/5 [==============================] - 1s 187ms/step - loss: 8.1102e-04 - mae: 0.0235 - mape: 1474.2587 - val_loss: 2.8625e-04 - val_mae: 0.0202 - val_mape: 117.4066
# Epoch 25/100
# 5/5 [==============================] - 1s 181ms/step - loss: 7.7374e-04 - mae: 0.0234 - mape: 600.7250 - val_loss: 2.6530e-04 - val_mae: 0.0194 - val_mape: 112.9572
# Epoch 26/100
# 5/5 [==============================] - 1s 172ms/step - loss: 7.5222e-04 - mae: 0.0228 - mape: 733.3228 - val_loss: 2.7451e-04 - val_mae: 0.0199 - val_mape: 115.6451
# Epoch 27/100
# 5/5 [==============================] - 1s 192ms/step - loss: 7.5893e-04 - mae: 0.0233 - mape: 1651.4739 - val_loss: 2.0390e-04 - val_mae: 0.0165 - val_mape: 95.4070
# Epoch 28/100
# 5/5 [==============================] - 1s 193ms/step - loss: 7.5422e-04 - mae: 0.0233 - mape: 811.7326 - val_loss: 3.1711e-04 - val_mae: 0.0216 - val_mape: 127.0146
# Epoch 29/100
# 5/5 [==============================] - 1s 208ms/step - loss: 9.4975e-04 - mae: 0.0267 - mape: 905.9807 - val_loss: 2.8553e-04 - val_mae: 0.0203 - val_mape: 119.3386
# Epoch 30/100
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0012 - mae: 0.0276 - mape: 925.4603 - val_loss: 2.7420e-04 - val_mae: 0.0196 - val_mape: 115.0882
# Epoch 31/100
# 5/5 [==============================] - 1s 182ms/step - loss: 8.5246e-04 - mae: 0.0264 - mape: 1096.6708 - val_loss: 4.3390e-04 - val_mae: 0.0262 - val_mape: 146.9576
# Epoch 32/100
# 5/5 [==============================] - 1s 178ms/step - loss: 7.5147e-04 - mae: 0.0238 - mape: 1447.5220 - val_loss: 1.7319e-04 - val_mae: 0.0148 - val_mape: 82.5108
# Epoch 33/100
# 5/5 [==============================] - 1s 195ms/step - loss: 7.9219e-04 - mae: 0.0229 - mape: 501.5744 - val_loss: 3.0513e-04 - val_mae: 0.0212 - val_mape: 121.9435
# Epoch 34/100
# 5/5 [==============================] - 1s 189ms/step - loss: 6.8481e-04 - mae: 0.0222 - mape: 1844.4543 - val_loss: 2.0231e-04 - val_mae: 0.0166 - val_mape: 96.3354
# Epoch 35/100
# 5/5 [==============================] - 1s 189ms/step - loss: 7.0721e-04 - mae: 0.0219 - mape: 1057.3625 - val_loss: 2.4712e-04 - val_mae: 0.0187 - val_mape: 110.2991
# Epoch 36/100
# 5/5 [==============================] - 1s 184ms/step - loss: 6.6867e-04 - mae: 0.0222 - mape: 1382.6879 - val_loss: 2.8457e-04 - val_mae: 0.0204 - val_mape: 120.2144
# Epoch 37/100
# 5/5 [==============================] - 1s 181ms/step - loss: 7.0602e-04 - mae: 0.0220 - mape: 1349.3363 - val_loss: 2.3050e-04 - val_mae: 0.0179 - val_mape: 106.0227
# Epoch 38/100
# 5/5 [==============================] - 1s 256ms/step - loss: 6.7501e-04 - mae: 0.0221 - mape: 1063.6086 - val_loss: 2.1105e-04 - val_mae: 0.0171 - val_mape: 99.6523
# Epoch 39/100
# 5/5 [==============================] - 1s 211ms/step - loss: 6.6349e-04 - mae: 0.0210 - mape: 1173.9667 - val_loss: 1.7491e-04 - val_mae: 0.0153 - val_mape: 88.5560
# Epoch 40/100
# 5/5 [==============================] - 1s 198ms/step - loss: 6.8795e-04 - mae: 0.0217 - mape: 481.1817 - val_loss: 2.1032e-04 - val_mae: 0.0171 - val_mape: 99.9292
# Epoch 41/100
# 5/5 [==============================] - 1s 187ms/step - loss: 6.1455e-04 - mae: 0.0204 - mape: 1295.8232 - val_loss: 1.9281e-04 - val_mae: 0.0162 - val_mape: 95.0399
# Epoch 42/100
# 5/5 [==============================] - 1s 208ms/step - loss: 5.9823e-04 - mae: 0.0206 - mape: 1321.4926 - val_loss: 1.9566e-04 - val_mae: 0.0164 - val_mape: 96.0578
# Epoch 43/100
# 5/5 [==============================] - 1s 215ms/step - loss: 6.5337e-04 - mae: 0.0207 - mape: 450.5697 - val_loss: 2.1732e-04 - val_mae: 0.0174 - val_mape: 103.0827
# Epoch 44/100
# 5/5 [==============================] - 1s 197ms/step - loss: 5.7843e-04 - mae: 0.0205 - mape: 734.4435 - val_loss: 1.3365e-04 - val_mae: 0.0130 - val_mape: 73.0840
# Epoch 45/100
# 5/5 [==============================] - 1s 183ms/step - loss: 5.7327e-04 - mae: 0.0205 - mape: 952.4476 - val_loss: 2.7008e-04 - val_mae: 0.0200 - val_mape: 117.5918
# Epoch 46/100
# 5/5 [==============================] - 1s 230ms/step - loss: 5.8825e-04 - mae: 0.0211 - mape: 1590.6566 - val_loss: 1.5581e-04 - val_mae: 0.0143 - val_mape: 83.0603
# Epoch 47/100
# 5/5 [==============================] - 1s 185ms/step - loss: 6.1854e-04 - mae: 0.0209 - mape: 825.8276 - val_loss: 2.3762e-04 - val_mae: 0.0185 - val_mape: 109.3028
# Epoch 48/100
# 5/5 [==============================] - 1s 211ms/step - loss: 5.8984e-04 - mae: 0.0212 - mape: 1223.4888 - val_loss: 1.3955e-04 - val_mae: 0.0134 - val_mape: 76.4120
# Epoch 49/100
# 5/5 [==============================] - 1s 210ms/step - loss: 5.9098e-04 - mae: 0.0210 - mape: 64.3093 - val_loss: 2.3892e-04 - val_mae: 0.0186 - val_mape: 109.8700
# Epoch 50/100
# 5/5 [==============================] - 1s 187ms/step - loss: 5.0674e-04 - mae: 0.0205 - mape: 582.3834 - val_loss: 2.0464e-04 - val_mae: 0.0169 - val_mape: 100.1629
# Epoch 51/100
# 5/5 [==============================] - 1s 179ms/step - loss: 6.3285e-04 - mae: 0.0212 - mape: 1607.5712 - val_loss: 2.3921e-04 - val_mae: 0.0186 - val_mape: 109.9729
# Epoch 52/100
# 5/5 [==============================] - 1s 227ms/step - loss: 6.5545e-04 - mae: 0.0227 - mape: 869.6519 - val_loss: 1.3508e-04 - val_mae: 0.0131 - val_mape: 72.2134
# Epoch 53/100
# 5/5 [==============================] - 1s 180ms/step - loss: 9.4729e-04 - mae: 0.0276 - mape: 818.4827 - val_loss: 3.7163e-04 - val_mae: 0.0239 - val_mape: 140.2311
# Epoch 54/100
# 5/5 [==============================] - 1s 174ms/step - loss: 9.0705e-04 - mae: 0.0294 - mape: 1593.2344 - val_loss: 4.3379e-04 - val_mae: 0.0262 - val_mape: 152.2530
# Epoch 55/100
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0014 - mae: 0.0314 - mape: 1058.5450 - val_loss: 2.6549e-04 - val_mae: 0.0192 - val_mape: 112.2712
# Epoch 56/100
# 5/5 [==============================] - 1s 184ms/step - loss: 7.4624e-04 - mae: 0.0245 - mape: 1696.2133 - val_loss: 6.2738e-04 - val_mae: 0.0325 - val_mape: 177.3368
# Epoch 57/100
# 5/5 [==============================] - 1s 183ms/step - loss: 7.2786e-04 - mae: 0.0249 - mape: 1514.4464 - val_loss: 1.4950e-04 - val_mae: 0.0137 - val_mape: 74.7157
# Epoch 58/100
# 5/5 [==============================] - 1s 184ms/step - loss: 6.6609e-04 - mae: 0.0224 - mape: 1353.5504 - val_loss: 2.3739e-04 - val_mae: 0.0184 - val_mape: 108.7853
# Epoch 59/100
# 5/5 [==============================] - 1s 195ms/step - loss: 5.6024e-04 - mae: 0.0203 - mape: 829.8720 - val_loss: 2.8508e-04 - val_mae: 0.0205 - val_mape: 120.9887
# Epoch 60/100
# 5/5 [==============================] - 1s 184ms/step - loss: 5.6127e-04 - mae: 0.0200 - mape: 1101.6031 - val_loss: 2.2962e-04 - val_mae: 0.0180 - val_mape: 106.7896
# Epoch 61/100
# 5/5 [==============================] - 1s 211ms/step - loss: 6.0298e-04 - mae: 0.0201 - mape: 657.0187 - val_loss: 1.9440e-04 - val_mae: 0.0163 - val_mape: 96.2106
# Epoch 62/100
# 5/5 [==============================] - 1s 171ms/step - loss: 5.6733e-04 - mae: 0.0195 - mape: 1621.1885 - val_loss: 1.8731e-04 - val_mae: 0.0160 - val_mape: 94.4836
# Epoch 63/100
# 5/5 [==============================] - 1s 184ms/step - loss: 5.1349e-04 - mae: 0.0192 - mape: 1140.4835 - val_loss: 2.1716e-04 - val_mae: 0.0175 - val_mape: 103.2866
# Epoch 64/100
# 5/5 [==============================] - 1s 179ms/step - loss: 5.5949e-04 - mae: 0.0193 - mape: 920.6245 - val_loss: 1.6618e-04 - val_mae: 0.0149 - val_mape: 87.4201
# Epoch 65/100
# 5/5 [==============================] - 1s 202ms/step - loss: 5.2878e-04 - mae: 0.0186 - mape: 1410.5684 - val_loss: 1.8820e-04 - val_mae: 0.0160 - val_mape: 95.0303
# Epoch 66/100
# 5/5 [==============================] - 1s 182ms/step - loss: 5.0779e-04 - mae: 0.0185 - mape: 1313.8518 - val_loss: 1.9616e-04 - val_mae: 0.0164 - val_mape: 97.8074
# Epoch 67/100
# 5/5 [==============================] - 1s 170ms/step - loss: 4.7260e-04 - mae: 0.0184 - mape: 1208.9280 - val_loss: 1.9190e-04 - val_mae: 0.0162 - val_mape: 96.5905
# Epoch 68/100
# 5/5 [==============================] - 1s 203ms/step - loss: 5.2553e-04 - mae: 0.0184 - mape: 973.6272 - val_loss: 1.7104e-04 - val_mae: 0.0152 - val_mape: 89.9265
# Epoch 69/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.0498e-04 - mae: 0.0187 - mape: 1223.7109 - val_loss: 1.9677e-04 - val_mae: 0.0165 - val_mape: 98.4219
# Epoch 70/100
# 5/5 [==============================] - 1s 175ms/step - loss: 5.2907e-04 - mae: 0.0185 - mape: 1209.8087 - val_loss: 1.4414e-04 - val_mae: 0.0137 - val_mape: 79.9504
# Epoch 71/100
# 5/5 [==============================] - 1s 199ms/step - loss: 4.9108e-04 - mae: 0.0184 - mape: 590.4085 - val_loss: 1.6573e-04 - val_mae: 0.0149 - val_mape: 87.8270
# Epoch 72/100
# 5/5 [==============================] - 1s 168ms/step - loss: 5.2768e-04 - mae: 0.0183 - mape: 1093.1836 - val_loss: 1.4482e-04 - val_mae: 0.0137 - val_mape: 79.6304
# Epoch 73/100
# 5/5 [==============================] - 1s 185ms/step - loss: 5.2006e-04 - mae: 0.0186 - mape: 846.0820 - val_loss: 1.8936e-04 - val_mae: 0.0162 - val_mape: 95.8586
# Epoch 74/100
# 5/5 [==============================] - 1s 231ms/step - loss: 4.9399e-04 - mae: 0.0184 - mape: 1089.6940 - val_loss: 1.6272e-04 - val_mae: 0.0148 - val_mape: 87.0169
# Epoch 75/100
# 5/5 [==============================] - 1s 184ms/step - loss: 4.1972e-04 - mae: 0.0179 - mape: 477.9832 - val_loss: 1.3068e-04 - val_mae: 0.0130 - val_mape: 74.0047
# Epoch 76/100
# 5/5 [==============================] - 1s 182ms/step - loss: 4.7255e-04 - mae: 0.0182 - mape: 1030.3982 - val_loss: 2.0082e-04 - val_mae: 0.0168 - val_mape: 99.7627
# Epoch 77/100
# 5/5 [==============================] - 1s 223ms/step - loss: 5.2671e-04 - mae: 0.0189 - mape: 618.0916 - val_loss: 1.6306e-04 - val_mae: 0.0148 - val_mape: 87.1905
# Epoch 78/100
# 5/5 [==============================] - 1s 180ms/step - loss: 5.5045e-04 - mae: 0.0185 - mape: 758.5103 - val_loss: 1.1133e-04 - val_mae: 0.0115 - val_mape: 51.5173
# Epoch 79/100
# 5/5 [==============================] - 1s 174ms/step - loss: 6.5374e-04 - mae: 0.0224 - mape: 1173.0974 - val_loss: 4.6276e-04 - val_mae: 0.0275 - val_mape: 156.0498
# Epoch 80/100
# 5/5 [==============================] - 1s 189ms/step - loss: 6.2041e-04 - mae: 0.0260 - mape: 1559.3018 - val_loss: 2.0515e-04 - val_mae: 0.0169 - val_mape: 100.7796
# Epoch 81/100
# 5/5 [==============================] - 1s 196ms/step - loss: 7.0375e-04 - mae: 0.0235 - mape: 419.1787 - val_loss: 2.1207e-04 - val_mae: 0.0172 - val_mape: 102.0918
# Epoch 82/100
# 5/5 [==============================] - 1s 195ms/step - loss: 7.6209e-04 - mae: 0.0245 - mape: 1649.2671 - val_loss: 2.8778e-04 - val_mae: 0.0206 - val_mape: 122.4982
# Epoch 83/100
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0012 - mae: 0.0302 - mape: 1206.3290 - val_loss: 3.0912e-04 - val_mae: 0.0212 - val_mape: 124.4973
# Epoch 84/100
# 5/5 [==============================] - 1s 178ms/step - loss: 6.5628e-04 - mae: 0.0244 - mape: 1543.7169 - val_loss: 7.5207e-04 - val_mae: 0.0361 - val_mape: 194.1936
# Epoch 85/100
# 5/5 [==============================] - 1s 178ms/step - loss: 6.8064e-04 - mae: 0.0256 - mape: 1624.4425 - val_loss: 1.4299e-04 - val_mae: 0.0132 - val_mape: 68.6207
# Epoch 86/100
# 5/5 [==============================] - 1s 169ms/step - loss: 6.4352e-04 - mae: 0.0225 - mape: 780.4622 - val_loss: 2.7061e-04 - val_mae: 0.0198 - val_mape: 118.5605
# Epoch 87/100
# 5/5 [==============================] - 1s 221ms/step - loss: 5.2790e-04 - mae: 0.0198 - mape: 1412.7085 - val_loss: 3.5563e-04 - val_mae: 0.0233 - val_mape: 137.7504
# Epoch 88/100
# 5/5 [==============================] - 1s 182ms/step - loss: 5.6015e-04 - mae: 0.0202 - mape: 1175.8254 - val_loss: 2.6289e-04 - val_mae: 0.0195 - val_mape: 116.5690
# Epoch 89/100
# 5/5 [==============================] - 1s 190ms/step - loss: 5.4852e-04 - mae: 0.0194 - mape: 1029.8152 - val_loss: 1.7190e-04 - val_mae: 0.0152 - val_mape: 89.3107
# Epoch 90/100
# 5/5 [==============================] - 1s 209ms/step - loss: 5.5030e-04 - mae: 0.0199 - mape: 587.2549 - val_loss: 1.7313e-04 - val_mae: 0.0152 - val_mape: 90.0056
# Epoch 91/100
# 5/5 [==============================] - 1s 212ms/step - loss: 5.1201e-04 - mae: 0.0195 - mape: 931.8997 - val_loss: 2.1490e-04 - val_mae: 0.0173 - val_mape: 102.8701
# Epoch 92/100
# 5/5 [==============================] - 1s 196ms/step - loss: 4.9673e-04 - mae: 0.0186 - mape: 1100.0658 - val_loss: 1.7150e-04 - val_mae: 0.0151 - val_mape: 88.6583
# Epoch 93/100
# 5/5 [==============================] - 1s 222ms/step - loss: 5.1376e-04 - mae: 0.0184 - mape: 1132.6655 - val_loss: 2.6887e-04 - val_mae: 0.0198 - val_mape: 117.8597
# Epoch 94/100
# 5/5 [==============================] - 1s 186ms/step - loss: 4.9153e-04 - mae: 0.0186 - mape: 1256.9508 - val_loss: 2.0708e-04 - val_mae: 0.0170 - val_mape: 101.6890
# Epoch 95/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.6638e-04 - mae: 0.0178 - mape: 1048.3733 - val_loss: 1.5825e-04 - val_mae: 0.0145 - val_mape: 85.0672
# Epoch 96/100
# 5/5 [==============================] - 1s 205ms/step - loss: 4.8014e-04 - mae: 0.0186 - mape: 1125.4387 - val_loss: 1.7941e-04 - val_mae: 0.0156 - val_mape: 92.8675
# Epoch 97/100
# 5/5 [==============================] - 1s 195ms/step - loss: 4.6544e-04 - mae: 0.0180 - mape: 1256.3521 - val_loss: 2.2195e-04 - val_mae: 0.0177 - val_mape: 105.7414
# Epoch 98/100
# 5/5 [==============================] - 1s 198ms/step - loss: 5.0211e-04 - mae: 0.0177 - mape: 1396.3806 - val_loss: 1.6742e-04 - val_mae: 0.0149 - val_mape: 88.3122
# Epoch 99/100
# 5/5 [==============================] - 1s 187ms/step - loss: 4.1256e-04 - mae: 0.0175 - mape: 1459.9335 - val_loss: 2.0477e-04 - val_mae: 0.0169 - val_mape: 100.8971
# Epoch 100/100
# 5/5 [==============================] - 1s 190ms/step - loss: 4.2542e-04 - mae: 0.0174 - mape: 1457.7255 - val_loss: 1.7725e-04 - val_mae: 0.0155 - val_mape: 92.2758
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>

# %%
# from tensorflow import keras
# for key, value in model_configs.items():
#     print(key, value)
#     model=value['model']
#     # file_data=os.path.join(s_prt_path,'experimental_files\DataModel_' + key + '_72l_24a_' + dt.datetime.now().strftime("%Y-%m-%d"))
#     file_data=os.path.join(s_prt_path,'experimental_files\\')
#     print(file_data)
#     # keras.experimental.export_saved_model(model, file_data)
#     model.save(file_data,save_format='tf')
#     break

# %%
# import pickle
# import datetime as dt
# file_data=os.path.join(s_prt_path,'experimental_files\DataModel_72l_24a_' + dt.datetime.now().strftime("%Y-%m-%d") + '.plk')

# #Save Data
# with open(file_data, 'wb') as file:
#     pickle.dump(model_configs, file)

# with open('tensor_data.pkl', 'rb') as file:
#     loaded_dict = pickle.load(file)

# print(loaded_dict)

# %%
# from tensorflow import keras
# import datetime as dt
# model_configs=dict()
# models=['dnn','lstm','gru','lstm_cnn']
# for i in range(4):
#     print(i)
#     file_data=os.path.join(s_prt_path,'experimental_files\\DataModel_' + models[i] + '_72l_24a_' + (dt.datetime.now()-dt.timedelta(days=1)).strftime("%Y-%m-%d") + '.h5')
#     print(file_data)
#     model = keras.models.load_model(file_data, compile=False, encoding='utf-8')
#     model_configs[models[i]]=model

# %% [markdown]
# #### Gráficas de entrenamiento modelo con ventanado

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='loss'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='mae'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %% [markdown]
# ##### Evaluar modelo con ventanado

# %%
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xtr= x.numpy()
    Ytr=y.numpy()
    break

for idx,(x,y) in enumerate(val_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xval= x.numpy()
    Yval=y.numpy()
    break

for idx,(x,y) in enumerate(test_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xts= x.numpy()
    Yts=y.numpy()
    break
# Out:
# Example sample shapes
# x =  (256, 72, 7)
# y =  (256, 24, 1)
# x =  (256, 72, 7)
# y =  (256, 24, 1)
# x =  (256, 72, 7)
# y =  (256, 24, 1)

# %%
pip install pandas==1.5.3
# Out:
# Collecting pandas==1.5.3Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\sebas\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\~andas\\_libs\\algos.cp311-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\sebas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas==1.5.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas==1.5.3) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas==1.5.3) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1

# %%
pip unisntall pandas==2.0.1
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "unisntall" - maybe you meant "uninstall"

# %%
import pandas as pd
models=['dnn','lstm','gru','cnn_lstm']
# results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
results = []
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(3)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}

    results.append(data)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 56ms/step
# WARNING:tensorflow:5 out of the last 78 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026A3D6D07C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.1

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe.csv')
results.to_csv(file)

# %%
results= df
results
# Out:
#        Model   Tipo         MAE       MAPE      sMAPE        RMSE
# 0        dnn  Train   17.788591   9.867283   9.458042   20.570338
# 1        dnn    Val  130.346047  21.370930  24.297017  147.964563
# 2        dnn   Test   50.726957  36.376580  30.450450   52.971711
# 3       lstm  Train   16.189610   9.042388   9.810876   21.439055
# 4       lstm    Val   73.384321  12.461312  12.926554   87.010097
# 5       lstm   Test   20.501955  14.647518  13.331566   24.024079
# 6        gru  Train   19.662518  10.954101  11.919094   23.873010
# 7        gru    Val   74.621018  13.079823  13.137641   87.608255
# 8        gru   Test   17.657825  12.607728  11.603327   20.979280
# 9   cnn_lstm  Train   13.214940   7.408956   7.800521   17.077269
# 10  cnn_lstm    Val   71.157723  12.103012  12.538443   85.347226
# 11  cnn_lstm   Test    9.613538   7.051145   7.367712   11.537525

# %%
models=['dnn','lstm','gru','cnn_lstm']
results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
resultsYtestP={}
listP=[]
for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtr)
    Ye=scalerP.inverse_transform(Ytr.reshape(Ytr.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    #Evaluación de las X en validación
    Yp=model.predict(Xval)
    Ye=scalerP.inverse_transform(Yval.reshape(Yval.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    # Hacer pedicciones con el Xtest
    Yp=model.predict(Xts)
    Ye=scalerP.inverse_transform(Yts.reshape(Yts.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 8/8 [==============================] - 0s 12ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22616\488922259.py in ?()
#      17     rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
#      18
#      19     data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
#      20         'sMAPE':smape_validation,'RMSE':rmse_validation}
# ---> 21     results=results.append(data, ignore_index=True)
#      22
#      23     #Evaluación de las X en validación
#      24     Yp=model.predict(Xval)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
results
# Out:
#        Model   Tipo        MAE       MAPE      sMAPE       RMSE
# 0        dnn  Train  35.009787  27.799792  21.259975  45.192182
# 1        dnn    Val  74.815705  57.303106  39.843220  86.912634
# 2        dnn   Test  72.286043  87.005964  54.496088  80.937927
# 3       lstm  Train  29.077497  22.844246  18.443536  38.939274
# 4       lstm    Val  39.634517  29.407009  24.352165  50.413300
# 5       lstm   Test  59.111138  72.415736  47.658192  67.953266
# 6        gru  Train  31.301156  23.477642  19.555677  41.601890
# 7        gru    Val  41.610427  32.046301  25.285145  51.648321
# 8        gru   Test  57.006754  69.947076  46.460653  65.772473
# 9   cnn_lstm  Train  27.834014  20.762781  17.400259  37.040484
# 10  cnn_lstm    Val  38.326378  28.750917  23.444168  49.428195
# 11  cnn_lstm   Test  52.005022  63.152574  43.434538  59.813987

# %% [markdown]
# #### Gráfica del original y del pronóstico

# %%
listreg=[i for i in range(3)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A15941A10>, 'history': <keras.src.callbacks.History object at 0x0000026A11856B10>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 54ms/step
# lstm {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A159AF010>, 'history': <keras.src.callbacks.History object at 0x0000026A16A148D0>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 67ms/step
# gru {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A19A7B310>, 'history': <keras.src.callbacks.History object at 0x0000026A16BAC8D0>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 78ms/step
# cnn_lstm {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A2637B750>, 'history': <keras.src.callbacks.History object at 0x0000026A25E06AD0>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 60ms/step
