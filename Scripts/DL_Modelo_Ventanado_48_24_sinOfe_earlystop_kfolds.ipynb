# %% [markdown]
# #### Cargas las librerías

# %%
# Load Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
import os
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf

from evaluation._mae import MAE
from evaluation._smape import sMAPE
from evaluation._mape import MAPE
from evaluation._rmse import RMSE
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### Cargar dataset

# %%
s_path=Path.cwd()
s_prt_path=s_path.parent

file=os.path.join(s_prt_path,'datasets\XM_H_sinOfe.csv')
df_Data= pd.read_csv(file, index_col=0)
# df_Data.reset_index(inplace=True)

# %%
df_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52584 entries, 01/01/2013 0:00 to 31/12/2018 23:00
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PrecioB    52584 non-null  float64
#  1   Demanda    52584 non-null  float64
#  2   DispTer    52584 non-null  int64
#  3   DispNoTer  52584 non-null  int64
#  4   VolUtil    52584 non-null  int64
#  5   Aportes    52584 non-null  int64
#  6   day_cls    52584 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Funciones necesarias para las ejecuciones

# %% [markdown]
# ##### División de datos

# %%
# Dividir los datos en train, validación y test
def split_data(data, indexTotal, train_fraq, test_len=8760):

    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(data)-test_len

    test_data = data[test_slice:]
    indexTest=indexTotal[test_slice:]

    train_val_data = data[:test_slice]
    index_val_data=indexTotal[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    indexTrain=index_val_data[:train_size]

    val_data = train_val_data[train_size:]
    indexVal=index_val_data[train_size:]
    
    return train_data, val_data, test_data, indexTrain, indexVal, indexTest

# %% [markdown]
# ##### Construcción del dataset

# %%
# Crear los datos para entrar al modelo, definición de ventanas
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
    """ Create a windowed tensorflow dataset
    
    """

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
    
    #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    #ds = ds.shuffle(shuffle_buffer)
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    
    return ds

# Construcción del dataset usando las ventanas
def build_dataset(traindata,valdata,testdata,train_fraq=0.8, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
    """If multi variate then first column is always the column from which the target is contstructed.
    """
    
    tf.random.set_seed(23)
    
    
    train_ds = window_dataset(traindata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(valdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(testdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    
    
    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# ##### Parámetros y ejecución

# %%
# Definición de parámetros para la ejecución del modelo
def get_params(multivar=True):
    lr = 3e-4
    n_steps=48
    n_horizon=24
    if multivar:
        n_features=7
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

# Almacenamiento de los datos de las ejecuciones
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}

# Ejecuciones de los modelos con función de ventanado
def run_model(traindata,valdata,testdata,model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    
    train_ds, val_ds, test_ds = build_dataset(traindata,valdata,testdata,n_steps=n_steps, n_horizon=n_horizon, multi_var=True)

    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    # Define el early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=40)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=[early_stopping])

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    
    return test_ds

# %% [markdown]
# #### Modelos

# %% [markdown]
# ##### DNN

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 336)               0
#
#  dense (Dense)               (None, 128)               43136
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 62744 (245.09 KB)
# Trainable params: 62744 (245.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### LSTM

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48, 72)            23040
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55640 (217.34 KB)
# Trainable params: 55640 (217.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### GRU

# %%
def gru_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.GRU(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.GRU(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='gru')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

gru = gru_model(*get_params(multivar=True))
gru.summary()
# Out:
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 48, 72)            17496
#
#  gru_1 (GRU)                 (None, 48)                17568
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 44432 (173.56 KB)
# Trainable params: 44432 (173.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### CNN_LSTM

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 43, 64)            2752
#
#  max_pooling1d (MaxPooling1  (None, 21, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 19, 64)            12352
#
#  max_pooling1d_1 (MaxPoolin  (None, 9, 64)             0
#  g1D)
#
#  lstm (LSTM)                 (None, 9, 72)             39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 87160 (340.47 KB)
# Trainable params: 87160 (340.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Escalamiento de los datos y división del dataset

# %%
#scale
scaler = MinMaxScaler(feature_range=(0, 1))
scalerP=MinMaxScaler(feature_range=(0, 1))

vec_precio=scalerP.fit_transform(df_Data.values[:,0].reshape(-1,1))

indexTotal=df_Data.index

multivar_df = scaler.fit_transform(df_Data)
train_multi, val_multi, test_multi, indexTrain, indexVal, indexTest = split_data(multivar_df,indexTotal, train_fraq=0.8, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
print('Precio',vec_precio.shape)
print('Todo',df_Data.shape)
# Out:
# Multivarate Datasets
# Train Data Shape: (35059, 7)
# Val Data Shape: (8765, 7)
# Test Data Shape: (8760, 7)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False
# Precio (52584, 1)
# Todo (52584, 7)

# %% [markdown]
# ##### Obtener dataset para el modelo utilizando la función de ventanado

# %%
n_steps=48
n_horizon=24

train_ds, val_ds, test_ds = build_dataset(train_multi, val_multi, test_multi,n_steps=n_steps, n_horizon=n_horizon,multi_var=True)
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Example sample shapes
# x =  (256, 48, 7)
# y =  (256, 24, 1)

# %% [markdown]
# ##### Ejecución de modelo con datos del ventanado

# %%
from sklearn.model_selection import KFold

model_configs_v = dict()
nepochs = 100

# Define the number of folds for cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits)

# Iterate over the folds
for fold, (train_index, val_index) in enumerate(kf.split(train_multi)):
    print(f"Fold {fold+1}/{n_splits}")
    
    # Get the training and validation data for the current fold
    fold_train_data = train_multi[train_index]
    fold_val_data = train_multi[val_index]
    
    print('Ejecutando la dnn')
    run_model(fold_train_data, fold_val_data, test_multi, "dnn", dnn_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la lstm')
    run_model(fold_train_data, fold_val_data, test_multi, "lstm", lstm_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la gru')
    run_model(fold_train_data, fold_val_data, test_multi, "gru", gru_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la cnn_lstm')
    run_model(fold_train_data, fold_val_data, test_multi, "cnn_lstm", lstm_cnn_model, model_configs_v, epochs=nepochs)
# Out:
# Fold 1/5
# Ejecutando la dnn
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 2s 133ms/step - loss: 0.0830 - mae: 0.3143 - mape: 3583.3142 - val_loss: 0.0049 - val_mae: 0.0807 - val_mape: 299.7951
# Epoch 2/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0217 - mae: 0.1608 - mape: 12138.2666 - val_loss: 0.0020 - val_mae: 0.0516 - val_mape: 178.6237
# Epoch 3/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0113 - mae: 0.1119 - mape: 15908.5527 - val_loss: 0.0013 - val_mae: 0.0395 - val_mape: 146.3113
# Epoch 4/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0078 - mae: 0.0874 - mape: 1195.0829 - val_loss: 8.7633e-04 - val_mae: 0.0329 - val_mape: 119.0933
# Epoch 5/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0066 - mae: 0.0765 - mape: 1740.6528 - val_loss: 6.7757e-04 - val_mae: 0.0284 - val_mape: 99.7395
# Epoch 6/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0057 - mae: 0.0695 - mape: 3692.8062 - val_loss: 6.4908e-04 - val_mae: 0.0280 - val_mape: 104.8818
# Epoch 7/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0053 - mae: 0.0653 - mape: 7793.6973 - val_loss: 6.7508e-04 - val_mae: 0.0290 - val_mape: 113.9629
# Epoch 8/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0045 - mae: 0.0600 - mape: 1336.5612 - val_loss: 6.9076e-04 - val_mae: 0.0297 - val_mape: 118.5473
# Epoch 9/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0040 - mae: 0.0561 - mape: 4530.9922 - val_loss: 6.6182e-04 - val_mae: 0.0291 - val_mape: 118.3284
# Epoch 10/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0036 - mae: 0.0520 - mape: 8717.4170 - val_loss: 6.3504e-04 - val_mae: 0.0282 - val_mape: 120.0929
# Epoch 11/100
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0031 - mae: 0.0482 - mape: 3243.3752 - val_loss: 6.3960e-04 - val_mae: 0.0284 - val_mape: 123.9619
# Epoch 12/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0026 - mae: 0.0437 - mape: 5117.0088 - val_loss: 6.1958e-04 - val_mae: 0.0282 - val_mape: 123.2293
# Epoch 13/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0024 - mae: 0.0413 - mape: 1414.3303 - val_loss: 5.2027e-04 - val_mae: 0.0258 - val_mape: 115.3684
# Epoch 14/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0022 - mae: 0.0385 - mape: 2895.9866 - val_loss: 4.3160e-04 - val_mae: 0.0232 - val_mape: 108.7853
# Epoch 15/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0018 - mae: 0.0354 - mape: 1962.3617 - val_loss: 4.4318e-04 - val_mae: 0.0234 - val_mape: 113.1353
# Epoch 16/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0016 - mae: 0.0340 - mape: 4955.3408 - val_loss: 3.7935e-04 - val_mae: 0.0218 - val_mape: 107.7868
# Epoch 17/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0017 - mae: 0.0334 - mape: 3686.7029 - val_loss: 3.6946e-04 - val_mae: 0.0217 - val_mape: 108.6772
# Epoch 18/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0015 - mae: 0.0316 - mape: 1822.9532 - val_loss: 4.2380e-04 - val_mae: 0.0235 - val_mape: 117.5670
# Epoch 19/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0015 - mae: 0.0307 - mape: 111.2707 - val_loss: 3.1163e-04 - val_mae: 0.0200 - val_mape: 104.6114
# Epoch 20/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0015 - mae: 0.0310 - mape: 1938.1400 - val_loss: 4.2326e-04 - val_mae: 0.0240 - val_mape: 120.3339
# Epoch 21/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0012 - mae: 0.0287 - mape: 2274.3252 - val_loss: 3.8564e-04 - val_mae: 0.0225 - val_mape: 118.3603
# Epoch 22/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0014 - mae: 0.0295 - mape: 1623.5430 - val_loss: 4.8637e-04 - val_mae: 0.0256 - val_mape: 132.0493
# Epoch 23/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0013 - mae: 0.0284 - mape: 1576.5559 - val_loss: 3.7667e-04 - val_mae: 0.0228 - val_mape: 118.9765
# Epoch 24/100
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0013 - mae: 0.0290 - mape: 2199.0369 - val_loss: 4.9966e-04 - val_mae: 0.0271 - val_mape: 133.8524
# Epoch 25/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0012 - mae: 0.0287 - mape: 1045.9767 - val_loss: 4.8948e-04 - val_mae: 0.0263 - val_mape: 133.4876
# Epoch 26/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0013 - mae: 0.0282 - mape: 1305.8779 - val_loss: 4.7550e-04 - val_mae: 0.0258 - val_mape: 131.7535
# Epoch 27/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0012 - mae: 0.0278 - mape: 943.0890 - val_loss: 4.8185e-04 - val_mae: 0.0266 - val_mape: 131.8297
# Epoch 28/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0012 - mae: 0.0275 - mape: 1725.7722 - val_loss: 4.4488e-04 - val_mae: 0.0254 - val_mape: 127.7714
# Epoch 29/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0011 - mae: 0.0269 - mape: 1639.7804 - val_loss: 4.8840e-04 - val_mae: 0.0265 - val_mape: 133.1560
# Epoch 30/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0012 - mae: 0.0265 - mape: 1309.0696 - val_loss: 4.7313e-04 - val_mae: 0.0263 - val_mape: 130.5607
# Epoch 31/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0011 - mae: 0.0264 - mape: 1855.8517 - val_loss: 5.2383e-04 - val_mae: 0.0279 - val_mape: 136.6047
# Epoch 32/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0011 - mae: 0.0256 - mape: 1498.2144 - val_loss: 4.9337e-04 - val_mae: 0.0267 - val_mape: 133.7696
# Epoch 33/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0010 - mae: 0.0257 - mape: 2446.9475 - val_loss: 6.5163e-04 - val_mae: 0.0315 - val_mape: 149.9144
# Epoch 34/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0011 - mae: 0.0267 - mape: 2069.8882 - val_loss: 3.7875e-04 - val_mae: 0.0230 - val_mape: 118.7668
# Epoch 35/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0011 - mae: 0.0265 - mape: 958.8256 - val_loss: 9.1817e-04 - val_mae: 0.0387 - val_mape: 173.5585
# Epoch 36/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0011 - mae: 0.0278 - mape: 2413.6802 - val_loss: 3.3185e-04 - val_mae: 0.0210 - val_mape: 111.9107
# Epoch 37/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0011 - mae: 0.0272 - mape: 1123.8646 - val_loss: 7.4316e-04 - val_mae: 0.0334 - val_mape: 156.8528
# Epoch 38/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0011 - mae: 0.0279 - mape: 1593.7928 - val_loss: 3.7056e-04 - val_mae: 0.0222 - val_mape: 118.0274
# Epoch 39/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0012 - mae: 0.0270 - mape: 1668.1725 - val_loss: 7.0019e-04 - val_mae: 0.0327 - val_mape: 153.4109
# Epoch 40/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0011 - mae: 0.0270 - mape: 3037.8335 - val_loss: 3.4618e-04 - val_mae: 0.0221 - val_mape: 114.2477
# Epoch 41/100
# 5/5 [==============================] - 0s 54ms/step - loss: 9.6691e-04 - mae: 0.0254 - mape: 1215.0894 - val_loss: 4.9564e-04 - val_mae: 0.0273 - val_mape: 130.9454
# Epoch 42/100
# 5/5 [==============================] - 0s 55ms/step - loss: 9.9263e-04 - mae: 0.0254 - mape: 1579.2992 - val_loss: 3.5532e-04 - val_mae: 0.0221 - val_mape: 114.4488
# Epoch 43/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0012 - mae: 0.0266 - mape: 1633.3303 - val_loss: 7.7004e-04 - val_mae: 0.0348 - val_mape: 160.2785
# Epoch 44/100
# 5/5 [==============================] - 0s 62ms/step - loss: 9.9249e-04 - mae: 0.0260 - mape: 2667.0872 - val_loss: 3.6829e-04 - val_mae: 0.0231 - val_mape: 116.8007
# Epoch 45/100
# 5/5 [==============================] - 0s 58ms/step - loss: 9.5855e-04 - mae: 0.0251 - mape: 1654.7914 - val_loss: 6.8424e-04 - val_mae: 0.0336 - val_mape: 151.5368
# Epoch 46/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0011 - mae: 0.0276 - mape: 1302.5260 - val_loss: 2.9883e-04 - val_mae: 0.0203 - val_mape: 107.9476
# Epoch 47/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0012 - mae: 0.0266 - mape: 1474.1520 - val_loss: 7.1783e-04 - val_mae: 0.0336 - val_mape: 156.0286
# Epoch 48/100
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0010 - mae: 0.0258 - mape: 1535.9091 - val_loss: 3.4888e-04 - val_mae: 0.0220 - val_mape: 114.8342
# Epoch 49/100
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0012 - mae: 0.0289 - mape: 1669.7812 - val_loss: 0.0016 - val_mae: 0.0531 - val_mape: 220.4366
# Epoch 50/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0011 - mae: 0.0295 - mape: 2696.7822 - val_loss: 4.4826e-04 - val_mae: 0.0260 - val_mape: 129.4169
# Epoch 51/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0010 - mae: 0.0259 - mape: 1360.1403 - val_loss: 5.1111e-04 - val_mae: 0.0283 - val_mape: 135.4170
# Epoch 52/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0011 - mae: 0.0263 - mape: 1399.0154 - val_loss: 4.5043e-04 - val_mae: 0.0258 - val_mape: 128.4201
# Epoch 53/100
# 5/5 [==============================] - 0s 62ms/step - loss: 9.4205e-04 - mae: 0.0238 - mape: 1023.8448 - val_loss: 6.3104e-04 - val_mae: 0.0308 - val_mape: 145.6909
# Epoch 54/100
# 5/5 [==============================] - 0s 62ms/step - loss: 8.9480e-04 - mae: 0.0240 - mape: 2438.2412 - val_loss: 5.4702e-04 - val_mae: 0.0288 - val_mape: 138.9083
# Epoch 55/100
# 5/5 [==============================] - 0s 75ms/step - loss: 8.9995e-04 - mae: 0.0235 - mape: 1392.0709 - val_loss: 5.5844e-04 - val_mae: 0.0295 - val_mape: 141.0946
# Epoch 56/100
# 5/5 [==============================] - 1s 115ms/step - loss: 9.6538e-04 - mae: 0.0239 - mape: 1659.4978 - val_loss: 6.3584e-04 - val_mae: 0.0313 - val_mape: 147.6464
# Epoch 57/100
# 5/5 [==============================] - 0s 102ms/step - loss: 8.8324e-04 - mae: 0.0235 - mape: 1439.4648 - val_loss: 3.1850e-04 - val_mae: 0.0209 - val_mape: 110.5963
# Epoch 58/100
# 5/5 [==============================] - 0s 85ms/step - loss: 9.6712e-04 - mae: 0.0243 - mape: 1330.2649 - val_loss: 6.8882e-04 - val_mae: 0.0334 - val_mape: 154.8318
# Epoch 59/100
# 5/5 [==============================] - 0s 106ms/step - loss: 9.0932e-04 - mae: 0.0266 - mape: 2444.2957 - val_loss: 5.2787e-04 - val_mae: 0.0281 - val_mape: 136.6373
# Epoch 60/100
# 5/5 [==============================] - 1s 118ms/step - loss: 9.0853e-04 - mae: 0.0247 - mape: 1825.3849 - val_loss: 7.9118e-04 - val_mae: 0.0356 - val_mape: 162.4163
# Epoch 61/100
# 5/5 [==============================] - 0s 89ms/step - loss: 8.2689e-04 - mae: 0.0242 - mape: 1471.1669 - val_loss: 3.9014e-04 - val_mae: 0.0235 - val_mape: 122.2681
# Epoch 62/100
# 5/5 [==============================] - 0s 96ms/step - loss: 8.9788e-04 - mae: 0.0238 - mape: 1849.7086 - val_loss: 5.5822e-04 - val_mae: 0.0291 - val_mape: 143.1697
# Epoch 63/100
# 5/5 [==============================] - 0s 99ms/step - loss: 9.2068e-04 - mae: 0.0242 - mape: 2150.4194 - val_loss: 2.7434e-04 - val_mae: 0.0190 - val_mape: 104.4471
# Epoch 64/100
# 5/5 [==============================] - 0s 83ms/step - loss: 9.1223e-04 - mae: 0.0235 - mape: 1485.5298 - val_loss: 4.7513e-04 - val_mae: 0.0266 - val_mape: 130.2456
# Epoch 65/100
# 5/5 [==============================] - 0s 102ms/step - loss: 7.9046e-04 - mae: 0.0228 - mape: 1743.5549 - val_loss: 5.4373e-04 - val_mae: 0.0289 - val_mape: 138.5796
# Epoch 66/100
# 5/5 [==============================] - 0s 101ms/step - loss: 8.3775e-04 - mae: 0.0226 - mape: 1377.8894 - val_loss: 5.7042e-04 - val_mae: 0.0299 - val_mape: 141.5828
# Epoch 67/100
# 5/5 [==============================] - 0s 78ms/step - loss: 7.1286e-04 - mae: 0.0218 - mape: 1303.9746 - val_loss: 4.3863e-04 - val_mae: 0.0254 - val_mape: 125.9884
# Epoch 68/100
# 5/5 [==============================] - 1s 119ms/step - loss: 7.2976e-04 - mae: 0.0221 - mape: 1301.7273 - val_loss: 4.3367e-04 - val_mae: 0.0251 - val_mape: 125.2181
# Epoch 69/100
# 5/5 [==============================] - 0s 95ms/step - loss: 8.0776e-04 - mae: 0.0228 - mape: 1467.5559 - val_loss: 4.2092e-04 - val_mae: 0.0247 - val_mape: 123.7464
# Epoch 70/100
# 5/5 [==============================] - 0s 86ms/step - loss: 7.8257e-04 - mae: 0.0219 - mape: 1491.7340 - val_loss: 4.8224e-04 - val_mae: 0.0270 - val_mape: 132.9149
# Epoch 71/100
# 5/5 [==============================] - 0s 100ms/step - loss: 7.6539e-04 - mae: 0.0215 - mape: 1225.5111 - val_loss: 6.2090e-04 - val_mae: 0.0314 - val_mape: 148.2457
# Epoch 72/100
# 5/5 [==============================] - 1s 113ms/step - loss: 7.7582e-04 - mae: 0.0223 - mape: 1788.6997 - val_loss: 5.1391e-04 - val_mae: 0.0278 - val_mape: 136.6563
# Epoch 73/100
# 5/5 [==============================] - 0s 101ms/step - loss: 8.1461e-04 - mae: 0.0223 - mape: 1964.0497 - val_loss: 5.7870e-04 - val_mae: 0.0299 - val_mape: 144.2331
# Epoch 74/100
# 5/5 [==============================] - 0s 86ms/step - loss: 6.9953e-04 - mae: 0.0214 - mape: 1569.8658 - val_loss: 4.8388e-04 - val_mae: 0.0270 - val_mape: 134.5209
# Epoch 75/100
# 5/5 [==============================] - 0s 83ms/step - loss: 7.8318e-04 - mae: 0.0224 - mape: 1258.1755 - val_loss: 7.9725e-04 - val_mae: 0.0363 - val_mape: 165.2558
# Epoch 76/100
# 5/5 [==============================] - 0s 71ms/step - loss: 7.2614e-04 - mae: 0.0224 - mape: 1607.1697 - val_loss: 4.8833e-04 - val_mae: 0.0270 - val_mape: 133.2798
# Epoch 77/100
# 5/5 [==============================] - 0s 96ms/step - loss: 7.5437e-04 - mae: 0.0221 - mape: 1795.5756 - val_loss: 6.1351e-04 - val_mae: 0.0309 - val_mape: 147.2835
# Epoch 78/100
# 5/5 [==============================] - 0s 83ms/step - loss: 7.7752e-04 - mae: 0.0224 - mape: 1497.5814 - val_loss: 6.1166e-04 - val_mae: 0.0309 - val_mape: 147.0832
# Epoch 79/100
# 5/5 [==============================] - 0s 69ms/step - loss: 7.4311e-04 - mae: 0.0216 - mape: 1290.9928 - val_loss: 5.0140e-04 - val_mae: 0.0275 - val_mape: 133.4779
# Epoch 80/100
# 5/5 [==============================] - 0s 92ms/step - loss: 7.0323e-04 - mae: 0.0215 - mape: 1438.7241 - val_loss: 5.8459e-04 - val_mae: 0.0303 - val_mape: 143.4294
# Epoch 81/100
# 5/5 [==============================] - 0s 89ms/step - loss: 7.3926e-04 - mae: 0.0225 - mape: 1271.9547 - val_loss: 3.9127e-04 - val_mae: 0.0239 - val_mape: 121.4057
# Epoch 82/100
# 5/5 [==============================] - 0s 64ms/step - loss: 7.6168e-04 - mae: 0.0222 - mape: 1256.0806 - val_loss: 5.2961e-04 - val_mae: 0.0288 - val_mape: 138.5619
# Epoch 83/100
# 5/5 [==============================] - 0s 100ms/step - loss: 7.4022e-04 - mae: 0.0219 - mape: 1322.8906 - val_loss: 3.8364e-04 - val_mae: 0.0236 - val_mape: 119.7880
# Epoch 84/100
# 5/5 [==============================] - 0s 86ms/step - loss: 7.8408e-04 - mae: 0.0228 - mape: 1269.9240 - val_loss: 5.6314e-04 - val_mae: 0.0295 - val_mape: 141.9938
# Epoch 85/100
# 5/5 [==============================] - 0s 70ms/step - loss: 8.5244e-04 - mae: 0.0226 - mape: 1673.3612 - val_loss: 5.6424e-04 - val_mae: 0.0298 - val_mape: 144.4132
# Epoch 86/100
# 5/5 [==============================] - 0s 89ms/step - loss: 7.4208e-04 - mae: 0.0223 - mape: 1290.1288 - val_loss: 5.7663e-04 - val_mae: 0.0302 - val_mape: 145.3307
# Epoch 87/100
# 5/5 [==============================] - 0s 83ms/step - loss: 6.4672e-04 - mae: 0.0208 - mape: 1501.7069 - val_loss: 3.8504e-04 - val_mae: 0.0238 - val_mape: 121.6261
# Epoch 88/100
# 5/5 [==============================] - 0s 66ms/step - loss: 7.1294e-04 - mae: 0.0217 - mape: 1353.8534 - val_loss: 5.1205e-04 - val_mae: 0.0282 - val_mape: 136.3930
# Epoch 89/100
# 5/5 [==============================] - 1s 121ms/step - loss: 7.0333e-04 - mae: 0.0216 - mape: 1543.6064 - val_loss: 5.6497e-04 - val_mae: 0.0299 - val_mape: 142.3573
# Epoch 90/100
# 5/5 [==============================] - 0s 82ms/step - loss: 6.9864e-04 - mae: 0.0221 - mape: 1668.5770 - val_loss: 5.1757e-04 - val_mae: 0.0282 - val_mape: 139.0058
# Epoch 91/100
# 5/5 [==============================] - 0s 66ms/step - loss: 6.3606e-04 - mae: 0.0211 - mape: 1458.2759 - val_loss: 8.7915e-04 - val_mae: 0.0384 - val_mape: 173.3176
# Epoch 92/100
# 5/5 [==============================] - 0s 98ms/step - loss: 7.3062e-04 - mae: 0.0227 - mape: 1301.8827 - val_loss: 6.6806e-04 - val_mae: 0.0328 - val_mape: 155.1894
# Epoch 93/100
# 5/5 [==============================] - 0s 89ms/step - loss: 7.5564e-04 - mae: 0.0215 - mape: 1365.6667 - val_loss: 5.3930e-04 - val_mae: 0.0287 - val_mape: 138.8175
# Epoch 94/100
# 5/5 [==============================] - 0s 63ms/step - loss: 6.7622e-04 - mae: 0.0209 - mape: 1326.4817 - val_loss: 4.7121e-04 - val_mae: 0.0263 - val_mape: 129.4268
# Epoch 95/100
# 5/5 [==============================] - 0s 101ms/step - loss: 6.8104e-04 - mae: 0.0212 - mape: 1262.8051 - val_loss: 6.2164e-04 - val_mae: 0.0311 - val_mape: 146.0853
# Epoch 96/100
# 5/5 [==============================] - 1s 98ms/step - loss: 6.5910e-04 - mae: 0.0216 - mape: 1284.5343 - val_loss: 3.6328e-04 - val_mae: 0.0230 - val_mape: 116.9262
# Epoch 97/100
# 5/5 [==============================] - 0s 69ms/step - loss: 6.9416e-04 - mae: 0.0211 - mape: 1265.5310 - val_loss: 4.8220e-04 - val_mae: 0.0271 - val_mape: 133.9021
# Epoch 98/100
# 5/5 [==============================] - 0s 93ms/step - loss: 6.6591e-04 - mae: 0.0208 - mape: 1242.2253 - val_loss: 5.9474e-04 - val_mae: 0.0307 - val_mape: 146.7078
# Epoch 99/100
# 5/5 [==============================] - 0s 101ms/step - loss: 5.8819e-04 - mae: 0.0205 - mape: 1261.6421 - val_loss: 6.3606e-04 - val_mae: 0.0318 - val_mape: 149.3851
# Epoch 100/100
# 5/5 [==============================] - 0s 86ms/step - loss: 6.4658e-04 - mae: 0.0206 - mape: 1567.8807 - val_loss: 7.4408e-04 - val_mae: 0.0349 - val_mape: 162.1423
# Ejecutando la lstm
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 12s 490ms/step - loss: 0.0092 - mae: 0.0971 - mape: 425.1370 - val_loss: 8.9048e-04 - val_mae: 0.0355 - val_mape: 86.3321
# Epoch 2/100
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0071 - mae: 0.0762 - mape: 363.0990 - val_loss: 4.6952e-04 - val_mae: 0.0235 - val_mape: 75.9295
# Epoch 3/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0060 - mae: 0.0654 - mape: 356.3448 - val_loss: 3.4180e-04 - val_mae: 0.0197 - val_mape: 95.2678
# Epoch 4/100
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0053 - mae: 0.0616 - mape: 1240.8242 - val_loss: 5.1166e-04 - val_mae: 0.0264 - val_mape: 137.8222
# Epoch 5/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0047 - mae: 0.0617 - mape: 553.7133 - val_loss: 7.8199e-04 - val_mae: 0.0353 - val_mape: 173.1916
# Epoch 6/100
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0045 - mae: 0.0626 - mape: 1184.3391 - val_loss: 9.0224e-04 - val_mae: 0.0390 - val_mape: 185.0758
# Epoch 7/100
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0044 - mae: 0.0622 - mape: 1676.2557 - val_loss: 8.7205e-04 - val_mae: 0.0385 - val_mape: 181.9078
# Epoch 8/100
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0041 - mae: 0.0595 - mape: 3618.6853 - val_loss: 9.0530e-04 - val_mae: 0.0394 - val_mape: 185.0082
# Epoch 9/100
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0038 - mae: 0.0582 - mape: 2897.7048 - val_loss: 0.0010 - val_mae: 0.0422 - val_mape: 194.8741
# Epoch 10/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0033 - mae: 0.0554 - mape: 2533.3418 - val_loss: 0.0010 - val_mae: 0.0428 - val_mape: 195.4654
# Epoch 11/100
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0025 - mae: 0.0494 - mape: 3423.2996 - val_loss: 9.7185e-04 - val_mae: 0.0408 - val_mape: 185.0105
# Epoch 12/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0022 - mae: 0.0443 - mape: 3111.4133 - val_loss: 4.0649e-04 - val_mae: 0.0241 - val_mape: 124.9467
# Epoch 13/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0019 - mae: 0.0394 - mape: 2144.8179 - val_loss: 0.0010 - val_mae: 0.0398 - val_mape: 174.7768
# Epoch 14/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0014 - mae: 0.0388 - mape: 1914.6136 - val_loss: 7.9297e-04 - val_mae: 0.0347 - val_mape: 156.5492
# Epoch 15/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0012 - mae: 0.0315 - mape: 1979.2444 - val_loss: 3.3488e-04 - val_mae: 0.0213 - val_mape: 111.3980
# Epoch 16/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0012 - mae: 0.0289 - mape: 1108.7568 - val_loss: 2.9310e-04 - val_mae: 0.0197 - val_mape: 105.1850
# Epoch 17/100
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0010 - mae: 0.0275 - mape: 1648.8447 - val_loss: 4.2520e-04 - val_mae: 0.0244 - val_mape: 121.5649
# Epoch 18/100
# 5/5 [==============================] - 1s 178ms/step - loss: 9.0357e-04 - mae: 0.0269 - mape: 1648.6631 - val_loss: 2.2657e-04 - val_mae: 0.0169 - val_mape: 94.7976
# Epoch 19/100
# 5/5 [==============================] - 1s 198ms/step - loss: 8.2068e-04 - mae: 0.0246 - mape: 1267.4907 - val_loss: 4.1688e-04 - val_mae: 0.0241 - val_mape: 119.6856
# Epoch 20/100
# 5/5 [==============================] - 1s 188ms/step - loss: 8.7634e-04 - mae: 0.0256 - mape: 1164.7719 - val_loss: 1.5613e-04 - val_mae: 0.0134 - val_mape: 75.8252
# Epoch 21/100
# 5/5 [==============================] - 1s 155ms/step - loss: 8.9951e-04 - mae: 0.0251 - mape: 1634.8182 - val_loss: 4.5681e-04 - val_mae: 0.0252 - val_mape: 123.1096
# Epoch 22/100
# 5/5 [==============================] - 1s 178ms/step - loss: 8.0158e-04 - mae: 0.0251 - mape: 1335.3397 - val_loss: 1.6188e-04 - val_mae: 0.0138 - val_mape: 78.3949
# Epoch 23/100
# 5/5 [==============================] - 1s 134ms/step - loss: 8.5692e-04 - mae: 0.0254 - mape: 946.2562 - val_loss: 4.0006e-04 - val_mae: 0.0234 - val_mape: 118.2644
# Epoch 24/100
# 5/5 [==============================] - 1s 180ms/step - loss: 9.1657e-04 - mae: 0.0267 - mape: 1223.9764 - val_loss: 1.6138e-04 - val_mae: 0.0137 - val_mape: 76.1810
# Epoch 25/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0014 - mae: 0.0314 - mape: 1384.5300 - val_loss: 2.7261e-04 - val_mae: 0.0189 - val_mape: 103.3212
# Epoch 26/100
# 5/5 [==============================] - 1s 196ms/step - loss: 9.5587e-04 - mae: 0.0280 - mape: 1245.2355 - val_loss: 2.7760e-04 - val_mae: 0.0191 - val_mape: 103.8162
# Epoch 27/100
# 5/5 [==============================] - 1s 154ms/step - loss: 9.3190e-04 - mae: 0.0250 - mape: 1319.8654 - val_loss: 1.9176e-04 - val_mae: 0.0154 - val_mape: 87.4899
# Epoch 28/100
# 5/5 [==============================] - 1s 177ms/step - loss: 7.2711e-04 - mae: 0.0228 - mape: 1406.4316 - val_loss: 4.7474e-04 - val_mae: 0.0261 - val_mape: 125.0079
# Epoch 29/100
# 5/5 [==============================] - 1s 172ms/step - loss: 7.4911e-04 - mae: 0.0236 - mape: 1436.4558 - val_loss: 1.5155e-04 - val_mae: 0.0132 - val_mape: 73.2484
# Epoch 30/100
# 5/5 [==============================] - 1s 184ms/step - loss: 6.9216e-04 - mae: 0.0227 - mape: 1873.5950 - val_loss: 1.7580e-04 - val_mae: 0.0145 - val_mape: 81.0418
# Epoch 31/100
# 5/5 [==============================] - 1s 179ms/step - loss: 7.3839e-04 - mae: 0.0221 - mape: 944.0418 - val_loss: 2.3505e-04 - val_mae: 0.0172 - val_mape: 94.8803
# Epoch 32/100
# 5/5 [==============================] - 1s 152ms/step - loss: 6.4842e-04 - mae: 0.0215 - mape: 1189.5463 - val_loss: 2.8575e-04 - val_mae: 0.0193 - val_mape: 104.6083
# Epoch 33/100
# 5/5 [==============================] - 1s 174ms/step - loss: 7.5720e-04 - mae: 0.0222 - mape: 1095.4965 - val_loss: 3.3142e-04 - val_mae: 0.0209 - val_mape: 109.1226
# Epoch 34/100
# 5/5 [==============================] - 1s 150ms/step - loss: 6.6248e-04 - mae: 0.0216 - mape: 1459.7599 - val_loss: 1.7288e-04 - val_mae: 0.0143 - val_mape: 79.5474
# Epoch 35/100
# 5/5 [==============================] - 1s 172ms/step - loss: 6.2575e-04 - mae: 0.0207 - mape: 1562.0558 - val_loss: 2.1307e-04 - val_mae: 0.0161 - val_mape: 88.2032
# Epoch 36/100
# 5/5 [==============================] - 1s 138ms/step - loss: 6.0889e-04 - mae: 0.0208 - mape: 1697.7522 - val_loss: 1.6696e-04 - val_mae: 0.0141 - val_mape: 79.8341
# Epoch 37/100
# 5/5 [==============================] - 1s 165ms/step - loss: 6.3086e-04 - mae: 0.0207 - mape: 1392.0275 - val_loss: 2.1709e-04 - val_mae: 0.0165 - val_mape: 92.2657
# Epoch 38/100
# 5/5 [==============================] - 1s 155ms/step - loss: 5.9159e-04 - mae: 0.0206 - mape: 1412.3638 - val_loss: 2.1362e-04 - val_mae: 0.0163 - val_mape: 91.0794
# Epoch 39/100
# 5/5 [==============================] - 1s 188ms/step - loss: 5.6267e-04 - mae: 0.0197 - mape: 1117.9465 - val_loss: 1.6246e-04 - val_mae: 0.0138 - val_mape: 78.5294
# Epoch 40/100
# 5/5 [==============================] - 1s 174ms/step - loss: 5.8997e-04 - mae: 0.0198 - mape: 1440.2161 - val_loss: 2.0195e-04 - val_mae: 0.0157 - val_mape: 87.3009
# Epoch 41/100
# 5/5 [==============================] - 1s 182ms/step - loss: 6.0643e-04 - mae: 0.0198 - mape: 1183.8966 - val_loss: 2.6638e-04 - val_mae: 0.0186 - val_mape: 97.3732
# Epoch 42/100
# 5/5 [==============================] - 1s 191ms/step - loss: 5.6348e-04 - mae: 0.0200 - mape: 1233.1063 - val_loss: 1.4313e-04 - val_mae: 0.0130 - val_mape: 71.1813
# Epoch 43/100
# 5/5 [==============================] - 1s 158ms/step - loss: 5.6399e-04 - mae: 0.0195 - mape: 1169.4310 - val_loss: 2.1777e-04 - val_mae: 0.0167 - val_mape: 89.4759
# Epoch 44/100
# 5/5 [==============================] - 1s 209ms/step - loss: 5.5051e-04 - mae: 0.0196 - mape: 1340.5183 - val_loss: 1.4239e-04 - val_mae: 0.0131 - val_mape: 73.9994
# Epoch 45/100
# 5/5 [==============================] - 1s 184ms/step - loss: 5.2662e-04 - mae: 0.0194 - mape: 1415.7614 - val_loss: 2.3011e-04 - val_mae: 0.0173 - val_mape: 93.1590
# Epoch 46/100
# 5/5 [==============================] - 1s 205ms/step - loss: 5.2914e-04 - mae: 0.0192 - mape: 1298.4150 - val_loss: 1.6903e-04 - val_mae: 0.0144 - val_mape: 80.1931
# Epoch 47/100
# 5/5 [==============================] - 1s 165ms/step - loss: 5.5058e-04 - mae: 0.0192 - mape: 1086.3324 - val_loss: 2.2428e-04 - val_mae: 0.0169 - val_mape: 90.1507
# Epoch 48/100
# 5/5 [==============================] - 1s 196ms/step - loss: 5.1538e-04 - mae: 0.0190 - mape: 1275.2499 - val_loss: 1.3279e-04 - val_mae: 0.0124 - val_mape: 69.2462
# Epoch 49/100
# 5/5 [==============================] - 1s 205ms/step - loss: 5.0629e-04 - mae: 0.0188 - mape: 1131.6836 - val_loss: 1.7548e-04 - val_mae: 0.0148 - val_mape: 82.6447
# Epoch 50/100
# 5/5 [==============================] - 1s 195ms/step - loss: 5.5715e-04 - mae: 0.0191 - mape: 1231.3702 - val_loss: 1.7444e-04 - val_mae: 0.0148 - val_mape: 82.1774
# Epoch 51/100
# 5/5 [==============================] - 1s 197ms/step - loss: 5.0702e-04 - mae: 0.0187 - mape: 1250.1283 - val_loss: 1.2646e-04 - val_mae: 0.0121 - val_mape: 68.8278
# Epoch 52/100
# 5/5 [==============================] - 1s 181ms/step - loss: 5.3948e-04 - mae: 0.0189 - mape: 1200.4218 - val_loss: 1.7989e-04 - val_mae: 0.0151 - val_mape: 84.3341
# Epoch 53/100
# 5/5 [==============================] - 1s 243ms/step - loss: 4.8940e-04 - mae: 0.0185 - mape: 1161.3722 - val_loss: 1.4856e-04 - val_mae: 0.0134 - val_mape: 76.8865
# Epoch 54/100
# 5/5 [==============================] - 1s 172ms/step - loss: 5.4380e-04 - mae: 0.0188 - mape: 1249.2434 - val_loss: 1.3812e-04 - val_mae: 0.0128 - val_mape: 73.7788
# Epoch 55/100
# 5/5 [==============================] - 1s 217ms/step - loss: 5.4739e-04 - mae: 0.0192 - mape: 1480.2593 - val_loss: 4.0736e-04 - val_mae: 0.0239 - val_mape: 115.7482
# Epoch 56/100
# 5/5 [==============================] - 1s 172ms/step - loss: 5.2745e-04 - mae: 0.0200 - mape: 1190.5175 - val_loss: 1.3083e-04 - val_mae: 0.0122 - val_mape: 61.1421
# Epoch 57/100
# 5/5 [==============================] - 1s 185ms/step - loss: 5.8386e-04 - mae: 0.0194 - mape: 1405.8309 - val_loss: 1.4998e-04 - val_mae: 0.0136 - val_mape: 77.8822
# Epoch 58/100
# 5/5 [==============================] - 1s 183ms/step - loss: 5.2046e-04 - mae: 0.0193 - mape: 1589.0164 - val_loss: 3.2605e-04 - val_mae: 0.0216 - val_mape: 109.9167
# Epoch 59/100
# 5/5 [==============================] - 1s 184ms/step - loss: 4.9388e-04 - mae: 0.0196 - mape: 1387.1847 - val_loss: 1.2076e-04 - val_mae: 0.0116 - val_mape: 63.1407
# Epoch 60/100
# 5/5 [==============================] - 1s 253ms/step - loss: 5.0439e-04 - mae: 0.0195 - mape: 1226.7582 - val_loss: 1.5732e-04 - val_mae: 0.0138 - val_mape: 77.3120
# Epoch 61/100
# 5/5 [==============================] - 1s 187ms/step - loss: 5.1395e-04 - mae: 0.0188 - mape: 1221.2166 - val_loss: 2.3541e-04 - val_mae: 0.0176 - val_mape: 92.6299
# Epoch 62/100
# 5/5 [==============================] - 1s 201ms/step - loss: 5.0998e-04 - mae: 0.0183 - mape: 1133.4436 - val_loss: 1.2486e-04 - val_mae: 0.0120 - val_mape: 67.7637
# Epoch 63/100
# 5/5 [==============================] - 1s 196ms/step - loss: 5.0641e-04 - mae: 0.0186 - mape: 1292.9950 - val_loss: 1.2140e-04 - val_mae: 0.0117 - val_mape: 63.7716
# Epoch 64/100
# 5/5 [==============================] - 1s 202ms/step - loss: 5.0499e-04 - mae: 0.0190 - mape: 1924.0419 - val_loss: 3.3265e-04 - val_mae: 0.0216 - val_mape: 107.5553
# Epoch 65/100
# 5/5 [==============================] - 1s 177ms/step - loss: 5.0527e-04 - mae: 0.0195 - mape: 1330.4445 - val_loss: 1.4851e-04 - val_mae: 0.0133 - val_mape: 73.3439
# Epoch 66/100
# 5/5 [==============================] - 1s 201ms/step - loss: 4.5978e-04 - mae: 0.0181 - mape: 1188.9987 - val_loss: 1.2876e-04 - val_mae: 0.0122 - val_mape: 68.6286
# Epoch 67/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.6394e-04 - mae: 0.0180 - mape: 1200.7838 - val_loss: 2.7936e-04 - val_mae: 0.0195 - val_mape: 98.1966
# Epoch 68/100
# 5/5 [==============================] - 1s 193ms/step - loss: 4.3903e-04 - mae: 0.0180 - mape: 1350.4373 - val_loss: 1.2904e-04 - val_mae: 0.0122 - val_mape: 69.6401
# Epoch 69/100
# 5/5 [==============================] - 1s 189ms/step - loss: 5.4220e-04 - mae: 0.0180 - mape: 1145.4896 - val_loss: 1.2001e-04 - val_mae: 0.0118 - val_mape: 67.5889
# Epoch 70/100
# 5/5 [==============================] - 1s 193ms/step - loss: 5.4519e-04 - mae: 0.0193 - mape: 1222.5424 - val_loss: 3.7055e-04 - val_mae: 0.0226 - val_mape: 107.9539
# Epoch 71/100
# 5/5 [==============================] - 1s 197ms/step - loss: 4.9592e-04 - mae: 0.0194 - mape: 1235.0830 - val_loss: 1.4602e-04 - val_mae: 0.0129 - val_mape: 62.2420
# Epoch 72/100
# 5/5 [==============================] - 1s 162ms/step - loss: 5.1097e-04 - mae: 0.0194 - mape: 1777.2748 - val_loss: 1.4147e-04 - val_mae: 0.0130 - val_mape: 74.9631
# Epoch 73/100
# 5/5 [==============================] - 1s 199ms/step - loss: 4.6868e-04 - mae: 0.0181 - mape: 1504.2163 - val_loss: 3.7966e-04 - val_mae: 0.0235 - val_mape: 115.3391
# Epoch 74/100
# 5/5 [==============================] - 1s 165ms/step - loss: 4.7800e-04 - mae: 0.0192 - mape: 1297.1219 - val_loss: 1.2184e-04 - val_mae: 0.0117 - val_mape: 64.3028
# Epoch 75/100
# 5/5 [==============================] - 1s 189ms/step - loss: 4.7395e-04 - mae: 0.0186 - mape: 1212.2769 - val_loss: 1.4135e-04 - val_mae: 0.0129 - val_mape: 73.9684
# Epoch 76/100
# 5/5 [==============================] - 1s 154ms/step - loss: 4.1316e-04 - mae: 0.0172 - mape: 1318.0409 - val_loss: 1.8886e-04 - val_mae: 0.0156 - val_mape: 86.9811
# Epoch 77/100
# 5/5 [==============================] - 1s 201ms/step - loss: 4.3413e-04 - mae: 0.0176 - mape: 1015.5672 - val_loss: 1.7794e-04 - val_mae: 0.0150 - val_mape: 82.8830
# Epoch 78/100
# 5/5 [==============================] - 1s 167ms/step - loss: 4.6467e-04 - mae: 0.0178 - mape: 1258.7614 - val_loss: 1.1805e-04 - val_mae: 0.0115 - val_mape: 63.8506
# Epoch 79/100
# 5/5 [==============================] - 1s 191ms/step - loss: 4.6930e-04 - mae: 0.0178 - mape: 1024.0548 - val_loss: 3.1240e-04 - val_mae: 0.0205 - val_mape: 101.1351
# Epoch 80/100
# 5/5 [==============================] - 1s 189ms/step - loss: 4.5460e-04 - mae: 0.0182 - mape: 1912.9893 - val_loss: 1.2129e-04 - val_mae: 0.0117 - val_mape: 66.6419
# Epoch 81/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.0196e-04 - mae: 0.0173 - mape: 1128.3972 - val_loss: 1.5608e-04 - val_mae: 0.0136 - val_mape: 76.2466
# Epoch 82/100
# 5/5 [==============================] - 1s 203ms/step - loss: 4.9275e-04 - mae: 0.0177 - mape: 1151.3640 - val_loss: 1.4136e-04 - val_mae: 0.0130 - val_mape: 75.0699
# Epoch 83/100
# 5/5 [==============================] - 1s 175ms/step - loss: 4.4841e-04 - mae: 0.0174 - mape: 1064.1747 - val_loss: 1.2842e-04 - val_mae: 0.0122 - val_mape: 70.7818
# Epoch 84/100
# 5/5 [==============================] - 1s 193ms/step - loss: 4.2206e-04 - mae: 0.0168 - mape: 1139.9830 - val_loss: 1.2212e-04 - val_mae: 0.0118 - val_mape: 68.0720
# Epoch 85/100
# 5/5 [==============================] - 1s 162ms/step - loss: 4.2025e-04 - mae: 0.0172 - mape: 1190.6456 - val_loss: 1.8966e-04 - val_mae: 0.0153 - val_mape: 83.9040
# Epoch 86/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.2347e-04 - mae: 0.0170 - mape: 1139.0444 - val_loss: 1.3223e-04 - val_mae: 0.0123 - val_mape: 71.0055
# Epoch 87/100
# 5/5 [==============================] - 1s 178ms/step - loss: 4.6624e-04 - mae: 0.0172 - mape: 1084.2947 - val_loss: 1.4593e-04 - val_mae: 0.0132 - val_mape: 76.5402
# Epoch 88/100
# 5/5 [==============================] - 1s 201ms/step - loss: 4.8461e-04 - mae: 0.0180 - mape: 1074.4519 - val_loss: 3.6369e-04 - val_mae: 0.0218 - val_mape: 105.1913
# Epoch 89/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.5393e-04 - mae: 0.0190 - mape: 1855.0621 - val_loss: 1.6873e-04 - val_mae: 0.0139 - val_mape: 63.8847
# Epoch 90/100
# 5/5 [==============================] - 1s 193ms/step - loss: 5.0299e-04 - mae: 0.0195 - mape: 779.3317 - val_loss: 1.5740e-04 - val_mae: 0.0138 - val_mape: 78.5479
# Epoch 91/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.8377e-04 - mae: 0.0185 - mape: 1210.7345 - val_loss: 3.4200e-04 - val_mae: 0.0221 - val_mape: 109.7904
# Epoch 92/100
# 5/5 [==============================] - 1s 184ms/step - loss: 4.0560e-04 - mae: 0.0183 - mape: 1253.8042 - val_loss: 1.3177e-04 - val_mae: 0.0122 - val_mape: 64.2749
# Epoch 93/100
# 5/5 [==============================] - 1s 203ms/step - loss: 4.3645e-04 - mae: 0.0185 - mape: 1001.4273 - val_loss: 2.4320e-04 - val_mae: 0.0172 - val_mape: 88.2321
# Epoch 94/100
# 5/5 [==============================] - 1s 177ms/step - loss: 4.7915e-04 - mae: 0.0181 - mape: 1161.4800 - val_loss: 1.2027e-04 - val_mae: 0.0117 - val_mape: 68.2089
# Epoch 95/100
# 5/5 [==============================] - 1s 191ms/step - loss: 5.4997e-04 - mae: 0.0186 - mape: 1081.0823 - val_loss: 4.8403e-04 - val_mae: 0.0268 - val_mape: 123.0062
# Epoch 96/100
# 5/5 [==============================] - 1s 164ms/step - loss: 5.2716e-04 - mae: 0.0195 - mape: 1143.8286 - val_loss: 1.4914e-04 - val_mae: 0.0129 - val_mape: 65.3882
# Epoch 97/100
# 5/5 [==============================] - 1s 190ms/step - loss: 4.6918e-04 - mae: 0.0191 - mape: 1338.1384 - val_loss: 5.5832e-04 - val_mae: 0.0274 - val_mape: 122.7115
# Epoch 98/100
# 5/5 [==============================] - 1s 152ms/step - loss: 4.3779e-04 - mae: 0.0188 - mape: 1254.7666 - val_loss: 1.3239e-04 - val_mae: 0.0122 - val_mape: 67.2356
# Epoch 99/100
# 5/5 [==============================] - 1s 199ms/step - loss: 4.0559e-04 - mae: 0.0180 - mape: 1131.4061 - val_loss: 1.8814e-04 - val_mae: 0.0149 - val_mape: 84.0460
# Epoch 100/100
# 5/5 [==============================] - 1s 169ms/step - loss: 4.9484e-04 - mae: 0.0181 - mape: 1355.3109 - val_loss: 1.2622e-04 - val_mae: 0.0120 - val_mape: 70.2808
# Ejecutando la gru
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 9s 528ms/step - loss: 0.0094 - mae: 0.0994 - mape: 354.7865 - val_loss: 8.3470e-04 - val_mae: 0.0332 - val_mape: 84.4717
# Epoch 2/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0068 - mae: 0.0745 - mape: 465.1248 - val_loss: 4.5366e-04 - val_mae: 0.0237 - val_mape: 93.3462
# Epoch 3/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0056 - mae: 0.0647 - mape: 695.0837 - val_loss: 6.2913e-04 - val_mae: 0.0276 - val_mape: 136.5491
# Epoch 4/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0049 - mae: 0.0626 - mape: 2020.3615 - val_loss: 9.4112e-04 - val_mae: 0.0363 - val_mape: 177.6688
# Epoch 5/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0045 - mae: 0.0611 - mape: 2615.8855 - val_loss: 0.0011 - val_mae: 0.0405 - val_mape: 193.3578
# Epoch 6/100
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0041 - mae: 0.0583 - mape: 2452.2585 - val_loss: 0.0010 - val_mae: 0.0414 - val_mape: 194.8557
# Epoch 7/100
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0039 - mae: 0.0558 - mape: 1808.1703 - val_loss: 0.0012 - val_mae: 0.0444 - val_mape: 203.0522
# Epoch 8/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0035 - mae: 0.0532 - mape: 2342.9690 - val_loss: 0.0015 - val_mae: 0.0513 - val_mape: 223.0477
# Epoch 9/100
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0032 - mae: 0.0517 - mape: 3456.9517 - val_loss: 0.0019 - val_mae: 0.0567 - val_mape: 236.6974
# Epoch 10/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0027 - mae: 0.0477 - mape: 1638.9235 - val_loss: 0.0020 - val_mae: 0.0592 - val_mape: 239.4655
# Epoch 11/100
# 5/5 [==============================] - 1s 130ms/step - loss: 0.0022 - mae: 0.0434 - mape: 2024.8175 - val_loss: 0.0024 - val_mae: 0.0636 - val_mape: 247.4858
# Epoch 12/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.0017 - mae: 0.0385 - mape: 1462.4370 - val_loss: 0.0023 - val_mae: 0.0621 - val_mape: 236.2290
# Epoch 13/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0013 - mae: 0.0330 - mape: 557.5413 - val_loss: 0.0015 - val_mae: 0.0468 - val_mape: 184.4761
# Epoch 14/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0011 - mae: 0.0296 - mape: 773.2485 - val_loss: 8.0910e-04 - val_mae: 0.0323 - val_mape: 137.9831
# Epoch 15/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0011 - mae: 0.0283 - mape: 1947.9819 - val_loss: 9.4668e-04 - val_mae: 0.0361 - val_mape: 149.9240
# Epoch 16/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0010 - mae: 0.0276 - mape: 862.6964 - val_loss: 0.0011 - val_mae: 0.0405 - val_mape: 166.1647
# Epoch 17/100
# 5/5 [==============================] - 1s 151ms/step - loss: 9.8120e-04 - mae: 0.0279 - mape: 1126.5260 - val_loss: 0.0015 - val_mae: 0.0485 - val_mape: 189.2985
# Epoch 18/100
# 5/5 [==============================] - 1s 145ms/step - loss: 8.5803e-04 - mae: 0.0261 - mape: 1229.2301 - val_loss: 8.5112e-04 - val_mae: 0.0346 - val_mape: 144.0361
# Epoch 19/100
# 5/5 [==============================] - 1s 158ms/step - loss: 8.2528e-04 - mae: 0.0248 - mape: 1137.4247 - val_loss: 0.0013 - val_mae: 0.0450 - val_mape: 176.1378
# Epoch 20/100
# 5/5 [==============================] - 1s 135ms/step - loss: 8.4662e-04 - mae: 0.0249 - mape: 1225.0171 - val_loss: 0.0010 - val_mae: 0.0387 - val_mape: 158.1684
# Epoch 21/100
# 5/5 [==============================] - 1s 158ms/step - loss: 8.2208e-04 - mae: 0.0244 - mape: 1208.2469 - val_loss: 0.0018 - val_mae: 0.0539 - val_mape: 206.7241
# Epoch 22/100
# 5/5 [==============================] - 1s 217ms/step - loss: 8.3220e-04 - mae: 0.0252 - mape: 1273.9169 - val_loss: 4.0342e-04 - val_mae: 0.0230 - val_mape: 110.0028
# Epoch 23/100
# 5/5 [==============================] - 1s 194ms/step - loss: 7.5395e-04 - mae: 0.0234 - mape: 1349.3865 - val_loss: 0.0013 - val_mae: 0.0451 - val_mape: 182.1690
# Epoch 24/100
# 5/5 [==============================] - 1s 133ms/step - loss: 7.1622e-04 - mae: 0.0234 - mape: 2533.0608 - val_loss: 3.7853e-04 - val_mae: 0.0225 - val_mape: 113.7485
# Epoch 25/100
# 5/5 [==============================] - 1s 149ms/step - loss: 7.5991e-04 - mae: 0.0235 - mape: 1237.3973 - val_loss: 0.0020 - val_mae: 0.0587 - val_mape: 232.6251
# Epoch 26/100
# 5/5 [==============================] - 1s 140ms/step - loss: 7.4882e-04 - mae: 0.0252 - mape: 984.5820 - val_loss: 2.2965e-04 - val_mae: 0.0168 - val_mape: 92.3076
# Epoch 27/100
# 5/5 [==============================] - 1s 208ms/step - loss: 7.9209e-04 - mae: 0.0244 - mape: 2072.4250 - val_loss: 0.0018 - val_mae: 0.0561 - val_mape: 218.5050
# Epoch 28/100
# 5/5 [==============================] - 1s 209ms/step - loss: 7.7269e-04 - mae: 0.0253 - mape: 1088.1625 - val_loss: 2.0848e-04 - val_mae: 0.0159 - val_mape: 87.2023
# Epoch 29/100
# 5/5 [==============================] - 1s 173ms/step - loss: 9.7124e-04 - mae: 0.0264 - mape: 1393.3904 - val_loss: 0.0015 - val_mae: 0.0496 - val_mape: 197.2489
# Epoch 30/100
# 5/5 [==============================] - 1s 140ms/step - loss: 8.4904e-04 - mae: 0.0264 - mape: 1428.0664 - val_loss: 2.0800e-04 - val_mae: 0.0160 - val_mape: 88.9107
# Epoch 31/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0011 - mae: 0.0290 - mape: 1048.6096 - val_loss: 6.4020e-04 - val_mae: 0.0309 - val_mape: 142.2122
# Epoch 32/100
# 5/5 [==============================] - 1s 144ms/step - loss: 7.8070e-04 - mae: 0.0263 - mape: 1260.8646 - val_loss: 0.0012 - val_mae: 0.0455 - val_mape: 187.4828
# Epoch 33/100
# 5/5 [==============================] - 1s 178ms/step - loss: 7.7069e-04 - mae: 0.0236 - mape: 972.2961 - val_loss: 3.7395e-04 - val_mae: 0.0227 - val_mape: 112.5599
# Epoch 34/100
# 5/5 [==============================] - 1s 139ms/step - loss: 6.5810e-04 - mae: 0.0219 - mape: 1298.0858 - val_loss: 0.0013 - val_mae: 0.0468 - val_mape: 187.2090
# Epoch 35/100
# 5/5 [==============================] - 1s 163ms/step - loss: 6.7598e-04 - mae: 0.0223 - mape: 892.0718 - val_loss: 4.9848e-04 - val_mae: 0.0265 - val_mape: 122.9920
# Epoch 36/100
# 5/5 [==============================] - 1s 142ms/step - loss: 6.3575e-04 - mae: 0.0217 - mape: 1246.0568 - val_loss: 6.9936e-04 - val_mae: 0.0324 - val_mape: 142.2315
# Epoch 37/100
# 5/5 [==============================] - 1s 161ms/step - loss: 6.4181e-04 - mae: 0.0216 - mape: 1298.6630 - val_loss: 5.6270e-04 - val_mae: 0.0286 - val_mape: 132.4691
# Epoch 38/100
# 5/5 [==============================] - 1s 142ms/step - loss: 6.2451e-04 - mae: 0.0210 - mape: 947.1770 - val_loss: 6.8281e-04 - val_mae: 0.0321 - val_mape: 146.3238
# Epoch 39/100
# 5/5 [==============================] - 1s 148ms/step - loss: 5.8251e-04 - mae: 0.0209 - mape: 1083.5233 - val_loss: 6.9110e-04 - val_mae: 0.0322 - val_mape: 146.9483
# Epoch 40/100
# 5/5 [==============================] - 1s 165ms/step - loss: 5.5840e-04 - mae: 0.0202 - mape: 1198.4890 - val_loss: 5.4171e-04 - val_mae: 0.0277 - val_mape: 131.6644
# Epoch 41/100
# 5/5 [==============================] - 1s 168ms/step - loss: 5.5615e-04 - mae: 0.0198 - mape: 1181.5160 - val_loss: 4.8751e-04 - val_mae: 0.0261 - val_mape: 126.2963
# Epoch 42/100
# 5/5 [==============================] - 1s 176ms/step - loss: 5.6448e-04 - mae: 0.0201 - mape: 1410.7535 - val_loss: 6.2761e-04 - val_mae: 0.0305 - val_mape: 141.7020
# Epoch 43/100
# 5/5 [==============================] - 1s 138ms/step - loss: 5.7836e-04 - mae: 0.0203 - mape: 892.0944 - val_loss: 4.3024e-04 - val_mae: 0.0242 - val_mape: 120.8504
# Epoch 44/100
# 5/5 [==============================] - 1s 152ms/step - loss: 5.5590e-04 - mae: 0.0197 - mape: 1141.0101 - val_loss: 5.6368e-04 - val_mae: 0.0285 - val_mape: 135.4610
# Epoch 45/100
# 5/5 [==============================] - 1s 121ms/step - loss: 5.0798e-04 - mae: 0.0197 - mape: 2151.0273 - val_loss: 4.3515e-04 - val_mae: 0.0243 - val_mape: 121.7533
# Epoch 46/100
# 5/5 [==============================] - 1s 154ms/step - loss: 6.1002e-04 - mae: 0.0198 - mape: 1142.6506 - val_loss: 7.2500e-04 - val_mae: 0.0331 - val_mape: 151.3236
# Epoch 47/100
# 5/5 [==============================] - 1s 196ms/step - loss: 5.0733e-04 - mae: 0.0194 - mape: 1169.0463 - val_loss: 5.7586e-04 - val_mae: 0.0286 - val_mape: 133.4977
# Epoch 48/100
# 5/5 [==============================] - 1s 198ms/step - loss: 4.9506e-04 - mae: 0.0191 - mape: 1066.2997 - val_loss: 4.1703e-04 - val_mae: 0.0235 - val_mape: 115.9574
# Epoch 49/100
# 5/5 [==============================] - 1s 156ms/step - loss: 5.1270e-04 - mae: 0.0193 - mape: 1119.1135 - val_loss: 5.5232e-04 - val_mae: 0.0283 - val_mape: 133.3464
# Epoch 50/100
# 5/5 [==============================] - 1s 145ms/step - loss: 5.6613e-04 - mae: 0.0197 - mape: 1126.6227 - val_loss: 5.2185e-04 - val_mae: 0.0274 - val_mape: 129.8787
# Epoch 51/100
# 5/5 [==============================] - 1s 219ms/step - loss: 5.6177e-04 - mae: 0.0193 - mape: 1011.8907 - val_loss: 4.8405e-04 - val_mae: 0.0259 - val_mape: 123.6098
# Epoch 52/100
# 5/5 [==============================] - 1s 183ms/step - loss: 4.8375e-04 - mae: 0.0186 - mape: 1146.7003 - val_loss: 2.7918e-04 - val_mae: 0.0184 - val_mape: 99.0100
# Epoch 53/100
# 5/5 [==============================] - 1s 276ms/step - loss: 4.9293e-04 - mae: 0.0191 - mape: 1246.5664 - val_loss: 4.4723e-04 - val_mae: 0.0249 - val_mape: 123.5209
# Epoch 54/100
# 5/5 [==============================] - 1s 154ms/step - loss: 4.6719e-04 - mae: 0.0186 - mape: 1333.9130 - val_loss: 2.5198e-04 - val_mae: 0.0175 - val_mape: 99.0999
# Epoch 55/100
# 5/5 [==============================] - 1s 248ms/step - loss: 5.3143e-04 - mae: 0.0195 - mape: 1070.2847 - val_loss: 9.7021e-04 - val_mae: 0.0397 - val_mape: 174.7835
# Epoch 56/100
# 5/5 [==============================] - 1s 167ms/step - loss: 4.9950e-04 - mae: 0.0201 - mape: 1278.8333 - val_loss: 1.4504e-04 - val_mae: 0.0125 - val_mape: 71.5169
# Epoch 57/100
# 5/5 [==============================] - 1s 215ms/step - loss: 5.7162e-04 - mae: 0.0209 - mape: 1338.8130 - val_loss: 9.0222e-04 - val_mae: 0.0372 - val_mape: 162.2819
# Epoch 58/100
# 5/5 [==============================] - 1s 225ms/step - loss: 5.3421e-04 - mae: 0.0201 - mape: 1113.9171 - val_loss: 2.1020e-04 - val_mae: 0.0155 - val_mape: 89.3607
# Epoch 59/100
# 5/5 [==============================] - 1s 163ms/step - loss: 5.7062e-04 - mae: 0.0198 - mape: 1311.1726 - val_loss: 6.3181e-04 - val_mae: 0.0304 - val_mape: 139.8567
# Epoch 60/100
# 5/5 [==============================] - 1s 257ms/step - loss: 5.3355e-04 - mae: 0.0199 - mape: 999.3668 - val_loss: 1.7861e-04 - val_mae: 0.0143 - val_mape: 84.5842
# Epoch 61/100
# 5/5 [==============================] - 1s 147ms/step - loss: 4.9682e-04 - mae: 0.0194 - mape: 1280.1770 - val_loss: 6.3264e-04 - val_mae: 0.0308 - val_mape: 140.9599
# Epoch 62/100
# 5/5 [==============================] - 1s 238ms/step - loss: 5.1421e-04 - mae: 0.0198 - mape: 1027.2529 - val_loss: 1.4837e-04 - val_mae: 0.0128 - val_mape: 76.6790
# Epoch 63/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.4222e-04 - mae: 0.0203 - mape: 1122.1510 - val_loss: 6.8508e-04 - val_mae: 0.0318 - val_mape: 144.6199
# Epoch 64/100
# 5/5 [==============================] - 1s 230ms/step - loss: 5.2569e-04 - mae: 0.0207 - mape: 1295.9794 - val_loss: 1.7375e-04 - val_mae: 0.0140 - val_mape: 82.2250
# Epoch 65/100
# 5/5 [==============================] - 1s 254ms/step - loss: 5.9757e-04 - mae: 0.0206 - mape: 1316.3265 - val_loss: 7.6381e-04 - val_mae: 0.0339 - val_mape: 151.0345
# Epoch 66/100
# 5/5 [==============================] - 1s 185ms/step - loss: 5.0456e-04 - mae: 0.0205 - mape: 1387.3228 - val_loss: 1.6815e-04 - val_mae: 0.0137 - val_mape: 80.3632
# Epoch 67/100
# 5/5 [==============================] - 1s 258ms/step - loss: 5.3017e-04 - mae: 0.0204 - mape: 1400.0863 - val_loss: 3.7266e-04 - val_mae: 0.0219 - val_mape: 110.9419
# Epoch 68/100
# ...
# Epoch 11/100
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0012 - mae: 0.0291 - mape: 1353.3103 - val_loss: 5.1694e-04 - val_mae: 0.0249 - val_mape: 75.3231
# Epoch 12/100
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0011 - mae: 0.0286 - mape: 858.2191 - val_loss: 4.6417e-04 - val_mae: 0.0239 - val_mape: 72.6131
# Epoch 13/100
# 5/5 [==============================] - 1s 125ms/step - loss: 9.7412e-04 - mae: 0.0271 - mape: 873.8237 - val_loss: 3.7570e-04 - val_mae: 0.0213 - val_mape: 65.1700
# Epoch 14/100
# 5/5 [==============================] - 1s 108ms/step - loss: 9.6265e-04 - mae: 0.0258 - mape: 1947.0999 - val_loss: 3.6443e-04 - val_mae: 0.0201 - val_mape: 57.5120
# Epoch 15/100
# 5/5 [==============================] - 1s 135ms/step - loss: 8.7259e-04 - mae: 0.0247 - mape: 1503.1483 - val_loss: 3.8004e-04 - val_mae: 0.0222 - val_mape: 71.4344
# Epoch 16/100
# 5/5 [==============================] - 0s 101ms/step - loss: 8.5644e-04 - mae: 0.0255 - mape: 1049.3149 - val_loss: 3.4017e-04 - val_mae: 0.0197 - val_mape: 58.6423
# Epoch 17/100
# 5/5 [==============================] - 1s 136ms/step - loss: 8.4781e-04 - mae: 0.0245 - mape: 1052.2395 - val_loss: 3.2098e-04 - val_mae: 0.0206 - val_mape: 68.5776
# Epoch 18/100
# 5/5 [==============================] - 1s 111ms/step - loss: 8.1416e-04 - mae: 0.0242 - mape: 1797.0797 - val_loss: 3.4244e-04 - val_mae: 0.0196 - val_mape: 57.1969
# Epoch 19/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0012 - mae: 0.0289 - mape: 1502.9548 - val_loss: 3.9982e-04 - val_mae: 0.0236 - val_mape: 79.6781
# Epoch 20/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0012 - mae: 0.0355 - mape: 2289.7146 - val_loss: 4.2850e-04 - val_mae: 0.0220 - val_mape: 64.0661
# Epoch 21/100
# 5/5 [==============================] - 1s 155ms/step - loss: 0.0022 - mae: 0.0392 - mape: 2407.6909 - val_loss: 8.0013e-04 - val_mae: 0.0275 - val_mape: 72.5184
# Epoch 22/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0011 - mae: 0.0302 - mape: 1701.5017 - val_loss: 8.5658e-04 - val_mae: 0.0366 - val_mape: 128.1641
# Epoch 23/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0012 - mae: 0.0350 - mape: 2197.5044 - val_loss: 7.6933e-04 - val_mae: 0.0332 - val_mape: 107.2107
# Epoch 24/100
# 5/5 [==============================] - 1s 116ms/step - loss: 9.6787e-04 - mae: 0.0292 - mape: 1949.8693 - val_loss: 5.3170e-04 - val_mae: 0.0277 - val_mape: 93.3384
# Epoch 25/100
# 5/5 [==============================] - 1s 127ms/step - loss: 8.6343e-04 - mae: 0.0277 - mape: 2014.0842 - val_loss: 3.0913e-04 - val_mae: 0.0200 - val_mape: 66.8141
# Epoch 26/100
# 5/5 [==============================] - 1s 117ms/step - loss: 7.8153e-04 - mae: 0.0232 - mape: 1489.4602 - val_loss: 2.8009e-04 - val_mae: 0.0174 - val_mape: 48.5289
# Epoch 27/100
# 5/5 [==============================] - 1s 121ms/step - loss: 7.2701e-04 - mae: 0.0225 - mape: 991.0227 - val_loss: 2.5554e-04 - val_mae: 0.0174 - val_mape: 54.8732
# Epoch 28/100
# 5/5 [==============================] - 1s 129ms/step - loss: 6.6729e-04 - mae: 0.0213 - mape: 1151.1904 - val_loss: 3.0649e-04 - val_mae: 0.0192 - val_mape: 59.7691
# Epoch 29/100
# 5/5 [==============================] - 1s 112ms/step - loss: 7.3716e-04 - mae: 0.0216 - mape: 1028.0083 - val_loss: 3.1970e-04 - val_mae: 0.0203 - val_mape: 66.2567
# Epoch 30/100
# 5/5 [==============================] - 1s 131ms/step - loss: 7.0934e-04 - mae: 0.0218 - mape: 761.3048 - val_loss: 2.9830e-04 - val_mae: 0.0191 - val_mape: 59.9211
# Epoch 31/100
# 5/5 [==============================] - 1s 150ms/step - loss: 6.1224e-04 - mae: 0.0206 - mape: 1236.1405 - val_loss: 2.7559e-04 - val_mae: 0.0184 - val_mape: 58.6862
# Epoch 32/100
# 5/5 [==============================] - 1s 157ms/step - loss: 7.4142e-04 - mae: 0.0211 - mape: 1624.7202 - val_loss: 2.6325e-04 - val_mae: 0.0179 - val_mape: 57.4112
# Epoch 33/100
# 5/5 [==============================] - 1s 110ms/step - loss: 6.8608e-04 - mae: 0.0214 - mape: 1280.2942 - val_loss: 2.8053e-04 - val_mae: 0.0186 - val_mape: 59.3656
# Epoch 34/100
# 5/5 [==============================] - 1s 152ms/step - loss: 6.2753e-04 - mae: 0.0211 - mape: 1536.5857 - val_loss: 2.7689e-04 - val_mae: 0.0188 - val_mape: 61.9743
# Epoch 35/100
# 5/5 [==============================] - 1s 113ms/step - loss: 7.2169e-04 - mae: 0.0219 - mape: 866.0678 - val_loss: 2.9337e-04 - val_mae: 0.0188 - val_mape: 59.0273
# Epoch 36/100
# 5/5 [==============================] - 1s 184ms/step - loss: 7.1430e-04 - mae: 0.0218 - mape: 1405.2089 - val_loss: 2.8517e-04 - val_mae: 0.0191 - val_mape: 63.6334
# Epoch 37/100
# 5/5 [==============================] - 1s 163ms/step - loss: 7.9435e-04 - mae: 0.0232 - mape: 1243.0602 - val_loss: 3.1032e-04 - val_mae: 0.0192 - val_mape: 59.5467
# Epoch 38/100
# 5/5 [==============================] - 1s 179ms/step - loss: 6.1094e-04 - mae: 0.0216 - mape: 1298.6827 - val_loss: 2.9882e-04 - val_mae: 0.0198 - val_mape: 66.4967
# Epoch 39/100
# 5/5 [==============================] - 1s 173ms/step - loss: 7.3988e-04 - mae: 0.0224 - mape: 2304.0305 - val_loss: 3.0522e-04 - val_mae: 0.0188 - val_mape: 56.5051
# Epoch 40/100
# 5/5 [==============================] - 1s 156ms/step - loss: 5.9073e-04 - mae: 0.0204 - mape: 986.1245 - val_loss: 2.9725e-04 - val_mae: 0.0196 - val_mape: 65.7839
# Epoch 41/100
# 5/5 [==============================] - 1s 210ms/step - loss: 6.1700e-04 - mae: 0.0211 - mape: 989.5921 - val_loss: 2.7625e-04 - val_mae: 0.0179 - val_mape: 54.3298
# Epoch 42/100
# 5/5 [==============================] - 1s 254ms/step - loss: 6.2205e-04 - mae: 0.0200 - mape: 1091.5079 - val_loss: 2.6942e-04 - val_mae: 0.0183 - val_mape: 59.8307
# Epoch 43/100
# 5/5 [==============================] - 1s 142ms/step - loss: 5.7651e-04 - mae: 0.0201 - mape: 1342.2401 - val_loss: 2.7523e-04 - val_mae: 0.0182 - val_mape: 57.1642
# Epoch 44/100
# 5/5 [==============================] - 1s 214ms/step - loss: 5.6465e-04 - mae: 0.0199 - mape: 1587.1624 - val_loss: 2.7203e-04 - val_mae: 0.0185 - val_mape: 61.0146
# Epoch 45/100
# 5/5 [==============================] - 1s 145ms/step - loss: 5.6768e-04 - mae: 0.0198 - mape: 458.5756 - val_loss: 2.6299e-04 - val_mae: 0.0176 - val_mape: 55.2092
# Epoch 46/100
# 5/5 [==============================] - 1s 214ms/step - loss: 6.4100e-04 - mae: 0.0196 - mape: 811.2548 - val_loss: 2.7679e-04 - val_mae: 0.0187 - val_mape: 61.5545
# Epoch 47/100
# 5/5 [==============================] - 1s 159ms/step - loss: 5.9371e-04 - mae: 0.0196 - mape: 852.8715 - val_loss: 2.8011e-04 - val_mae: 0.0187 - val_mape: 60.5325
# Epoch 48/100
# 5/5 [==============================] - 1s 180ms/step - loss: 5.5156e-04 - mae: 0.0194 - mape: 1243.4009 - val_loss: 2.5308e-04 - val_mae: 0.0174 - val_mape: 55.3282
# Epoch 49/100
# 5/5 [==============================] - 1s 164ms/step - loss: 5.2693e-04 - mae: 0.0192 - mape: 1041.1626 - val_loss: 2.5571e-04 - val_mae: 0.0176 - val_mape: 56.2572
# Epoch 50/100
# 5/5 [==============================] - 1s 157ms/step - loss: 5.2558e-04 - mae: 0.0194 - mape: 1868.5692 - val_loss: 2.5026e-04 - val_mae: 0.0173 - val_mape: 55.2044
# Epoch 51/100
# 5/5 [==============================] - 1s 179ms/step - loss: 6.6081e-04 - mae: 0.0213 - mape: 1220.2866 - val_loss: 2.9052e-04 - val_mae: 0.0194 - val_mape: 63.5650
# Epoch 52/100
# 5/5 [==============================] - 1s 229ms/step - loss: 7.5233e-04 - mae: 0.0226 - mape: 1593.8293 - val_loss: 2.4627e-04 - val_mae: 0.0170 - val_mape: 53.1584
# Epoch 53/100
# 5/5 [==============================] - 1s 161ms/step - loss: 7.4047e-04 - mae: 0.0237 - mape: 1039.6187 - val_loss: 2.9219e-04 - val_mae: 0.0191 - val_mape: 61.1569
# Epoch 54/100
# 5/5 [==============================] - 1s 210ms/step - loss: 7.0342e-04 - mae: 0.0235 - mape: 1358.3795 - val_loss: 2.9034e-04 - val_mae: 0.0195 - val_mape: 65.4743
# Epoch 55/100
# 5/5 [==============================] - 1s 131ms/step - loss: 7.8164e-04 - mae: 0.0248 - mape: 799.5483 - val_loss: 3.1061e-04 - val_mae: 0.0191 - val_mape: 57.6246
# Epoch 56/100
# 5/5 [==============================] - 1s 209ms/step - loss: 7.8928e-04 - mae: 0.0236 - mape: 1259.4797 - val_loss: 3.3399e-04 - val_mae: 0.0212 - val_mape: 72.4158
# Epoch 57/100
# 5/5 [==============================] - 1s 162ms/step - loss: 7.1457e-04 - mae: 0.0229 - mape: 1385.4644 - val_loss: 3.2380e-04 - val_mae: 0.0189 - val_mape: 54.4704
# Epoch 58/100
# 5/5 [==============================] - 1s 175ms/step - loss: 5.5546e-04 - mae: 0.0199 - mape: 1047.2310 - val_loss: 3.6102e-04 - val_mae: 0.0221 - val_mape: 74.7982
# Epoch 59/100
# 5/5 [==============================] - 1s 161ms/step - loss: 6.4340e-04 - mae: 0.0215 - mape: 1049.7810 - val_loss: 2.4794e-04 - val_mae: 0.0165 - val_mape: 47.7176
# Epoch 60/100
# 5/5 [==============================] - 1s 202ms/step - loss: 5.5765e-04 - mae: 0.0205 - mape: 532.6327 - val_loss: 2.6048e-04 - val_mae: 0.0179 - val_mape: 58.4426
# Epoch 61/100
# 5/5 [==============================] - 1s 222ms/step - loss: 5.0387e-04 - mae: 0.0187 - mape: 791.4752 - val_loss: 3.0378e-04 - val_mae: 0.0200 - val_mape: 67.5453
# Epoch 62/100
# 5/5 [==============================] - 1s 197ms/step - loss: 5.9504e-04 - mae: 0.0198 - mape: 1523.8225 - val_loss: 2.8402e-04 - val_mae: 0.0190 - val_mape: 62.5845
# Epoch 63/100
# 5/5 [==============================] - 1s 147ms/step - loss: 5.2027e-04 - mae: 0.0189 - mape: 998.1921 - val_loss: 2.5017e-04 - val_mae: 0.0174 - val_mape: 56.1545
# Epoch 64/100
# 5/5 [==============================] - 1s 259ms/step - loss: 5.7663e-04 - mae: 0.0193 - mape: 1428.9056 - val_loss: 2.4897e-04 - val_mae: 0.0173 - val_mape: 54.6458
# Epoch 65/100
# 5/5 [==============================] - 1s 138ms/step - loss: 5.6728e-04 - mae: 0.0192 - mape: 1039.7670 - val_loss: 2.4650e-04 - val_mae: 0.0172 - val_mape: 55.1426
# Epoch 66/100
# 5/5 [==============================] - 1s 207ms/step - loss: 5.7251e-04 - mae: 0.0202 - mape: 1987.2803 - val_loss: 2.8008e-04 - val_mae: 0.0185 - val_mape: 58.2137
# Epoch 67/100
# 5/5 [==============================] - 1s 169ms/step - loss: 5.3235e-04 - mae: 0.0199 - mape: 1436.0898 - val_loss: 2.7546e-04 - val_mae: 0.0187 - val_mape: 62.3114
# Epoch 68/100
# 5/5 [==============================] - 1s 191ms/step - loss: 5.9284e-04 - mae: 0.0200 - mape: 1166.0989 - val_loss: 2.4501e-04 - val_mae: 0.0167 - val_mape: 50.3168
# Epoch 69/100
# 5/5 [==============================] - 1s 174ms/step - loss: 5.2636e-04 - mae: 0.0189 - mape: 1992.7495 - val_loss: 2.7144e-04 - val_mae: 0.0185 - val_mape: 61.3953
# Epoch 70/100
# 5/5 [==============================] - 1s 181ms/step - loss: 5.4304e-04 - mae: 0.0190 - mape: 1148.1279 - val_loss: 2.6492e-04 - val_mae: 0.0176 - val_mape: 54.6799
# Epoch 71/100
# 5/5 [==============================] - 1s 182ms/step - loss: 4.7080e-04 - mae: 0.0183 - mape: 617.7324 - val_loss: 3.0891e-04 - val_mae: 0.0202 - val_mape: 68.6027
# Epoch 72/100
# 5/5 [==============================] - 1s 215ms/step - loss: 5.0090e-04 - mae: 0.0189 - mape: 1293.1521 - val_loss: 2.3371e-04 - val_mae: 0.0163 - val_mape: 50.3933
# Epoch 73/100
# 5/5 [==============================] - 1s 175ms/step - loss: 5.1315e-04 - mae: 0.0185 - mape: 1517.4213 - val_loss: 2.4711e-04 - val_mae: 0.0174 - val_mape: 56.4521
# Epoch 74/100
# 5/5 [==============================] - 1s 204ms/step - loss: 4.7717e-04 - mae: 0.0177 - mape: 986.1146 - val_loss: 2.6765e-04 - val_mae: 0.0183 - val_mape: 59.3925
# Epoch 75/100
# 5/5 [==============================] - 1s 151ms/step - loss: 4.9166e-04 - mae: 0.0185 - mape: 1245.7830 - val_loss: 2.7893e-04 - val_mae: 0.0189 - val_mape: 62.8683
# Epoch 76/100
# 5/5 [==============================] - 1s 208ms/step - loss: 4.6691e-04 - mae: 0.0183 - mape: 1616.6141 - val_loss: 2.3365e-04 - val_mae: 0.0162 - val_mape: 48.8949
# Epoch 77/100
# 5/5 [==============================] - 1s 151ms/step - loss: 4.6066e-04 - mae: 0.0187 - mape: 345.7253 - val_loss: 2.7549e-04 - val_mae: 0.0186 - val_mape: 60.9183
# Epoch 78/100
# 5/5 [==============================] - 1s 159ms/step - loss: 4.9575e-04 - mae: 0.0190 - mape: 1492.2832 - val_loss: 2.3893e-04 - val_mae: 0.0167 - val_mape: 51.4969
# Epoch 79/100
# 5/5 [==============================] - 1s 201ms/step - loss: 5.1363e-04 - mae: 0.0186 - mape: 1209.8014 - val_loss: 2.4718e-04 - val_mae: 0.0173 - val_mape: 55.1763
# Epoch 80/100
# 5/5 [==============================] - 1s 166ms/step - loss: 4.9440e-04 - mae: 0.0183 - mape: 1252.7128 - val_loss: 2.3500e-04 - val_mae: 0.0165 - val_mape: 51.4210
# Epoch 81/100
# 5/5 [==============================] - 1s 210ms/step - loss: 5.7514e-04 - mae: 0.0200 - mape: 1416.2489 - val_loss: 2.8405e-04 - val_mae: 0.0190 - val_mape: 61.9152
# Epoch 82/100
# 5/5 [==============================] - 1s 147ms/step - loss: 5.8556e-04 - mae: 0.0213 - mape: 1225.3071 - val_loss: 2.4206e-04 - val_mae: 0.0170 - val_mape: 54.8766
# Epoch 83/100
# 5/5 [==============================] - 1s 209ms/step - loss: 6.0433e-04 - mae: 0.0213 - mape: 473.7587 - val_loss: 2.6419e-04 - val_mae: 0.0179 - val_mape: 57.6315
# Epoch 84/100
# 5/5 [==============================] - 1s 148ms/step - loss: 6.9324e-04 - mae: 0.0215 - mape: 1219.3354 - val_loss: 2.8407e-04 - val_mae: 0.0192 - val_mape: 64.8928
# Epoch 85/100
# 5/5 [==============================] - 1s 213ms/step - loss: 8.6296e-04 - mae: 0.0252 - mape: 1529.8900 - val_loss: 3.5922e-04 - val_mae: 0.0207 - val_mape: 63.3531
# Epoch 86/100
# 5/5 [==============================] - 1s 194ms/step - loss: 5.9577e-04 - mae: 0.0234 - mape: 1460.7047 - val_loss: 3.7745e-04 - val_mae: 0.0229 - val_mape: 78.5235
# Epoch 87/100
# 5/5 [==============================] - 1s 176ms/step - loss: 6.7531e-04 - mae: 0.0223 - mape: 1831.0510 - val_loss: 2.7283e-04 - val_mae: 0.0171 - val_mape: 46.8725
# Epoch 88/100
# 5/5 [==============================] - 1s 142ms/step - loss: 5.7655e-04 - mae: 0.0200 - mape: 890.3474 - val_loss: 3.1611e-04 - val_mae: 0.0205 - val_mape: 70.3698
# Epoch 89/100
# 5/5 [==============================] - 1s 145ms/step - loss: 5.6314e-04 - mae: 0.0195 - mape: 1624.8470 - val_loss: 3.2494e-04 - val_mae: 0.0201 - val_mape: 64.5298
# Epoch 90/100
# 5/5 [==============================] - 1s 190ms/step - loss: 4.7646e-04 - mae: 0.0185 - mape: 858.4299 - val_loss: 3.0186e-04 - val_mae: 0.0196 - val_mape: 66.2485
# Epoch 91/100
# 5/5 [==============================] - 1s 170ms/step - loss: 5.3201e-04 - mae: 0.0184 - mape: 1237.0690 - val_loss: 2.4174e-04 - val_mae: 0.0162 - val_mape: 47.1580
# Epoch 92/100
# 5/5 [==============================] - 1s 171ms/step - loss: 4.2502e-04 - mae: 0.0183 - mape: 1084.9778 - val_loss: 2.8797e-04 - val_mae: 0.0192 - val_mape: 64.4392
# Epoch 93/100
# 5/5 [==============================] - 1s 192ms/step - loss: 4.5348e-04 - mae: 0.0184 - mape: 1160.4227 - val_loss: 2.6128e-04 - val_mae: 0.0179 - val_mape: 58.2981
# Epoch 94/100
# 5/5 [==============================] - 1s 212ms/step - loss: 4.6162e-04 - mae: 0.0185 - mape: 516.3369 - val_loss: 2.6003e-04 - val_mae: 0.0176 - val_mape: 55.7698
# Epoch 95/100
# 5/5 [==============================] - 1s 240ms/step - loss: 4.2836e-04 - mae: 0.0171 - mape: 1074.3983 - val_loss: 2.7818e-04 - val_mae: 0.0188 - val_mape: 62.9423
# Epoch 96/100
# 5/5 [==============================] - 1s 150ms/step - loss: 4.4014e-04 - mae: 0.0175 - mape: 1068.3579 - val_loss: 2.5351e-04 - val_mae: 0.0172 - val_mape: 53.5390
# Epoch 97/100
# 5/5 [==============================] - 1s 203ms/step - loss: 4.2531e-04 - mae: 0.0169 - mape: 713.5262 - val_loss: 2.5829e-04 - val_mae: 0.0177 - val_mape: 57.6284
# Epoch 98/100
# 5/5 [==============================] - 1s 162ms/step - loss: 5.1232e-04 - mae: 0.0174 - mape: 1202.5629 - val_loss: 2.6661e-04 - val_mae: 0.0179 - val_mape: 57.3278
# Epoch 99/100
# 5/5 [==============================] - 1s 209ms/step - loss: 4.4784e-04 - mae: 0.0172 - mape: 1616.8109 - val_loss: 2.5515e-04 - val_mae: 0.0175 - val_mape: 56.9473
# Epoch 100/100
# 5/5 [==============================] - 1s 173ms/step - loss: 4.2914e-04 - mae: 0.0171 - mape: 831.5889 - val_loss: 2.4222e-04 - val_mae: 0.0167 - val_mape: 52.5618

# %% [markdown]
# #### Gráficas de entrenamiento modelo con ventanado

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='loss'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='mae'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %% [markdown]
# ##### Evaluar modelo con ventanado

# %%
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xtr= x.numpy()
    Ytr=y.numpy()
    break

for idx,(x,y) in enumerate(val_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xval= x.numpy()
    Yval=y.numpy()
    break

for idx,(x,y) in enumerate(test_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xts= x.numpy()
    Yts=y.numpy()
    break
# Out:
# Example sample shapes
# x =  (256, 48, 7)
# y =  (256, 24, 1)
# x =  (256, 48, 7)
# y =  (256, 24, 1)
# x =  (256, 48, 7)
# y =  (256, 24, 1)

# %%
import pandas as pd
models=['dnn','lstm','gru','cnn_lstm']
# results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
results = []
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(3)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}

    results.append(data)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)

    resultsYtestP[mod]=listP
    listP=[]
df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
# Out:
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 201ms/step
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002644F2A3EC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 66ms/step

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe_80_20_earlystop_kfolds.csv')
df.to_csv(file)

# %%
df
# Out:
#        Model   Tipo        MAE        MAPE      sMAPE        RMSE
# 0        dnn  Train  16.072263    8.775844   8.725420   18.457435
# 1        dnn    Val  99.786264  123.240215  70.413725  110.424203
# 2        dnn   Test  31.283433   23.043064  20.178799   34.796497
# 3       lstm  Train  22.990025   12.676505  13.852664   26.341938
# 4       lstm    Val  66.553096   82.618987  55.378318   70.887569
# 5       lstm   Test  16.608432   12.365261  11.362068   19.458167
# 6        gru  Train  18.315169    9.968785  10.395212   22.664508
# 7        gru    Val  72.391976   89.325627  58.518702   76.784173
# 8        gru   Test  23.411030   17.134181  15.487028   25.934145
# 9   cnn_lstm  Train  14.049619    7.823063   8.308538   17.826211
# 10  cnn_lstm    Val  59.201195   73.400785  50.939118   63.551574
# 11  cnn_lstm   Test   8.973201    6.867651   6.740312   11.068140

# %% [markdown]
# #### Gráfica del original y del pronóstico

# %%
listreg=[i for i in range(3)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.src.engine.sequential.Sequential object at 0x0000026443578A90>, 'history': <keras.src.callbacks.History object at 0x00000264438A9210>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 74ms/step
# lstm {'model': <keras.src.engine.sequential.Sequential object at 0x000002644383E750>, 'history': <keras.src.callbacks.History object at 0x0000026445058A50>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 29ms/step
# gru {'model': <keras.src.engine.sequential.Sequential object at 0x000002643FFE8550>, 'history': <keras.src.callbacks.History object at 0x000002643FFCD110>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 58ms/step
# cnn_lstm {'model': <keras.src.engine.sequential.Sequential object at 0x000002641CCEE4D0>, 'history': <keras.src.callbacks.History object at 0x0000026429FE4F90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 59ms/step
