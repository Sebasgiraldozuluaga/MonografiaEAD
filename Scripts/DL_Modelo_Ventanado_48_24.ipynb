# %% [markdown]
# #### Cargas las librerías

# %%
# Load Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
import os
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf

from evaluation._mae import MAE
from evaluation._smape import sMAPE
from evaluation._mape import MAPE
from evaluation._rmse import RMSE

# %% [markdown]
# #### Cargar dataset

# %%
s_path=Path.cwd()
s_prt_path=s_path.parent

file=os.path.join(s_prt_path,'datasets\XM_H_sinOfe.csv')
df_Data= pd.read_csv(file, index_col=0)
# df_Data.reset_index(inplace=True)

# %%
df_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52584 entries, 01/01/2013 0:00 to 31/12/2018 23:00
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PrecioB    52584 non-null  float64
#  1   Demanda    52584 non-null  float64
#  2   DispTer    52584 non-null  int64
#  3   DispNoTer  52584 non-null  int64
#  4   VolUtil    52584 non-null  int64
#  5   Aportes    52584 non-null  int64
#  6   day_cls    52584 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Funciones necesarias para las ejecuciones

# %% [markdown]
# ##### División de datos

# %%
# Dividir los datos en train, validación y test
def split_data(data, indexTotal, train_fraq, test_len=8760):

    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(data)-test_len

    test_data = data[test_slice:]
    indexTest=indexTotal[test_slice:]

    train_val_data = data[:test_slice]
    index_val_data=indexTotal[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    indexTrain=index_val_data[:train_size]

    val_data = train_val_data[train_size:]
    indexVal=index_val_data[train_size:]
    
    return train_data, val_data, test_data, indexTrain, indexVal, indexTest

# %% [markdown]
# ##### Construcción del dataset

# %%
# Crear los datos para entrar al modelo, definición de ventanas
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
    """ Create a windowed tensorflow dataset
    
    """

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
    
    #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    #ds = ds.shuffle(shuffle_buffer)
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    
    return ds

# Construcción del dataset usando las ventanas
def build_dataset(traindata,valdata,testdata,train_fraq=0.65, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
    """If multi variate then first column is always the column from which the target is contstructed.
    """
    
    tf.random.set_seed(23)
    
    
    train_ds = window_dataset(traindata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(valdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(testdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    
    
    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# ##### Parámetros y ejecución

# %%
# Definición de parámetros para la ejecución del modelo
def get_params(multivar=True):
    lr = 3e-4
    n_steps=48
    n_horizon=24
    if multivar:
        n_features=7
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

# Almacenamiento de los datos de las ejecuciones
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}

# Ejecuciones de los modelos con función de ventanado
def run_model(traindata,valdata,testdata,model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    
    train_ds, val_ds, test_ds = build_dataset(traindata,valdata,testdata,n_steps=n_steps, n_horizon=n_horizon, multi_var=True)

    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs)

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    
    return test_ds

# %% [markdown]
# #### Modelos

# %% [markdown]
# ##### DNN

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 336)               0
#
#  dense (Dense)               (None, 128)               43136
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 62,744
# Trainable params: 62,744
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### LSTM

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48, 72)            23040
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55,640
# Trainable params: 55,640
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### GRU

# %%
def gru_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.GRU(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.GRU(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='gru')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

gru = gru_model(*get_params(multivar=True))
gru.summary()
# Out:
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 48, 72)            17496
#
#  gru_1 (GRU)                 (None, 48)                17568
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 44,432
# Trainable params: 44,432
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### CNN_LSTM

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 43, 64)            2752
#
#  max_pooling1d (MaxPooling1D  (None, 21, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 19, 64)            12352
#
#  max_pooling1d_1 (MaxPooling  (None, 9, 64)            0
#  1D)
#
#  lstm (LSTM)                 (None, 9, 72)             39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 87,160
# Trainable params: 87,160
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Escalamiento de los datos y división del dataset

# %%
#scale
scaler = MinMaxScaler(feature_range=(0, 1))
scalerP=MinMaxScaler(feature_range=(0, 1))

vec_precio=scalerP.fit_transform(df_Data.values[:,0].reshape(-1,1))

indexTotal=df_Data.index

multivar_df = scaler.fit_transform(df_Data)
train_multi, val_multi, test_multi, indexTrain, indexVal, indexTest = split_data(multivar_df,indexTotal, train_fraq=0.65, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
print('Precio',vec_precio.shape)
print('Todo',df_Data.shape)
# Out:
# Multivarate Datasets
# Train Data Shape: (28485, 7)
# Val Data Shape: (15339, 7)
# Test Data Shape: (8760, 7)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False
# Precio (52584, 1)
# Todo (52584, 7)

# %% [markdown]
# ##### Obtener dataset para el modelo utilizando la función de ventanado

# %%
n_steps=48
n_horizon=24

train_ds, val_ds, test_ds = build_dataset(train_multi, val_multi, test_multi,n_steps=n_steps, n_horizon=n_horizon,multi_var=True)
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Example sample shapes
# x =  (256, 48, 7)
# y =  (256, 24, 1)

# %% [markdown]
# ##### Ejecución de modelo con datos del ventanado

# %%
model_configs_v=dict()
nepochs=100

print('Ejecutando la dnn')
run_model(train_multi, val_multi, test_multi,"dnn", dnn_model, model_configs_v, epochs=nepochs)

print('Ejecutando la lstm')
run_model(train_multi, val_multi, test_multi,"lstm", lstm_model, model_configs_v, epochs=nepochs)

print('Ejecutando la gru')
run_model(train_multi, val_multi, test_multi,"gru", gru_model, model_configs_v, epochs=nepochs)

print('Ejecutando la cnn_lstm')
run_model(train_multi, val_multi, test_multi,"cnn_lstm", lstm_cnn_model, model_configs_v, epochs=nepochs)
# Out:
# Ejecutando la dnn
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 7s 441ms/step - loss: 0.0543 - mae: 0.2550 - mape: 7200.5117 - val_loss: 0.0057 - val_mae: 0.0863 - val_mape: 413.5303
# Epoch 2/100
# 5/5 [==============================] - 2s 361ms/step - loss: 0.0142 - mae: 0.1309 - mape: 5731.1118 - val_loss: 0.0020 - val_mae: 0.0492 - val_mape: 231.8899
# Epoch 3/100
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0075 - mae: 0.0875 - mape: 1189.4296 - val_loss: 7.0349e-04 - val_mae: 0.0278 - val_mape: 121.6764
# Epoch 4/100
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0055 - mae: 0.0682 - mape: 866.6964 - val_loss: 5.9539e-04 - val_mae: 0.0252 - val_mape: 122.6402
# Epoch 5/100
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0043 - mae: 0.0599 - mape: 796.8055 - val_loss: 7.0903e-04 - val_mae: 0.0287 - val_mape: 147.8461
# Epoch 6/100
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0038 - mae: 0.0562 - mape: 1179.1478 - val_loss: 4.6837e-04 - val_mae: 0.0226 - val_mape: 111.1548
# Epoch 7/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0028 - mae: 0.0466 - mape: 516.3483 - val_loss: 4.6122e-04 - val_mae: 0.0228 - val_mape: 115.1450
# Epoch 8/100
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0024 - mae: 0.0428 - mape: 698.0392 - val_loss: 3.6612e-04 - val_mae: 0.0208 - val_mape: 106.5744
# Epoch 9/100
# 5/5 [==============================] - 1s 306ms/step - loss: 0.0021 - mae: 0.0388 - mape: 588.9264 - val_loss: 3.0120e-04 - val_mae: 0.0189 - val_mape: 96.7778
# Epoch 10/100
# 5/5 [==============================] - 1s 272ms/step - loss: 0.0019 - mae: 0.0364 - mape: 753.7057 - val_loss: 3.2137e-04 - val_mae: 0.0196 - val_mape: 103.9829
# Epoch 11/100
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0018 - mae: 0.0349 - mape: 1132.4342 - val_loss: 3.3243e-04 - val_mae: 0.0201 - val_mape: 108.5134
# Epoch 12/100
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0017 - mae: 0.0340 - mape: 1312.5911 - val_loss: 3.4242e-04 - val_mae: 0.0206 - val_mape: 112.7328
# Epoch 13/100
# 5/5 [==============================] - 2s 364ms/step - loss: 0.0016 - mae: 0.0333 - mape: 1381.5586 - val_loss: 4.1716e-04 - val_mae: 0.0230 - val_mape: 126.2203
# Epoch 14/100
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0015 - mae: 0.0313 - mape: 1323.3981 - val_loss: 3.8701e-04 - val_mae: 0.0225 - val_mape: 125.1477
# Epoch 15/100
# 5/5 [==============================] - 1s 288ms/step - loss: 0.0015 - mae: 0.0309 - mape: 1177.1436 - val_loss: 4.6832e-04 - val_mae: 0.0251 - val_mape: 139.3406
# Epoch 16/100
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0015 - mae: 0.0300 - mape: 1423.4895 - val_loss: 5.6655e-04 - val_mae: 0.0277 - val_mape: 152.7194
# Epoch 17/100
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0013 - mae: 0.0312 - mape: 1614.8645 - val_loss: 5.1575e-04 - val_mae: 0.0272 - val_mape: 151.6581
# Epoch 18/100
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0014 - mae: 0.0297 - mape: 1383.0559 - val_loss: 5.7700e-04 - val_mae: 0.0290 - val_mape: 163.8757
# Epoch 19/100
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0012 - mae: 0.0302 - mape: 1482.4261 - val_loss: 5.0860e-04 - val_mae: 0.0273 - val_mape: 154.2253
# Epoch 20/100
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0013 - mae: 0.0291 - mape: 1607.9369 - val_loss: 5.5261e-04 - val_mae: 0.0288 - val_mape: 160.0477
# Epoch 21/100
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0013 - mae: 0.0310 - mape: 1814.3987 - val_loss: 4.9874e-04 - val_mae: 0.0277 - val_mape: 155.6195
# Epoch 22/100
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0013 - mae: 0.0288 - mape: 1820.9691 - val_loss: 4.6816e-04 - val_mae: 0.0270 - val_mape: 153.8063
# Epoch 23/100
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0012 - mae: 0.0302 - mape: 1605.5127 - val_loss: 5.4322e-04 - val_mae: 0.0286 - val_mape: 161.7992
# Epoch 24/100
# 5/5 [==============================] - 1s 284ms/step - loss: 0.0014 - mae: 0.0298 - mape: 1286.3733 - val_loss: 7.9715e-04 - val_mae: 0.0347 - val_mape: 191.3717
# Epoch 25/100
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0014 - mae: 0.0336 - mape: 1468.6835 - val_loss: 5.3884e-04 - val_mae: 0.0289 - val_mape: 161.4654
# Epoch 26/100
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0013 - mae: 0.0293 - mape: 1782.2535 - val_loss: 7.7184e-04 - val_mae: 0.0357 - val_mape: 191.4538
# Epoch 27/100
# 5/5 [==============================] - 1s 305ms/step - loss: 0.0012 - mae: 0.0335 - mape: 1949.5659 - val_loss: 5.1400e-04 - val_mae: 0.0283 - val_mape: 160.2108
# Epoch 28/100
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0012 - mae: 0.0287 - mape: 1912.3606 - val_loss: 5.8131e-04 - val_mae: 0.0296 - val_mape: 165.8069
# Epoch 29/100
# 5/5 [==============================] - 2s 331ms/step - loss: 0.0015 - mae: 0.0316 - mape: 2243.2085 - val_loss: 4.6566e-04 - val_mae: 0.0265 - val_mape: 151.4717
# Epoch 30/100
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0013 - mae: 0.0288 - mape: 1663.5247 - val_loss: 5.0198e-04 - val_mae: 0.0278 - val_mape: 158.0859
# Epoch 31/100
# 5/5 [==============================] - 1s 291ms/step - loss: 0.0012 - mae: 0.0325 - mape: 2093.1028 - val_loss: 5.3763e-04 - val_mae: 0.0288 - val_mape: 162.1776
# Epoch 32/100
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0011 - mae: 0.0273 - mape: 1769.2598 - val_loss: 5.7948e-04 - val_mae: 0.0295 - val_mape: 165.2819
# Epoch 33/100
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0013 - mae: 0.0307 - mape: 2593.3491 - val_loss: 5.2129e-04 - val_mae: 0.0279 - val_mape: 157.9081
# Epoch 34/100
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0012 - mae: 0.0280 - mape: 1553.9104 - val_loss: 6.2449e-04 - val_mae: 0.0307 - val_mape: 170.3610
# Epoch 35/100
# 5/5 [==============================] - 1s 310ms/step - loss: 0.0012 - mae: 0.0321 - mape: 1377.5072 - val_loss: 4.5636e-04 - val_mae: 0.0264 - val_mape: 151.9135
# Epoch 36/100
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0011 - mae: 0.0268 - mape: 1545.7158 - val_loss: 4.3743e-04 - val_mae: 0.0257 - val_mape: 148.4990
# Epoch 37/100
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0012 - mae: 0.0292 - mape: 1786.3032 - val_loss: 4.9767e-04 - val_mae: 0.0275 - val_mape: 156.4436
# Epoch 38/100
# 5/5 [==============================] - 2s 362ms/step - loss: 0.0011 - mae: 0.0269 - mape: 1621.5590 - val_loss: 5.1407e-04 - val_mae: 0.0281 - val_mape: 157.1232
# Epoch 39/100
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0014 - mae: 0.0307 - mape: 2707.0029 - val_loss: 5.3392e-04 - val_mae: 0.0287 - val_mape: 161.2151
# Epoch 40/100
# 5/5 [==============================] - 2s 355ms/step - loss: 0.0011 - mae: 0.0267 - mape: 1683.4655 - val_loss: 4.9726e-04 - val_mae: 0.0275 - val_mape: 156.5879
# Epoch 41/100
# 5/5 [==============================] - 2s 407ms/step - loss: 0.0012 - mae: 0.0297 - mape: 1879.0568 - val_loss: 4.9065e-04 - val_mae: 0.0273 - val_mape: 156.0754
# Epoch 42/100
# 5/5 [==============================] - 2s 322ms/step - loss: 0.0011 - mae: 0.0267 - mape: 1679.6892 - val_loss: 5.3909e-04 - val_mae: 0.0289 - val_mape: 163.2748
# Epoch 43/100
# 5/5 [==============================] - 1s 321ms/step - loss: 0.0012 - mae: 0.0302 - mape: 1511.1838 - val_loss: 5.1955e-04 - val_mae: 0.0283 - val_mape: 160.4532
# Epoch 44/100
# 5/5 [==============================] - 2s 307ms/step - loss: 9.9103e-04 - mae: 0.0255 - mape: 1666.9504 - val_loss: 4.9033e-04 - val_mae: 0.0273 - val_mape: 155.6613
# Epoch 45/100
# 5/5 [==============================] - 1s 248ms/step - loss: 9.9850e-04 - mae: 0.0263 - mape: 1600.6736 - val_loss: 4.8083e-04 - val_mae: 0.0270 - val_mape: 154.1432
# Epoch 46/100
# 5/5 [==============================] - 1s 298ms/step - loss: 0.0011 - mae: 0.0255 - mape: 1692.5759 - val_loss: 4.6465e-04 - val_mae: 0.0265 - val_mape: 151.5418
# Epoch 47/100
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0011 - mae: 0.0266 - mape: 1721.9393 - val_loss: 5.4514e-04 - val_mae: 0.0291 - val_mape: 162.7008
# Epoch 48/100
# 5/5 [==============================] - 2s 338ms/step - loss: 0.0011 - mae: 0.0271 - mape: 1736.2860 - val_loss: 4.6983e-04 - val_mae: 0.0266 - val_mape: 151.6892
# Epoch 49/100
# 5/5 [==============================] - 2s 326ms/step - loss: 9.9234e-04 - mae: 0.0261 - mape: 1771.3064 - val_loss: 6.1656e-04 - val_mae: 0.0306 - val_mape: 170.0245
# Epoch 50/100
# 5/5 [==============================] - 2s 339ms/step - loss: 8.9521e-04 - mae: 0.0250 - mape: 1586.3242 - val_loss: 4.3626e-04 - val_mae: 0.0257 - val_mape: 148.4904
# Epoch 51/100
# 5/5 [==============================] - 2s 416ms/step - loss: 8.4124e-04 - mae: 0.0255 - mape: 1655.0811 - val_loss: 5.4685e-04 - val_mae: 0.0291 - val_mape: 163.1904
# Epoch 52/100
# 5/5 [==============================] - 1s 287ms/step - loss: 9.3844e-04 - mae: 0.0246 - mape: 1585.9398 - val_loss: 5.2802e-04 - val_mae: 0.0283 - val_mape: 158.3523
# Epoch 53/100
# 5/5 [==============================] - 2s 428ms/step - loss: 7.8876e-04 - mae: 0.0237 - mape: 1585.2926 - val_loss: 6.3080e-04 - val_mae: 0.0307 - val_mape: 169.1904
# Epoch 54/100
# 5/5 [==============================] - 1s 265ms/step - loss: 8.9698e-04 - mae: 0.0250 - mape: 1682.1727 - val_loss: 4.5345e-04 - val_mae: 0.0259 - val_mape: 148.3077
# Epoch 55/100
# 5/5 [==============================] - 1s 299ms/step - loss: 8.6059e-04 - mae: 0.0231 - mape: 1658.9185 - val_loss: 4.0075e-04 - val_mae: 0.0245 - val_mape: 141.7446
# Epoch 56/100
# 5/5 [==============================] - 1s 225ms/step - loss: 8.2878e-04 - mae: 0.0234 - mape: 1520.7328 - val_loss: 4.6955e-04 - val_mae: 0.0265 - val_mape: 150.2407
# Epoch 57/100
# 5/5 [==============================] - 1s 215ms/step - loss: 9.3479e-04 - mae: 0.0228 - mape: 1564.1831 - val_loss: 5.0961e-04 - val_mae: 0.0276 - val_mape: 154.7871
# Epoch 58/100
# 5/5 [==============================] - 1s 209ms/step - loss: 8.5887e-04 - mae: 0.0235 - mape: 1454.8176 - val_loss: 5.2567e-04 - val_mae: 0.0283 - val_mape: 158.2274
# Epoch 59/100
# 5/5 [==============================] - 1s 213ms/step - loss: 8.3687e-04 - mae: 0.0227 - mape: 1556.4561 - val_loss: 4.0608e-04 - val_mae: 0.0247 - val_mape: 142.5656
# Epoch 60/100
# 5/5 [==============================] - 1s 262ms/step - loss: 8.0265e-04 - mae: 0.0223 - mape: 1606.2269 - val_loss: 5.0099e-04 - val_mae: 0.0274 - val_mape: 154.9243
# Epoch 61/100
# 5/5 [==============================] - 1s 241ms/step - loss: 7.0992e-04 - mae: 0.0217 - mape: 1530.2378 - val_loss: 5.1638e-04 - val_mae: 0.0277 - val_mape: 155.2141
# Epoch 62/100
# 5/5 [==============================] - 1s 269ms/step - loss: 7.5562e-04 - mae: 0.0219 - mape: 1621.8503 - val_loss: 5.5585e-04 - val_mae: 0.0288 - val_mape: 160.2206
# Epoch 63/100
# 5/5 [==============================] - 1s 232ms/step - loss: 7.4626e-04 - mae: 0.0221 - mape: 1424.2576 - val_loss: 4.6889e-04 - val_mae: 0.0265 - val_mape: 150.0982
# Epoch 64/100
# 5/5 [==============================] - 1s 290ms/step - loss: 7.1583e-04 - mae: 0.0214 - mape: 1447.4128 - val_loss: 4.1695e-04 - val_mae: 0.0248 - val_mape: 142.3451
# Epoch 65/100
# 5/5 [==============================] - 2s 355ms/step - loss: 6.9523e-04 - mae: 0.0209 - mape: 1470.7872 - val_loss: 5.4500e-04 - val_mae: 0.0282 - val_mape: 157.3422
# Epoch 66/100
# 5/5 [==============================] - 1s 316ms/step - loss: 7.9007e-04 - mae: 0.0228 - mape: 1480.6742 - val_loss: 4.6762e-04 - val_mae: 0.0263 - val_mape: 148.7064
# Epoch 67/100
# 5/5 [==============================] - 1s 274ms/step - loss: 6.8862e-04 - mae: 0.0210 - mape: 1530.1573 - val_loss: 4.8453e-04 - val_mae: 0.0271 - val_mape: 152.1872
# Epoch 68/100
# 5/5 [==============================] - 1s 208ms/step - loss: 7.2637e-04 - mae: 0.0228 - mape: 1416.7657 - val_loss: 5.1260e-04 - val_mae: 0.0274 - val_mape: 152.9083
# Epoch 69/100
# 5/5 [==============================] - 1s 246ms/step - loss: 7.4584e-04 - mae: 0.0213 - mape: 1516.3434 - val_loss: 4.3794e-04 - val_mae: 0.0253 - val_mape: 143.1267
# Epoch 70/100
# 5/5 [==============================] - 1s 237ms/step - loss: 6.7225e-04 - mae: 0.0213 - mape: 1504.8657 - val_loss: 4.9124e-04 - val_mae: 0.0267 - val_mape: 149.4279
# Epoch 71/100
# 5/5 [==============================] - 1s 283ms/step - loss: 7.2358e-04 - mae: 0.0210 - mape: 1519.9927 - val_loss: 4.2879e-04 - val_mae: 0.0253 - val_mape: 143.2754
# Epoch 72/100
# 5/5 [==============================] - 1s 257ms/step - loss: 7.2039e-04 - mae: 0.0228 - mape: 1432.7372 - val_loss: 5.0997e-04 - val_mae: 0.0269 - val_mape: 150.1087
# Epoch 73/100
# 5/5 [==============================] - 1s 226ms/step - loss: 7.0367e-04 - mae: 0.0209 - mape: 1404.5508 - val_loss: 6.0007e-04 - val_mae: 0.0286 - val_mape: 157.2646
# Epoch 74/100
# 5/5 [==============================] - 1s 223ms/step - loss: 6.8763e-04 - mae: 0.0222 - mape: 1557.5215 - val_loss: 4.3709e-04 - val_mae: 0.0253 - val_mape: 142.7726
# Epoch 75/100
# 5/5 [==============================] - 1s 311ms/step - loss: 7.0678e-04 - mae: 0.0207 - mape: 1500.6093 - val_loss: 4.1474e-04 - val_mae: 0.0252 - val_mape: 144.1333
# Epoch 76/100
# 5/5 [==============================] - 1s 292ms/step - loss: 7.2957e-04 - mae: 0.0229 - mape: 1543.6254 - val_loss: 3.6182e-04 - val_mae: 0.0232 - val_mape: 135.1466
# Epoch 77/100
# 5/5 [==============================] - 1s 239ms/step - loss: 6.4741e-04 - mae: 0.0203 - mape: 1546.3750 - val_loss: 4.3267e-04 - val_mae: 0.0254 - val_mape: 143.7828
# Epoch 78/100
# 5/5 [==============================] - 1s 227ms/step - loss: 6.7854e-04 - mae: 0.0211 - mape: 1482.0870 - val_loss: 4.8240e-04 - val_mae: 0.0267 - val_mape: 148.8393
# Epoch 79/100
# 5/5 [==============================] - 1s 273ms/step - loss: 6.7489e-04 - mae: 0.0208 - mape: 1505.1075 - val_loss: 4.1465e-04 - val_mae: 0.0248 - val_mape: 140.7528
# Epoch 80/100
# 5/5 [==============================] - 1s 238ms/step - loss: 7.0704e-04 - mae: 0.0221 - mape: 1435.9033 - val_loss: 4.4004e-04 - val_mae: 0.0256 - val_mape: 144.2956
# Epoch 81/100
# 5/5 [==============================] - 1s 241ms/step - loss: 7.8044e-04 - mae: 0.0224 - mape: 1407.1023 - val_loss: 3.7000e-04 - val_mae: 0.0236 - val_mape: 136.2477
# Epoch 82/100
# 5/5 [==============================] - 2s 386ms/step - loss: 7.1785e-04 - mae: 0.0251 - mape: 2029.0043 - val_loss: 4.7779e-04 - val_mae: 0.0270 - val_mape: 150.6305
# Epoch 83/100
# 5/5 [==============================] - 1s 214ms/step - loss: 7.2509e-04 - mae: 0.0224 - mape: 1429.6641 - val_loss: 5.6950e-04 - val_mae: 0.0285 - val_mape: 156.4555
# Epoch 84/100
# 5/5 [==============================] - 2s 344ms/step - loss: 6.7498e-04 - mae: 0.0216 - mape: 1603.4445 - val_loss: 3.9129e-04 - val_mae: 0.0241 - val_mape: 137.5027
# Epoch 85/100
# 5/5 [==============================] - 2s 293ms/step - loss: 6.3545e-04 - mae: 0.0202 - mape: 1449.8508 - val_loss: 3.7590e-04 - val_mae: 0.0238 - val_mape: 136.5432
# Epoch 86/100
# 5/5 [==============================] - 2s 328ms/step - loss: 6.8228e-04 - mae: 0.0206 - mape: 1439.6129 - val_loss: 3.7380e-04 - val_mae: 0.0236 - val_mape: 135.6243
# Epoch 87/100
# 5/5 [==============================] - 2s 460ms/step - loss: 6.6135e-04 - mae: 0.0212 - mape: 1433.0282 - val_loss: 5.1994e-04 - val_mae: 0.0277 - val_mape: 152.6219
# Epoch 88/100
# 5/5 [==============================] - 1s 264ms/step - loss: 6.2054e-04 - mae: 0.0199 - mape: 1417.6514 - val_loss: 4.3011e-04 - val_mae: 0.0251 - val_mape: 141.8987
# Epoch 89/100
# 5/5 [==============================] - 2s 353ms/step - loss: 6.0031e-04 - mae: 0.0203 - mape: 1437.8877 - val_loss: 5.1241e-04 - val_mae: 0.0273 - val_mape: 151.7377
# Epoch 90/100
# 5/5 [==============================] - 2s 521ms/step - loss: 7.6161e-04 - mae: 0.0211 - mape: 1452.8441 - val_loss: 4.8325e-04 - val_mae: 0.0268 - val_mape: 149.2936
# Epoch 91/100
# 5/5 [==============================] - 1s 291ms/step - loss: 6.0633e-04 - mae: 0.0205 - mape: 1380.6501 - val_loss: 5.2412e-04 - val_mae: 0.0278 - val_mape: 153.6353
# Epoch 92/100
# 5/5 [==============================] - 2s 519ms/step - loss: 6.0246e-04 - mae: 0.0197 - mape: 1437.9753 - val_loss: 4.4652e-04 - val_mae: 0.0256 - val_mape: 144.2961
# Epoch 93/100
# 5/5 [==============================] - 1s 233ms/step - loss: 6.1405e-04 - mae: 0.0198 - mape: 1439.7437 - val_loss: 4.7107e-04 - val_mae: 0.0265 - val_mape: 147.8098
# Epoch 94/100
# 5/5 [==============================] - 1s 268ms/step - loss: 6.1483e-04 - mae: 0.0197 - mape: 1417.4515 - val_loss: 4.5303e-04 - val_mae: 0.0262 - val_mape: 146.4565
# Epoch 95/100
# 5/5 [==============================] - 2s 420ms/step - loss: 6.1527e-04 - mae: 0.0202 - mape: 1373.7168 - val_loss: 5.1199e-04 - val_mae: 0.0274 - val_mape: 152.0014
# Epoch 96/100
# 5/5 [==============================] - 2s 314ms/step - loss: 6.0448e-04 - mae: 0.0195 - mape: 1442.6427 - val_loss: 4.3492e-04 - val_mae: 0.0253 - val_mape: 142.8375
# Epoch 97/100
# 5/5 [==============================] - 1s 200ms/step - loss: 6.4037e-04 - mae: 0.0201 - mape: 1445.7369 - val_loss: 5.4626e-04 - val_mae: 0.0283 - val_mape: 155.9295
# Epoch 98/100
# 5/5 [==============================] - 2s 387ms/step - loss: 6.5491e-04 - mae: 0.0202 - mape: 1436.2463 - val_loss: 5.3733e-04 - val_mae: 0.0281 - val_mape: 154.7083
# Epoch 99/100
# 5/5 [==============================] - 1s 196ms/step - loss: 5.8971e-04 - mae: 0.0193 - mape: 1415.0555 - val_loss: 5.1093e-04 - val_mae: 0.0274 - val_mape: 151.7073
# Epoch 100/100
# 5/5 [==============================] - 1s 254ms/step - loss: 5.3017e-04 - mae: 0.0191 - mape: 1419.3206 - val_loss: 4.3104e-04 - val_mae: 0.0253 - val_mape: 142.8121
# Ejecutando la lstm
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 42s 2s/step - loss: 0.0074 - mae: 0.0825 - mape: 1411.4863 - val_loss: 5.2935e-04 - val_mae: 0.0232 - val_mape: 96.7972
# Epoch 2/100
# 5/5 [==============================] - 3s 586ms/step - loss: 0.0058 - mae: 0.0659 - mape: 1708.7725 - val_loss: 7.6919e-04 - val_mae: 0.0310 - val_mape: 166.0545
# Epoch 3/100
# 5/5 [==============================] - 3s 676ms/step - loss: 0.0048 - mae: 0.0606 - mape: 3108.9285 - val_loss: 0.0016 - val_mae: 0.0492 - val_mape: 271.8567
# Epoch 4/100
# 5/5 [==============================] - 4s 744ms/step - loss: 0.0046 - mae: 0.0645 - mape: 1994.9199 - val_loss: 0.0023 - val_mae: 0.0614 - val_mape: 333.9582
# Epoch 5/100
# 5/5 [==============================] - 4s 827ms/step - loss: 0.0046 - mae: 0.0668 - mape: 4407.8447 - val_loss: 0.0022 - val_mae: 0.0619 - val_mape: 334.6248
# Epoch 6/100
# 5/5 [==============================] - 4s 762ms/step - loss: 0.0042 - mae: 0.0642 - mape: 3076.1392 - val_loss: 0.0019 - val_mae: 0.0576 - val_mape: 311.7939
# Epoch 7/100
# 5/5 [==============================] - 4s 771ms/step - loss: 0.0039 - mae: 0.0607 - mape: 1693.9928 - val_loss: 0.0017 - val_mae: 0.0549 - val_mape: 296.8022
# Epoch 8/100
# 5/5 [==============================] - 3s 668ms/step - loss: 0.0035 - mae: 0.0583 - mape: 4827.8311 - val_loss: 0.0017 - val_mae: 0.0539 - val_mape: 289.6894
# Epoch 9/100
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0030 - mae: 0.0560 - mape: 2899.1289 - val_loss: 0.0015 - val_mae: 0.0505 - val_mape: 269.6216
# Epoch 10/100
# 5/5 [==============================] - 3s 529ms/step - loss: 0.0024 - mae: 0.0507 - mape: 2813.6196 - val_loss: 9.8743e-04 - val_mae: 0.0404 - val_mape: 217.8286
# Epoch 11/100
# 5/5 [==============================] - 3s 613ms/step - loss: 0.0034 - mae: 0.0466 - mape: 1474.4379 - val_loss: 4.8941e-04 - val_mae: 0.0255 - val_mape: 144.2769
# Epoch 12/100
# 5/5 [==============================] - 4s 842ms/step - loss: 0.0026 - mae: 0.0432 - mape: 1046.2188 - val_loss: 4.3354e-04 - val_mae: 0.0238 - val_mape: 134.2090
# Epoch 13/100
# 5/5 [==============================] - 3s 620ms/step - loss: 0.0020 - mae: 0.0373 - mape: 1616.6832 - val_loss: 8.1344e-04 - val_mae: 0.0367 - val_mape: 197.3339
# Epoch 14/100
# 5/5 [==============================] - 3s 476ms/step - loss: 0.0020 - mae: 0.0458 - mape: 1689.7103 - val_loss: 0.0014 - val_mae: 0.0494 - val_mape: 250.1650
# Epoch 15/100
# 5/5 [==============================] - 3s 571ms/step - loss: 0.0020 - mae: 0.0480 - mape: 3310.0229 - val_loss: 5.7178e-04 - val_mae: 0.0303 - val_mape: 165.2118
# Epoch 16/100
# 5/5 [==============================] - 4s 756ms/step - loss: 0.0015 - mae: 0.0343 - mape: 1537.0979 - val_loss: 3.4421e-04 - val_mae: 0.0218 - val_mape: 124.7558
# Epoch 17/100
# 5/5 [==============================] - 5s 815ms/step - loss: 9.7679e-04 - mae: 0.0282 - mape: 640.1846 - val_loss: 3.2647e-04 - val_mae: 0.0216 - val_mape: 122.4677
# Epoch 18/100
# 5/5 [==============================] - 4s 777ms/step - loss: 0.0010 - mae: 0.0300 - mape: 971.1153 - val_loss: 2.4766e-04 - val_mae: 0.0178 - val_mape: 103.0326
# Epoch 19/100
# 5/5 [==============================] - 4s 922ms/step - loss: 9.6623e-04 - mae: 0.0277 - mape: 1112.4191 - val_loss: 2.3214e-04 - val_mae: 0.0166 - val_mape: 93.4663
# Epoch 20/100
# 5/5 [==============================] - 4s 754ms/step - loss: 8.9041e-04 - mae: 0.0263 - mape: 1132.3247 - val_loss: 2.2900e-04 - val_mae: 0.0175 - val_mape: 100.6866
# Epoch 21/100
# 5/5 [==============================] - 4s 796ms/step - loss: 8.5801e-04 - mae: 0.0255 - mape: 1219.4010 - val_loss: 2.2850e-04 - val_mae: 0.0175 - val_mape: 100.9130
# Epoch 22/100
# 5/5 [==============================] - 3s 534ms/step - loss: 8.0051e-04 - mae: 0.0248 - mape: 1599.7437 - val_loss: 2.2759e-04 - val_mae: 0.0175 - val_mape: 100.8483
# Epoch 23/100
# 5/5 [==============================] - 3s 699ms/step - loss: 7.8374e-04 - mae: 0.0247 - mape: 1151.1329 - val_loss: 2.3017e-04 - val_mae: 0.0178 - val_mape: 102.4814
# Epoch 24/100
# 5/5 [==============================] - 3s 629ms/step - loss: 7.4951e-04 - mae: 0.0246 - mape: 1288.7830 - val_loss: 2.0320e-04 - val_mae: 0.0165 - val_mape: 94.9117
# Epoch 25/100
# 5/5 [==============================] - 3s 452ms/step - loss: 8.2022e-04 - mae: 0.0244 - mape: 1829.8868 - val_loss: 1.8802e-04 - val_mae: 0.0156 - val_mape: 89.4032
# Epoch 26/100
# 5/5 [==============================] - 2s 443ms/step - loss: 7.4684e-04 - mae: 0.0235 - mape: 846.1614 - val_loss: 1.8436e-04 - val_mae: 0.0154 - val_mape: 88.6076
# Epoch 27/100
# 5/5 [==============================] - 3s 495ms/step - loss: 7.1910e-04 - mae: 0.0228 - mape: 1891.4766 - val_loss: 1.8812e-04 - val_mae: 0.0157 - val_mape: 90.1539
# Epoch 28/100
# 5/5 [==============================] - 3s 514ms/step - loss: 6.4420e-04 - mae: 0.0225 - mape: 861.4636 - val_loss: 2.0294e-04 - val_mae: 0.0167 - val_mape: 96.6753
# Epoch 29/100
# 5/5 [==============================] - 2s 523ms/step - loss: 7.1854e-04 - mae: 0.0228 - mape: 1023.4279 - val_loss: 1.8523e-04 - val_mae: 0.0156 - val_mape: 90.6774
# Epoch 30/100
# 5/5 [==============================] - 2s 493ms/step - loss: 6.3616e-04 - mae: 0.0217 - mape: 1187.2534 - val_loss: 1.8093e-04 - val_mae: 0.0155 - val_mape: 90.1921
# Epoch 31/100
# 5/5 [==============================] - 3s 545ms/step - loss: 7.1075e-04 - mae: 0.0219 - mape: 836.7602 - val_loss: 1.7752e-04 - val_mae: 0.0152 - val_mape: 88.2889
# Epoch 32/100
# 5/5 [==============================] - 2s 480ms/step - loss: 6.5078e-04 - mae: 0.0216 - mape: 968.1866 - val_loss: 1.8230e-04 - val_mae: 0.0155 - val_mape: 90.8859
# Epoch 33/100
# 5/5 [==============================] - 3s 545ms/step - loss: 6.7629e-04 - mae: 0.0217 - mape: 1303.8553 - val_loss: 1.8380e-04 - val_mae: 0.0157 - val_mape: 92.3120
# Epoch 34/100
# 5/5 [==============================] - 2s 447ms/step - loss: 6.6832e-04 - mae: 0.0215 - mape: 957.7322 - val_loss: 1.7343e-04 - val_mae: 0.0150 - val_mape: 87.7466
# Epoch 35/100
# 5/5 [==============================] - 3s 567ms/step - loss: 6.2229e-04 - mae: 0.0208 - mape: 1183.3226 - val_loss: 1.6683e-04 - val_mae: 0.0147 - val_mape: 86.4518
# Epoch 36/100
# 5/5 [==============================] - 3s 491ms/step - loss: 6.5264e-04 - mae: 0.0211 - mape: 890.0822 - val_loss: 1.6609e-04 - val_mae: 0.0146 - val_mape: 85.2473
# Epoch 37/100
# 5/5 [==============================] - 2s 450ms/step - loss: 6.0310e-04 - mae: 0.0202 - mape: 1110.0520 - val_loss: 1.6850e-04 - val_mae: 0.0148 - val_mape: 87.3488
# Epoch 38/100
# 5/5 [==============================] - 3s 549ms/step - loss: 5.6786e-04 - mae: 0.0202 - mape: 1022.6759 - val_loss: 1.6932e-04 - val_mae: 0.0149 - val_mape: 88.0794
# Epoch 39/100
# 5/5 [==============================] - 4s 829ms/step - loss: 5.9421e-04 - mae: 0.0203 - mape: 922.6115 - val_loss: 1.6649e-04 - val_mae: 0.0147 - val_mape: 87.2085
# Epoch 40/100
# 5/5 [==============================] - 3s 495ms/step - loss: 6.1999e-04 - mae: 0.0202 - mape: 1493.5815 - val_loss: 1.6669e-04 - val_mae: 0.0146 - val_mape: 84.9154
# Epoch 41/100
# 5/5 [==============================] - 3s 570ms/step - loss: 5.3677e-04 - mae: 0.0196 - mape: 926.4521 - val_loss: 1.6596e-04 - val_mae: 0.0147 - val_mape: 87.2385
# Epoch 42/100
# 5/5 [==============================] - 4s 741ms/step - loss: 5.3347e-04 - mae: 0.0199 - mape: 1386.6355 - val_loss: 1.6848e-04 - val_mae: 0.0147 - val_mape: 86.6016
# Epoch 43/100
# 5/5 [==============================] - 3s 550ms/step - loss: 5.2418e-04 - mae: 0.0192 - mape: 1200.3130 - val_loss: 1.7286e-04 - val_mae: 0.0150 - val_mape: 89.8280
# Epoch 44/100
# 5/5 [==============================] - 3s 611ms/step - loss: 5.2087e-04 - mae: 0.0194 - mape: 1192.5686 - val_loss: 1.7296e-04 - val_mae: 0.0150 - val_mape: 88.5764
# Epoch 45/100
# 5/5 [==============================] - 3s 634ms/step - loss: 5.7034e-04 - mae: 0.0195 - mape: 970.6868 - val_loss: 1.7179e-04 - val_mae: 0.0150 - val_mape: 89.1184
# Epoch 46/100
# 5/5 [==============================] - 3s 501ms/step - loss: 5.7228e-04 - mae: 0.0196 - mape: 1100.0643 - val_loss: 1.7310e-04 - val_mae: 0.0150 - val_mape: 89.1899
# Epoch 47/100
# 5/5 [==============================] - 3s 514ms/step - loss: 5.3111e-04 - mae: 0.0194 - mape: 1606.2821 - val_loss: 1.7696e-04 - val_mae: 0.0152 - val_mape: 90.1363
# Epoch 48/100
# 5/5 [==============================] - 4s 914ms/step - loss: 5.2726e-04 - mae: 0.0189 - mape: 1266.6516 - val_loss: 1.7860e-04 - val_mae: 0.0153 - val_mape: 92.2529
# Epoch 49/100
# 5/5 [==============================] - 3s 528ms/step - loss: 5.0065e-04 - mae: 0.0191 - mape: 1124.4652 - val_loss: 1.7629e-04 - val_mae: 0.0152 - val_mape: 91.1365
# Epoch 50/100
# 5/5 [==============================] - 4s 742ms/step - loss: 4.9994e-04 - mae: 0.0190 - mape: 1115.1007 - val_loss: 1.8028e-04 - val_mae: 0.0152 - val_mape: 89.7126
# Epoch 51/100
# 5/5 [==============================] - 2s 380ms/step - loss: 5.3297e-04 - mae: 0.0187 - mape: 1056.3838 - val_loss: 1.8307e-04 - val_mae: 0.0156 - val_mape: 94.4091
# Epoch 52/100
# 5/5 [==============================] - 2s 336ms/step - loss: 5.4532e-04 - mae: 0.0193 - mape: 905.3307 - val_loss: 1.8566e-04 - val_mae: 0.0156 - val_mape: 93.0542
# Epoch 53/100
# 5/5 [==============================] - 3s 582ms/step - loss: 4.9140e-04 - mae: 0.0189 - mape: 1186.6368 - val_loss: 1.9731e-04 - val_mae: 0.0160 - val_mape: 94.4080
# Epoch 54/100
# 5/5 [==============================] - 4s 624ms/step - loss: 5.2678e-04 - mae: 0.0196 - mape: 1577.1052 - val_loss: 2.0855e-04 - val_mae: 0.0170 - val_mape: 102.1505
# Epoch 55/100
# 5/5 [==============================] - 4s 715ms/step - loss: 6.0668e-04 - mae: 0.0206 - mape: 1139.7004 - val_loss: 2.0163e-04 - val_mae: 0.0163 - val_mape: 98.0504
# Epoch 56/100
# 5/5 [==============================] - 3s 529ms/step - loss: 5.1500e-04 - mae: 0.0188 - mape: 1131.4263 - val_loss: 2.0436e-04 - val_mae: 0.0165 - val_mape: 99.2772
# Epoch 57/100
# 5/5 [==============================] - 3s 682ms/step - loss: 5.3611e-04 - mae: 0.0190 - mape: 1330.6003 - val_loss: 2.0878e-04 - val_mae: 0.0169 - val_mape: 102.6721
# Epoch 58/100
# 5/5 [==============================] - 3s 621ms/step - loss: 5.1703e-04 - mae: 0.0192 - mape: 1480.7129 - val_loss: 2.0456e-04 - val_mae: 0.0166 - val_mape: 99.7024
# Epoch 59/100
# 5/5 [==============================] - 2s 464ms/step - loss: 4.3606e-04 - mae: 0.0180 - mape: 1308.4473 - val_loss: 2.0171e-04 - val_mae: 0.0165 - val_mape: 99.6178
# Epoch 60/100
# 5/5 [==============================] - 3s 541ms/step - loss: 4.8729e-04 - mae: 0.0184 - mape: 1160.6202 - val_loss: 2.0125e-04 - val_mae: 0.0166 - val_mape: 100.1141
# Epoch 61/100
# 5/5 [==============================] - 3s 507ms/step - loss: 4.7505e-04 - mae: 0.0183 - mape: 961.0576 - val_loss: 1.9562e-04 - val_mae: 0.0161 - val_mape: 96.9866
# Epoch 62/100
# 5/5 [==============================] - 3s 564ms/step - loss: 4.8042e-04 - mae: 0.0182 - mape: 1359.3608 - val_loss: 1.9430e-04 - val_mae: 0.0161 - val_mape: 97.1424
# Epoch 63/100
# 5/5 [==============================] - 2s 392ms/step - loss: 4.8039e-04 - mae: 0.0179 - mape: 1156.4930 - val_loss: 1.9601e-04 - val_mae: 0.0162 - val_mape: 97.7695
# Epoch 64/100
# 5/5 [==============================] - 2s 427ms/step - loss: 4.5059e-04 - mae: 0.0178 - mape: 1287.0530 - val_loss: 1.9992e-04 - val_mae: 0.0165 - val_mape: 100.0334
# Epoch 65/100
# 5/5 [==============================] - 1s 293ms/step - loss: 4.4616e-04 - mae: 0.0179 - mape: 1091.9774 - val_loss: 1.9923e-04 - val_mae: 0.0162 - val_mape: 97.3481
# Epoch 66/100
# 5/5 [==============================] - 2s 453ms/step - loss: 5.0971e-04 - mae: 0.0184 - mape: 1133.2877 - val_loss: 1.9830e-04 - val_mae: 0.0163 - val_mape: 98.4190
# Epoch 67/100
# 5/5 [==============================] - 3s 501ms/step - loss: 4.3980e-04 - mae: 0.0176 - mape: 1110.4059 - val_loss: 2.0035e-04 - val_mae: 0.0165 - val_mape: 100.2312
# Epoch 68/100
# 5/5 [==============================] - 3s 621ms/step - loss: 5.2547e-04 - mae: 0.0188 - mape: 991.9370 - val_loss: 1.9828e-04 - val_mae: 0.0162 - val_mape: 98.2474
# Epoch 69/100
# 5/5 [==============================] - 3s 451ms/step - loss: 4.9087e-04 - mae: 0.0176 - mape: 1781.9919 - val_loss: 2.0593e-04 - val_mae: 0.0165 - val_mape: 98.8535
# Epoch 70/100
# 5/5 [==============================] - 2s 452ms/step - loss: 5.2928e-04 - mae: 0.0194 - mape: 1404.2611 - val_loss: 2.1655e-04 - val_mae: 0.0174 - val_mape: 105.0853
# Epoch 71/100
# 5/5 [==============================] - 2s 422ms/step - loss: 5.2632e-04 - mae: 0.0196 - mape: 1692.0939 - val_loss: 2.1304e-04 - val_mae: 0.0169 - val_mape: 101.0615
# Epoch 72/100
# 5/5 [==============================] - 3s 519ms/step - loss: 4.4435e-04 - mae: 0.0183 - mape: 1601.5638 - val_loss: 2.1439e-04 - val_mae: 0.0171 - val_mape: 104.2469
# Epoch 73/100
# 5/5 [==============================] - 2s 457ms/step - loss: 4.3718e-04 - mae: 0.0173 - mape: 1284.8629 - val_loss: 2.1033e-04 - val_mae: 0.0169 - val_mape: 102.6143
# Epoch 74/100
# 5/5 [==============================] - 2s 497ms/step - loss: 4.2355e-04 - mae: 0.0175 - mape: 1596.6188 - val_loss: 2.1367e-04 - val_mae: 0.0172 - val_mape: 104.3833
# Epoch 75/100
# 5/5 [==============================] - 2s 361ms/step - loss: 4.3120e-04 - mae: 0.0172 - mape: 1599.6058 - val_loss: 2.0676e-04 - val_mae: 0.0167 - val_mape: 100.6097
# Epoch 76/100
# 5/5 [==============================] - 3s 513ms/step - loss: 4.3527e-04 - mae: 0.0175 - mape: 1205.6399 - val_loss: 2.0748e-04 - val_mae: 0.0169 - val_mape: 102.3471
# Epoch 77/100
# 5/5 [==============================] - 2s 356ms/step - loss: 4.6590e-04 - mae: 0.0177 - mape: 1268.7168 - val_loss: 2.0529e-04 - val_mae: 0.0166 - val_mape: 100.2292
# Epoch 78/100
# 5/5 [==============================] - 3s 507ms/step - loss: 4.3751e-04 - mae: 0.0171 - mape: 1447.0579 - val_loss: 2.0651e-04 - val_mae: 0.0168 - val_mape: 102.0639
# Epoch 79/100
# 5/5 [==============================] - 2s 482ms/step - loss: 4.4876e-04 - mae: 0.0175 - mape: 871.0150 - val_loss: 2.0844e-04 - val_mae: 0.0168 - val_mape: 102.5774
# Epoch 80/100
# 5/5 [==============================] - 4s 588ms/step - loss: 3.9417e-04 - mae: 0.0171 - mape: 1146.4430 - val_loss: 2.1284e-04 - val_mae: 0.0169 - val_mape: 101.8253
# Epoch 81/100
# 5/5 [==============================] - 2s 418ms/step - loss: 4.2024e-04 - mae: 0.0174 - mape: 1142.7576 - val_loss: 2.1137e-04 - val_mae: 0.0170 - val_mape: 103.4615
# Epoch 82/100
# 5/5 [==============================] - 3s 605ms/step - loss: 4.3423e-04 - mae: 0.0175 - mape: 894.6641 - val_loss: 2.1358e-04 - val_mae: 0.0170 - val_mape: 102.9040
# Epoch 83/100
# 5/5 [==============================] - 3s 470ms/step - loss: 4.3543e-04 - mae: 0.0169 - mape: 1157.5902 - val_loss: 2.1446e-04 - val_mae: 0.0171 - val_mape: 104.0594
# Epoch 84/100
# 5/5 [==============================] - 2s 428ms/step - loss: 4.0763e-04 - mae: 0.0172 - mape: 1136.4020 - val_loss: 2.1596e-04 - val_mae: 0.0172 - val_mape: 104.9756
# Epoch 85/100
# 5/5 [==============================] - 2s 356ms/step - loss: 4.0466e-04 - mae: 0.0175 - mape: 1155.9301 - val_loss: 2.2482e-04 - val_mae: 0.0174 - val_mape: 103.1635
# Epoch 86/100
# 5/5 [==============================] - 3s 752ms/step - loss: 4.6999e-04 - mae: 0.0184 - mape: 1295.4933 - val_loss: 2.2242e-04 - val_mae: 0.0175 - val_mape: 106.6085
# Epoch 87/100
# 5/5 [==============================] - 3s 533ms/step - loss: 4.3879e-04 - mae: 0.0174 - mape: 1295.0886 - val_loss: 2.2345e-04 - val_mae: 0.0175 - val_mape: 106.4606
# Epoch 88/100
# 5/5 [==============================] - 3s 693ms/step - loss: 3.7281e-04 - mae: 0.0167 - mape: 1536.2959 - val_loss: 2.2569e-04 - val_mae: 0.0176 - val_mape: 106.8784
# Epoch 89/100
# 5/5 [==============================] - 3s 616ms/step - loss: 3.7498e-04 - mae: 0.0164 - mape: 1283.8491 - val_loss: 2.2619e-04 - val_mae: 0.0176 - val_mape: 107.4609
# Epoch 90/100
# 5/5 [==============================] - 2s 369ms/step - loss: 3.8143e-04 - mae: 0.0165 - mape: 1459.4380 - val_loss: 2.2798e-04 - val_mae: 0.0177 - val_mape: 107.5278
# Epoch 91/100
# 5/5 [==============================] - 3s 630ms/step - loss: 4.0669e-04 - mae: 0.0166 - mape: 1207.6433 - val_loss: 2.2982e-04 - val_mae: 0.0178 - val_mape: 107.9106
# Epoch 92/100
# 5/5 [==============================] - 3s 469ms/step - loss: 3.9227e-04 - mae: 0.0165 - mape: 1169.8611 - val_loss: 2.3160e-04 - val_mae: 0.0179 - val_mape: 108.2930
# Epoch 93/100
# 5/5 [==============================] - 4s 762ms/step - loss: 3.7921e-04 - mae: 0.0164 - mape: 1308.7418 - val_loss: 2.3188e-04 - val_mae: 0.0179 - val_mape: 109.1003
# Epoch 94/100
# 5/5 [==============================] - 4s 711ms/step - loss: 3.9813e-04 - mae: 0.0167 - mape: 1333.7410 - val_loss: 2.3421e-04 - val_mae: 0.0180 - val_mape: 109.2154
# Epoch 95/100
# 5/5 [==============================] - 4s 604ms/step - loss: 4.3274e-04 - mae: 0.0167 - mape: 1549.6704 - val_loss: 2.4052e-04 - val_mae: 0.0182 - val_mape: 109.6820
# Epoch 96/100
# 5/5 [==============================] - 2s 465ms/step - loss: 4.1939e-04 - mae: 0.0170 - mape: 1250.7651 - val_loss: 2.4047e-04 - val_mae: 0.0183 - val_mape: 111.5406
# Epoch 97/100
# 5/5 [==============================] - 2s 423ms/step - loss: 4.6430e-04 - mae: 0.0175 - mape: 1304.6589 - val_loss: 2.4748e-04 - val_mae: 0.0185 - val_mape: 111.1546
# Epoch 98/100
# 5/5 [==============================] - 3s 611ms/step - loss: 4.1361e-04 - mae: 0.0172 - mape: 1220.8337 - val_loss: 2.4418e-04 - val_mae: 0.0184 - val_mape: 112.3797
# Epoch 99/100
# 5/5 [==============================] - 3s 511ms/step - loss: 4.1252e-04 - mae: 0.0170 - mape: 1290.4926 - val_loss: 2.4542e-04 - val_mae: 0.0185 - val_mape: 112.8107
# Epoch 100/100
# 5/5 [==============================] - 3s 659ms/step - loss: 3.6410e-04 - mae: 0.0167 - mape: 1217.4652 - val_loss: 2.5370e-04 - val_mae: 0.0188 - val_mape: 112.7336
# Ejecutando la gru
# Prediction lookback (n_steps): 48
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 69s 3s/step - loss: 0.0071 - mae: 0.0806 - mape: 1313.5784 - val_loss: 5.0950e-04 - val_mae: 0.0229 - val_mape: 100.7752
# Epoch 2/100
# 5/5 [==============================] - 4s 782ms/step - loss: 0.0056 - mae: 0.0641 - mape: 722.8606 - val_loss: 8.8572e-04 - val_mae: 0.0342 - val_mape: 179.6328
# Epoch 3/100
# 5/5 [==============================] - 4s 774ms/step - loss: 0.0048 - mae: 0.0603 - mape: 395.0170 - val_loss: 0.0019 - val_mae: 0.0535 - val_mape: 283.3674
# Epoch 4/100
# 5/5 [==============================] - 4s 761ms/step - loss: 0.0045 - mae: 0.0645 - mape: 2127.9180 - val_loss: 0.0027 - val_mae: 0.0675 - val_mape: 354.0404
# Epoch 5/100
# 5/5 [==============================] - 4s 727ms/step - loss: 0.0045 - mae: 0.0683 - mape: 2648.6680 - val_loss: 0.0028 - val_mae: 0.0703 - val_mape: 369.4009
# Epoch 6/100
# 5/5 [==============================] - 4s 761ms/step - loss: 0.0043 - mae: 0.0669 - mape: 1843.4120 - val_loss: 0.0026 - val_mae: 0.0679 - val_mape: 359.2762
# Epoch 7/100
# 5/5 [==============================] - 3s 526ms/step - loss: 0.0039 - mae: 0.0629 - mape: 2134.2134 - val_loss: 0.0025 - val_mae: 0.0661 - val_mape: 350.4915
# Epoch 8/100
# 5/5 [==============================] - 3s 635ms/step - loss: 0.0034 - mae: 0.0591 - mape: 2432.7322 - val_loss: 0.0024 - val_mae: 0.0651 - val_mape: 343.6946
# Epoch 9/100
# 5/5 [==============================] - 5s 881ms/step - loss: 0.0030 - mae: 0.0561 - mape: 2821.6013 - val_loss: 0.0023 - val_mae: 0.0635 - val_mape: 332.6637
# Epoch 10/100
# 5/5 [==============================] - 3s 578ms/step - loss: 0.0028 - mae: 0.0533 - mape: 1391.2845 - val_loss: 0.0020 - val_mae: 0.0584 - val_mape: 305.6483
# Epoch 11/100
# 5/5 [==============================] - 4s 726ms/step - loss: 0.0023 - mae: 0.0482 - mape: 2069.5181 - val_loss: 0.0015 - val_mae: 0.0501 - val_mape: 263.8932
# Epoch 12/100
# 5/5 [==============================] - 4s 736ms/step - loss: 0.0018 - mae: 0.0419 - mape: 1956.9172 - val_loss: 0.0011 - val_mae: 0.0417 - val_mape: 221.8153
# Epoch 13/100
# 5/5 [==============================] - 4s 728ms/step - loss: 0.0014 - mae: 0.0364 - mape: 1395.7601 - val_loss: 7.0747e-04 - val_mae: 0.0330 - val_mape: 179.6095
# Epoch 14/100
# 5/5 [==============================] - 3s 571ms/step - loss: 0.0011 - mae: 0.0317 - mape: 899.4871 - val_loss: 4.2909e-04 - val_mae: 0.0248 - val_mape: 140.7745
# Epoch 15/100
# 5/5 [==============================] - 4s 736ms/step - loss: 9.6719e-04 - mae: 0.0280 - mape: 1236.7758 - val_loss: 3.2526e-04 - val_mae: 0.0213 - val_mape: 123.5831
# Epoch 16/100
# 5/5 [==============================] - 4s 713ms/step - loss: 9.8686e-04 - mae: 0.0270 - mape: 1753.3191 - val_loss: 3.0648e-04 - val_mae: 0.0209 - val_mape: 121.3890
# Epoch 17/100
# 5/5 [==============================] - 5s 1s/step - loss: 8.8192e-04 - mae: 0.0259 - mape: 1656.2302 - val_loss: 3.0652e-04 - val_mae: 0.0212 - val_mape: 122.5077
# Epoch 18/100
# 5/5 [==============================] - 4s 849ms/step - loss: 8.7721e-04 - mae: 0.0260 - mape: 1084.4055 - val_loss: 3.3445e-04 - val_mae: 0.0225 - val_mape: 128.1548
# Epoch 19/100
# 5/5 [==============================] - 5s 867ms/step - loss: 9.4263e-04 - mae: 0.0262 - mape: 1723.5970 - val_loss: 3.2202e-04 - val_mae: 0.0220 - val_mape: 126.1642
# Epoch 20/100
# 5/5 [==============================] - 3s 597ms/step - loss: 8.3011e-04 - mae: 0.0256 - mape: 1805.3687 - val_loss: 3.2817e-04 - val_mae: 0.0222 - val_mape: 126.9925
# Epoch 21/100
# 5/5 [==============================] - 5s 914ms/step - loss: 7.8287e-04 - mae: 0.0249 - mape: 1621.8489 - val_loss: 2.9648e-04 - val_mae: 0.0208 - val_mape: 120.9713
# Epoch 22/100
# 5/5 [==============================] - 5s 924ms/step - loss: 7.8782e-04 - mae: 0.0240 - mape: 1659.3121 - val_loss: 2.7685e-04 - val_mae: 0.0200 - val_mape: 117.1392
# Epoch 23/100
# 5/5 [==============================] - 3s 599ms/step - loss: 8.7270e-04 - mae: 0.0240 - mape: 1487.2211 - val_loss: 3.0549e-04 - val_mae: 0.0213 - val_mape: 123.1075
# Epoch 24/100
# 5/5 [==============================] - 2s 460ms/step - loss: 7.2846e-04 - mae: 0.0235 - mape: 1670.2488 - val_loss: 2.9422e-04 - val_mae: 0.0208 - val_mape: 121.2170
# Epoch 25/100
# 5/5 [==============================] - 4s 927ms/step - loss: 7.4016e-04 - mae: 0.0231 - mape: 1329.6980 - val_loss: 2.8082e-04 - val_mae: 0.0202 - val_mape: 118.7152
# Epoch 26/100
# 5/5 [==============================] - 3s 540ms/step - loss: 7.0626e-04 - mae: 0.0224 - mape: 1611.1533 - val_loss: 3.1598e-04 - val_mae: 0.0218 - val_mape: 125.6965
# Epoch 27/100
# 5/5 [==============================] - 3s 430ms/step - loss: 6.9991e-04 - mae: 0.0228 - mape: 1623.5188 - val_loss: 2.9929e-04 - val_mae: 0.0211 - val_mape: 122.5259
# Epoch 28/100
# 5/5 [==============================] - 4s 767ms/step - loss: 7.1424e-04 - mae: 0.0229 - mape: 1583.6536 - val_loss: 2.7040e-04 - val_mae: 0.0198 - val_mape: 116.4898
# Epoch 29/100
# 5/5 [==============================] - 4s 739ms/step - loss: 6.3280e-04 - mae: 0.0216 - mape: 1323.4233 - val_loss: 2.5896e-04 - val_mae: 0.0193 - val_mape: 114.0488
# Epoch 30/100
# 5/5 [==============================] - 5s 933ms/step - loss: 7.0905e-04 - mae: 0.0225 - mape: 1251.3213 - val_loss: 2.4614e-04 - val_mae: 0.0187 - val_mape: 111.4499
# Epoch 31/100
# 5/5 [==============================] - 3s 734ms/step - loss: 6.9418e-04 - mae: 0.0223 - mape: 1437.7981 - val_loss: 2.4190e-04 - val_mae: 0.0186 - val_mape: 110.9724
# Epoch 32/100
# 5/5 [==============================] - 4s 838ms/step - loss: 6.9037e-04 - mae: 0.0234 - mape: 1437.8552 - val_loss: 2.4144e-04 - val_mae: 0.0186 - val_mape: 110.9501
# Epoch 33/100
# 5/5 [==============================] - 3s 544ms/step - loss: 9.9753e-04 - mae: 0.0272 - mape: 1553.4431 - val_loss: 2.3941e-04 - val_mae: 0.0183 - val_mape: 109.2859
# Epoch 34/100
# 5/5 [==============================] - 4s 776ms/step - loss: 9.7093e-04 - mae: 0.0286 - mape: 1459.8773 - val_loss: 3.2766e-04 - val_mae: 0.0224 - val_mape: 128.2023
# Epoch 35/100
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0013 - mae: 0.0307 - mape: 1388.8489 - val_loss: 2.4414e-04 - val_mae: 0.0179 - val_mape: 104.6324
# Epoch 36/100
# 5/5 [==============================] - 4s 609ms/step - loss: 6.7482e-04 - mae: 0.0221 - mape: 1498.6224 - val_loss: 6.0949e-04 - val_mae: 0.0320 - val_mape: 168.9864
# Epoch 37/100
# 5/5 [==============================] - 3s 547ms/step - loss: 7.7328e-04 - mae: 0.0282 - mape: 1425.7294 - val_loss: 3.2374e-04 - val_mae: 0.0221 - val_mape: 128.4971
# Epoch 38/100
# 5/5 [==============================] - 3s 539ms/step - loss: 6.6777e-04 - mae: 0.0225 - mape: 1050.3615 - val_loss: 2.6388e-04 - val_mae: 0.0193 - val_mape: 114.9705
# Epoch 39/100
# 5/5 [==============================] - 3s 489ms/step - loss: 7.0146e-04 - mae: 0.0222 - mape: 1153.6785 - val_loss: 3.2799e-04 - val_mae: 0.0222 - val_mape: 128.3255
# Epoch 40/100
# 5/5 [==============================] - 2s 459ms/step - loss: 6.0461e-04 - mae: 0.0214 - mape: 1490.6517 - val_loss: 2.7431e-04 - val_mae: 0.0199 - val_mape: 118.3012
# Epoch 41/100
# 5/5 [==============================] - 2s 430ms/step - loss: 5.8953e-04 - mae: 0.0206 - mape: 1670.9432 - val_loss: 3.0326e-04 - val_mae: 0.0213 - val_mape: 123.9804
# Epoch 42/100
# 5/5 [==============================] - 4s 864ms/step - loss: 6.0277e-04 - mae: 0.0209 - mape: 1294.5632 - val_loss: 2.9035e-04 - val_mae: 0.0208 - val_mape: 121.1159
# Epoch 43/100
# 5/5 [==============================] - 3s 583ms/step - loss: 6.3471e-04 - mae: 0.0210 - mape: 1456.6722 - val_loss: 2.6043e-04 - val_mae: 0.0194 - val_mape: 114.6580
# Epoch 44/100
# 5/5 [==============================] - 2s 512ms/step - loss: 6.1137e-04 - mae: 0.0205 - mape: 1124.2168 - val_loss: 2.4443e-04 - val_mae: 0.0186 - val_mape: 110.8315
# Epoch 45/100
# 5/5 [==============================] - 3s 600ms/step - loss: 5.4622e-04 - mae: 0.0199 - mape: 1121.4568 - val_loss: 2.3312e-04 - val_mae: 0.0181 - val_mape: 108.1673
# Epoch 46/100
# 5/5 [==============================] - 3s 469ms/step - loss: 5.7740e-04 - mae: 0.0199 - mape: 1679.6938 - val_loss: 2.4253e-04 - val_mae: 0.0185 - val_mape: 110.3219
# Epoch 47/100
# 5/5 [==============================] - 3s 576ms/step - loss: 6.0313e-04 - mae: 0.0199 - mape: 1198.0342 - val_loss: 2.4980e-04 - val_mae: 0.0189 - val_mape: 112.0180
# Epoch 48/100
# 5/5 [==============================] - 2s 445ms/step - loss: 5.4689e-04 - mae: 0.0198 - mape: 1293.0579 - val_loss: 2.3685e-04 - val_mae: 0.0183 - val_mape: 109.3932
# Epoch 49/100
# 5/5 [==============================] - 3s 619ms/step - loss: 5.5078e-04 - mae: 0.0194 - mape: 1304.9795 - val_loss: 2.3067e-04 - val_mae: 0.0180 - val_mape: 108.0240
# Epoch 50/100
# 5/5 [==============================] - 3s 639ms/step - loss: 4.9306e-04 - mae: 0.0189 - mape: 1355.4628 - val_loss: 2.5570e-04 - val_mae: 0.0192 - val_mape: 113.3877
# Epoch 51/100
# 5/5 [==============================] - 2s 529ms/step - loss: 5.8498e-04 - mae: 0.0197 - mape: 1451.2644 - val_loss: 2.3730e-04 - val_mae: 0.0183 - val_mape: 109.3995
# Epoch 52/100
# 5/5 [==============================] - 2s 322ms/step - loss: 5.0697e-04 - mae: 0.0189 - mape: 1093.3507 - val_loss: 2.2883e-04 - val_mae: 0.0179 - val_mape: 107.4035
# Epoch 53/100
# 5/5 [==============================] - 3s 580ms/step - loss: 5.3919e-04 - mae: 0.0190 - mape: 1393.2275 - val_loss: 2.3399e-04 - val_mae: 0.0181 - val_mape: 108.4842
# Epoch 54/100
# 5/5 [==============================] - 3s 521ms/step - loss: 4.9990e-04 - mae: 0.0191 - mape: 1441.7792 - val_loss: 2.2917e-04 - val_mae: 0.0179 - val_mape: 107.4445
# Epoch 55/100
# 5/5 [==============================] - 3s 764ms/step - loss: 5.8172e-04 - mae: 0.0192 - mape: 1387.8000 - val_loss: 2.3749e-04 - val_mae: 0.0183 - val_mape: 109.3467
# Epoch 56/100
# 5/5 [==============================] - 3s 558ms/step - loss: 5.4107e-04 - mae: 0.0192 - mape: 1329.4963 - val_loss: 2.4569e-04 - val_mae: 0.0187 - val_mape: 111.0243
# Epoch 57/100
# 5/5 [==============================] - 4s 641ms/step - loss: 6.1456e-04 - mae: 0.0197 - mape: 1177.3843 - val_loss: 2.4337e-04 - val_mae: 0.0186 - val_mape: 110.4836
# Epoch 58/100
# 5/5 [==============================] - 3s 617ms/step - loss: 5.2392e-04 - mae: 0.0190 - mape: 1097.7026 - val_loss: 2.4372e-04 - val_mae: 0.0186 - val_mape: 110.3910
# Epoch 59/100
# 5/5 [==============================] - 3s 487ms/step - loss: 5.1164e-04 - mae: 0.0188 - mape: 1200.1176 - val_loss: 2.2095e-04 - val_mae: 0.0175 - val_mape: 105.2945
# Epoch 60/100
# 5/5 [==============================] - 4s 753ms/step - loss: 4.8261e-04 - mae: 0.0183 - mape: 1105.7291 - val_loss: 2.5002e-04 - val_mae: 0.0189 - val_mape: 111.9255
# Epoch 61/100
# 5/5 [==============================] - 3s 695ms/step - loss: 4.9430e-04 - mae: 0.0185 - mape: 1234.8533 - val_loss: 2.6353e-04 - val_mae: 0.0195 - val_mape: 115.0433
# Epoch 62/100
# 5/5 [==============================] - 2s 380ms/step - loss: 4.4600e-04 - mae: 0.0183 - mape: 1149.8479 - val_loss: 2.4881e-04 - val_mae: 0.0188 - val_mape: 111.8562
# Epoch 63/100
# 5/5 [==============================] - 3s 643ms/step - loss: 5.3920e-04 - mae: 0.0184 - mape: 1378.7819 - val_loss: 2.3873e-04 - val_mae: 0.0184 - val_mape: 109.4659
# Epoch 64/100
# 5/5 [==============================] - 4s 926ms/step - loss: 5.1768e-04 - mae: 0.0184 - mape: 1198.8617 - val_loss: 2.1546e-04 - val_mae: 0.0172 - val_mape: 104.2058
# Epoch 65/100
# 5/5 [==============================] - 6s 1s/step - loss: 4.6747e-04 - mae: 0.0179 - mape: 1563.4463 - val_loss: 2.4385e-04 - val_mae: 0.0186 - val_mape: 110.2206
# Epoch 66/100
# 5/5 [==============================] - 3s 727ms/step - loss: 5.0298e-04 - mae: 0.0189 - mape: 1102.7361 - val_loss: 2.1660e-04 - val_mae: 0.0172 - val_mape: 104.2334
# Epoch 67/100
# ...
# 5/5 [==============================] - 3s 657ms/step - loss: 0.0015 - mae: 0.0338 - mape: 1760.7588 - val_loss: 4.6456e-04 - val_mae: 0.0266 - val_mape: 152.6747
# Epoch 13/100
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0018 - mae: 0.0389 - mape: 1280.1770 - val_loss: 4.2626e-04 - val_mae: 0.0255 - val_mape: 147.6031
# Epoch 14/100
# 5/5 [==============================] - 1s 297ms/step - loss: 0.0029 - mae: 0.0442 - mape: 1127.8008 - val_loss: 4.4958e-04 - val_mae: 0.0245 - val_mape: 138.4405
# Epoch 15/100
# 5/5 [==============================] - 2s 495ms/step - loss: 0.0019 - mae: 0.0366 - mape: 1197.7966 - val_loss: 7.4755e-04 - val_mae: 0.0353 - val_mape: 198.8613
# Epoch 16/100
# 5/5 [==============================] - 1s 293ms/step - loss: 0.0013 - mae: 0.0374 - mape: 2672.6055 - val_loss: 0.0015 - val_mae: 0.0526 - val_mape: 267.2476
# Epoch 17/100
# 5/5 [==============================] - 3s 576ms/step - loss: 0.0016 - mae: 0.0444 - mape: 2427.2815 - val_loss: 7.6150e-04 - val_mae: 0.0357 - val_mape: 200.9326
# Epoch 18/100
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0013 - mae: 0.0333 - mape: 1667.8018 - val_loss: 5.9023e-04 - val_mae: 0.0306 - val_mape: 173.0820
# Epoch 19/100
# 5/5 [==============================] - 2s 480ms/step - loss: 0.0011 - mae: 0.0301 - mape: 1315.7184 - val_loss: 4.8679e-04 - val_mae: 0.0277 - val_mape: 158.7966
# Epoch 20/100
# 5/5 [==============================] - 2s 420ms/step - loss: 9.1883e-04 - mae: 0.0270 - mape: 1580.9387 - val_loss: 3.5069e-04 - val_mae: 0.0224 - val_mape: 128.1662
# Epoch 21/100
# 5/5 [==============================] - 3s 561ms/step - loss: 9.8969e-04 - mae: 0.0263 - mape: 1380.9717 - val_loss: 3.5145e-04 - val_mae: 0.0229 - val_mape: 132.2146
# Epoch 22/100
# 5/5 [==============================] - 2s 340ms/step - loss: 8.3506e-04 - mae: 0.0251 - mape: 1171.5426 - val_loss: 3.4896e-04 - val_mae: 0.0231 - val_mape: 133.2502
# Epoch 23/100
# 5/5 [==============================] - 2s 448ms/step - loss: 8.3964e-04 - mae: 0.0247 - mape: 2059.1953 - val_loss: 2.6378e-04 - val_mae: 0.0194 - val_mape: 112.0700
# Epoch 24/100
# 5/5 [==============================] - 1s 277ms/step - loss: 7.9551e-04 - mae: 0.0237 - mape: 1745.7515 - val_loss: 2.6033e-04 - val_mae: 0.0195 - val_mape: 112.6290
# Epoch 25/100
# 5/5 [==============================] - 1s 274ms/step - loss: 7.8675e-04 - mae: 0.0236 - mape: 1184.4565 - val_loss: 2.0670e-04 - val_mae: 0.0170 - val_mape: 97.6993
# Epoch 26/100
# 5/5 [==============================] - 4s 645ms/step - loss: 7.6872e-04 - mae: 0.0229 - mape: 463.8302 - val_loss: 2.1066e-04 - val_mae: 0.0171 - val_mape: 99.1521
# Epoch 27/100
# 5/5 [==============================] - 2s 470ms/step - loss: 6.9082e-04 - mae: 0.0221 - mape: 804.2378 - val_loss: 2.9509e-04 - val_mae: 0.0209 - val_mape: 122.7933
# Epoch 28/100
# 5/5 [==============================] - 1s 258ms/step - loss: 7.3573e-04 - mae: 0.0228 - mape: 1150.0188 - val_loss: 2.4600e-04 - val_mae: 0.0188 - val_mape: 110.5621
# Epoch 29/100
# 5/5 [==============================] - 1s 300ms/step - loss: 7.4091e-04 - mae: 0.0224 - mape: 757.7576 - val_loss: 2.1805e-04 - val_mae: 0.0175 - val_mape: 102.7544
# Epoch 30/100
# 5/5 [==============================] - 3s 766ms/step - loss: 7.3370e-04 - mae: 0.0222 - mape: 1458.9291 - val_loss: 2.6088e-04 - val_mae: 0.0195 - val_mape: 115.1386
# Epoch 31/100
# 5/5 [==============================] - 4s 791ms/step - loss: 7.1893e-04 - mae: 0.0221 - mape: 1347.3390 - val_loss: 1.7195e-04 - val_mae: 0.0152 - val_mape: 88.5245
# Epoch 32/100
# 5/5 [==============================] - 3s 637ms/step - loss: 6.3944e-04 - mae: 0.0214 - mape: 964.1866 - val_loss: 2.5746e-04 - val_mae: 0.0193 - val_mape: 114.6501
# Epoch 33/100
# 5/5 [==============================] - 2s 322ms/step - loss: 6.4237e-04 - mae: 0.0215 - mape: 777.2031 - val_loss: 2.2823e-04 - val_mae: 0.0180 - val_mape: 106.7247
# Epoch 34/100
# 5/5 [==============================] - 4s 567ms/step - loss: 6.5495e-04 - mae: 0.0214 - mape: 1046.5791 - val_loss: 2.0070e-04 - val_mae: 0.0167 - val_mape: 98.6199
# Epoch 35/100
# 5/5 [==============================] - 3s 796ms/step - loss: 6.7797e-04 - mae: 0.0211 - mape: 645.0856 - val_loss: 1.8538e-04 - val_mae: 0.0159 - val_mape: 94.0347
# Epoch 36/100
# 5/5 [==============================] - 4s 816ms/step - loss: 6.8504e-04 - mae: 0.0210 - mape: 857.2103 - val_loss: 2.0056e-04 - val_mae: 0.0166 - val_mape: 99.1223
# Epoch 37/100
# 5/5 [==============================] - 3s 725ms/step - loss: 5.9465e-04 - mae: 0.0208 - mape: 1130.2516 - val_loss: 1.9069e-04 - val_mae: 0.0162 - val_mape: 96.3260
# Epoch 38/100
# 5/5 [==============================] - 3s 680ms/step - loss: 5.8841e-04 - mae: 0.0203 - mape: 1141.5872 - val_loss: 1.4217e-04 - val_mae: 0.0136 - val_mape: 78.4492
# Epoch 39/100
# 5/5 [==============================] - 3s 435ms/step - loss: 6.1346e-04 - mae: 0.0204 - mape: 572.7505 - val_loss: 2.2680e-04 - val_mae: 0.0181 - val_mape: 107.4428
# Epoch 40/100
# 5/5 [==============================] - 1s 330ms/step - loss: 5.5859e-04 - mae: 0.0201 - mape: 1039.8102 - val_loss: 1.7433e-04 - val_mae: 0.0154 - val_mape: 91.1389
# Epoch 41/100
# 5/5 [==============================] - 2s 356ms/step - loss: 5.5688e-04 - mae: 0.0200 - mape: 460.7640 - val_loss: 1.2349e-04 - val_mae: 0.0125 - val_mape: 68.8789
# Epoch 42/100
# 5/5 [==============================] - 5s 853ms/step - loss: 7.0120e-04 - mae: 0.0213 - mape: 639.9926 - val_loss: 3.2193e-04 - val_mae: 0.0222 - val_mape: 129.8392
# Epoch 43/100
# 5/5 [==============================] - 3s 477ms/step - loss: 7.2053e-04 - mae: 0.0229 - mape: 2130.0452 - val_loss: 1.7288e-04 - val_mae: 0.0153 - val_mape: 90.1121
# Epoch 44/100
# 5/5 [==============================] - 1s 280ms/step - loss: 6.5895e-04 - mae: 0.0207 - mape: 682.9566 - val_loss: 1.7152e-04 - val_mae: 0.0153 - val_mape: 89.9389
# Epoch 45/100
# 5/5 [==============================] - 4s 609ms/step - loss: 5.6345e-04 - mae: 0.0200 - mape: 1161.5148 - val_loss: 1.2925e-04 - val_mae: 0.0129 - val_mape: 72.5940
# Epoch 46/100
# 5/5 [==============================] - 1s 306ms/step - loss: 6.1662e-04 - mae: 0.0213 - mape: 823.5483 - val_loss: 2.6289e-04 - val_mae: 0.0198 - val_mape: 116.7336
# Epoch 47/100
# 5/5 [==============================] - 2s 455ms/step - loss: 6.8241e-04 - mae: 0.0226 - mape: 1251.7556 - val_loss: 1.7852e-04 - val_mae: 0.0157 - val_mape: 92.8196
# Epoch 48/100
# 5/5 [==============================] - 3s 533ms/step - loss: 6.5355e-04 - mae: 0.0216 - mape: 1972.9056 - val_loss: 2.1667e-04 - val_mae: 0.0176 - val_mape: 104.7294
# Epoch 49/100
# 5/5 [==============================] - 3s 764ms/step - loss: 6.2358e-04 - mae: 0.0210 - mape: 1286.3346 - val_loss: 2.0342e-04 - val_mae: 0.0169 - val_mape: 100.7692
# Epoch 50/100
# 5/5 [==============================] - 3s 563ms/step - loss: 6.7947e-04 - mae: 0.0228 - mape: 1094.7965 - val_loss: 2.5129e-04 - val_mae: 0.0192 - val_mape: 113.9560
# Epoch 51/100
# 5/5 [==============================] - 4s 655ms/step - loss: 7.0908e-04 - mae: 0.0240 - mape: 1457.9688 - val_loss: 1.7684e-04 - val_mae: 0.0156 - val_mape: 92.1861
# Epoch 52/100
# 5/5 [==============================] - 2s 507ms/step - loss: 7.4047e-04 - mae: 0.0240 - mape: 1178.1742 - val_loss: 1.9030e-04 - val_mae: 0.0163 - val_mape: 96.1909
# Epoch 53/100
# 5/5 [==============================] - 3s 542ms/step - loss: 7.2584e-04 - mae: 0.0230 - mape: 1478.9368 - val_loss: 2.9799e-04 - val_mae: 0.0213 - val_mape: 124.9658
# Epoch 54/100
# 5/5 [==============================] - 2s 460ms/step - loss: 7.0545e-04 - mae: 0.0233 - mape: 1121.3792 - val_loss: 2.0038e-04 - val_mae: 0.0167 - val_mape: 98.1101
# Epoch 55/100
# 5/5 [==============================] - 2s 412ms/step - loss: 6.9113e-04 - mae: 0.0218 - mape: 1254.8074 - val_loss: 2.7980e-04 - val_mae: 0.0205 - val_mape: 119.9676
# Epoch 56/100
# 5/5 [==============================] - 4s 724ms/step - loss: 6.9084e-04 - mae: 0.0225 - mape: 1350.9910 - val_loss: 1.7690e-04 - val_mae: 0.0155 - val_mape: 90.2384
# Epoch 57/100
# 5/5 [==============================] - 2s 446ms/step - loss: 6.6885e-04 - mae: 0.0208 - mape: 1323.1719 - val_loss: 2.6641e-04 - val_mae: 0.0198 - val_mape: 116.4895
# Epoch 58/100
# 5/5 [==============================] - 2s 387ms/step - loss: 6.1352e-04 - mae: 0.0204 - mape: 1213.7679 - val_loss: 1.5866e-04 - val_mae: 0.0145 - val_mape: 83.7866
# Epoch 59/100
# 5/5 [==============================] - 2s 458ms/step - loss: 5.6357e-04 - mae: 0.0197 - mape: 992.1854 - val_loss: 2.4857e-04 - val_mae: 0.0189 - val_mape: 113.0468
# Epoch 60/100
# 5/5 [==============================] - 3s 780ms/step - loss: 5.6218e-04 - mae: 0.0199 - mape: 1083.3063 - val_loss: 2.2417e-04 - val_mae: 0.0178 - val_mape: 106.5769
# Epoch 61/100
# 5/5 [==============================] - 2s 474ms/step - loss: 4.9563e-04 - mae: 0.0191 - mape: 1461.6002 - val_loss: 2.2195e-04 - val_mae: 0.0177 - val_mape: 105.9796
# Epoch 62/100
# 5/5 [==============================] - 3s 470ms/step - loss: 5.2309e-04 - mae: 0.0191 - mape: 537.6740 - val_loss: 1.5996e-04 - val_mae: 0.0146 - val_mape: 85.9774
# Epoch 63/100
# 5/5 [==============================] - 3s 596ms/step - loss: 5.8476e-04 - mae: 0.0192 - mape: 667.0604 - val_loss: 2.0219e-04 - val_mae: 0.0168 - val_mape: 100.4538
# Epoch 64/100
# 5/5 [==============================] - 3s 491ms/step - loss: 5.4913e-04 - mae: 0.0194 - mape: 1368.7717 - val_loss: 2.1502e-04 - val_mae: 0.0174 - val_mape: 104.2445
# Epoch 65/100
# 5/5 [==============================] - 2s 315ms/step - loss: 4.9670e-04 - mae: 0.0191 - mape: 1481.7559 - val_loss: 1.3964e-04 - val_mae: 0.0135 - val_mape: 78.0776
# Epoch 66/100
# 5/5 [==============================] - 1s 283ms/step - loss: 5.5382e-04 - mae: 0.0201 - mape: 1297.0676 - val_loss: 2.3321e-04 - val_mae: 0.0183 - val_mape: 109.0861
# Epoch 67/100
# 5/5 [==============================] - 3s 600ms/step - loss: 5.5659e-04 - mae: 0.0200 - mape: 1284.9897 - val_loss: 1.6057e-04 - val_mae: 0.0146 - val_mape: 86.2100
# Epoch 68/100
# 5/5 [==============================] - 1s 262ms/step - loss: 5.6382e-04 - mae: 0.0203 - mape: 1077.1633 - val_loss: 2.5211e-04 - val_mae: 0.0192 - val_mape: 114.2511
# Epoch 69/100
# 5/5 [==============================] - 3s 694ms/step - loss: 5.2292e-04 - mae: 0.0210 - mape: 1821.3273 - val_loss: 1.5648e-04 - val_mae: 0.0145 - val_mape: 84.5596
# Epoch 70/100
# 5/5 [==============================] - 3s 715ms/step - loss: 7.0742e-04 - mae: 0.0231 - mape: 391.9441 - val_loss: 2.5655e-04 - val_mae: 0.0194 - val_mape: 115.1204
# Epoch 71/100
# 5/5 [==============================] - 3s 623ms/step - loss: 7.0839e-04 - mae: 0.0238 - mape: 1521.9032 - val_loss: 1.9584e-04 - val_mae: 0.0166 - val_mape: 98.1778
# Epoch 72/100
# 5/5 [==============================] - 2s 471ms/step - loss: 7.6347e-04 - mae: 0.0242 - mape: 1472.8312 - val_loss: 2.3207e-04 - val_mae: 0.0183 - val_mape: 108.4096
# Epoch 73/100
# 5/5 [==============================] - 3s 607ms/step - loss: 7.4178e-04 - mae: 0.0241 - mape: 1119.6467 - val_loss: 3.0150e-04 - val_mae: 0.0213 - val_mape: 125.9840
# Epoch 74/100
# 5/5 [==============================] - 3s 719ms/step - loss: 8.6395e-04 - mae: 0.0260 - mape: 1348.3563 - val_loss: 2.4574e-04 - val_mae: 0.0187 - val_mape: 110.7043
# Epoch 75/100
# 5/5 [==============================] - 2s 364ms/step - loss: 6.4369e-04 - mae: 0.0230 - mape: 1605.4423 - val_loss: 4.3917e-04 - val_mae: 0.0266 - val_mape: 151.7982
# Epoch 76/100
# 5/5 [==============================] - 3s 597ms/step - loss: 6.2318e-04 - mae: 0.0231 - mape: 989.1636 - val_loss: 1.5583e-04 - val_mae: 0.0142 - val_mape: 79.2296
# Epoch 77/100
# 5/5 [==============================] - 2s 385ms/step - loss: 6.4425e-04 - mae: 0.0210 - mape: 684.5639 - val_loss: 3.2265e-04 - val_mae: 0.0221 - val_mape: 130.3356
# Epoch 78/100
# 5/5 [==============================] - 3s 618ms/step - loss: 5.4688e-04 - mae: 0.0203 - mape: 1464.6000 - val_loss: 2.3338e-04 - val_mae: 0.0182 - val_mape: 108.7584
# Epoch 79/100
# 5/5 [==============================] - 3s 718ms/step - loss: 5.4890e-04 - mae: 0.0194 - mape: 1287.1721 - val_loss: 2.8482e-04 - val_mae: 0.0205 - val_mape: 122.0061
# Epoch 80/100
# 5/5 [==============================] - 3s 512ms/step - loss: 4.9562e-04 - mae: 0.0193 - mape: 1175.0332 - val_loss: 1.5497e-04 - val_mae: 0.0143 - val_mape: 82.4348
# Epoch 81/100
# 5/5 [==============================] - 2s 383ms/step - loss: 5.4119e-04 - mae: 0.0204 - mape: 1247.3317 - val_loss: 2.5080e-04 - val_mae: 0.0190 - val_mape: 113.8364
# Epoch 82/100
# 5/5 [==============================] - 2s 393ms/step - loss: 5.2850e-04 - mae: 0.0192 - mape: 1346.9600 - val_loss: 2.7844e-04 - val_mae: 0.0202 - val_mape: 120.6129
# Epoch 83/100
# 5/5 [==============================] - 2s 438ms/step - loss: 5.3302e-04 - mae: 0.0195 - mape: 837.5630 - val_loss: 2.2129e-04 - val_mae: 0.0176 - val_mape: 105.4483
# Epoch 84/100
# 5/5 [==============================] - 3s 531ms/step - loss: 5.6070e-04 - mae: 0.0196 - mape: 1017.6872 - val_loss: 1.8139e-04 - val_mae: 0.0157 - val_mape: 93.1317
# Epoch 85/100
# 5/5 [==============================] - 2s 497ms/step - loss: 5.1748e-04 - mae: 0.0195 - mape: 1354.1389 - val_loss: 2.1242e-04 - val_mae: 0.0172 - val_mape: 103.1510
# Epoch 86/100
# 5/5 [==============================] - 2s 401ms/step - loss: 4.9728e-04 - mae: 0.0193 - mape: 1202.8816 - val_loss: 2.4214e-04 - val_mae: 0.0187 - val_mape: 111.5694
# Epoch 87/100
# 5/5 [==============================] - 3s 659ms/step - loss: 5.9774e-04 - mae: 0.0201 - mape: 1367.6580 - val_loss: 1.9502e-04 - val_mae: 0.0164 - val_mape: 97.8970
# Epoch 88/100
# 5/5 [==============================] - 2s 372ms/step - loss: 5.4071e-04 - mae: 0.0190 - mape: 798.4686 - val_loss: 2.3252e-04 - val_mae: 0.0182 - val_mape: 109.1602
# Epoch 89/100
# 5/5 [==============================] - 3s 610ms/step - loss: 5.8191e-04 - mae: 0.0201 - mape: 866.7220 - val_loss: 2.3130e-04 - val_mae: 0.0181 - val_mape: 108.5601
# Epoch 90/100
# 5/5 [==============================] - 3s 617ms/step - loss: 4.7774e-04 - mae: 0.0191 - mape: 1262.2224 - val_loss: 2.6042e-04 - val_mae: 0.0194 - val_mape: 115.8761
# Epoch 91/100
# 5/5 [==============================] - 2s 439ms/step - loss: 5.2184e-04 - mae: 0.0193 - mape: 1547.8256 - val_loss: 1.8185e-04 - val_mae: 0.0157 - val_mape: 93.0653
# Epoch 92/100
# 5/5 [==============================] - 3s 610ms/step - loss: 4.7196e-04 - mae: 0.0187 - mape: 1082.8887 - val_loss: 2.2309e-04 - val_mae: 0.0177 - val_mape: 106.1622
# Epoch 93/100
# 5/5 [==============================] - 3s 734ms/step - loss: 5.4639e-04 - mae: 0.0195 - mape: 1443.1901 - val_loss: 2.6497e-04 - val_mae: 0.0196 - val_mape: 116.9846
# Epoch 94/100
# 5/5 [==============================] - 2s 434ms/step - loss: 4.4253e-04 - mae: 0.0193 - mape: 1661.3011 - val_loss: 2.2959e-04 - val_mae: 0.0181 - val_mape: 107.6463
# Epoch 95/100
# 5/5 [==============================] - 2s 331ms/step - loss: 5.2560e-04 - mae: 0.0192 - mape: 849.7296 - val_loss: 1.6790e-04 - val_mae: 0.0150 - val_mape: 87.5965
# Epoch 96/100
# 5/5 [==============================] - 2s 326ms/step - loss: 5.3735e-04 - mae: 0.0185 - mape: 1320.7870 - val_loss: 2.7674e-04 - val_mae: 0.0202 - val_mape: 119.8462
# Epoch 97/100
# 5/5 [==============================] - 4s 639ms/step - loss: 5.3457e-04 - mae: 0.0192 - mape: 1445.0942 - val_loss: 2.1139e-04 - val_mae: 0.0172 - val_mape: 102.8290
# Epoch 98/100
# 5/5 [==============================] - 3s 730ms/step - loss: 4.9301e-04 - mae: 0.0183 - mape: 1434.0607 - val_loss: 1.9780e-04 - val_mae: 0.0165 - val_mape: 98.9066
# Epoch 99/100
# 5/5 [==============================] - 3s 592ms/step - loss: 4.6875e-04 - mae: 0.0180 - mape: 1045.4053 - val_loss: 2.0857e-04 - val_mae: 0.0171 - val_mape: 102.3353
# Epoch 100/100
# 5/5 [==============================] - 5s 975ms/step - loss: 4.5859e-04 - mae: 0.0182 - mape: 1649.6511 - val_loss: 1.8113e-04 - val_mae: 0.0157 - val_mape: 93.7118
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>

# %%
# from tensorflow import keras
# for key, value in model_configs.items():
#     print(key, value)
#     model=value['model']
#     # file_data=os.path.join(s_prt_path,'experimental_files\DataModel_' + key + '_72l_24a_' + dt.datetime.now().strftime("%Y-%m-%d"))
#     file_data=os.path.join(s_prt_path,'experimental_files\\')
#     print(file_data)
#     # keras.experimental.export_saved_model(model, file_data)
#     model.save(file_data,save_format='tf')
#     break

# %%
# import pickle
# import datetime as dt
# file_data=os.path.join(s_prt_path,'experimental_files\DataModel_72l_24a_' + dt.datetime.now().strftime("%Y-%m-%d") + '.plk')

# #Save Data
# with open(file_data, 'wb') as file:
#     pickle.dump(model_configs, file)

# with open('tensor_data.pkl', 'rb') as file:
#     loaded_dict = pickle.load(file)

# print(loaded_dict)

# %%
# from tensorflow import keras
# import datetime as dt
# model_configs=dict()
# models=['dnn','lstm','gru','lstm_cnn']
# for i in range(4):
#     print(i)
#     file_data=os.path.join(s_prt_path,'experimental_files\\DataModel_' + models[i] + '_72l_24a_' + (dt.datetime.now()-dt.timedelta(days=1)).strftime("%Y-%m-%d") + '.h5')
#     print(file_data)
#     model = keras.models.load_model(file_data, compile=False, encoding='utf-8')
#     model_configs[models[i]]=model

# %% [markdown]
# #### Gráficas de entrenamiento modelo con ventanado

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,5))

metric='loss'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,5))

metric='mae'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %% [markdown]
# ##### Evaluar modelo con ventanado

# %%
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xtr= x.numpy()
    Ytr=y.numpy()
    break

for idx,(x,y) in enumerate(val_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xval= x.numpy()
    Yval=y.numpy()
    break

for idx,(x,y) in enumerate(test_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xts= x.numpy()
    Yts=y.numpy()
    break
# Out:
# Example sample shapes
# x =  (256, 48, 7)
# y =  (256, 24, 1)
# x =  (256, 48, 7)
# y =  (256, 24, 1)
# x =  (256, 48, 7)
# y =  (256, 24, 1)

# %%
models=['dnn','lstm','gru','cnn_lstm']
results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(3)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 1/1 [==============================] - 2s 2s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 0s 365ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 914ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 3s 3s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 1s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 1s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 53ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 0s 352ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# WARNING:tensorflow:5 out of the last 24 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000184965B8A40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 7s 7s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 755ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 529ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe.csv')
results.to_csv(file)

# %%
results
# Out:
#        Model   Tipo         MAE       MAPE      sMAPE        RMSE
# 0        dnn  Train   15.259766   8.301842   8.134571   17.798458
# 1        dnn    Val  161.190347  24.774451  29.425418  183.542264
# 2        dnn   Test   35.089201  25.590333  22.418040   36.860506
# 3       lstm  Train   19.856965  10.959895  11.873984   23.261879
# 4       lstm    Val  108.843603  17.176104  18.567980  119.977953
# 5       lstm   Test   24.758004  18.261235  16.461432   26.736478
# 6        gru  Train   20.584788  11.350472  12.358327   24.349462
# 7        gru    Val   72.898832  12.260010  12.340771   85.962143
# 8        gru   Test   17.097323  12.637547  11.631182   19.786872
# 9   cnn_lstm  Train   13.058250   7.280485   7.766902   17.513017
# 10  cnn_lstm    Val   82.956437  13.523406  14.015652   92.199599
# 11  cnn_lstm   Test    7.678625   5.637141   5.602547    9.365486

# %%
models=['dnn','lstm','gru','cnn_lstm']
results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
resultsYtestP={}
listP=[]
for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtr)
    Ye=scalerP.inverse_transform(Ytr.reshape(Ytr.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    #Evaluación de las X en validación
    Yp=model.predict(Xval)
    Ye=scalerP.inverse_transform(Yval.reshape(Yval.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    # Hacer pedicciones con el Xtest
    Yp=model.predict(Xts)
    Ye=scalerP.inverse_transform(Yts.reshape(Yts.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 8/8 [==============================] - 2s 6ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 4ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 4ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 34ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 48ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 45ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 40ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 33ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 35ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 12ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 13ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 19ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_21228\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)

# %%
results
# Out:
#        Model   Tipo        MAE       MAPE      sMAPE       RMSE
# 0        dnn  Train  33.900758  26.408260  20.633766  43.983384
# 1        dnn    Val  58.528870  43.543505  32.377569  72.222179
# 2        dnn   Test  68.463951  82.618337  52.456659  77.282279
# 3       lstm  Train  33.892677  24.564894  20.878221  45.421912
# 4       lstm    Val  41.557130  29.599537  25.124448  53.094370
# 5       lstm   Test  58.663985  71.521739  47.149196  67.812971
# 6        gru  Train  28.567258  22.011808  18.070697  37.612991
# 7        gru    Val  41.626987  31.963946  24.809970  53.209697
# 8        gru   Test  54.499798  66.974700  44.899503  63.397349
# 9   cnn_lstm  Train  25.068425  18.381467  15.863126  33.780832
# 10  cnn_lstm    Val  35.999100  26.346580  22.044237  47.227575
# 11  cnn_lstm   Test  43.142519  52.529136  37.879142  50.563399

# %% [markdown]
# ##### Gráfica del original y del pronóstico

# %%
fig, axs = plt.subplots(4, 1, figsize=(18, 10))
days = 3

vline = np.linspace(0, days*24, days+1)

for (key, val), ax in zip(model_configs_v.items(), axs):

    test = val['test_ds']
    preds = val['model'].predict(test)

    xbatch, ybatch = iter(test).get_next()

    Ye=ybatch.numpy()[:days].reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[:days].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    ax.plot(Ye)
    ax.plot(Yp)
    ax.set_title(key)
    ax.vlines(vline, ymin=0, ymax=1, linestyle='dotted', transform = ax.get_xaxis_transform())
    ax.legend(["Actual", "Predicted"])

plt.xlabel("Hours Cumulative")
print('First Two Weeks of Predictions')
# Out:
# 2/2 [==============================] - 3s 235ms/step
# 2/2 [==============================] - 6s 115ms/step
# 2/2 [==============================] - 5s 246ms/step
# 2/2 [==============================] - 7s 209ms/step
# First Two Weeks of Predictions

# %%
listreg=[i for i in range(3)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.engine.sequential.Sequential object at 0x00000184820B0C90>, 'history': <keras.callbacks.History object at 0x0000018482101990>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 1s 922ms/step
# lstm {'model': <keras.engine.sequential.Sequential object at 0x0000018481561010>, 'history': <keras.callbacks.History object at 0x00000184815AE610>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 441ms/step
# gru {'model': <keras.engine.sequential.Sequential object at 0x00000184808701D0>, 'history': <keras.callbacks.History object at 0x00000184815DB310>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 1s 850ms/step
# cnn_lstm {'model': <keras.engine.sequential.Sequential object at 0x00000184977A3AD0>, 'history': <keras.callbacks.History object at 0x0000018496FE5250>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 442ms/step
