# %% [markdown]
# #### Cargas las librerías

# %%
# Load Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
import os
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf

from evaluation._mae import MAE
from evaluation._smape import sMAPE
from evaluation._mape import MAPE
from evaluation._rmse import RMSE
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### Cargar dataset

# %%
s_path=Path.cwd()
s_prt_path=s_path.parent

file=os.path.join(s_prt_path,'datasets\XM_H_sinOfe.csv')
df_Data= pd.read_csv(file, index_col=0)
# df_Data.reset_index(inplace=True)

# %%
df_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52584 entries, 01/01/2013 0:00 to 31/12/2018 23:00
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PrecioB    52584 non-null  float64
#  1   Demanda    52584 non-null  float64
#  2   DispTer    52584 non-null  int64
#  3   DispNoTer  52584 non-null  int64
#  4   VolUtil    52584 non-null  int64
#  5   Aportes    52584 non-null  int64
#  6   day_cls    52584 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Funciones necesarias para las ejecuciones

# %% [markdown]
# ##### División de datos

# %%
# Dividir los datos en train, validación y test
def split_data(data, indexTotal, train_fraq, test_len=8760):

    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(data)-test_len

    test_data = data[test_slice:]
    indexTest=indexTotal[test_slice:]

    train_val_data = data[:test_slice]
    index_val_data=indexTotal[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    indexTrain=index_val_data[:train_size]

    val_data = train_val_data[train_size:]
    indexVal=index_val_data[train_size:]
    
    return train_data, val_data, test_data, indexTrain, indexVal, indexTest

# %% [markdown]
# ##### Construcción del dataset

# %%
# Crear los datos para entrar al modelo, definición de ventanas
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
    """ Create a windowed tensorflow dataset
    
    """

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
    
    #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    #ds = ds.shuffle(shuffle_buffer)
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    
    return ds

# Construcción del dataset usando las ventanas
def build_dataset(traindata,valdata,testdata,train_fraq=0.8, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
    """If multi variate then first column is always the column from which the target is contstructed.
    """
    
    tf.random.set_seed(23)
    
    
    train_ds = window_dataset(traindata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(valdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(testdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    
    
    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# ##### Parámetros y ejecución

# %%
# Definición de parámetros para la ejecución del modelo
def get_params(multivar=True):
    lr = 3e-4
    n_steps=24
    n_horizon=24
    if multivar:
        n_features=7
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

# Almacenamiento de los datos de las ejecuciones
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}

# Ejecuciones de los modelos con función de ventanado
def run_model(traindata,valdata,testdata,model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    
    train_ds, val_ds, test_ds = build_dataset(traindata,valdata,testdata,n_steps=n_steps, n_horizon=n_horizon, multi_var=True)

    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    # Define el early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=20)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=[early_stopping])

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    
    return test_ds

# %% [markdown]
# #### Modelos

# %% [markdown]
# ##### DNN

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 168)               0
#
#  dense (Dense)               (None, 128)               21632
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 41240 (161.09 KB)
# Trainable params: 41240 (161.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### LSTM

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 72)            23040
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55640 (217.34 KB)
# Trainable params: 55640 (217.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### GRU

# %%
def gru_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.GRU(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.GRU(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='gru')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

gru = gru_model(*get_params(multivar=True))
gru.summary()
# Out:
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 24, 72)            17496
#
#  gru_1 (GRU)                 (None, 48)                17568
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 44432 (173.56 KB)
# Trainable params: 44432 (173.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### CNN_LSTM

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 19, 64)            2752
#
#  max_pooling1d (MaxPooling1  (None, 9, 64)             0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 7, 64)             12352
#
#  max_pooling1d_1 (MaxPoolin  (None, 3, 64)             0
#  g1D)
#
#  lstm (LSTM)                 (None, 3, 72)             39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 87160 (340.47 KB)
# Trainable params: 87160 (340.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Escalamiento de los datos y división del dataset

# %%
#scale
scaler = MinMaxScaler(feature_range=(0, 1))
scalerP=MinMaxScaler(feature_range=(0, 1))

vec_precio=scalerP.fit_transform(df_Data.values[:,0].reshape(-1,1))

indexTotal=df_Data.index

multivar_df = scaler.fit_transform(df_Data)
train_multi, val_multi, test_multi, indexTrain, indexVal, indexTest = split_data(multivar_df,indexTotal, train_fraq=0.8, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
print('Precio',vec_precio.shape)
print('Todo',df_Data.shape)
# Out:
# Multivarate Datasets
# Train Data Shape: (35059, 7)
# Val Data Shape: (8765, 7)
# Test Data Shape: (8760, 7)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False
# Precio (52584, 1)
# Todo (52584, 7)

# %% [markdown]
# ##### Obtener dataset para el modelo utilizando la función de ventanado

# %%
n_steps=24
n_horizon=24

train_ds, val_ds, test_ds = build_dataset(train_multi, val_multi, test_multi,n_steps=n_steps, n_horizon=n_horizon,multi_var=True)
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Example sample shapes
# x =  (256, 24, 7)
# y =  (256, 24, 1)

# %% [markdown]
# ##### Ejecución de modelo con datos del ventanado

# %%
from sklearn.model_selection import KFold

model_configs_v = dict()
nepochs = 100

# Define the number of folds for cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits)

# Iterate over the folds
for fold, (train_index, val_index) in enumerate(kf.split(train_multi)):
    print(f"Fold {fold+1}/{n_splits}")
    
    # Get the training and validation data for the current fold
    fold_train_data = train_multi[train_index]
    fold_val_data = train_multi[val_index]
    
    print('Ejecutando la dnn')
    run_model(fold_train_data, fold_val_data, test_multi, "dnn", dnn_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la lstm')
    run_model(fold_train_data, fold_val_data, test_multi, "lstm", lstm_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la gru')
    run_model(fold_train_data, fold_val_data, test_multi, "gru", gru_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la cnn_lstm')
    run_model(fold_train_data, fold_val_data, test_multi, "cnn_lstm", lstm_cnn_model, model_configs_v, epochs=nepochs)
# Out:
# Fold 1/5
# Ejecutando la dnn
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0813 - mae: 0.3143 - mape: 16626.3750 - val_loss: 0.0061 - val_mae: 0.0902 - val_mape: 314.9594
# Epoch 2/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0226 - mae: 0.1650 - mape: 492.1913 - val_loss: 0.0028 - val_mae: 0.0588 - val_mape: 209.5006
# Epoch 3/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0116 - mae: 0.1136 - mape: 3599.2158 - val_loss: 0.0011 - val_mae: 0.0376 - val_mape: 132.6996
# Epoch 4/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0082 - mae: 0.0892 - mape: 3046.0537 - val_loss: 7.9582e-04 - val_mae: 0.0313 - val_mape: 102.0775
# Epoch 5/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0070 - mae: 0.0788 - mape: 3609.1953 - val_loss: 6.6499e-04 - val_mae: 0.0283 - val_mape: 91.3567
# Epoch 6/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0063 - mae: 0.0718 - mape: 2700.7300 - val_loss: 5.7473e-04 - val_mae: 0.0263 - val_mape: 89.5980
# Epoch 7/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0056 - mae: 0.0662 - mape: 3749.9722 - val_loss: 5.2527e-04 - val_mae: 0.0249 - val_mape: 98.6142
# Epoch 8/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0049 - mae: 0.0619 - mape: 1991.6796 - val_loss: 5.2690e-04 - val_mae: 0.0254 - val_mape: 114.5510
# Epoch 9/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0044 - mae: 0.0585 - mape: 995.4624 - val_loss: 4.6981e-04 - val_mae: 0.0240 - val_mape: 112.6257
# Epoch 10/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0037 - mae: 0.0538 - mape: 1744.9553 - val_loss: 4.9694e-04 - val_mae: 0.0249 - val_mape: 119.3513
# Epoch 11/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0032 - mae: 0.0505 - mape: 1856.6722 - val_loss: 5.3612e-04 - val_mae: 0.0260 - val_mape: 125.2994
# Epoch 12/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0028 - mae: 0.0468 - mape: 2297.6853 - val_loss: 5.1975e-04 - val_mae: 0.0253 - val_mape: 123.4275
# Epoch 13/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0024 - mae: 0.0428 - mape: 2414.4106 - val_loss: 5.3456e-04 - val_mae: 0.0255 - val_mape: 125.5109
# Epoch 14/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0022 - mae: 0.0406 - mape: 2980.1047 - val_loss: 5.3051e-04 - val_mae: 0.0254 - val_mape: 125.0011
# Epoch 15/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0019 - mae: 0.0384 - mape: 3282.3323 - val_loss: 4.1837e-04 - val_mae: 0.0223 - val_mape: 113.2477
# Epoch 16/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0016 - mae: 0.0352 - mape: 4036.1809 - val_loss: 3.7425e-04 - val_mae: 0.0212 - val_mape: 109.3603
# Epoch 17/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0016 - mae: 0.0344 - mape: 1418.9154 - val_loss: 3.2332e-04 - val_mae: 0.0196 - val_mape: 103.7669
# Epoch 18/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0015 - mae: 0.0329 - mape: 1748.6497 - val_loss: 3.2388e-04 - val_mae: 0.0199 - val_mape: 106.1544
# Epoch 19/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0014 - mae: 0.0322 - mape: 2226.3452 - val_loss: 3.0146e-04 - val_mae: 0.0191 - val_mape: 103.4216
# Epoch 20/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0013 - mae: 0.0309 - mape: 1738.6014 - val_loss: 2.8839e-04 - val_mae: 0.0186 - val_mape: 101.5464
# Epoch 21/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0013 - mae: 0.0305 - mape: 2261.0486 - val_loss: 2.8106e-04 - val_mae: 0.0183 - val_mape: 100.1795
# Epoch 22/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0013 - mae: 0.0302 - mape: 1691.4200 - val_loss: 3.0683e-04 - val_mae: 0.0195 - val_mape: 104.8551
# Epoch 23/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0013 - mae: 0.0304 - mape: 1818.2418 - val_loss: 2.9898e-04 - val_mae: 0.0191 - val_mape: 103.6317
# Epoch 24/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0012 - mae: 0.0293 - mape: 1417.5419 - val_loss: 2.8280e-04 - val_mae: 0.0186 - val_mape: 102.3078
# Epoch 25/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0014 - mae: 0.0297 - mape: 1445.3193 - val_loss: 2.3939e-04 - val_mae: 0.0167 - val_mape: 94.3426
# Epoch 26/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0012 - mae: 0.0284 - mape: 1825.4458 - val_loss: 3.0308e-04 - val_mae: 0.0200 - val_mape: 108.9014
# Epoch 27/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0013 - mae: 0.0308 - mape: 1424.7931 - val_loss: 2.4760e-04 - val_mae: 0.0172 - val_mape: 96.3934
# Epoch 28/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0012 - mae: 0.0281 - mape: 1261.5312 - val_loss: 2.9196e-04 - val_mae: 0.0189 - val_mape: 103.5354
# Epoch 29/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0012 - mae: 0.0283 - mape: 1099.2864 - val_loss: 2.4162e-04 - val_mae: 0.0170 - val_mape: 95.8793
# Epoch 30/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0011 - mae: 0.0273 - mape: 1337.5560 - val_loss: 2.6659e-04 - val_mae: 0.0185 - val_mape: 102.5806
# Epoch 31/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0010 - mae: 0.0277 - mape: 1483.9061 - val_loss: 2.5038e-04 - val_mae: 0.0175 - val_mape: 98.2178
# Epoch 32/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0011 - mae: 0.0265 - mape: 1454.3744 - val_loss: 2.4608e-04 - val_mae: 0.0172 - val_mape: 96.4268
# Epoch 33/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0011 - mae: 0.0269 - mape: 1708.8322 - val_loss: 3.1861e-04 - val_mae: 0.0205 - val_mape: 109.4708
# Epoch 34/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0010 - mae: 0.0265 - mape: 1835.7050 - val_loss: 2.3509e-04 - val_mae: 0.0168 - val_mape: 94.6900
# Epoch 35/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0011 - mae: 0.0264 - mape: 1283.3864 - val_loss: 3.1056e-04 - val_mae: 0.0203 - val_mape: 108.4512
# Epoch 36/100
# 5/5 [==============================] - 0s 45ms/step - loss: 9.5473e-04 - mae: 0.0261 - mape: 1709.8708 - val_loss: 2.3388e-04 - val_mae: 0.0167 - val_mape: 93.6778
# Epoch 37/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0010 - mae: 0.0259 - mape: 1490.8750 - val_loss: 2.7446e-04 - val_mae: 0.0188 - val_mape: 101.6586
# Epoch 38/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.0277e-04 - mae: 0.0259 - mape: 1753.3339 - val_loss: 2.4318e-04 - val_mae: 0.0171 - val_mape: 95.1813
# Epoch 39/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.9814e-04 - mae: 0.0251 - mape: 1568.5520 - val_loss: 3.6771e-04 - val_mae: 0.0224 - val_mape: 115.8836
# Epoch 40/100
# 5/5 [==============================] - 0s 47ms/step - loss: 9.4603e-04 - mae: 0.0254 - mape: 1864.6461 - val_loss: 2.2136e-04 - val_mae: 0.0161 - val_mape: 90.8511
# Epoch 41/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0010 - mae: 0.0253 - mape: 1872.4392 - val_loss: 2.7497e-04 - val_mae: 0.0186 - val_mape: 102.8302
# Epoch 42/100
# 5/5 [==============================] - 0s 47ms/step - loss: 9.8361e-04 - mae: 0.0265 - mape: 1755.8900 - val_loss: 2.7441e-04 - val_mae: 0.0185 - val_mape: 101.5826
# Epoch 43/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.9999e-04 - mae: 0.0253 - mape: 1931.2828 - val_loss: 3.3735e-04 - val_mae: 0.0216 - val_mape: 113.1633
# Epoch 44/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0010 - mae: 0.0255 - mape: 1391.8257 - val_loss: 2.9334e-04 - val_mae: 0.0198 - val_mape: 106.2787
# Epoch 45/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.9983e-04 - mae: 0.0250 - mape: 1469.8409 - val_loss: 3.0076e-04 - val_mae: 0.0197 - val_mape: 104.2977
# Epoch 46/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.2011e-04 - mae: 0.0237 - mape: 1452.6055 - val_loss: 2.6042e-04 - val_mae: 0.0177 - val_mape: 97.1898
# Epoch 47/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.8152e-04 - mae: 0.0236 - mape: 1253.7893 - val_loss: 2.5638e-04 - val_mae: 0.0180 - val_mape: 99.1096
# Epoch 48/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.9195e-04 - mae: 0.0234 - mape: 1423.8705 - val_loss: 2.1122e-04 - val_mae: 0.0160 - val_mape: 92.4697
# Epoch 49/100
# 5/5 [==============================] - 0s 45ms/step - loss: 8.4663e-04 - mae: 0.0230 - mape: 1661.8779 - val_loss: 2.3389e-04 - val_mae: 0.0173 - val_mape: 98.3628
# Epoch 50/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.3431e-04 - mae: 0.0235 - mape: 1567.5034 - val_loss: 2.3692e-04 - val_mae: 0.0174 - val_mape: 99.2009
# Epoch 51/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.7156e-04 - mae: 0.0230 - mape: 1367.1710 - val_loss: 2.5018e-04 - val_mae: 0.0181 - val_mape: 101.2022
# Epoch 52/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.5977e-04 - mae: 0.0225 - mape: 1246.6392 - val_loss: 2.9482e-04 - val_mae: 0.0202 - val_mape: 108.1255
# Epoch 53/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.4615e-04 - mae: 0.0233 - mape: 1474.0852 - val_loss: 2.3615e-04 - val_mae: 0.0172 - val_mape: 96.5585
# Epoch 54/100
# 5/5 [==============================] - 0s 49ms/step - loss: 8.1966e-04 - mae: 0.0227 - mape: 1450.2063 - val_loss: 2.1003e-04 - val_mae: 0.0158 - val_mape: 90.8809
# Epoch 55/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.8658e-04 - mae: 0.0225 - mape: 1240.7709 - val_loss: 2.6788e-04 - val_mae: 0.0187 - val_mape: 103.0035
# Epoch 56/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.3525e-04 - mae: 0.0225 - mape: 1532.9298 - val_loss: 2.4971e-04 - val_mae: 0.0178 - val_mape: 99.0247
# Epoch 57/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.0401e-04 - mae: 0.0217 - mape: 1277.8352 - val_loss: 3.0984e-04 - val_mae: 0.0204 - val_mape: 108.6292
# Epoch 58/100
# 5/5 [==============================] - 0s 51ms/step - loss: 7.1730e-04 - mae: 0.0221 - mape: 1298.0643 - val_loss: 2.9967e-04 - val_mae: 0.0197 - val_mape: 107.2093
# Epoch 59/100
# 5/5 [==============================] - 0s 48ms/step - loss: 7.5878e-04 - mae: 0.0222 - mape: 1345.8696 - val_loss: 2.3763e-04 - val_mae: 0.0171 - val_mape: 97.0491
# Epoch 60/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.1914e-04 - mae: 0.0222 - mape: 1078.2720 - val_loss: 2.9865e-04 - val_mae: 0.0203 - val_mape: 108.6140
# Epoch 61/100
# 5/5 [==============================] - 0s 54ms/step - loss: 7.7614e-04 - mae: 0.0226 - mape: 1392.4661 - val_loss: 2.2301e-04 - val_mae: 0.0167 - val_mape: 94.9358
# Epoch 62/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.3433e-04 - mae: 0.0217 - mape: 1413.1520 - val_loss: 3.5166e-04 - val_mae: 0.0222 - val_mape: 113.9790
# Epoch 63/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.0030e-04 - mae: 0.0219 - mape: 1837.3326 - val_loss: 3.4761e-04 - val_mae: 0.0215 - val_mape: 112.8827
# Epoch 64/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.6700e-04 - mae: 0.0223 - mape: 1567.2242 - val_loss: 2.3575e-04 - val_mae: 0.0170 - val_mape: 95.7799
# Epoch 65/100
# 5/5 [==============================] - 0s 51ms/step - loss: 7.1534e-04 - mae: 0.0215 - mape: 1294.3562 - val_loss: 3.0444e-04 - val_mae: 0.0206 - val_mape: 108.4873
# Epoch 66/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.2737e-04 - mae: 0.0215 - mape: 1723.9264 - val_loss: 2.7346e-04 - val_mae: 0.0189 - val_mape: 101.9635
# Epoch 67/100
# 5/5 [==============================] - 0s 48ms/step - loss: 6.9362e-04 - mae: 0.0216 - mape: 1541.5931 - val_loss: 2.2475e-04 - val_mae: 0.0164 - val_mape: 92.9063
# Epoch 68/100
# 5/5 [==============================] - 0s 45ms/step - loss: 6.9710e-04 - mae: 0.0216 - mape: 1275.5127 - val_loss: 3.5222e-04 - val_mae: 0.0226 - val_mape: 115.4446
# Epoch 69/100
# 5/5 [==============================] - 0s 45ms/step - loss: 6.8957e-04 - mae: 0.0223 - mape: 1152.5564 - val_loss: 2.2712e-04 - val_mae: 0.0170 - val_mape: 97.0401
# Epoch 70/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.5007e-04 - mae: 0.0230 - mape: 1203.3809 - val_loss: 5.3367e-04 - val_mae: 0.0291 - val_mape: 138.0928
# Epoch 71/100
# 5/5 [==============================] - 0s 46ms/step - loss: 6.8225e-04 - mae: 0.0229 - mape: 2140.2766 - val_loss: 2.0649e-04 - val_mae: 0.0158 - val_mape: 90.2906
# Epoch 72/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.0746e-04 - mae: 0.0217 - mape: 1368.6035 - val_loss: 1.7980e-04 - val_mae: 0.0146 - val_mape: 86.1224
# Epoch 73/100
# 5/5 [==============================] - 0s 46ms/step - loss: 6.8101e-04 - mae: 0.0219 - mape: 1348.9165 - val_loss: 2.3954e-04 - val_mae: 0.0180 - val_mape: 100.5404
# Epoch 74/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.3796e-04 - mae: 0.0212 - mape: 1264.7668 - val_loss: 2.2696e-04 - val_mae: 0.0172 - val_mape: 98.3346
# Epoch 75/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.0841e-04 - mae: 0.0216 - mape: 1380.4083 - val_loss: 3.4866e-04 - val_mae: 0.0227 - val_mape: 118.3643
# Epoch 76/100
# 5/5 [==============================] - 0s 48ms/step - loss: 7.0714e-04 - mae: 0.0220 - mape: 1897.8057 - val_loss: 2.6438e-04 - val_mae: 0.0190 - val_mape: 104.9354
# Epoch 77/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.7977e-04 - mae: 0.0211 - mape: 1808.1339 - val_loss: 1.8432e-04 - val_mae: 0.0148 - val_mape: 87.8872
# Epoch 78/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.1686e-04 - mae: 0.0210 - mape: 1099.9526 - val_loss: 2.9983e-04 - val_mae: 0.0206 - val_mape: 109.6712
# Epoch 79/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.7424e-04 - mae: 0.0223 - mape: 1240.9438 - val_loss: 2.2800e-04 - val_mae: 0.0171 - val_mape: 99.1487
# Epoch 80/100
# 5/5 [==============================] - 0s 45ms/step - loss: 6.7488e-04 - mae: 0.0213 - mape: 1472.4026 - val_loss: 4.3440e-04 - val_mae: 0.0259 - val_mape: 130.6266
# Epoch 81/100
# 5/5 [==============================] - 0s 45ms/step - loss: 6.5991e-04 - mae: 0.0218 - mape: 1394.2130 - val_loss: 2.5382e-04 - val_mae: 0.0182 - val_mape: 99.2808
# Epoch 82/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.3100e-04 - mae: 0.0213 - mape: 1306.7266 - val_loss: 2.2992e-04 - val_mae: 0.0169 - val_mape: 94.2091
# Epoch 83/100
# 5/5 [==============================] - 0s 53ms/step - loss: 6.1352e-04 - mae: 0.0195 - mape: 1386.3364 - val_loss: 2.4498e-04 - val_mae: 0.0178 - val_mape: 98.4292
# Epoch 84/100
# 5/5 [==============================] - 0s 46ms/step - loss: 5.9671e-04 - mae: 0.0195 - mape: 1203.0188 - val_loss: 3.0400e-04 - val_mae: 0.0209 - val_mape: 110.4376
# Epoch 85/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.5544e-04 - mae: 0.0197 - mape: 1233.3447 - val_loss: 2.4514e-04 - val_mae: 0.0182 - val_mape: 101.0289
# Epoch 86/100
# 5/5 [==============================] - 0s 45ms/step - loss: 5.6584e-04 - mae: 0.0193 - mape: 1276.3447 - val_loss: 2.0522e-04 - val_mae: 0.0161 - val_mape: 93.3812
# Epoch 87/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.0118e-04 - mae: 0.0196 - mape: 1189.3457 - val_loss: 2.4395e-04 - val_mae: 0.0181 - val_mape: 100.8126
# Epoch 88/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.8961e-04 - mae: 0.0194 - mape: 1343.3485 - val_loss: 1.9317e-04 - val_mae: 0.0154 - val_mape: 90.8176
# Epoch 89/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.3460e-04 - mae: 0.0194 - mape: 1171.0769 - val_loss: 2.1984e-04 - val_mae: 0.0168 - val_mape: 97.3924
# Epoch 90/100
# 5/5 [==============================] - 0s 48ms/step - loss: 6.1176e-04 - mae: 0.0198 - mape: 1335.9956 - val_loss: 2.5430e-04 - val_mae: 0.0186 - val_mape: 104.3282
# Epoch 91/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.0796e-04 - mae: 0.0186 - mape: 1296.3893 - val_loss: 2.1741e-04 - val_mae: 0.0168 - val_mape: 96.6090
# Epoch 92/100
# 5/5 [==============================] - 0s 46ms/step - loss: 5.6227e-04 - mae: 0.0192 - mape: 1306.0968 - val_loss: 2.0178e-04 - val_mae: 0.0160 - val_mape: 93.4201
# Ejecutando la lstm
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 3s 210ms/step - loss: 0.0076 - mae: 0.0823 - mape: 945.0164 - val_loss: 5.4341e-04 - val_mae: 0.0261 - val_mape: 77.7625
# Epoch 2/100
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0062 - mae: 0.0682 - mape: 477.7247 - val_loss: 3.7528e-04 - val_mae: 0.0210 - val_mape: 107.9286
# Epoch 3/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0052 - mae: 0.0641 - mape: 1718.6136 - val_loss: 7.0267e-04 - val_mae: 0.0319 - val_mape: 162.1985
# Epoch 4/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0048 - mae: 0.0653 - mape: 2799.3887 - val_loss: 7.6220e-04 - val_mae: 0.0343 - val_mape: 171.3127
# Epoch 5/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0045 - mae: 0.0622 - mape: 2835.9231 - val_loss: 6.7599e-04 - val_mae: 0.0323 - val_mape: 162.8456
# Epoch 6/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0043 - mae: 0.0597 - mape: 2250.5540 - val_loss: 6.8322e-04 - val_mae: 0.0327 - val_mape: 163.6900
# Epoch 7/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0041 - mae: 0.0580 - mape: 2967.9717 - val_loss: 7.8191e-04 - val_mae: 0.0355 - val_mape: 173.5354
# Epoch 8/100
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0038 - mae: 0.0564 - mape: 2595.4082 - val_loss: 8.6433e-04 - val_mae: 0.0378 - val_mape: 179.4378
# Epoch 9/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0034 - mae: 0.0531 - mape: 1908.1973 - val_loss: 9.0302e-04 - val_mae: 0.0385 - val_mape: 177.8244
# Epoch 10/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0027 - mae: 0.0483 - mape: 2266.3772 - val_loss: 0.0010 - val_mae: 0.0411 - val_mape: 180.8047
# Epoch 11/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0019 - mae: 0.0409 - mape: 2978.9202 - val_loss: 9.5441e-04 - val_mae: 0.0378 - val_mape: 162.0795
# Epoch 12/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0012 - mae: 0.0333 - mape: 2284.4521 - val_loss: 2.6844e-04 - val_mae: 0.0179 - val_mape: 89.2765
# Epoch 13/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0015 - mae: 0.0305 - mape: 1693.0778 - val_loss: 1.8970e-04 - val_mae: 0.0149 - val_mape: 75.1281
# Epoch 14/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0011 - mae: 0.0292 - mape: 1627.4342 - val_loss: 0.0010 - val_mae: 0.0376 - val_mape: 158.2015
# Epoch 15/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0010 - mae: 0.0302 - mape: 1576.6989 - val_loss: 2.8313e-04 - val_mae: 0.0187 - val_mape: 97.0302
# Epoch 16/100
# 5/5 [==============================] - 0s 88ms/step - loss: 9.9425e-04 - mae: 0.0265 - mape: 1169.6035 - val_loss: 3.4340e-04 - val_mae: 0.0206 - val_mape: 104.4038
# Epoch 17/100
# 5/5 [==============================] - 0s 92ms/step - loss: 8.7174e-04 - mae: 0.0257 - mape: 1016.6545 - val_loss: 2.1210e-04 - val_mae: 0.0159 - val_mape: 86.3224
# Epoch 18/100
# 5/5 [==============================] - 0s 88ms/step - loss: 8.0513e-04 - mae: 0.0246 - mape: 1082.0676 - val_loss: 2.2759e-04 - val_mae: 0.0167 - val_mape: 90.4575
# Epoch 19/100
# 5/5 [==============================] - 0s 79ms/step - loss: 7.2303e-04 - mae: 0.0236 - mape: 1781.6267 - val_loss: 3.0979e-04 - val_mae: 0.0200 - val_mape: 103.4990
# Epoch 20/100
# 5/5 [==============================] - 0s 86ms/step - loss: 7.6224e-04 - mae: 0.0234 - mape: 1683.2339 - val_loss: 3.3149e-04 - val_mae: 0.0208 - val_mape: 106.6472
# Epoch 21/100
# 5/5 [==============================] - 0s 76ms/step - loss: 7.3987e-04 - mae: 0.0233 - mape: 1457.4658 - val_loss: 2.0867e-04 - val_mae: 0.0159 - val_mape: 88.2283
# Epoch 22/100
# 5/5 [==============================] - 0s 92ms/step - loss: 7.7087e-04 - mae: 0.0227 - mape: 1534.8668 - val_loss: 2.8701e-04 - val_mae: 0.0188 - val_mape: 100.4890
# Epoch 23/100
# 5/5 [==============================] - 0s 89ms/step - loss: 6.3943e-04 - mae: 0.0219 - mape: 1063.2905 - val_loss: 1.9797e-04 - val_mae: 0.0154 - val_mape: 86.7161
# Epoch 24/100
# 5/5 [==============================] - 0s 89ms/step - loss: 6.7966e-04 - mae: 0.0217 - mape: 1383.7777 - val_loss: 2.1426e-04 - val_mae: 0.0162 - val_mape: 91.0610
# Epoch 25/100
# 5/5 [==============================] - 0s 75ms/step - loss: 6.7680e-04 - mae: 0.0212 - mape: 906.4791 - val_loss: 2.1473e-04 - val_mae: 0.0163 - val_mape: 92.4243
# Epoch 26/100
# 5/5 [==============================] - 0s 84ms/step - loss: 7.2043e-04 - mae: 0.0215 - mape: 1652.8842 - val_loss: 3.7886e-04 - val_mae: 0.0227 - val_mape: 116.0404
# Epoch 27/100
# 5/5 [==============================] - 0s 76ms/step - loss: 6.3519e-04 - mae: 0.0213 - mape: 1898.3081 - val_loss: 1.6180e-04 - val_mae: 0.0137 - val_mape: 78.1210
# Epoch 28/100
# 5/5 [==============================] - 0s 88ms/step - loss: 6.2859e-04 - mae: 0.0207 - mape: 767.7707 - val_loss: 2.2278e-04 - val_mae: 0.0166 - val_mape: 91.0232
# Epoch 29/100
# 5/5 [==============================] - 0s 78ms/step - loss: 5.5261e-04 - mae: 0.0200 - mape: 1072.1548 - val_loss: 3.0129e-04 - val_mae: 0.0201 - val_mape: 103.9717
# Epoch 30/100
# 5/5 [==============================] - 0s 77ms/step - loss: 6.8664e-04 - mae: 0.0214 - mape: 685.8122 - val_loss: 1.7164e-04 - val_mae: 0.0143 - val_mape: 81.4885
# Epoch 31/100
# 5/5 [==============================] - 0s 75ms/step - loss: 6.2577e-04 - mae: 0.0200 - mape: 1024.7019 - val_loss: 2.1437e-04 - val_mae: 0.0163 - val_mape: 90.4908
# Epoch 32/100
# 5/5 [==============================] - 0s 78ms/step - loss: 5.8307e-04 - mae: 0.0199 - mape: 803.8594 - val_loss: 2.2866e-04 - val_mae: 0.0171 - val_mape: 94.3300
# Epoch 33/100
# 5/5 [==============================] - 0s 85ms/step - loss: 5.9184e-04 - mae: 0.0199 - mape: 1157.3186 - val_loss: 2.6764e-04 - val_mae: 0.0186 - val_mape: 98.9947
# Epoch 34/100
# 5/5 [==============================] - 0s 82ms/step - loss: 5.6514e-04 - mae: 0.0197 - mape: 1328.2402 - val_loss: 1.5409e-04 - val_mae: 0.0134 - val_mape: 76.9437
# Epoch 35/100
# 5/5 [==============================] - 0s 77ms/step - loss: 5.4111e-04 - mae: 0.0194 - mape: 1211.2537 - val_loss: 2.8646e-04 - val_mae: 0.0196 - val_mape: 103.4230
# Epoch 36/100
# 5/5 [==============================] - 0s 82ms/step - loss: 5.9226e-04 - mae: 0.0195 - mape: 1026.8962 - val_loss: 2.0561e-04 - val_mae: 0.0160 - val_mape: 88.5573
# Epoch 37/100
# 5/5 [==============================] - 0s 78ms/step - loss: 5.2091e-04 - mae: 0.0191 - mape: 1266.8090 - val_loss: 1.3729e-04 - val_mae: 0.0126 - val_mape: 72.2573
# Epoch 38/100
# 5/5 [==============================] - 0s 84ms/step - loss: 5.1630e-04 - mae: 0.0193 - mape: 1112.2842 - val_loss: 3.5389e-04 - val_mae: 0.0223 - val_mape: 112.8633
# Epoch 39/100
# 5/5 [==============================] - 0s 96ms/step - loss: 5.6972e-04 - mae: 0.0200 - mape: 1124.3054 - val_loss: 1.4981e-04 - val_mae: 0.0133 - val_mape: 77.3372
# Epoch 40/100
# 5/5 [==============================] - 0s 97ms/step - loss: 5.7042e-04 - mae: 0.0193 - mape: 982.9598 - val_loss: 2.0482e-04 - val_mae: 0.0160 - val_mape: 89.1042
# Epoch 41/100
# 5/5 [==============================] - 1s 85ms/step - loss: 5.3364e-04 - mae: 0.0187 - mape: 1028.1664 - val_loss: 3.3254e-04 - val_mae: 0.0215 - val_mape: 107.9017
# Epoch 42/100
# 5/5 [==============================] - 0s 95ms/step - loss: 6.1595e-04 - mae: 0.0200 - mape: 1293.0411 - val_loss: 1.4194e-04 - val_mae: 0.0128 - val_mape: 71.4874
# Epoch 43/100
# 5/5 [==============================] - 0s 91ms/step - loss: 5.7528e-04 - mae: 0.0196 - mape: 1250.8945 - val_loss: 2.7339e-04 - val_mae: 0.0186 - val_mape: 99.5098
# Epoch 44/100
# 5/5 [==============================] - 0s 91ms/step - loss: 5.5256e-04 - mae: 0.0188 - mape: 1106.6267 - val_loss: 3.9389e-04 - val_mae: 0.0233 - val_mape: 118.0098
# Epoch 45/100
# 5/5 [==============================] - 0s 94ms/step - loss: 4.7907e-04 - mae: 0.0186 - mape: 1410.7809 - val_loss: 1.6079e-04 - val_mae: 0.0135 - val_mape: 77.7391
# Epoch 46/100
# 5/5 [==============================] - 0s 96ms/step - loss: 4.5752e-04 - mae: 0.0183 - mape: 1214.0186 - val_loss: 2.4900e-04 - val_mae: 0.0177 - val_mape: 95.9103
# Epoch 47/100
# 5/5 [==============================] - 0s 80ms/step - loss: 5.0472e-04 - mae: 0.0187 - mape: 1292.6063 - val_loss: 4.0092e-04 - val_mae: 0.0239 - val_mape: 117.2611
# Epoch 48/100
# 5/5 [==============================] - 0s 84ms/step - loss: 5.4749e-04 - mae: 0.0193 - mape: 994.2488 - val_loss: 1.3239e-04 - val_mae: 0.0122 - val_mape: 68.6074
# Epoch 49/100
# 5/5 [==============================] - 0s 80ms/step - loss: 5.1052e-04 - mae: 0.0189 - mape: 1101.3240 - val_loss: 1.6169e-04 - val_mae: 0.0137 - val_mape: 78.9846
# Epoch 50/100
# 5/5 [==============================] - 0s 84ms/step - loss: 5.2636e-04 - mae: 0.0194 - mape: 1174.9479 - val_loss: 6.8000e-04 - val_mae: 0.0327 - val_mape: 148.8321
# Epoch 51/100
# 5/5 [==============================] - 0s 83ms/step - loss: 5.4621e-04 - mae: 0.0197 - mape: 1522.6324 - val_loss: 1.3175e-04 - val_mae: 0.0122 - val_mape: 68.8197
# Epoch 52/100
# 5/5 [==============================] - 1s 109ms/step - loss: 5.1952e-04 - mae: 0.0192 - mape: 1332.2007 - val_loss: 2.1589e-04 - val_mae: 0.0162 - val_mape: 88.7024
# Epoch 53/100
# 5/5 [==============================] - 0s 85ms/step - loss: 4.4667e-04 - mae: 0.0177 - mape: 1325.7194 - val_loss: 3.5588e-04 - val_mae: 0.0224 - val_mape: 112.4135
# Epoch 54/100
# 5/5 [==============================] - 0s 79ms/step - loss: 4.7477e-04 - mae: 0.0184 - mape: 1579.5688 - val_loss: 2.1565e-04 - val_mae: 0.0163 - val_mape: 89.1578
# Epoch 55/100
# 5/5 [==============================] - 0s 95ms/step - loss: 4.7473e-04 - mae: 0.0180 - mape: 1191.6241 - val_loss: 1.3930e-04 - val_mae: 0.0126 - val_mape: 72.4452
# Epoch 56/100
# 5/5 [==============================] - 0s 93ms/step - loss: 4.6135e-04 - mae: 0.0181 - mape: 1138.2013 - val_loss: 3.5728e-04 - val_mae: 0.0218 - val_mape: 111.2712
# Epoch 57/100
# 5/5 [==============================] - 0s 89ms/step - loss: 4.2561e-04 - mae: 0.0178 - mape: 1174.7822 - val_loss: 2.9807e-04 - val_mae: 0.0193 - val_mape: 101.6468
# Epoch 58/100
# 5/5 [==============================] - 0s 80ms/step - loss: 4.7004e-04 - mae: 0.0177 - mape: 1173.9423 - val_loss: 1.3488e-04 - val_mae: 0.0122 - val_mape: 70.4646
# Epoch 59/100
# 5/5 [==============================] - 0s 83ms/step - loss: 4.4595e-04 - mae: 0.0176 - mape: 1128.2955 - val_loss: 2.7201e-04 - val_mae: 0.0187 - val_mape: 96.9342
# Epoch 60/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.4496e-04 - mae: 0.0175 - mape: 1140.1031 - val_loss: 2.0953e-04 - val_mae: 0.0162 - val_mape: 89.0609
# Epoch 61/100
# 5/5 [==============================] - 0s 91ms/step - loss: 3.9989e-04 - mae: 0.0170 - mape: 1137.8629 - val_loss: 2.5704e-04 - val_mae: 0.0182 - val_mape: 95.0297
# Epoch 62/100
# 5/5 [==============================] - 0s 89ms/step - loss: 4.2741e-04 - mae: 0.0172 - mape: 1167.5608 - val_loss: 1.3584e-04 - val_mae: 0.0125 - val_mape: 72.4594
# Epoch 63/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.4615e-04 - mae: 0.0177 - mape: 918.4626 - val_loss: 3.1283e-04 - val_mae: 0.0206 - val_mape: 104.2987
# Epoch 64/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.6258e-04 - mae: 0.0176 - mape: 1231.8448 - val_loss: 3.3739e-04 - val_mae: 0.0211 - val_mape: 103.2426
# Epoch 65/100
# 5/5 [==============================] - 0s 80ms/step - loss: 4.4784e-04 - mae: 0.0176 - mape: 1024.1576 - val_loss: 1.2039e-04 - val_mae: 0.0116 - val_mape: 63.9902
# Epoch 66/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.7738e-04 - mae: 0.0182 - mape: 1616.3865 - val_loss: 3.4853e-04 - val_mae: 0.0219 - val_mape: 104.9897
# Epoch 67/100
# 5/5 [==============================] - 0s 83ms/step - loss: 4.3530e-04 - mae: 0.0176 - mape: 1053.7129 - val_loss: 2.3817e-04 - val_mae: 0.0172 - val_mape: 90.3603
# Epoch 68/100
# 5/5 [==============================] - 0s 83ms/step - loss: 4.9073e-04 - mae: 0.0172 - mape: 1061.7303 - val_loss: 1.3612e-04 - val_mae: 0.0124 - val_mape: 72.3389
# Epoch 69/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.3600e-04 - mae: 0.0177 - mape: 1121.3053 - val_loss: 4.7419e-04 - val_mae: 0.0259 - val_mape: 120.6492
# Epoch 70/100
# 5/5 [==============================] - 0s 82ms/step - loss: 4.8002e-04 - mae: 0.0183 - mape: 1048.4744 - val_loss: 1.5271e-04 - val_mae: 0.0131 - val_mape: 74.3098
# Epoch 71/100
# 5/5 [==============================] - 0s 85ms/step - loss: 4.5961e-04 - mae: 0.0180 - mape: 1147.1179 - val_loss: 1.2266e-04 - val_mae: 0.0117 - val_mape: 66.1070
# Epoch 72/100
# 5/5 [==============================] - 0s 82ms/step - loss: 4.4017e-04 - mae: 0.0187 - mape: 1076.2523 - val_loss: 6.1067e-04 - val_mae: 0.0305 - val_mape: 139.0297
# Epoch 73/100
# 5/5 [==============================] - 0s 85ms/step - loss: 4.6437e-04 - mae: 0.0192 - mape: 1228.6797 - val_loss: 1.5667e-04 - val_mae: 0.0131 - val_mape: 76.2448
# Epoch 74/100
# 5/5 [==============================] - 0s 87ms/step - loss: 4.9112e-04 - mae: 0.0181 - mape: 1195.6013 - val_loss: 1.2866e-04 - val_mae: 0.0120 - val_mape: 69.0715
# Epoch 75/100
# 5/5 [==============================] - 0s 82ms/step - loss: 5.8380e-04 - mae: 0.0204 - mape: 1343.1721 - val_loss: 0.0011 - val_mae: 0.0417 - val_mape: 175.9702
# Epoch 76/100
# 5/5 [==============================] - 0s 80ms/step - loss: 4.9217e-04 - mae: 0.0204 - mape: 1358.2942 - val_loss: 1.4006e-04 - val_mae: 0.0126 - val_mape: 67.7521
# Epoch 77/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.8532e-04 - mae: 0.0194 - mape: 1034.5355 - val_loss: 2.2490e-04 - val_mae: 0.0157 - val_mape: 85.2567
# Epoch 78/100
# 5/5 [==============================] - 0s 80ms/step - loss: 4.1040e-04 - mae: 0.0175 - mape: 1132.7643 - val_loss: 1.6650e-04 - val_mae: 0.0140 - val_mape: 81.0253
# Epoch 79/100
# 5/5 [==============================] - 0s 82ms/step - loss: 4.2762e-04 - mae: 0.0178 - mape: 1120.8186 - val_loss: 5.1259e-04 - val_mae: 0.0270 - val_mape: 127.5404
# Epoch 80/100
# 5/5 [==============================] - 0s 94ms/step - loss: 4.2927e-04 - mae: 0.0182 - mape: 1418.7540 - val_loss: 1.5128e-04 - val_mae: 0.0133 - val_mape: 78.1040
# Epoch 81/100
# 5/5 [==============================] - 0s 82ms/step - loss: 4.3905e-04 - mae: 0.0176 - mape: 1205.3402 - val_loss: 1.7306e-04 - val_mae: 0.0141 - val_mape: 81.2159
# Epoch 82/100
# 5/5 [==============================] - 0s 80ms/step - loss: 4.2282e-04 - mae: 0.0171 - mape: 1079.0887 - val_loss: 2.0226e-04 - val_mae: 0.0154 - val_mape: 87.2621
# Epoch 83/100
# 5/5 [==============================] - 0s 79ms/step - loss: 4.1475e-04 - mae: 0.0171 - mape: 1085.9076 - val_loss: 3.5620e-04 - val_mae: 0.0214 - val_mape: 107.9326
# Epoch 84/100
# 5/5 [==============================] - 0s 80ms/step - loss: 3.9149e-04 - mae: 0.0169 - mape: 1183.2224 - val_loss: 1.3829e-04 - val_mae: 0.0125 - val_mape: 73.9420
# Epoch 85/100
# 5/5 [==============================] - 0s 81ms/step - loss: 4.2598e-04 - mae: 0.0171 - mape: 1001.0469 - val_loss: 1.7447e-04 - val_mae: 0.0145 - val_mape: 82.4014
# Ejecutando la gru
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 4s 215ms/step - loss: 0.0077 - mae: 0.0841 - mape: 654.7397 - val_loss: 6.2412e-04 - val_mae: 0.0264 - val_mape: 96.3177
# Epoch 2/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0059 - mae: 0.0683 - mape: 550.2778 - val_loss: 5.4364e-04 - val_mae: 0.0265 - val_mape: 128.3242
# Epoch 3/100
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0050 - mae: 0.0640 - mape: 4932.2646 - val_loss: 9.4836e-04 - val_mae: 0.0370 - val_mape: 179.8286
# Epoch 4/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0046 - mae: 0.0642 - mape: 2144.0432 - val_loss: 0.0012 - val_mae: 0.0431 - val_mape: 203.9845
# Epoch 5/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0043 - mae: 0.0622 - mape: 732.5899 - val_loss: 0.0011 - val_mae: 0.0424 - val_mape: 199.7471
# Epoch 6/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0039 - mae: 0.0582 - mape: 2808.2200 - val_loss: 0.0011 - val_mae: 0.0432 - val_mape: 201.2861
# Epoch 7/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0036 - mae: 0.0558 - mape: 4228.5684 - val_loss: 0.0014 - val_mae: 0.0482 - val_mape: 217.7285
# Epoch 8/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0034 - mae: 0.0545 - mape: 810.6321 - val_loss: 0.0016 - val_mae: 0.0515 - val_mape: 227.2875
# Epoch 9/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0029 - mae: 0.0514 - mape: 2564.1128 - val_loss: 0.0015 - val_mae: 0.0490 - val_mape: 214.5850
# Epoch 10/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0025 - mae: 0.0463 - mape: 2297.7048 - val_loss: 0.0015 - val_mae: 0.0498 - val_mape: 213.0887
# Epoch 11/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0020 - mae: 0.0419 - mape: 1420.1719 - val_loss: 0.0017 - val_mae: 0.0526 - val_mape: 215.8283
# Epoch 12/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0016 - mae: 0.0373 - mape: 2601.9395 - val_loss: 0.0012 - val_mae: 0.0424 - val_mape: 173.8746
# Epoch 13/100
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0012 - mae: 0.0316 - mape: 2068.7354 - val_loss: 7.4526e-04 - val_mae: 0.0318 - val_mape: 134.5937
# Epoch 14/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0011 - mae: 0.0291 - mape: 1166.0485 - val_loss: 4.2543e-04 - val_mae: 0.0230 - val_mape: 105.1001
# Epoch 15/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0010 - mae: 0.0284 - mape: 1125.5217 - val_loss: 9.2947e-04 - val_mae: 0.0363 - val_mape: 147.6071
# Epoch 16/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0010 - mae: 0.0284 - mape: 1253.2551 - val_loss: 3.5756e-04 - val_mae: 0.0210 - val_mape: 101.6055
# Epoch 17/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0012 - mae: 0.0305 - mape: 1242.9158 - val_loss: 9.7799e-04 - val_mae: 0.0380 - val_mape: 157.0594
# Epoch 18/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0011 - mae: 0.0309 - mape: 1011.3455 - val_loss: 7.0685e-04 - val_mae: 0.0315 - val_mape: 138.5756
# Epoch 19/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0011 - mae: 0.0282 - mape: 1089.8329 - val_loss: 6.9449e-04 - val_mae: 0.0312 - val_mape: 138.3321
# Epoch 20/100
# 5/5 [==============================] - 0s 71ms/step - loss: 8.5158e-04 - mae: 0.0264 - mape: 1047.7574 - val_loss: 0.0012 - val_mae: 0.0431 - val_mape: 173.7970
# Epoch 21/100
# 5/5 [==============================] - 0s 75ms/step - loss: 8.3817e-04 - mae: 0.0261 - mape: 1697.3392 - val_loss: 5.6937e-04 - val_mae: 0.0277 - val_mape: 126.1027
# Epoch 22/100
# 5/5 [==============================] - 0s 74ms/step - loss: 7.8589e-04 - mae: 0.0242 - mape: 1212.8030 - val_loss: 8.0953e-04 - val_mae: 0.0342 - val_mape: 145.5950
# Epoch 23/100
# 5/5 [==============================] - 0s 71ms/step - loss: 7.6608e-04 - mae: 0.0246 - mape: 1745.0994 - val_loss: 7.1211e-04 - val_mae: 0.0317 - val_mape: 138.0273
# Epoch 24/100
# 5/5 [==============================] - 0s 72ms/step - loss: 7.6579e-04 - mae: 0.0238 - mape: 1896.5645 - val_loss: 7.2128e-04 - val_mae: 0.0319 - val_mape: 139.4623
# Epoch 25/100
# 5/5 [==============================] - 0s 72ms/step - loss: 7.7489e-04 - mae: 0.0240 - mape: 1234.8761 - val_loss: 9.1286e-04 - val_mae: 0.0366 - val_mape: 155.1630
# Epoch 26/100
# 5/5 [==============================] - 0s 76ms/step - loss: 7.7429e-04 - mae: 0.0237 - mape: 987.4202 - val_loss: 6.7948e-04 - val_mae: 0.0307 - val_mape: 137.0184
# Epoch 27/100
# 5/5 [==============================] - 0s 73ms/step - loss: 7.3165e-04 - mae: 0.0229 - mape: 1142.4714 - val_loss: 9.2205e-04 - val_mae: 0.0369 - val_mape: 158.7460
# Epoch 28/100
# 5/5 [==============================] - 0s 73ms/step - loss: 6.9869e-04 - mae: 0.0231 - mape: 1716.9589 - val_loss: 6.7025e-04 - val_mae: 0.0305 - val_mape: 137.5067
# Epoch 29/100
# 5/5 [==============================] - 0s 72ms/step - loss: 7.3587e-04 - mae: 0.0226 - mape: 1458.1880 - val_loss: 0.0010 - val_mae: 0.0396 - val_mape: 167.6915
# Epoch 30/100
# 5/5 [==============================] - 0s 71ms/step - loss: 6.7775e-04 - mae: 0.0230 - mape: 1535.8921 - val_loss: 4.8635e-04 - val_mae: 0.0250 - val_mape: 117.9610
# Epoch 31/100
# 5/5 [==============================] - 0s 73ms/step - loss: 6.6525e-04 - mae: 0.0216 - mape: 1250.0387 - val_loss: 8.9211e-04 - val_mae: 0.0363 - val_mape: 156.9224
# Epoch 32/100
# 5/5 [==============================] - 0s 73ms/step - loss: 6.7411e-04 - mae: 0.0225 - mape: 1385.8534 - val_loss: 4.1000e-04 - val_mae: 0.0228 - val_mape: 111.6794
# Epoch 33/100
# 5/5 [==============================] - 0s 77ms/step - loss: 7.4661e-04 - mae: 0.0230 - mape: 1110.7236 - val_loss: 0.0012 - val_mae: 0.0444 - val_mape: 184.5333
# Epoch 34/100
# 5/5 [==============================] - 0s 72ms/step - loss: 7.0074e-04 - mae: 0.0243 - mape: 1717.1644 - val_loss: 3.5014e-04 - val_mae: 0.0208 - val_mape: 104.9198
# Epoch 35/100
# 5/5 [==============================] - 0s 75ms/step - loss: 8.0612e-04 - mae: 0.0247 - mape: 1010.2839 - val_loss: 0.0012 - val_mae: 0.0429 - val_mape: 178.3712
# Epoch 36/100
# 5/5 [==============================] - 0s 74ms/step - loss: 7.6707e-04 - mae: 0.0253 - mape: 1450.4728 - val_loss: 3.4004e-04 - val_mae: 0.0205 - val_mape: 103.1450
# Epoch 37/100
# 5/5 [==============================] - 0s 92ms/step - loss: 8.7047e-04 - mae: 0.0255 - mape: 1162.8409 - val_loss: 8.6934e-04 - val_mae: 0.0357 - val_mape: 155.0973
# Epoch 38/100
# 5/5 [==============================] - 0s 83ms/step - loss: 8.0422e-04 - mae: 0.0252 - mape: 1985.8826 - val_loss: 4.0388e-04 - val_mae: 0.0227 - val_mape: 111.9826
# Epoch 39/100
# 5/5 [==============================] - 0s 92ms/step - loss: 8.0297e-04 - mae: 0.0243 - mape: 1090.3710 - val_loss: 5.8409e-04 - val_mae: 0.0285 - val_mape: 132.8600
# Epoch 40/100
# 5/5 [==============================] - 0s 76ms/step - loss: 7.5345e-04 - mae: 0.0240 - mape: 1494.9445 - val_loss: 7.3509e-04 - val_mae: 0.0329 - val_mape: 147.3637
# Epoch 41/100
# 5/5 [==============================] - 0s 82ms/step - loss: 6.6369e-04 - mae: 0.0214 - mape: 1153.6826 - val_loss: 5.1127e-04 - val_mae: 0.0265 - val_mape: 126.2933
# Epoch 42/100
# 5/5 [==============================] - 0s 72ms/step - loss: 5.8614e-04 - mae: 0.0210 - mape: 1073.3613 - val_loss: 7.2759e-04 - val_mae: 0.0325 - val_mape: 145.8574
# Epoch 43/100
# 5/5 [==============================] - 0s 81ms/step - loss: 5.9237e-04 - mae: 0.0207 - mape: 1631.7400 - val_loss: 3.6480e-04 - val_mae: 0.0216 - val_mape: 109.0490
# Epoch 44/100
# 5/5 [==============================] - 0s 87ms/step - loss: 5.3685e-04 - mae: 0.0200 - mape: 1175.5144 - val_loss: 6.7256e-04 - val_mae: 0.0312 - val_mape: 143.5482
# Epoch 45/100
# 5/5 [==============================] - 0s 79ms/step - loss: 5.6159e-04 - mae: 0.0205 - mape: 1675.6290 - val_loss: 5.7151e-04 - val_mae: 0.0283 - val_mape: 134.2241
# Epoch 46/100
# 5/5 [==============================] - 0s 80ms/step - loss: 5.7532e-04 - mae: 0.0201 - mape: 1183.5642 - val_loss: 6.4658e-04 - val_mae: 0.0305 - val_mape: 141.1836
# Epoch 47/100
# 5/5 [==============================] - 0s 77ms/step - loss: 5.4282e-04 - mae: 0.0198 - mape: 1558.0049 - val_loss: 5.7715e-04 - val_mae: 0.0284 - val_mape: 133.1216
# Epoch 48/100
# 5/5 [==============================] - 0s 89ms/step - loss: 5.8558e-04 - mae: 0.0199 - mape: 1200.5173 - val_loss: 4.6585e-04 - val_mae: 0.0250 - val_mape: 120.9381
# Epoch 49/100
# 5/5 [==============================] - 0s 74ms/step - loss: 5.2811e-04 - mae: 0.0195 - mape: 1247.0608 - val_loss: 6.6394e-04 - val_mae: 0.0309 - val_mape: 141.4513
# Epoch 50/100
# 5/5 [==============================] - 0s 71ms/step - loss: 5.5144e-04 - mae: 0.0195 - mape: 913.9129 - val_loss: 5.2366e-04 - val_mae: 0.0269 - val_mape: 126.8342
# Epoch 51/100
# 5/5 [==============================] - 0s 75ms/step - loss: 5.2302e-04 - mae: 0.0191 - mape: 1195.2400 - val_loss: 4.9615e-04 - val_mae: 0.0261 - val_mape: 124.5002
# Epoch 52/100
# 5/5 [==============================] - 0s 72ms/step - loss: 5.1767e-04 - mae: 0.0193 - mape: 1113.9247 - val_loss: 4.6985e-04 - val_mae: 0.0254 - val_mape: 122.6461
# Epoch 53/100
# 5/5 [==============================] - 0s 77ms/step - loss: 5.2195e-04 - mae: 0.0187 - mape: 1256.1071 - val_loss: 4.9377e-04 - val_mae: 0.0261 - val_mape: 125.8120
# Epoch 54/100
# 5/5 [==============================] - 0s 72ms/step - loss: 5.4031e-04 - mae: 0.0188 - mape: 1061.8851 - val_loss: 5.1697e-04 - val_mae: 0.0267 - val_mape: 127.9432
# Epoch 55/100
# 5/5 [==============================] - 0s 74ms/step - loss: 5.3623e-04 - mae: 0.0188 - mape: 1194.9749 - val_loss: 4.3481e-04 - val_mae: 0.0241 - val_mape: 118.2817
# Epoch 56/100
# 5/5 [==============================] - 0s 72ms/step - loss: 4.7227e-04 - mae: 0.0185 - mape: 1311.7933 - val_loss: 4.1993e-04 - val_mae: 0.0236 - val_mape: 116.4393
# Ejecutando la cnn_lstm
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 4s 238ms/step - loss: 0.0076 - mae: 0.0834 - mape: 168.2353 - val_loss: 4.4639e-04 - val_mae: 0.0233 - val_mape: 66.9752
# Epoch 2/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0057 - mae: 0.0645 - mape: 2000.1866 - val_loss: 4.5319e-04 - val_mae: 0.0245 - val_mape: 124.0793
# Epoch 3/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0048 - mae: 0.0639 - mape: 2462.6704 - val_loss: 9.8786e-04 - val_mae: 0.0404 - val_mape: 187.9345
# Epoch 4/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0046 - mae: 0.0648 - mape: 2612.1978 - val_loss: 8.7231e-04 - val_mae: 0.0378 - val_mape: 179.8776
# Epoch 5/100
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0044 - mae: 0.0615 - mape: 1814.4214 - val_loss: 7.2800e-04 - val_mae: 0.0341 - val_mape: 166.8143
# Epoch 6/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0043 - mae: 0.0589 - mape: 2336.2747 - val_loss: 7.2620e-04 - val_mae: 0.0344 - val_mape: 167.0421
# Epoch 7/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0041 - mae: 0.0580 - mape: 2306.7097 - val_loss: 8.2169e-04 - val_mae: 0.0371 - val_mape: 176.3395
# Epoch 8/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0040 - mae: 0.0581 - mape: 3424.3887 - val_loss: 9.0586e-04 - val_mae: 0.0394 - val_mape: 183.0265
# Epoch 9/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0037 - mae: 0.0575 - mape: 3121.3943 - val_loss: 8.8079e-04 - val_mae: 0.0388 - val_mape: 178.9333
# Epoch 10/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0034 - mae: 0.0543 - mape: 2445.3225 - val_loss: 8.2731e-04 - val_mae: 0.0374 - val_mape: 171.8676
# Epoch 11/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0027 - mae: 0.0491 - mape: 2565.0999 - val_loss: 8.0526e-04 - val_mae: 0.0364 - val_mape: 165.3150
# Epoch 12/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0020 - mae: 0.0426 - mape: 2417.8164 - val_loss: 4.6251e-04 - val_mae: 0.0261 - val_mape: 128.1355
# Epoch 13/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0012 - mae: 0.0330 - mape: 2046.2644 - val_loss: 1.9147e-04 - val_mae: 0.0146 - val_mape: 82.6985
# Epoch 14/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0013 - mae: 0.0288 - mape: 1571.8239 - val_loss: 2.0434e-04 - val_mae: 0.0144 - val_mape: 77.4781
# Epoch 15/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0013 - mae: 0.0308 - mape: 957.4187 - val_loss: 2.9974e-04 - val_mae: 0.0202 - val_mape: 107.9502
# Epoch 16/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0012 - mae: 0.0325 - mape: 1414.5114 - val_loss: 2.0466e-04 - val_mae: 0.0151 - val_mape: 84.8821
# Epoch 17/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0015 - mae: 0.0330 - mape: 1303.9320 - val_loss: 2.0932e-04 - val_mae: 0.0161 - val_mape: 93.2549
# Epoch 18/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0010 - mae: 0.0296 - mape: 2152.8401 - val_loss: 2.2971e-04 - val_mae: 0.0173 - val_mape: 97.6136
# Epoch 19/100
# 5/5 [==============================] - 0s 60ms/step - loss: 8.6379e-04 - mae: 0.0253 - mape: 1617.0779 - val_loss: 1.7233e-04 - val_mae: 0.0139 - val_mape: 78.3716
# Epoch 20/100
# 5/5 [==============================] - 0s 54ms/step - loss: 7.8117e-04 - mae: 0.0235 - mape: 1264.0138 - val_loss: 1.7425e-04 - val_mae: 0.0145 - val_mape: 83.9105
# Epoch 21/100
# 5/5 [==============================] - 0s 64ms/step - loss: 8.3887e-04 - mae: 0.0244 - mape: 1094.9094 - val_loss: 1.7302e-04 - val_mae: 0.0136 - val_mape: 72.2539
# Epoch 22/100
# 5/5 [==============================] - 0s 61ms/step - loss: 8.6770e-04 - mae: 0.0256 - mape: 986.1678 - val_loss: 1.7310e-04 - val_mae: 0.0144 - val_mape: 85.2227
# Epoch 23/100
# 5/5 [==============================] - 0s 61ms/step - loss: 7.2254e-04 - mae: 0.0243 - mape: 1083.1165 - val_loss: 1.8611e-04 - val_mae: 0.0152 - val_mape: 89.8860
# Epoch 24/100
# 5/5 [==============================] - 0s 65ms/step - loss: 7.6322e-04 - mae: 0.0228 - mape: 1354.2047 - val_loss: 1.5493e-04 - val_mae: 0.0133 - val_mape: 76.7881
# Epoch 25/100
# 5/5 [==============================] - 0s 59ms/step - loss: 7.4648e-04 - mae: 0.0224 - mape: 1517.0337 - val_loss: 1.5414e-04 - val_mae: 0.0135 - val_mape: 79.9076
# Epoch 26/100
# 5/5 [==============================] - 0s 64ms/step - loss: 7.0561e-04 - mae: 0.0217 - mape: 976.2307 - val_loss: 1.4538e-04 - val_mae: 0.0129 - val_mape: 74.1916
# Epoch 27/100
# 5/5 [==============================] - 0s 58ms/step - loss: 6.7009e-04 - mae: 0.0217 - mape: 1008.8932 - val_loss: 1.5503e-04 - val_mae: 0.0136 - val_mape: 81.3123
# Epoch 28/100
# 5/5 [==============================] - 0s 66ms/step - loss: 6.4510e-04 - mae: 0.0213 - mape: 1345.6318 - val_loss: 1.4314e-04 - val_mae: 0.0128 - val_mape: 73.9894
# Epoch 29/100
# 5/5 [==============================] - 0s 60ms/step - loss: 6.3795e-04 - mae: 0.0212 - mape: 1774.4886 - val_loss: 1.4959e-04 - val_mae: 0.0134 - val_mape: 78.9040
# Epoch 30/100
# 5/5 [==============================] - 0s 55ms/step - loss: 6.1756e-04 - mae: 0.0207 - mape: 1308.2646 - val_loss: 1.4170e-04 - val_mae: 0.0126 - val_mape: 70.6667
# Epoch 31/100
# 5/5 [==============================] - 0s 59ms/step - loss: 6.4279e-04 - mae: 0.0209 - mape: 1043.8087 - val_loss: 1.4621e-04 - val_mae: 0.0130 - val_mape: 76.8340
# Epoch 32/100
# 5/5 [==============================] - 0s 58ms/step - loss: 6.4696e-04 - mae: 0.0209 - mape: 1100.5148 - val_loss: 1.5120e-04 - val_mae: 0.0133 - val_mape: 79.1190
# Epoch 33/100
# 5/5 [==============================] - 0s 71ms/step - loss: 6.1413e-04 - mae: 0.0207 - mape: 854.6205 - val_loss: 1.6310e-04 - val_mae: 0.0141 - val_mape: 83.4067
# Epoch 34/100
# 5/5 [==============================] - 0s 53ms/step - loss: 6.3638e-04 - mae: 0.0208 - mape: 1483.1138 - val_loss: 1.3830e-04 - val_mae: 0.0125 - val_mape: 67.7520
# Epoch 35/100
# ...
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0033 - mae: 0.0574 - mape: 2291.9678 - val_loss: 0.0021 - val_mae: 0.0542 - val_mape: 160.6946
# Epoch 11/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0029 - mae: 0.0546 - mape: 3236.4763 - val_loss: 0.0018 - val_mae: 0.0502 - val_mape: 150.3666
# Epoch 12/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0023 - mae: 0.0497 - mape: 2056.5225 - val_loss: 0.0013 - val_mae: 0.0428 - val_mape: 130.4762
# Epoch 13/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0016 - mae: 0.0414 - mape: 2554.9392 - val_loss: 7.9082e-04 - val_mae: 0.0315 - val_mape: 96.7198
# Epoch 14/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0011 - mae: 0.0321 - mape: 1738.1564 - val_loss: 5.6011e-04 - val_mae: 0.0244 - val_mape: 67.0135
# Epoch 15/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0017 - mae: 0.0375 - mape: 1305.5815 - val_loss: 5.3351e-04 - val_mae: 0.0249 - val_mape: 73.5639
# Epoch 16/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0021 - mae: 0.0415 - mape: 1911.1150 - val_loss: 5.4029e-04 - val_mae: 0.0274 - val_mape: 89.2603
# Epoch 17/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0028 - mae: 0.0439 - mape: 1206.0919 - val_loss: 0.0016 - val_mae: 0.0351 - val_mape: 83.5616
# Epoch 18/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0030 - mae: 0.0446 - mape: 2122.8052 - val_loss: 0.0016 - val_mae: 0.0404 - val_mape: 107.0873
# Epoch 19/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0022 - mae: 0.0440 - mape: 2746.1848 - val_loss: 0.0015 - val_mae: 0.0461 - val_mape: 137.9531
# Epoch 20/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0015 - mae: 0.0417 - mape: 2526.5789 - val_loss: 0.0015 - val_mae: 0.0510 - val_mape: 166.8464
# Epoch 21/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0019 - mae: 0.0525 - mape: 2893.8823 - val_loss: 0.0011 - val_mae: 0.0434 - val_mape: 145.3934
# Epoch 22/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0012 - mae: 0.0376 - mape: 2571.2317 - val_loss: 6.6968e-04 - val_mae: 0.0301 - val_mape: 93.1716
# Epoch 23/100
# 5/5 [==============================] - 0s 52ms/step - loss: 9.2561e-04 - mae: 0.0281 - mape: 1602.5602 - val_loss: 3.8966e-04 - val_mae: 0.0211 - val_mape: 59.1086
# Epoch 24/100
# 5/5 [==============================] - 0s 51ms/step - loss: 9.8704e-04 - mae: 0.0270 - mape: 1137.3031 - val_loss: 2.9616e-04 - val_mae: 0.0185 - val_mape: 52.6608
# Epoch 25/100
# 5/5 [==============================] - 0s 51ms/step - loss: 8.5769e-04 - mae: 0.0251 - mape: 726.6242 - val_loss: 4.2437e-04 - val_mae: 0.0212 - val_mape: 56.2949
# Epoch 26/100
# 5/5 [==============================] - 0s 66ms/step - loss: 7.1741e-04 - mae: 0.0233 - mape: 1477.6920 - val_loss: 4.1991e-04 - val_mae: 0.0234 - val_mape: 74.0034
# Epoch 27/100
# 5/5 [==============================] - 0s 52ms/step - loss: 7.8393e-04 - mae: 0.0252 - mape: 2070.0952 - val_loss: 4.0478e-04 - val_mae: 0.0233 - val_mape: 75.6418
# Epoch 28/100
# 5/5 [==============================] - 0s 59ms/step - loss: 7.7643e-04 - mae: 0.0240 - mape: 1622.1018 - val_loss: 3.6307e-04 - val_mae: 0.0205 - val_mape: 59.7213
# Epoch 29/100
# 5/5 [==============================] - 0s 56ms/step - loss: 7.0322e-04 - mae: 0.0221 - mape: 1439.7968 - val_loss: 3.0598e-04 - val_mae: 0.0186 - val_mape: 53.5921
# Epoch 30/100
# 5/5 [==============================] - 0s 55ms/step - loss: 6.7309e-04 - mae: 0.0217 - mape: 2117.6587 - val_loss: 2.7211e-04 - val_mae: 0.0176 - val_mape: 51.0488
# Epoch 31/100
# 5/5 [==============================] - 0s 59ms/step - loss: 6.3277e-04 - mae: 0.0213 - mape: 1309.9207 - val_loss: 3.0257e-04 - val_mae: 0.0181 - val_mape: 49.5301
# Epoch 32/100
# 5/5 [==============================] - 0s 51ms/step - loss: 6.2752e-04 - mae: 0.0210 - mape: 1005.7561 - val_loss: 3.2056e-04 - val_mae: 0.0197 - val_mape: 60.2021
# Epoch 33/100
# 5/5 [==============================] - 0s 49ms/step - loss: 6.1785e-04 - mae: 0.0211 - mape: 1134.4119 - val_loss: 3.0216e-04 - val_mae: 0.0189 - val_mape: 56.6089
# Epoch 34/100
# 5/5 [==============================] - 0s 59ms/step - loss: 6.2097e-04 - mae: 0.0209 - mape: 1503.6500 - val_loss: 3.0150e-04 - val_mae: 0.0182 - val_mape: 50.4221
# Epoch 35/100
# 5/5 [==============================] - 0s 53ms/step - loss: 5.5163e-04 - mae: 0.0200 - mape: 996.0872 - val_loss: 2.7955e-04 - val_mae: 0.0183 - val_mape: 54.6902
# Epoch 36/100
# 5/5 [==============================] - 0s 51ms/step - loss: 5.8475e-04 - mae: 0.0209 - mape: 1484.5410 - val_loss: 2.6268e-04 - val_mae: 0.0172 - val_mape: 48.9775
# Epoch 37/100
# 5/5 [==============================] - 0s 59ms/step - loss: 5.7510e-04 - mae: 0.0204 - mape: 692.1123 - val_loss: 2.7455e-04 - val_mae: 0.0175 - val_mape: 48.9818
# Epoch 38/100
# 5/5 [==============================] - 0s 50ms/step - loss: 5.4934e-04 - mae: 0.0196 - mape: 1542.8195 - val_loss: 2.7581e-04 - val_mae: 0.0183 - val_mape: 55.9892
# Epoch 39/100
# 5/5 [==============================] - 0s 50ms/step - loss: 5.3071e-04 - mae: 0.0201 - mape: 1429.8987 - val_loss: 2.7299e-04 - val_mae: 0.0176 - val_mape: 50.6449
# Epoch 40/100
# 5/5 [==============================] - 0s 59ms/step - loss: 5.8118e-04 - mae: 0.0198 - mape: 929.3135 - val_loss: 2.6689e-04 - val_mae: 0.0174 - val_mape: 50.0537
# Epoch 41/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.1961e-04 - mae: 0.0202 - mape: 1461.5035 - val_loss: 2.6303e-04 - val_mae: 0.0174 - val_mape: 51.1066
# Epoch 42/100
# 5/5 [==============================] - 0s 52ms/step - loss: 5.8015e-04 - mae: 0.0199 - mape: 909.0000 - val_loss: 2.5860e-04 - val_mae: 0.0170 - val_mape: 48.0647
# Epoch 43/100
# 5/5 [==============================] - 0s 63ms/step - loss: 5.6108e-04 - mae: 0.0193 - mape: 1151.6532 - val_loss: 2.6336e-04 - val_mae: 0.0174 - val_mape: 50.7522
# Epoch 44/100
# 5/5 [==============================] - 0s 51ms/step - loss: 5.3203e-04 - mae: 0.0197 - mape: 1173.1075 - val_loss: 2.6490e-04 - val_mae: 0.0175 - val_mape: 51.0741
# Epoch 45/100
# 5/5 [==============================] - 0s 46ms/step - loss: 4.8971e-04 - mae: 0.0189 - mape: 1111.9926 - val_loss: 2.5495e-04 - val_mae: 0.0168 - val_mape: 47.4668
# Epoch 46/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.6264e-04 - mae: 0.0192 - mape: 984.1273 - val_loss: 2.5996e-04 - val_mae: 0.0170 - val_mape: 48.6487
# Epoch 47/100
# 5/5 [==============================] - 0s 50ms/step - loss: 5.2152e-04 - mae: 0.0192 - mape: 613.3538 - val_loss: 2.5935e-04 - val_mae: 0.0169 - val_mape: 47.7843
# Epoch 48/100
# 5/5 [==============================] - 0s 59ms/step - loss: 5.4980e-04 - mae: 0.0192 - mape: 551.8989 - val_loss: 2.6395e-04 - val_mae: 0.0171 - val_mape: 49.4984
# Epoch 49/100
# 5/5 [==============================] - 0s 54ms/step - loss: 5.0549e-04 - mae: 0.0184 - mape: 1416.2688 - val_loss: 2.5925e-04 - val_mae: 0.0170 - val_mape: 48.9752
# Epoch 50/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.8148e-04 - mae: 0.0184 - mape: 1659.1521 - val_loss: 2.5245e-04 - val_mae: 0.0167 - val_mape: 47.6814
# Epoch 51/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.1639e-04 - mae: 0.0185 - mape: 1282.4824 - val_loss: 2.5277e-04 - val_mae: 0.0167 - val_mape: 48.1573
# Epoch 52/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.1345e-04 - mae: 0.0189 - mape: 1330.5292 - val_loss: 2.4409e-04 - val_mae: 0.0164 - val_mape: 47.4580
# Epoch 53/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.5155e-04 - mae: 0.0184 - mape: 1621.7999 - val_loss: 2.3255e-04 - val_mae: 0.0159 - val_mape: 44.1386
# Epoch 54/100
# 5/5 [==============================] - 0s 57ms/step - loss: 6.0499e-04 - mae: 0.0188 - mape: 821.0487 - val_loss: 2.5197e-04 - val_mae: 0.0169 - val_mape: 49.5621
# Epoch 55/100
# 5/5 [==============================] - 0s 46ms/step - loss: 5.1903e-04 - mae: 0.0187 - mape: 989.8107 - val_loss: 2.7179e-04 - val_mae: 0.0176 - val_mape: 51.6852
# Epoch 56/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.5635e-04 - mae: 0.0182 - mape: 1051.1064 - val_loss: 2.3489e-04 - val_mae: 0.0155 - val_mape: 38.9706
# Epoch 57/100
# 5/5 [==============================] - 0s 59ms/step - loss: 4.6796e-04 - mae: 0.0187 - mape: 633.6171 - val_loss: 2.3042e-04 - val_mae: 0.0158 - val_mape: 43.8874
# Epoch 58/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.7613e-04 - mae: 0.0182 - mape: 1619.4797 - val_loss: 2.5308e-04 - val_mae: 0.0166 - val_mape: 46.4961
# Epoch 59/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.8272e-04 - mae: 0.0184 - mape: 2004.7256 - val_loss: 2.3951e-04 - val_mae: 0.0159 - val_mape: 43.0806
# Epoch 60/100
# 5/5 [==============================] - 0s 53ms/step - loss: 5.1404e-04 - mae: 0.0182 - mape: 1059.9664 - val_loss: 2.3616e-04 - val_mae: 0.0162 - val_mape: 46.0885
# Epoch 61/100
# 5/5 [==============================] - 0s 50ms/step - loss: 5.4369e-04 - mae: 0.0181 - mape: 1176.8951 - val_loss: 2.3958e-04 - val_mae: 0.0160 - val_mape: 43.7439
# Epoch 62/100
# 5/5 [==============================] - 0s 56ms/step - loss: 4.7320e-04 - mae: 0.0180 - mape: 1065.8220 - val_loss: 2.4371e-04 - val_mae: 0.0166 - val_mape: 48.8591
# Epoch 63/100
# 5/5 [==============================] - 0s 60ms/step - loss: 4.3638e-04 - mae: 0.0178 - mape: 1162.3217 - val_loss: 2.3371e-04 - val_mae: 0.0159 - val_mape: 44.4000
# Epoch 64/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.2803e-04 - mae: 0.0175 - mape: 675.5132 - val_loss: 2.2702e-04 - val_mae: 0.0159 - val_mape: 45.8947
# Epoch 65/100
# 5/5 [==============================] - 0s 57ms/step - loss: 4.5081e-04 - mae: 0.0179 - mape: 1206.8781 - val_loss: 2.4173e-04 - val_mae: 0.0164 - val_mape: 48.2736
# Epoch 66/100
# 5/5 [==============================] - 0s 50ms/step - loss: 4.3570e-04 - mae: 0.0180 - mape: 1436.8715 - val_loss: 2.3611e-04 - val_mae: 0.0160 - val_mape: 45.8543
# Epoch 67/100
# 5/5 [==============================] - 0s 50ms/step - loss: 4.8379e-04 - mae: 0.0179 - mape: 1174.7212 - val_loss: 2.3124e-04 - val_mae: 0.0154 - val_mape: 38.5356
# Epoch 68/100
# 5/5 [==============================] - 0s 50ms/step - loss: 4.9172e-04 - mae: 0.0180 - mape: 1049.2737 - val_loss: 2.2869e-04 - val_mae: 0.0160 - val_mape: 46.3734
# Epoch 69/100
# 5/5 [==============================] - 0s 66ms/step - loss: 4.9988e-04 - mae: 0.0179 - mape: 1329.1976 - val_loss: 2.2916e-04 - val_mae: 0.0156 - val_mape: 42.7899
# Epoch 70/100
# 5/5 [==============================] - 0s 54ms/step - loss: 4.7818e-04 - mae: 0.0173 - mape: 850.1169 - val_loss: 2.3468e-04 - val_mae: 0.0160 - val_mape: 45.0364
# Epoch 71/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.4349e-04 - mae: 0.0176 - mape: 1295.1116 - val_loss: 2.4636e-04 - val_mae: 0.0166 - val_mape: 47.8184
# Epoch 72/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.7740e-04 - mae: 0.0179 - mape: 1286.7566 - val_loss: 2.3100e-04 - val_mae: 0.0154 - val_mape: 37.2292
# Epoch 73/100
# 5/5 [==============================] - 0s 57ms/step - loss: 4.5537e-04 - mae: 0.0177 - mape: 941.4473 - val_loss: 2.2467e-04 - val_mae: 0.0154 - val_mape: 41.5442
# Epoch 74/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.8178e-04 - mae: 0.0181 - mape: 745.0263 - val_loss: 3.1221e-04 - val_mae: 0.0199 - val_mape: 63.1476
# Epoch 75/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.4383e-04 - mae: 0.0196 - mape: 1725.3699 - val_loss: 2.6662e-04 - val_mae: 0.0167 - val_mape: 36.2593
# Epoch 76/100
# 5/5 [==============================] - 0s 57ms/step - loss: 5.1887e-04 - mae: 0.0192 - mape: 595.8849 - val_loss: 2.5089e-04 - val_mae: 0.0175 - val_mape: 54.1575
# Epoch 77/100
# 5/5 [==============================] - 0s 54ms/step - loss: 4.4385e-04 - mae: 0.0183 - mape: 1137.6357 - val_loss: 2.4093e-04 - val_mae: 0.0160 - val_mape: 43.6360
# Epoch 78/100
# 5/5 [==============================] - 0s 59ms/step - loss: 4.3778e-04 - mae: 0.0172 - mape: 1251.6595 - val_loss: 2.2197e-04 - val_mae: 0.0156 - val_mape: 44.0732
# Epoch 79/100
# 5/5 [==============================] - 0s 52ms/step - loss: 4.5575e-04 - mae: 0.0174 - mape: 1118.9349 - val_loss: 2.4108e-04 - val_mae: 0.0166 - val_mape: 49.5584
# Epoch 80/100
# 5/5 [==============================] - 0s 50ms/step - loss: 4.1123e-04 - mae: 0.0173 - mape: 984.8140 - val_loss: 2.3598e-04 - val_mae: 0.0163 - val_mape: 47.7088
# Epoch 81/100
# 5/5 [==============================] - 0s 62ms/step - loss: 4.6268e-04 - mae: 0.0175 - mape: 1203.2076 - val_loss: 2.2172e-04 - val_mae: 0.0152 - val_mape: 40.6277
# Epoch 82/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.8505e-04 - mae: 0.0171 - mape: 1029.0616 - val_loss: 2.2903e-04 - val_mae: 0.0162 - val_mape: 48.4661
# Epoch 83/100
# 5/5 [==============================] - 0s 63ms/step - loss: 4.5261e-04 - mae: 0.0175 - mape: 1201.9556 - val_loss: 2.2061e-04 - val_mae: 0.0155 - val_mape: 43.6826
# Epoch 84/100
# 5/5 [==============================] - 0s 75ms/step - loss: 4.5590e-04 - mae: 0.0172 - mape: 1357.8770 - val_loss: 2.1884e-04 - val_mae: 0.0152 - val_mape: 40.9020
# Epoch 85/100
# 5/5 [==============================] - 0s 50ms/step - loss: 3.8244e-04 - mae: 0.0169 - mape: 583.2511 - val_loss: 2.6609e-04 - val_mae: 0.0179 - val_mape: 55.8108
# Epoch 86/100
# 5/5 [==============================] - 0s 54ms/step - loss: 4.3662e-04 - mae: 0.0180 - mape: 1267.6737 - val_loss: 2.3085e-04 - val_mae: 0.0154 - val_mape: 39.5708
# Epoch 87/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.1228e-04 - mae: 0.0172 - mape: 796.3755 - val_loss: 2.1899e-04 - val_mae: 0.0155 - val_mape: 44.6980
# Epoch 88/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.1411e-04 - mae: 0.0171 - mape: 1285.6200 - val_loss: 2.2525e-04 - val_mae: 0.0157 - val_mape: 44.9746
# Epoch 89/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.2306e-04 - mae: 0.0171 - mape: 1393.5933 - val_loss: 2.2059e-04 - val_mae: 0.0154 - val_mape: 42.7940
# Epoch 90/100
# 5/5 [==============================] - 0s 51ms/step - loss: 4.0623e-04 - mae: 0.0168 - mape: 1340.7239 - val_loss: 2.2677e-04 - val_mae: 0.0161 - val_mape: 48.4957
# Epoch 91/100
# 5/5 [==============================] - 0s 60ms/step - loss: 4.1301e-04 - mae: 0.0169 - mape: 1095.2249 - val_loss: 2.1800e-04 - val_mae: 0.0153 - val_mape: 42.6681
# Epoch 92/100
# 5/5 [==============================] - 0s 61ms/step - loss: 4.1452e-04 - mae: 0.0168 - mape: 928.3159 - val_loss: 2.2697e-04 - val_mae: 0.0153 - val_mape: 39.5845
# Epoch 93/100
# 5/5 [==============================] - 0s 53ms/step - loss: 3.9751e-04 - mae: 0.0169 - mape: 701.1576 - val_loss: 2.9820e-04 - val_mae: 0.0196 - val_mape: 63.2423
# Epoch 94/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.7325e-04 - mae: 0.0191 - mape: 1098.4083 - val_loss: 2.7637e-04 - val_mae: 0.0174 - val_mape: 37.9316
# Epoch 95/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.3730e-04 - mae: 0.0194 - mape: 701.0898 - val_loss: 2.7747e-04 - val_mae: 0.0188 - val_mape: 60.6723
# Epoch 96/100
# 5/5 [==============================] - 0s 59ms/step - loss: 5.4377e-04 - mae: 0.0199 - mape: 990.1682 - val_loss: 2.8394e-04 - val_mae: 0.0186 - val_mape: 58.0777
# Epoch 97/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.0874e-04 - mae: 0.0202 - mape: 1285.7866 - val_loss: 2.8975e-04 - val_mae: 0.0178 - val_mape: 37.7140
# Epoch 98/100
# 5/5 [==============================] - 0s 48ms/step - loss: 6.4965e-04 - mae: 0.0248 - mape: 64.9333 - val_loss: 4.2132e-04 - val_mae: 0.0246 - val_mape: 84.2472
# Epoch 99/100
# 5/5 [==============================] - 0s 62ms/step - loss: 6.5014e-04 - mae: 0.0274 - mape: 2118.0115 - val_loss: 3.0335e-04 - val_mae: 0.0193 - val_mape: 60.5596
# Epoch 100/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.0702e-04 - mae: 0.0239 - mape: 1119.8843 - val_loss: 2.8524e-04 - val_mae: 0.0188 - val_mape: 59.5123

# %% [markdown]
# #### Gráficas de entrenamiento modelo con ventanado

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='loss'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='mae'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %% [markdown]
# ##### Evaluar modelo con ventanado

# %%
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xtr= x.numpy()
    Ytr=y.numpy()
    break

for idx,(x,y) in enumerate(val_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xval= x.numpy()
    Yval=y.numpy()
    break

for idx,(x,y) in enumerate(test_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xts= x.numpy()
    Yts=y.numpy()
    break
# Out:
# Example sample shapes
# x =  (256, 24, 7)
# y =  (256, 24, 1)
# x =  (256, 24, 7)
# y =  (256, 24, 1)
# x =  (256, 24, 7)
# y =  (256, 24, 1)

# %%
pip install pandas==1.5.3
# Out:
# Collecting pandas==1.5.3Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\sebas\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\~andas\\_libs\\algos.cp311-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\sebas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas==1.5.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas==1.5.3) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas==1.5.3) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\sebas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1

# %%
pip unisntall pandas==2.0.1
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "unisntall" - maybe you meant "uninstall"

# %%
import pandas as pd
models=['dnn','lstm','gru','cnn_lstm']
# results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
results = []
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(3)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}

    results.append(data)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.1

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe_80_20_earlystop_kfolds.csv')
df.to_csv(file)

# %%
results= df
results
# Out:
#        Model   Tipo         MAE        MAPE      sMAPE        RMSE
# 0        dnn  Train   25.399326   13.453513  12.246844   31.917545
# 1        dnn    Val  177.140982  218.293652  97.597612  196.298732
# 2        dnn   Test   32.405402   24.333749  20.891560   37.028440
# 3       lstm  Train   15.812161    8.509284   9.043322   19.519791
# 4       lstm    Val   73.119391   90.617016  60.570317   75.934261
# 5       lstm   Test   17.418428   13.376818  12.192461   20.584438
# 6        gru  Train   15.257370    8.196220   8.694196   19.115261
# 7        gru    Val   71.353658   88.967549  59.406152   74.737300
# 8        gru   Test   19.397387   14.653526  13.314636   22.241447
# 9   cnn_lstm  Train   13.233895    7.029575   7.147694   15.709522
# 10  cnn_lstm    Val   85.887313  106.703853  67.425164   89.025665
# 11  cnn_lstm   Test   24.708757   18.694818  16.641646   27.642360

# %%
models=['dnn','lstm','gru','cnn_lstm']
# results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
resultsYtestP={}
results = []
listP=[]
for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtr)
    Ye=scalerP.inverse_transform(Ytr.reshape(Ytr.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)

    #Evaluación de las X en validación
    Yp=model.predict(Xval)
    Ye=scalerP.inverse_transform(Yval.reshape(Yval.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)

    # Hacer pedicciones con el Xtest
    Yp=model.predict(Xts)
    Ye=scalerP.inverse_transform(Yts.reshape(Yts.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 8/8 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step

# %%
results = df

# %%
results
# Out:
#        Model   Tipo        MAE       MAPE      sMAPE       RMSE
# 0        dnn  Train  35.169953  26.783478  21.372506  46.595868
# 1        dnn    Val  46.634272  35.561104  27.779576  57.341338
# 2        dnn   Test  69.119929  83.436759  52.832232  78.005557
# 3       lstm  Train  24.129367  18.659046  15.651127  32.332171
# 4       lstm    Val  34.154888  25.111374  21.246130  44.888595
# 5       lstm   Test  48.760734  60.198095  41.625512  57.177373
# 6        gru  Train  24.237577  19.428192  15.520917  32.486323
# 7        gru    Val  44.578062  34.051248  26.015295  56.285911
# 8        gru   Test  49.832029  61.777203  42.206606  58.624542
# 9   cnn_lstm  Train  21.722503  15.849709  13.889561  29.413951
# 10  cnn_lstm    Val  34.986444  25.026893  21.343305  46.415130
# 11  cnn_lstm   Test  33.814317  40.319930  30.568013  41.833690

# %% [markdown]
# #### Gráfica del original y del pronóstico

# %%
listreg=[i for i in range(3)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A49FA1010>, 'history': <keras.src.callbacks.History object at 0x0000026A84D5D350>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 19ms/step
# lstm {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A8483DF90>, 'history': <keras.src.callbacks.History object at 0x0000026A8EA65350>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 26ms/step
# gru {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A8EAA46D0>, 'history': <keras.src.callbacks.History object at 0x0000026A8EF35350>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 19ms/step
# cnn_lstm {'model': <keras.src.engine.sequential.Sequential object at 0x0000026A8EFF1290>, 'history': <keras.src.callbacks.History object at 0x0000026A8EFDA3D0>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 24ms/step
