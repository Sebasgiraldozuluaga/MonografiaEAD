# %% [markdown]
# #### Cargas las librerías

# %%
# Load Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
import os
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf

from evaluation._mae import MAE
from evaluation._smape import sMAPE
from evaluation._mape import MAPE
from evaluation._rmse import RMSE
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### Cargar dataset

# %%
s_path=Path.cwd()
s_prt_path=s_path.parent

file=os.path.join(s_prt_path,'datasets\XM_H_sinOfe.csv')
df_Data= pd.read_csv(file, index_col=0)
# df_Data.reset_index(inplace=True)

# %%
df_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52584 entries, 01/01/2013 0:00 to 31/12/2018 23:00
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PrecioB    52584 non-null  float64
#  1   Demanda    52584 non-null  float64
#  2   DispTer    52584 non-null  int64
#  3   DispNoTer  52584 non-null  int64
#  4   VolUtil    52584 non-null  int64
#  5   Aportes    52584 non-null  int64
#  6   day_cls    52584 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Funciones necesarias para las ejecuciones

# %% [markdown]
# ##### División de datos

# %%
# Dividir los datos en train, validación y test
def split_data(data, indexTotal, train_fraq, test_len=8760):

    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(data)-test_len

    test_data = data[test_slice:]
    indexTest=indexTotal[test_slice:]

    train_val_data = data[:test_slice]
    index_val_data=indexTotal[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    indexTrain=index_val_data[:train_size]

    val_data = train_val_data[train_size:]
    indexVal=index_val_data[train_size:]
    
    return train_data, val_data, test_data, indexTrain, indexVal, indexTest

# %% [markdown]
# ##### Construcción del dataset

# %%
# Crear los datos para entrar al modelo, definición de ventanas
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
    """ Create a windowed tensorflow dataset
    
    """

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
    
    #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    #ds = ds.shuffle(shuffle_buffer)
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    
    return ds

# Construcción del dataset usando las ventanas
def build_dataset(traindata,valdata,testdata,train_fraq=0.8, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
    """If multi variate then first column is always the column from which the target is contstructed.
    """
    
    tf.random.set_seed(23)
    
    
    train_ds = window_dataset(traindata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(valdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(testdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    
    
    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# ##### Parámetros y ejecución

# %%
# Definición de parámetros para la ejecución del modelo
def get_params(multivar=True):
    lr = 3e-4
    n_steps=72
    n_horizon=24
    if multivar:
        n_features=7
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

# Almacenamiento de los datos de las ejecuciones
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}

# Ejecuciones de los modelos con función de ventanado
def run_model(traindata,valdata,testdata,model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    
    train_ds, val_ds, test_ds = build_dataset(traindata,valdata,testdata,n_steps=n_steps, n_horizon=n_horizon, multi_var=True)

    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    # Define el early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=40)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=[early_stopping])

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    
    return test_ds

# %% [markdown]
# #### Modelos

# %% [markdown]
# ##### DNN

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 504)               0
#
#  dense (Dense)               (None, 128)               64640
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 84248 (329.09 KB)
# Trainable params: 84248 (329.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### LSTM

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 72, 72)            23040
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55640 (217.34 KB)
# Trainable params: 55640 (217.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### GRU

# %%
def gru_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.GRU(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.GRU(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='gru')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

gru = gru_model(*get_params(multivar=True))
gru.summary()
# Out:
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 72, 72)            17496
#
#  gru_1 (GRU)                 (None, 48)                17568
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 44432 (173.56 KB)
# Trainable params: 44432 (173.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### CNN_LSTM

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 67, 64)            2752
#
#  max_pooling1d (MaxPooling1  (None, 33, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 31, 64)            12352
#
#  max_pooling1d_1 (MaxPoolin  (None, 15, 64)            0
#  g1D)
#
#  lstm (LSTM)                 (None, 15, 72)            39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 87160 (340.47 KB)
# Trainable params: 87160 (340.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### Escalamiento de los datos y división del dataset

# %%
#scale
scaler = MinMaxScaler(feature_range=(0, 1))
scalerP=MinMaxScaler(feature_range=(0, 1))

vec_precio=scalerP.fit_transform(df_Data.values[:,0].reshape(-1,1))

indexTotal=df_Data.index

multivar_df = scaler.fit_transform(df_Data)
train_multi, val_multi, test_multi, indexTrain, indexVal, indexTest = split_data(multivar_df,indexTotal, train_fraq=0.8, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
print('Precio',vec_precio.shape)
print('Todo',df_Data.shape)
# Out:
# Multivarate Datasets
# Train Data Shape: (35059, 7)
# Val Data Shape: (8765, 7)
# Test Data Shape: (8760, 7)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False
# Precio (52584, 1)
# Todo (52584, 7)

# %% [markdown]
# ##### Obtener dataset para el modelo utilizando la función de ventanado

# %%
n_steps=72
n_horizon=24

train_ds, val_ds, test_ds = build_dataset(train_multi, val_multi, test_multi,n_steps=n_steps, n_horizon=n_horizon,multi_var=True)
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Example sample shapes
# x =  (256, 72, 7)
# y =  (256, 24, 1)

# %% [markdown]
# ##### Ejecución de modelo con datos del ventanado

# %%
from sklearn.model_selection import KFold

model_configs_v = dict()
nepochs = 100

# Define the number of folds for cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits)

# Iterate over the folds
for fold, (train_index, val_index) in enumerate(kf.split(train_multi)):
    print(f"Fold {fold+1}/{n_splits}")
    
    # Get the training and validation data for the current fold
    fold_train_data = train_multi[train_index]
    fold_val_data = train_multi[val_index]
    
    print('Ejecutando la dnn')
    run_model(fold_train_data, fold_val_data, test_multi, "dnn", dnn_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la lstm')
    run_model(fold_train_data, fold_val_data, test_multi, "lstm", lstm_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la gru')
    run_model(fold_train_data, fold_val_data, test_multi, "gru", gru_model, model_configs_v, epochs=nepochs)

    print('Ejecutando la cnn_lstm')
    run_model(fold_train_data, fold_val_data, test_multi, "cnn_lstm", lstm_cnn_model, model_configs_v, epochs=nepochs)
# Out:
# Fold 1/5
# Ejecutando la dnn
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0957 - mae: 0.3359 - mape: 9605.8193 - val_loss: 0.0070 - val_mae: 0.0908 - val_mape: 305.4389
# Epoch 2/100
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0181 - mae: 0.1459 - mape: 10866.2744 - val_loss: 0.0024 - val_mae: 0.0543 - val_mape: 201.8451
# Epoch 3/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0087 - mae: 0.0940 - mape: 366.7488 - val_loss: 0.0011 - val_mae: 0.0380 - val_mape: 125.2225
# Epoch 4/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0062 - mae: 0.0729 - mape: 357.8149 - val_loss: 6.7240e-04 - val_mae: 0.0294 - val_mape: 90.0674
# Epoch 5/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0056 - mae: 0.0675 - mape: 2170.5718 - val_loss: 6.2505e-04 - val_mae: 0.0288 - val_mape: 78.4950
# Epoch 6/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0047 - mae: 0.0595 - mape: 1030.1060 - val_loss: 4.0046e-04 - val_mae: 0.0214 - val_mape: 70.7627
# Epoch 7/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0041 - mae: 0.0545 - mape: 646.8645 - val_loss: 3.5446e-04 - val_mae: 0.0200 - val_mape: 68.5195
# Epoch 8/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0032 - mae: 0.0468 - mape: 1286.2079 - val_loss: 2.7272e-04 - val_mae: 0.0172 - val_mape: 69.9759
# Epoch 9/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0028 - mae: 0.0438 - mape: 2359.7490 - val_loss: 2.5174e-04 - val_mae: 0.0166 - val_mape: 73.7153
# Epoch 10/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0023 - mae: 0.0398 - mape: 2696.1438 - val_loss: 2.9293e-04 - val_mae: 0.0182 - val_mape: 89.3818
# Epoch 11/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0024 - mae: 0.0398 - mape: 1276.9852 - val_loss: 2.3688e-04 - val_mae: 0.0162 - val_mape: 80.0774
# Epoch 12/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0022 - mae: 0.0375 - mape: 2034.0094 - val_loss: 3.0728e-04 - val_mae: 0.0189 - val_mape: 97.9586
# Epoch 13/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0020 - mae: 0.0362 - mape: 2133.4802 - val_loss: 2.4886e-04 - val_mae: 0.0167 - val_mape: 86.8313
# Epoch 14/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0020 - mae: 0.0357 - mape: 2390.8286 - val_loss: 3.0712e-04 - val_mae: 0.0194 - val_mape: 102.9467
# Epoch 15/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0018 - mae: 0.0342 - mape: 1636.1406 - val_loss: 2.4304e-04 - val_mae: 0.0164 - val_mape: 89.7263
# Epoch 16/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0020 - mae: 0.0361 - mape: 1324.7240 - val_loss: 2.4507e-04 - val_mae: 0.0171 - val_mape: 95.7835
# Epoch 17/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0019 - mae: 0.0370 - mape: 1715.4849 - val_loss: 2.4368e-04 - val_mae: 0.0167 - val_mape: 94.1771
# Epoch 18/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0017 - mae: 0.0330 - mape: 1753.2734 - val_loss: 2.5003e-04 - val_mae: 0.0173 - val_mape: 97.3261
# Epoch 19/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0017 - mae: 0.0350 - mape: 2107.2043 - val_loss: 2.5223e-04 - val_mae: 0.0172 - val_mape: 97.9552
# Epoch 20/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0016 - mae: 0.0321 - mape: 1586.5552 - val_loss: 4.9515e-04 - val_mae: 0.0262 - val_mape: 133.1277
# Epoch 21/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0015 - mae: 0.0324 - mape: 1364.8248 - val_loss: 2.5017e-04 - val_mae: 0.0172 - val_mape: 98.1640
# Epoch 22/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0015 - mae: 0.0316 - mape: 1460.3867 - val_loss: 2.5811e-04 - val_mae: 0.0178 - val_mape: 100.0160
# Epoch 23/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0015 - mae: 0.0322 - mape: 1927.1908 - val_loss: 2.4167e-04 - val_mae: 0.0167 - val_mape: 95.4037
# Epoch 24/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0014 - mae: 0.0305 - mape: 1733.5190 - val_loss: 2.4664e-04 - val_mae: 0.0173 - val_mape: 98.3315
# Epoch 25/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0014 - mae: 0.0311 - mape: 1777.8608 - val_loss: 2.5094e-04 - val_mae: 0.0170 - val_mape: 96.1988
# Epoch 26/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0015 - mae: 0.0313 - mape: 1988.5320 - val_loss: 2.7077e-04 - val_mae: 0.0184 - val_mape: 103.4446
# Epoch 27/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0015 - mae: 0.0322 - mape: 2143.0383 - val_loss: 2.5095e-04 - val_mae: 0.0170 - val_mape: 94.8863
# Epoch 28/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0016 - mae: 0.0326 - mape: 1857.5730 - val_loss: 2.5168e-04 - val_mae: 0.0176 - val_mape: 99.0432
# Epoch 29/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0014 - mae: 0.0319 - mape: 1499.4424 - val_loss: 2.5473e-04 - val_mae: 0.0171 - val_mape: 96.0130
# Epoch 30/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0014 - mae: 0.0294 - mape: 1500.0746 - val_loss: 2.5296e-04 - val_mae: 0.0175 - val_mape: 98.8029
# Epoch 31/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0014 - mae: 0.0317 - mape: 1604.9226 - val_loss: 2.5401e-04 - val_mae: 0.0171 - val_mape: 95.9707
# Epoch 32/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0016 - mae: 0.0308 - mape: 1321.7908 - val_loss: 2.5920e-04 - val_mae: 0.0179 - val_mape: 101.3550
# Epoch 33/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0014 - mae: 0.0300 - mape: 1872.6478 - val_loss: 2.5536e-04 - val_mae: 0.0172 - val_mape: 95.7430
# Epoch 34/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0016 - mae: 0.0321 - mape: 1569.6543 - val_loss: 2.4785e-04 - val_mae: 0.0174 - val_mape: 98.0943
# Epoch 35/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0015 - mae: 0.0332 - mape: 1800.4740 - val_loss: 2.5474e-04 - val_mae: 0.0173 - val_mape: 96.9228
# Epoch 36/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0013 - mae: 0.0295 - mape: 1469.4377 - val_loss: 2.5614e-04 - val_mae: 0.0176 - val_mape: 99.3320
# Epoch 37/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0013 - mae: 0.0289 - mape: 1818.2330 - val_loss: 2.4962e-04 - val_mae: 0.0171 - val_mape: 97.4606
# Epoch 38/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0013 - mae: 0.0292 - mape: 1484.2704 - val_loss: 2.6085e-04 - val_mae: 0.0182 - val_mape: 105.1116
# Epoch 39/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0013 - mae: 0.0289 - mape: 1552.8915 - val_loss: 2.4881e-04 - val_mae: 0.0167 - val_mape: 95.2883
# Epoch 40/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0014 - mae: 0.0302 - mape: 1695.4509 - val_loss: 2.5532e-04 - val_mae: 0.0175 - val_mape: 98.9122
# Epoch 41/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0013 - mae: 0.0315 - mape: 1476.3607 - val_loss: 2.4652e-04 - val_mae: 0.0167 - val_mape: 94.4960
# Epoch 42/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0014 - mae: 0.0291 - mape: 1754.6873 - val_loss: 2.5476e-04 - val_mae: 0.0178 - val_mape: 101.4502
# Epoch 43/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0012 - mae: 0.0291 - mape: 2423.6880 - val_loss: 2.4556e-04 - val_mae: 0.0167 - val_mape: 94.1946
# Epoch 44/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0012 - mae: 0.0278 - mape: 1319.2130 - val_loss: 2.4543e-04 - val_mae: 0.0169 - val_mape: 95.6971
# Epoch 45/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0012 - mae: 0.0286 - mape: 1815.5577 - val_loss: 2.4737e-04 - val_mae: 0.0169 - val_mape: 95.2767
# Epoch 46/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0013 - mae: 0.0264 - mape: 1384.1904 - val_loss: 2.4221e-04 - val_mae: 0.0167 - val_mape: 95.3933
# Epoch 47/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0012 - mae: 0.0269 - mape: 1514.2441 - val_loss: 2.3903e-04 - val_mae: 0.0166 - val_mape: 95.1998
# Epoch 48/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0011 - mae: 0.0267 - mape: 1487.2758 - val_loss: 2.3717e-04 - val_mae: 0.0166 - val_mape: 95.6302
# Epoch 49/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0010 - mae: 0.0257 - mape: 1391.5372 - val_loss: 2.4043e-04 - val_mae: 0.0165 - val_mape: 93.9571
# Epoch 50/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0011 - mae: 0.0256 - mape: 1224.3187 - val_loss: 2.3529e-04 - val_mae: 0.0165 - val_mape: 95.3893
# Epoch 51/100
# 5/5 [==============================] - 0s 53ms/step - loss: 9.6835e-04 - mae: 0.0255 - mape: 1556.4622 - val_loss: 2.3668e-04 - val_mae: 0.0163 - val_mape: 93.8753
# Epoch 52/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0010 - mae: 0.0249 - mape: 1423.5927 - val_loss: 2.3770e-04 - val_mae: 0.0166 - val_mape: 96.6409
# Epoch 53/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0010 - mae: 0.0252 - mape: 1445.9420 - val_loss: 2.5187e-04 - val_mae: 0.0172 - val_mape: 98.7565
# Epoch 54/100
# 5/5 [==============================] - 0s 58ms/step - loss: 8.5477e-04 - mae: 0.0238 - mape: 1399.8080 - val_loss: 2.6592e-04 - val_mae: 0.0183 - val_mape: 104.7987
# Epoch 55/100
# 5/5 [==============================] - 0s 59ms/step - loss: 9.1069e-04 - mae: 0.0255 - mape: 1681.0406 - val_loss: 2.3763e-04 - val_mae: 0.0166 - val_mape: 96.2262
# Epoch 56/100
# 5/5 [==============================] - 0s 58ms/step - loss: 9.8548e-04 - mae: 0.0244 - mape: 1390.2643 - val_loss: 2.5465e-04 - val_mae: 0.0177 - val_mape: 101.9327
# Epoch 57/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0010 - mae: 0.0250 - mape: 1305.7532 - val_loss: 2.5661e-04 - val_mae: 0.0177 - val_mape: 101.3098
# Epoch 58/100
# 5/5 [==============================] - 0s 67ms/step - loss: 9.6417e-04 - mae: 0.0246 - mape: 1350.0444 - val_loss: 3.2403e-04 - val_mae: 0.0206 - val_mape: 113.6222
# Epoch 59/100
# 5/5 [==============================] - 0s 59ms/step - loss: 8.9614e-04 - mae: 0.0241 - mape: 1355.8156 - val_loss: 2.2901e-04 - val_mae: 0.0163 - val_mape: 94.8920
# Epoch 60/100
# 5/5 [==============================] - 0s 57ms/step - loss: 8.5769e-04 - mae: 0.0237 - mape: 1289.7430 - val_loss: 2.4507e-04 - val_mae: 0.0173 - val_mape: 99.7638
# Epoch 61/100
# 5/5 [==============================] - 0s 57ms/step - loss: 8.8314e-04 - mae: 0.0237 - mape: 1293.9077 - val_loss: 3.0680e-04 - val_mae: 0.0199 - val_mape: 109.5013
# Epoch 62/100
# 5/5 [==============================] - 0s 52ms/step - loss: 8.8732e-04 - mae: 0.0235 - mape: 1469.4120 - val_loss: 2.4706e-04 - val_mae: 0.0173 - val_mape: 98.9358
# Epoch 63/100
# 5/5 [==============================] - 0s 63ms/step - loss: 8.7815e-04 - mae: 0.0233 - mape: 1308.2451 - val_loss: 2.2472e-04 - val_mae: 0.0162 - val_mape: 94.2500
# Epoch 64/100
# 5/5 [==============================] - 0s 59ms/step - loss: 9.2402e-04 - mae: 0.0239 - mape: 1308.2791 - val_loss: 3.4655e-04 - val_mae: 0.0219 - val_mape: 116.9451
# Epoch 65/100
# 5/5 [==============================] - 0s 55ms/step - loss: 7.9819e-04 - mae: 0.0238 - mape: 1603.0367 - val_loss: 2.1963e-04 - val_mae: 0.0158 - val_mape: 91.9165
# Epoch 66/100
# 5/5 [==============================] - 0s 62ms/step - loss: 8.2797e-04 - mae: 0.0231 - mape: 1323.7854 - val_loss: 2.5268e-04 - val_mae: 0.0179 - val_mape: 101.5350
# Epoch 67/100
# 5/5 [==============================] - 0s 54ms/step - loss: 7.8470e-04 - mae: 0.0227 - mape: 1485.3408 - val_loss: 2.6402e-04 - val_mae: 0.0182 - val_mape: 102.4169
# Epoch 68/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.6845e-04 - mae: 0.0229 - mape: 1272.4871 - val_loss: 3.3004e-04 - val_mae: 0.0212 - val_mape: 113.8950
# Epoch 69/100
# 5/5 [==============================] - 0s 59ms/step - loss: 8.2038e-04 - mae: 0.0230 - mape: 1361.8063 - val_loss: 3.7571e-04 - val_mae: 0.0227 - val_mape: 119.9194
# Epoch 70/100
# 5/5 [==============================] - 0s 54ms/step - loss: 8.3562e-04 - mae: 0.0233 - mape: 1655.8489 - val_loss: 2.2306e-04 - val_mae: 0.0161 - val_mape: 93.8483
# Epoch 71/100
# 5/5 [==============================] - 0s 55ms/step - loss: 8.2016e-04 - mae: 0.0230 - mape: 1248.4943 - val_loss: 2.3131e-04 - val_mae: 0.0169 - val_mape: 98.2846
# Epoch 72/100
# 5/5 [==============================] - 0s 55ms/step - loss: 7.2820e-04 - mae: 0.0226 - mape: 1327.4846 - val_loss: 3.7416e-04 - val_mae: 0.0228 - val_mape: 120.3720
# Epoch 73/100
# 5/5 [==============================] - 0s 65ms/step - loss: 8.0476e-04 - mae: 0.0231 - mape: 1683.8700 - val_loss: 2.1979e-04 - val_mae: 0.0158 - val_mape: 91.8041
# Epoch 74/100
# 5/5 [==============================] - 0s 80ms/step - loss: 8.0992e-04 - mae: 0.0231 - mape: 1344.2831 - val_loss: 2.2470e-04 - val_mae: 0.0162 - val_mape: 93.7036
# Epoch 75/100
# 5/5 [==============================] - 0s 66ms/step - loss: 7.4677e-04 - mae: 0.0225 - mape: 1384.0176 - val_loss: 2.7760e-04 - val_mae: 0.0190 - val_mape: 106.7988
# Epoch 76/100
# 5/5 [==============================] - 0s 59ms/step - loss: 7.9851e-04 - mae: 0.0223 - mape: 1384.4739 - val_loss: 2.7954e-04 - val_mae: 0.0191 - val_mape: 107.1189
# Epoch 77/100
# 5/5 [==============================] - 0s 54ms/step - loss: 7.3416e-04 - mae: 0.0223 - mape: 1288.3284 - val_loss: 3.6224e-04 - val_mae: 0.0225 - val_mape: 120.5338
# Epoch 78/100
# 5/5 [==============================] - 0s 56ms/step - loss: 7.4336e-04 - mae: 0.0224 - mape: 1396.8976 - val_loss: 3.9984e-04 - val_mae: 0.0239 - val_mape: 125.6859
# Epoch 79/100
# 5/5 [==============================] - 0s 56ms/step - loss: 7.5656e-04 - mae: 0.0223 - mape: 1454.1147 - val_loss: 2.1431e-04 - val_mae: 0.0156 - val_mape: 91.2242
# Epoch 80/100
# 5/5 [==============================] - 0s 58ms/step - loss: 7.1024e-04 - mae: 0.0220 - mape: 1304.4243 - val_loss: 2.2187e-04 - val_mae: 0.0160 - val_mape: 91.5821
# Epoch 81/100
# 5/5 [==============================] - 0s 82ms/step - loss: 7.2384e-04 - mae: 0.0220 - mape: 1293.5674 - val_loss: 2.2921e-04 - val_mae: 0.0160 - val_mape: 89.6589
# Epoch 82/100
# 5/5 [==============================] - 0s 62ms/step - loss: 7.0017e-04 - mae: 0.0222 - mape: 1268.2336 - val_loss: 2.3344e-04 - val_mae: 0.0170 - val_mape: 99.9286
# Epoch 83/100
# 5/5 [==============================] - 0s 56ms/step - loss: 6.9170e-04 - mae: 0.0219 - mape: 1255.5923 - val_loss: 4.1968e-04 - val_mae: 0.0245 - val_mape: 128.0763
# Epoch 84/100
# 5/5 [==============================] - 0s 55ms/step - loss: 7.8958e-04 - mae: 0.0220 - mape: 1277.2762 - val_loss: 2.2197e-04 - val_mae: 0.0162 - val_mape: 96.4073
# Epoch 85/100
# 5/5 [==============================] - 0s 68ms/step - loss: 8.0382e-04 - mae: 0.0220 - mape: 1257.9752 - val_loss: 2.3577e-04 - val_mae: 0.0165 - val_mape: 93.6783
# Epoch 86/100
# 5/5 [==============================] - 0s 65ms/step - loss: 8.2312e-04 - mae: 0.0226 - mape: 1379.6803 - val_loss: 2.3195e-04 - val_mae: 0.0162 - val_mape: 90.9690
# Epoch 87/100
# 5/5 [==============================] - 0s 58ms/step - loss: 7.4536e-04 - mae: 0.0219 - mape: 1296.4258 - val_loss: 2.2961e-04 - val_mae: 0.0162 - val_mape: 91.7437
# Epoch 88/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.9739e-04 - mae: 0.0217 - mape: 1308.8549 - val_loss: 2.3397e-04 - val_mae: 0.0161 - val_mape: 90.6452
# Epoch 89/100
# 5/5 [==============================] - 0s 61ms/step - loss: 7.0030e-04 - mae: 0.0214 - mape: 1352.2728 - val_loss: 2.3062e-04 - val_mae: 0.0163 - val_mape: 93.3456
# Epoch 90/100
# 5/5 [==============================] - 0s 58ms/step - loss: 6.3650e-04 - mae: 0.0211 - mape: 1269.2274 - val_loss: 2.2265e-04 - val_mae: 0.0159 - val_mape: 91.6379
# Epoch 91/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.2315e-04 - mae: 0.0212 - mape: 1280.5981 - val_loss: 2.4009e-04 - val_mae: 0.0171 - val_mape: 100.1372
# Epoch 92/100
# 5/5 [==============================] - 0s 63ms/step - loss: 7.0309e-04 - mae: 0.0208 - mape: 1244.3160 - val_loss: 2.3254e-04 - val_mae: 0.0165 - val_mape: 97.0793
# Epoch 93/100
# 5/5 [==============================] - 0s 63ms/step - loss: 6.4416e-04 - mae: 0.0213 - mape: 1246.1376 - val_loss: 3.0383e-04 - val_mae: 0.0203 - val_mape: 113.4043
# Epoch 94/100
# 5/5 [==============================] - 0s 55ms/step - loss: 7.5231e-04 - mae: 0.0228 - mape: 1357.4650 - val_loss: 3.6390e-04 - val_mae: 0.0227 - val_mape: 122.9977
# Epoch 95/100
# 5/5 [==============================] - 0s 54ms/step - loss: 6.8389e-04 - mae: 0.0221 - mape: 1252.8719 - val_loss: 2.3345e-04 - val_mae: 0.0169 - val_mape: 99.0574
# Epoch 96/100
# 5/5 [==============================] - 0s 54ms/step - loss: 6.8547e-04 - mae: 0.0208 - mape: 1253.1857 - val_loss: 2.5015e-04 - val_mae: 0.0177 - val_mape: 102.2535
# Epoch 97/100
# 5/5 [==============================] - 0s 58ms/step - loss: 6.5414e-04 - mae: 0.0204 - mape: 1261.9751 - val_loss: 2.8755e-04 - val_mae: 0.0196 - val_mape: 109.4195
# Epoch 98/100
# 5/5 [==============================] - 0s 51ms/step - loss: 6.8956e-04 - mae: 0.0209 - mape: 1496.3311 - val_loss: 4.3374e-04 - val_mae: 0.0251 - val_mape: 130.5552
# Epoch 99/100
# 5/5 [==============================] - 0s 58ms/step - loss: 7.6848e-04 - mae: 0.0213 - mape: 1354.6337 - val_loss: 4.2738e-04 - val_mae: 0.0249 - val_mape: 130.1368
# Epoch 100/100
# 5/5 [==============================] - 0s 59ms/step - loss: 6.2525e-04 - mae: 0.0205 - mape: 1292.0228 - val_loss: 3.5475e-04 - val_mae: 0.0222 - val_mape: 120.2613
# Ejecutando la lstm
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 4s 306ms/step - loss: 0.0083 - mae: 0.0892 - mape: 1808.0643 - val_loss: 7.1748e-04 - val_mae: 0.0302 - val_mape: 85.0595
# Epoch 2/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0064 - mae: 0.0704 - mape: 242.2742 - val_loss: 4.7806e-04 - val_mae: 0.0242 - val_mape: 102.5102
# Epoch 3/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0053 - mae: 0.0639 - mape: 2496.2224 - val_loss: 6.3283e-04 - val_mae: 0.0293 - val_mape: 139.4951
# Epoch 4/100
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0047 - mae: 0.0616 - mape: 3430.6396 - val_loss: 7.3050e-04 - val_mae: 0.0329 - val_mape: 162.2211
# Epoch 5/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0043 - mae: 0.0590 - mape: 3597.5198 - val_loss: 8.0371e-04 - val_mae: 0.0357 - val_mape: 173.5744
# Epoch 6/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0040 - mae: 0.0571 - mape: 2861.6956 - val_loss: 9.4827e-04 - val_mae: 0.0396 - val_mape: 185.6559
# Epoch 7/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0035 - mae: 0.0547 - mape: 3237.9387 - val_loss: 0.0012 - val_mae: 0.0443 - val_mape: 199.0413
# Epoch 8/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0029 - mae: 0.0501 - mape: 3021.1318 - val_loss: 0.0012 - val_mae: 0.0457 - val_mape: 199.6876
# Epoch 9/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0023 - mae: 0.0431 - mape: 1893.6130 - val_loss: 0.0012 - val_mae: 0.0435 - val_mape: 186.6161
# Epoch 10/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0016 - mae: 0.0355 - mape: 2129.7920 - val_loss: 2.6985e-04 - val_mae: 0.0183 - val_mape: 105.2812
# Epoch 11/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0017 - mae: 0.0314 - mape: 1485.3262 - val_loss: 1.9367e-04 - val_mae: 0.0147 - val_mape: 86.7829
# Epoch 12/100
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0016 - mae: 0.0340 - mape: 1650.5112 - val_loss: 7.1237e-04 - val_mae: 0.0332 - val_mape: 152.8660
# Epoch 13/100
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0013 - mae: 0.0366 - mape: 1644.0607 - val_loss: 4.0384e-04 - val_mae: 0.0235 - val_mape: 120.6026
# Epoch 14/100
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0011 - mae: 0.0281 - mape: 1470.8698 - val_loss: 2.2413e-04 - val_mae: 0.0165 - val_mape: 92.8260
# Epoch 15/100
# 5/5 [==============================] - 1s 174ms/step - loss: 9.8516e-04 - mae: 0.0268 - mape: 900.7853 - val_loss: 2.2633e-04 - val_mae: 0.0164 - val_mape: 90.7656
# Epoch 16/100
# 5/5 [==============================] - 1s 178ms/step - loss: 8.3896e-04 - mae: 0.0246 - mape: 1043.7534 - val_loss: 1.5707e-04 - val_mae: 0.0133 - val_mape: 75.6728
# Epoch 17/100
# 5/5 [==============================] - 1s 221ms/step - loss: 8.6736e-04 - mae: 0.0246 - mape: 2133.5854 - val_loss: 1.7777e-04 - val_mae: 0.0145 - val_mape: 82.5811
# Epoch 18/100
# 5/5 [==============================] - 1s 171ms/step - loss: 7.8594e-04 - mae: 0.0236 - mape: 895.7366 - val_loss: 2.4540e-04 - val_mae: 0.0175 - val_mape: 96.3293
# Epoch 19/100
# 5/5 [==============================] - 1s 175ms/step - loss: 7.6528e-04 - mae: 0.0240 - mape: 1173.4288 - val_loss: 2.3056e-04 - val_mae: 0.0169 - val_mape: 94.9461
# Epoch 20/100
# 5/5 [==============================] - 1s 175ms/step - loss: 7.2525e-04 - mae: 0.0231 - mape: 1135.3308 - val_loss: 2.1499e-04 - val_mae: 0.0162 - val_mape: 92.0103
# Epoch 21/100
# 5/5 [==============================] - 1s 183ms/step - loss: 7.3765e-04 - mae: 0.0226 - mape: 1412.2283 - val_loss: 1.7868e-04 - val_mae: 0.0145 - val_mape: 84.3887
# Epoch 22/100
# 5/5 [==============================] - 1s 171ms/step - loss: 7.2793e-04 - mae: 0.0224 - mape: 1054.9648 - val_loss: 2.3509e-04 - val_mae: 0.0171 - val_mape: 95.6493
# Epoch 23/100
# 5/5 [==============================] - 1s 167ms/step - loss: 7.3082e-04 - mae: 0.0222 - mape: 1850.4615 - val_loss: 1.8497e-04 - val_mae: 0.0148 - val_mape: 86.3470
# Epoch 24/100
# 5/5 [==============================] - 1s 162ms/step - loss: 7.3464e-04 - mae: 0.0218 - mape: 1420.1140 - val_loss: 2.4707e-04 - val_mae: 0.0178 - val_mape: 97.5214
# Epoch 25/100
# 5/5 [==============================] - 1s 169ms/step - loss: 6.8081e-04 - mae: 0.0216 - mape: 1171.8544 - val_loss: 1.8179e-04 - val_mae: 0.0148 - val_mape: 85.4770
# Epoch 26/100
# 5/5 [==============================] - 1s 163ms/step - loss: 6.6922e-04 - mae: 0.0210 - mape: 894.2709 - val_loss: 2.2929e-04 - val_mae: 0.0172 - val_mape: 94.7958
# Epoch 27/100
# 5/5 [==============================] - 1s 159ms/step - loss: 5.6324e-04 - mae: 0.0205 - mape: 1410.0061 - val_loss: 1.5897e-04 - val_mae: 0.0138 - val_mape: 81.2235
# Epoch 28/100
# 5/5 [==============================] - 1s 168ms/step - loss: 6.5786e-04 - mae: 0.0211 - mape: 1163.5306 - val_loss: 1.6906e-04 - val_mae: 0.0144 - val_mape: 84.1058
# Epoch 29/100
# 5/5 [==============================] - 1s 162ms/step - loss: 5.9812e-04 - mae: 0.0205 - mape: 1043.3051 - val_loss: 1.4999e-04 - val_mae: 0.0133 - val_mape: 79.6874
# Epoch 30/100
# 5/5 [==============================] - 1s 161ms/step - loss: 5.5539e-04 - mae: 0.0203 - mape: 1205.7004 - val_loss: 2.4315e-04 - val_mae: 0.0181 - val_mape: 99.1774
# Epoch 31/100
# 5/5 [==============================] - 1s 166ms/step - loss: 5.9876e-04 - mae: 0.0203 - mape: 1328.5363 - val_loss: 2.0711e-04 - val_mae: 0.0161 - val_mape: 90.2269
# Epoch 32/100
# 5/5 [==============================] - 1s 174ms/step - loss: 5.5961e-04 - mae: 0.0200 - mape: 1027.5912 - val_loss: 1.5373e-04 - val_mae: 0.0134 - val_mape: 78.4208
# Epoch 33/100
# 5/5 [==============================] - 1s 156ms/step - loss: 5.9681e-04 - mae: 0.0204 - mape: 1177.1562 - val_loss: 2.4539e-04 - val_mae: 0.0181 - val_mape: 98.2683
# Epoch 34/100
# 5/5 [==============================] - 1s 163ms/step - loss: 5.9776e-04 - mae: 0.0201 - mape: 1163.5022 - val_loss: 1.9559e-04 - val_mae: 0.0158 - val_mape: 88.9531
# Epoch 35/100
# 5/5 [==============================] - 1s 181ms/step - loss: 5.8621e-04 - mae: 0.0199 - mape: 1068.7716 - val_loss: 2.4704e-04 - val_mae: 0.0182 - val_mape: 95.6158
# Epoch 36/100
# 5/5 [==============================] - 1s 171ms/step - loss: 6.2678e-04 - mae: 0.0203 - mape: 860.0450 - val_loss: 1.2372e-04 - val_mae: 0.0118 - val_mape: 69.5361
# Epoch 37/100
# 5/5 [==============================] - 1s 190ms/step - loss: 5.6801e-04 - mae: 0.0199 - mape: 1482.6982 - val_loss: 1.5357e-04 - val_mae: 0.0137 - val_mape: 79.3521
# Epoch 38/100
# 5/5 [==============================] - 1s 185ms/step - loss: 5.3327e-04 - mae: 0.0195 - mape: 1080.1334 - val_loss: 3.0946e-04 - val_mae: 0.0211 - val_mape: 106.8414
# Epoch 39/100
# 5/5 [==============================] - 1s 217ms/step - loss: 6.0347e-04 - mae: 0.0208 - mape: 1053.9865 - val_loss: 1.1967e-04 - val_mae: 0.0116 - val_mape: 63.2835
# Epoch 40/100
# 5/5 [==============================] - 1s 195ms/step - loss: 5.6148e-04 - mae: 0.0202 - mape: 859.4603 - val_loss: 2.5067e-04 - val_mae: 0.0184 - val_mape: 96.9648
# Epoch 41/100
# 5/5 [==============================] - 1s 226ms/step - loss: 5.9058e-04 - mae: 0.0198 - mape: 1062.6045 - val_loss: 2.3951e-04 - val_mae: 0.0179 - val_mape: 95.4463
# Epoch 42/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.2911e-04 - mae: 0.0194 - mape: 1123.9719 - val_loss: 1.3065e-04 - val_mae: 0.0121 - val_mape: 70.8853
# Epoch 43/100
# 5/5 [==============================] - 1s 198ms/step - loss: 5.2156e-04 - mae: 0.0191 - mape: 1285.8223 - val_loss: 1.3680e-04 - val_mae: 0.0126 - val_mape: 73.5120
# Epoch 44/100
# 5/5 [==============================] - 1s 227ms/step - loss: 4.7994e-04 - mae: 0.0191 - mape: 1053.9429 - val_loss: 1.8327e-04 - val_mae: 0.0152 - val_mape: 84.7258
# Epoch 45/100
# 5/5 [==============================] - 1s 183ms/step - loss: 5.4277e-04 - mae: 0.0191 - mape: 1019.7148 - val_loss: 1.3211e-04 - val_mae: 0.0123 - val_mape: 72.7991
# Epoch 46/100
# 5/5 [==============================] - 1s 184ms/step - loss: 4.9939e-04 - mae: 0.0188 - mape: 1150.8594 - val_loss: 1.3796e-04 - val_mae: 0.0127 - val_mape: 74.4602
# Epoch 47/100
# 5/5 [==============================] - 1s 183ms/step - loss: 4.8077e-04 - mae: 0.0186 - mape: 1090.2878 - val_loss: 2.3299e-04 - val_mae: 0.0177 - val_mape: 93.4240
# Epoch 48/100
# 5/5 [==============================] - 1s 208ms/step - loss: 4.9766e-04 - mae: 0.0184 - mape: 979.4343 - val_loss: 1.4998e-04 - val_mae: 0.0133 - val_mape: 75.2031
# Epoch 49/100
# 5/5 [==============================] - 1s 180ms/step - loss: 5.5622e-04 - mae: 0.0190 - mape: 1091.6775 - val_loss: 1.1553e-04 - val_mae: 0.0114 - val_mape: 62.7593
# Epoch 50/100
# 5/5 [==============================] - 1s 175ms/step - loss: 5.3126e-04 - mae: 0.0202 - mape: 1409.5874 - val_loss: 3.4547e-04 - val_mae: 0.0226 - val_mape: 109.0853
# Epoch 51/100
# 5/5 [==============================] - 1s 180ms/step - loss: 5.8219e-04 - mae: 0.0201 - mape: 954.0989 - val_loss: 1.5538e-04 - val_mae: 0.0135 - val_mape: 75.2220
# Epoch 52/100
# 5/5 [==============================] - 1s 184ms/step - loss: 5.1159e-04 - mae: 0.0188 - mape: 1398.8993 - val_loss: 1.2250e-04 - val_mae: 0.0118 - val_mape: 62.5888
# Epoch 53/100
# 5/5 [==============================] - 1s 238ms/step - loss: 5.4894e-04 - mae: 0.0204 - mape: 1094.2603 - val_loss: 4.6681e-04 - val_mae: 0.0266 - val_mape: 121.1545
# Epoch 54/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.5572e-04 - mae: 0.0201 - mape: 1041.2228 - val_loss: 1.2956e-04 - val_mae: 0.0122 - val_mape: 71.9566
# Epoch 55/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.2409e-04 - mae: 0.0190 - mape: 1265.9071 - val_loss: 1.2703e-04 - val_mae: 0.0119 - val_mape: 64.8543
# Epoch 56/100
# 5/5 [==============================] - 1s 255ms/step - loss: 5.4381e-04 - mae: 0.0203 - mape: 1201.5791 - val_loss: 6.3886e-04 - val_mae: 0.0320 - val_mape: 140.1634
# Epoch 57/100
# 5/5 [==============================] - 1s 184ms/step - loss: 5.0784e-04 - mae: 0.0209 - mape: 1613.7760 - val_loss: 1.2973e-04 - val_mae: 0.0120 - val_mape: 64.1393
# Epoch 58/100
# 5/5 [==============================] - 1s 193ms/step - loss: 5.2416e-04 - mae: 0.0194 - mape: 1243.2729 - val_loss: 1.7125e-04 - val_mae: 0.0140 - val_mape: 78.9023
# Epoch 59/100
# 5/5 [==============================] - 1s 179ms/step - loss: 4.7648e-04 - mae: 0.0185 - mape: 1344.1382 - val_loss: 1.9145e-04 - val_mae: 0.0154 - val_mape: 85.5680
# Epoch 60/100
# 5/5 [==============================] - 1s 170ms/step - loss: 4.6608e-04 - mae: 0.0182 - mape: 1131.1133 - val_loss: 1.2479e-04 - val_mae: 0.0120 - val_mape: 70.8101
# Epoch 61/100
# 5/5 [==============================] - 1s 175ms/step - loss: 4.5779e-04 - mae: 0.0182 - mape: 1031.6149 - val_loss: 1.5645e-04 - val_mae: 0.0137 - val_mape: 77.6647
# Epoch 62/100
# 5/5 [==============================] - 1s 181ms/step - loss: 4.3483e-04 - mae: 0.0176 - mape: 1032.1274 - val_loss: 1.1968e-04 - val_mae: 0.0116 - val_mape: 66.6579
# Epoch 63/100
# 5/5 [==============================] - 1s 174ms/step - loss: 4.7104e-04 - mae: 0.0185 - mape: 1204.8263 - val_loss: 3.0679e-04 - val_mae: 0.0207 - val_mape: 102.2719
# Epoch 64/100
# 5/5 [==============================] - 1s 179ms/step - loss: 4.8386e-04 - mae: 0.0186 - mape: 1553.9171 - val_loss: 1.1741e-04 - val_mae: 0.0115 - val_mape: 65.0833
# Epoch 65/100
# 5/5 [==============================] - 1s 200ms/step - loss: 4.9692e-04 - mae: 0.0183 - mape: 1164.4231 - val_loss: 2.1231e-04 - val_mae: 0.0163 - val_mape: 86.7795
# Epoch 66/100
# 5/5 [==============================] - 1s 176ms/step - loss: 4.8014e-04 - mae: 0.0179 - mape: 1075.1813 - val_loss: 1.5087e-04 - val_mae: 0.0134 - val_mape: 76.7885
# Epoch 67/100
# 5/5 [==============================] - 1s 191ms/step - loss: 4.3889e-04 - mae: 0.0173 - mape: 1258.6659 - val_loss: 1.2551e-04 - val_mae: 0.0120 - val_mape: 69.8418
# Epoch 68/100
# 5/5 [==============================] - 1s 168ms/step - loss: 3.9902e-04 - mae: 0.0172 - mape: 1110.5288 - val_loss: 1.8595e-04 - val_mae: 0.0151 - val_mape: 81.3997
# Epoch 69/100
# 5/5 [==============================] - 1s 183ms/step - loss: 4.6434e-04 - mae: 0.0177 - mape: 1595.8284 - val_loss: 1.3819e-04 - val_mae: 0.0126 - val_mape: 71.8950
# Epoch 70/100
# 5/5 [==============================] - 1s 203ms/step - loss: 3.8857e-04 - mae: 0.0170 - mape: 1111.5372 - val_loss: 1.1827e-04 - val_mae: 0.0116 - val_mape: 67.1523
# Epoch 71/100
# 5/5 [==============================] - 1s 184ms/step - loss: 4.4292e-04 - mae: 0.0174 - mape: 1196.3282 - val_loss: 1.6578e-04 - val_mae: 0.0143 - val_mape: 78.3724
# Epoch 72/100
# 5/5 [==============================] - 1s 192ms/step - loss: 4.7590e-04 - mae: 0.0177 - mape: 1053.2247 - val_loss: 1.3178e-04 - val_mae: 0.0123 - val_mape: 70.0584
# Epoch 73/100
# 5/5 [==============================] - 1s 179ms/step - loss: 4.4736e-04 - mae: 0.0175 - mape: 1045.1143 - val_loss: 1.1230e-04 - val_mae: 0.0112 - val_mape: 64.5255
# Epoch 74/100
# 5/5 [==============================] - 1s 180ms/step - loss: 4.4567e-04 - mae: 0.0174 - mape: 1280.7275 - val_loss: 2.6093e-04 - val_mae: 0.0188 - val_mape: 94.9531
# Epoch 75/100
# 5/5 [==============================] - 1s 207ms/step - loss: 4.1697e-04 - mae: 0.0177 - mape: 1216.5115 - val_loss: 1.1697e-04 - val_mae: 0.0114 - val_mape: 64.4292
# Epoch 76/100
# 5/5 [==============================] - 1s 183ms/step - loss: 4.2153e-04 - mae: 0.0173 - mape: 1244.5350 - val_loss: 1.2915e-04 - val_mae: 0.0122 - val_mape: 71.2219
# Epoch 77/100
# 5/5 [==============================] - 1s 267ms/step - loss: 5.0542e-04 - mae: 0.0183 - mape: 1055.7307 - val_loss: 2.8842e-04 - val_mae: 0.0198 - val_mape: 95.8677
# Epoch 78/100
# 5/5 [==============================] - 1s 188ms/step - loss: 4.6581e-04 - mae: 0.0188 - mape: 1163.1653 - val_loss: 1.5376e-04 - val_mae: 0.0133 - val_mape: 62.7243
# Epoch 79/100
# 5/5 [==============================] - 1s 186ms/step - loss: 5.7301e-04 - mae: 0.0200 - mape: 1642.6608 - val_loss: 1.1736e-04 - val_mae: 0.0115 - val_mape: 66.6596
# Epoch 80/100
# 5/5 [==============================] - 1s 177ms/step - loss: 6.4273e-04 - mae: 0.0214 - mape: 1101.6887 - val_loss: 8.7887e-04 - val_mae: 0.0382 - val_mape: 161.4034
# Epoch 81/100
# 5/5 [==============================] - 1s 184ms/step - loss: 5.5412e-04 - mae: 0.0219 - mape: 1231.7714 - val_loss: 1.4998e-04 - val_mae: 0.0129 - val_mape: 66.7269
# Epoch 82/100
# 5/5 [==============================] - 1s 183ms/step - loss: 5.2909e-04 - mae: 0.0203 - mape: 1217.3258 - val_loss: 1.3824e-04 - val_mae: 0.0124 - val_mape: 68.9786
# Epoch 83/100
# 5/5 [==============================] - 1s 189ms/step - loss: 4.9941e-04 - mae: 0.0193 - mape: 1264.7860 - val_loss: 4.3190e-04 - val_mae: 0.0243 - val_mape: 115.8592
# Epoch 84/100
# 5/5 [==============================] - 1s 199ms/step - loss: 4.8116e-04 - mae: 0.0200 - mape: 1327.3972 - val_loss: 1.3205e-04 - val_mae: 0.0122 - val_mape: 71.0509
# Epoch 85/100
# 5/5 [==============================] - 1s 193ms/step - loss: 4.3719e-04 - mae: 0.0183 - mape: 1519.5007 - val_loss: 1.9359e-04 - val_mae: 0.0149 - val_mape: 83.6519
# Epoch 86/100
# 5/5 [==============================] - 1s 179ms/step - loss: 4.5960e-04 - mae: 0.0180 - mape: 1146.1816 - val_loss: 1.2886e-04 - val_mae: 0.0121 - val_mape: 71.0269
# Epoch 87/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.1619e-04 - mae: 0.0189 - mape: 1285.0693 - val_loss: 3.4536e-04 - val_mae: 0.0215 - val_mape: 105.7434
# Epoch 88/100
# 5/5 [==============================] - 1s 175ms/step - loss: 4.9786e-04 - mae: 0.0188 - mape: 1352.1862 - val_loss: 1.3999e-04 - val_mae: 0.0125 - val_mape: 65.5423
# Epoch 89/100
# 5/5 [==============================] - 1s 184ms/step - loss: 4.6302e-04 - mae: 0.0195 - mape: 1285.8318 - val_loss: 3.1991e-04 - val_mae: 0.0199 - val_mape: 98.9696
# Epoch 90/100
# 5/5 [==============================] - 1s 178ms/step - loss: 4.7057e-04 - mae: 0.0188 - mape: 1246.0061 - val_loss: 1.3237e-04 - val_mae: 0.0122 - val_mape: 68.6022
# Epoch 91/100
# 5/5 [==============================] - 1s 173ms/step - loss: 4.8874e-04 - mae: 0.0195 - mape: 1117.4752 - val_loss: 3.4229e-04 - val_mae: 0.0207 - val_mape: 102.5444
# Epoch 92/100
# 5/5 [==============================] - 1s 170ms/step - loss: 5.1921e-04 - mae: 0.0198 - mape: 1192.9075 - val_loss: 1.4505e-04 - val_mae: 0.0127 - val_mape: 68.7077
# Epoch 93/100
# 5/5 [==============================] - 1s 167ms/step - loss: 5.3411e-04 - mae: 0.0205 - mape: 1409.6539 - val_loss: 3.0605e-04 - val_mae: 0.0196 - val_mape: 100.3256
# Epoch 94/100
# 5/5 [==============================] - 1s 171ms/step - loss: 5.1189e-04 - mae: 0.0205 - mape: 1294.4949 - val_loss: 1.4397e-04 - val_mae: 0.0127 - val_mape: 69.8114
# Epoch 95/100
# 5/5 [==============================] - 1s 175ms/step - loss: 7.1376e-04 - mae: 0.0235 - mape: 1389.6945 - val_loss: 3.1664e-04 - val_mae: 0.0200 - val_mape: 101.8698
# Epoch 96/100
# 5/5 [==============================] - 1s 185ms/step - loss: 5.8608e-04 - mae: 0.0231 - mape: 1333.3522 - val_loss: 1.4540e-04 - val_mae: 0.0127 - val_mape: 71.0763
# Epoch 97/100
# 5/5 [==============================] - 1s 179ms/step - loss: 7.2053e-04 - mae: 0.0239 - mape: 1399.5363 - val_loss: 1.7852e-04 - val_mae: 0.0144 - val_mape: 81.9971
# Epoch 98/100
# 5/5 [==============================] - 1s 175ms/step - loss: 6.8531e-04 - mae: 0.0223 - mape: 1242.7893 - val_loss: 1.4356e-04 - val_mae: 0.0130 - val_mape: 76.6368
# Epoch 99/100
# 5/5 [==============================] - 1s 177ms/step - loss: 6.9964e-04 - mae: 0.0226 - mape: 1518.5414 - val_loss: 1.4505e-04 - val_mae: 0.0131 - val_mape: 77.9574
# Epoch 100/100
# 5/5 [==============================] - 1s 175ms/step - loss: 4.0415e-04 - mae: 0.0185 - mape: 1375.9829 - val_loss: 4.4626e-04 - val_mae: 0.0240 - val_mape: 109.9282
# Ejecutando la gru
# Prediction lookback (n_steps): 72
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 4s 320ms/step - loss: 0.0075 - mae: 0.0820 - mape: 1260.0010 - val_loss: 5.0626e-04 - val_mae: 0.0241 - val_mape: 97.0484
# Epoch 2/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0054 - mae: 0.0660 - mape: 1475.4182 - val_loss: 0.0012 - val_mae: 0.0394 - val_mape: 172.6838
# Epoch 3/100
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0047 - mae: 0.0648 - mape: 4914.5903 - val_loss: 0.0012 - val_mae: 0.0423 - val_mape: 188.3876
# Epoch 4/100
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0043 - mae: 0.0605 - mape: 2246.4407 - val_loss: 0.0010 - val_mae: 0.0397 - val_mape: 179.4647
# Epoch 5/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0039 - mae: 0.0557 - mape: 2148.5894 - val_loss: 0.0013 - val_mae: 0.0459 - val_mape: 199.2022
# Epoch 6/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0035 - mae: 0.0540 - mape: 3502.1003 - val_loss: 0.0019 - val_mae: 0.0556 - val_mape: 230.5088
# Epoch 7/100
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0031 - mae: 0.0515 - mape: 3668.8250 - val_loss: 0.0019 - val_mae: 0.0569 - val_mape: 233.8029
# Epoch 8/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0026 - mae: 0.0458 - mape: 848.8086 - val_loss: 0.0022 - val_mae: 0.0613 - val_mape: 245.8390
# Epoch 9/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0023 - mae: 0.0430 - mape: 1992.6985 - val_loss: 0.0026 - val_mae: 0.0659 - val_mape: 256.7453
# Epoch 10/100
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0017 - mae: 0.0368 - mape: 2211.2073 - val_loss: 0.0022 - val_mae: 0.0593 - val_mape: 231.5232
# Epoch 11/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.0012 - mae: 0.0313 - mape: 1958.9091 - val_loss: 0.0015 - val_mae: 0.0478 - val_mape: 193.0583
# Epoch 12/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0011 - mae: 0.0277 - mape: 1221.1951 - val_loss: 4.2127e-04 - val_mae: 0.0228 - val_mape: 114.5547
# Epoch 13/100
# 5/5 [==============================] - 1s 145ms/step - loss: 9.5820e-04 - mae: 0.0266 - mape: 1435.9698 - val_loss: 7.2103e-04 - val_mae: 0.0323 - val_mape: 148.4679
# Epoch 14/100
# 5/5 [==============================] - 1s 145ms/step - loss: 9.9966e-04 - mae: 0.0269 - mape: 1373.3784 - val_loss: 3.7834e-04 - val_mae: 0.0227 - val_mape: 117.5285
# Epoch 15/100
# 5/5 [==============================] - 1s 155ms/step - loss: 8.7458e-04 - mae: 0.0258 - mape: 709.1329 - val_loss: 0.0014 - val_mae: 0.0485 - val_mape: 198.5616
# Epoch 16/100
# 5/5 [==============================] - 1s 148ms/step - loss: 9.1305e-04 - mae: 0.0278 - mape: 1879.1328 - val_loss: 3.4179e-04 - val_mae: 0.0212 - val_mape: 109.1627
# Epoch 17/100
# 5/5 [==============================] - 1s 145ms/step - loss: 9.9565e-04 - mae: 0.0268 - mape: 1183.1439 - val_loss: 0.0019 - val_mae: 0.0562 - val_mape: 221.5846
# Epoch 18/100
# 5/5 [==============================] - 1s 170ms/step - loss: 9.6127e-04 - mae: 0.0283 - mape: 1220.1202 - val_loss: 2.6310e-04 - val_mae: 0.0182 - val_mape: 99.6268
# Epoch 19/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0014 - mae: 0.0317 - mape: 1360.0015 - val_loss: 0.0011 - val_mae: 0.0431 - val_mape: 182.1027
# Epoch 20/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0011 - mae: 0.0314 - mape: 1786.9685 - val_loss: 4.5830e-04 - val_mae: 0.0256 - val_mape: 126.8648
# Epoch 21/100
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0012 - mae: 0.0298 - mape: 1045.2661 - val_loss: 4.4248e-04 - val_mae: 0.0252 - val_mape: 125.8979
# Epoch 22/100
# 5/5 [==============================] - 1s 162ms/step - loss: 8.7290e-04 - mae: 0.0263 - mape: 1217.6086 - val_loss: 0.0016 - val_mae: 0.0521 - val_mape: 209.1680
# Epoch 23/100
# 5/5 [==============================] - 1s 162ms/step - loss: 8.1283e-04 - mae: 0.0255 - mape: 2083.2527 - val_loss: 3.7182e-04 - val_mae: 0.0226 - val_mape: 115.8354
# Epoch 24/100
# 5/5 [==============================] - 1s 161ms/step - loss: 9.1354e-04 - mae: 0.0254 - mape: 1276.9448 - val_loss: 7.9279e-04 - val_mae: 0.0350 - val_mape: 154.8402
# Epoch 25/100
# 5/5 [==============================] - 1s 160ms/step - loss: 8.5637e-04 - mae: 0.0254 - mape: 1717.5533 - val_loss: 6.0534e-04 - val_mae: 0.0299 - val_mape: 139.0476
# Epoch 26/100
# 5/5 [==============================] - 1s 170ms/step - loss: 7.7859e-04 - mae: 0.0234 - mape: 1113.8782 - val_loss: 5.2820e-04 - val_mae: 0.0278 - val_mape: 133.1311
# Epoch 27/100
# 5/5 [==============================] - 1s 167ms/step - loss: 7.3725e-04 - mae: 0.0228 - mape: 1021.6125 - val_loss: 9.3565e-04 - val_mae: 0.0388 - val_mape: 168.6946
# Epoch 28/100
# 5/5 [==============================] - 1s 168ms/step - loss: 7.3524e-04 - mae: 0.0231 - mape: 963.6559 - val_loss: 5.0707e-04 - val_mae: 0.0272 - val_mape: 131.6323
# Epoch 29/100
# 5/5 [==============================] - 1s 170ms/step - loss: 6.3714e-04 - mae: 0.0219 - mape: 1012.0401 - val_loss: 8.1547e-04 - val_mae: 0.0358 - val_mape: 159.0433
# Epoch 30/100
# 5/5 [==============================] - 1s 174ms/step - loss: 6.5671e-04 - mae: 0.0222 - mape: 1120.3286 - val_loss: 5.2288e-04 - val_mae: 0.0276 - val_mape: 132.2385
# Epoch 31/100
# 5/5 [==============================] - 1s 187ms/step - loss: 6.9576e-04 - mae: 0.0222 - mape: 807.5189 - val_loss: 8.6165e-04 - val_mae: 0.0371 - val_mape: 162.6637
# Epoch 32/100
# 5/5 [==============================] - 1s 158ms/step - loss: 7.1969e-04 - mae: 0.0234 - mape: 882.5178 - val_loss: 6.2401e-04 - val_mae: 0.0305 - val_mape: 140.8984
# Epoch 33/100
# 5/5 [==============================] - 1s 147ms/step - loss: 6.8398e-04 - mae: 0.0220 - mape: 868.3694 - val_loss: 7.1388e-04 - val_mae: 0.0330 - val_mape: 149.5990
# Epoch 34/100
# 5/5 [==============================] - 1s 158ms/step - loss: 6.6790e-04 - mae: 0.0216 - mape: 1361.9183 - val_loss: 6.2158e-04 - val_mae: 0.0305 - val_mape: 141.7024
# Epoch 35/100
# 5/5 [==============================] - 1s 147ms/step - loss: 5.7855e-04 - mae: 0.0208 - mape: 1072.9764 - val_loss: 7.2347e-04 - val_mae: 0.0333 - val_mape: 151.8155
# Epoch 36/100
# 5/5 [==============================] - 1s 155ms/step - loss: 6.9115e-04 - mae: 0.0219 - mape: 1125.2972 - val_loss: 6.4579e-04 - val_mae: 0.0310 - val_mape: 144.0331
# Epoch 37/100
# 5/5 [==============================] - 1s 158ms/step - loss: 6.9013e-04 - mae: 0.0214 - mape: 1046.3816 - val_loss: 7.2085e-04 - val_mae: 0.0330 - val_mape: 150.7800
# Epoch 38/100
# 5/5 [==============================] - 1s 151ms/step - loss: 5.8631e-04 - mae: 0.0205 - mape: 1003.9899 - val_loss: 5.8396e-04 - val_mae: 0.0291 - val_mape: 137.7948
# Epoch 39/100
# 5/5 [==============================] - 1s 147ms/step - loss: 5.9603e-04 - mae: 0.0203 - mape: 1482.5901 - val_loss: 7.6513e-04 - val_mae: 0.0344 - val_mape: 155.3477
# Epoch 40/100
# 5/5 [==============================] - 1s 142ms/step - loss: 5.9379e-04 - mae: 0.0206 - mape: 1617.0302 - val_loss: 4.8335e-04 - val_mae: 0.0261 - val_mape: 126.8860
# Epoch 41/100
# 5/5 [==============================] - 1s 141ms/step - loss: 6.2327e-04 - mae: 0.0205 - mape: 916.0742 - val_loss: 7.1682e-04 - val_mae: 0.0331 - val_mape: 151.9640
# Epoch 42/100
# 5/5 [==============================] - 1s 163ms/step - loss: 5.7468e-04 - mae: 0.0198 - mape: 1257.2010 - val_loss: 5.6462e-04 - val_mae: 0.0287 - val_mape: 137.1260
# Epoch 43/100
# 5/5 [==============================] - 1s 155ms/step - loss: 4.8551e-04 - mae: 0.0191 - mape: 1449.1228 - val_loss: 6.7551e-04 - val_mae: 0.0319 - val_mape: 148.4203
# Epoch 44/100
# 5/5 [==============================] - 1s 162ms/step - loss: 5.6781e-04 - mae: 0.0198 - mape: 1230.6794 - val_loss: 5.7681e-04 - val_mae: 0.0291 - val_mape: 138.0097
# Epoch 45/100
# 5/5 [==============================] - 1s 152ms/step - loss: 6.1645e-04 - mae: 0.0205 - mape: 1059.5632 - val_loss: 6.9830e-04 - val_mae: 0.0327 - val_mape: 150.0916
# Epoch 46/100
# 5/5 [==============================] - 1s 158ms/step - loss: 5.4552e-04 - mae: 0.0194 - mape: 1059.2428 - val_loss: 5.6387e-04 - val_mae: 0.0288 - val_mape: 135.3749
# Epoch 47/100
# 5/5 [==============================] - 1s 171ms/step - loss: 5.5521e-04 - mae: 0.0196 - mape: 881.3890 - val_loss: 4.8122e-04 - val_mae: 0.0263 - val_mape: 126.1509
# Epoch 48/100
# 5/5 [==============================] - 1s 146ms/step - loss: 5.3480e-04 - mae: 0.0193 - mape: 1097.2141 - val_loss: 7.8157e-04 - val_mae: 0.0351 - val_mape: 157.2583
# Epoch 49/100
# 5/5 [==============================] - 1s 142ms/step - loss: 5.7100e-04 - mae: 0.0200 - mape: 987.3334 - val_loss: 3.0902e-04 - val_mae: 0.0200 - val_mape: 103.0067
# Epoch 50/100
# 5/5 [==============================] - 1s 154ms/step - loss: 5.8142e-04 - mae: 0.0202 - mape: 923.9071 - val_loss: 6.7126e-04 - val_mae: 0.0318 - val_mape: 146.7618
# Epoch 51/100
# 5/5 [==============================] - 1s 168ms/step - loss: 5.1930e-04 - mae: 0.0190 - mape: 1116.2838 - val_loss: 4.7826e-04 - val_mae: 0.0260 - val_mape: 127.4777
# Epoch 52/100
# 5/5 [==============================] - 1s 151ms/step - loss: 5.2106e-04 - mae: 0.0190 - mape: 1101.8448 - val_loss: 6.5676e-04 - val_mae: 0.0313 - val_mape: 144.6238
# Epoch 53/100
# 5/5 [==============================] - 1s 154ms/step - loss: 5.0850e-04 - mae: 0.0190 - mape: 969.3459 - val_loss: 4.6081e-04 - val_mae: 0.0253 - val_mape: 122.4941
# Epoch 54/100
# 5/5 [==============================] - 1s 141ms/step - loss: 5.0451e-04 - mae: 0.0188 - mape: 1114.6359 - val_loss: 4.3717e-04 - val_mae: 0.0247 - val_mape: 121.3507
# Epoch 55/100
# 5/5 [==============================] - 1s 166ms/step - loss: 5.4747e-04 - mae: 0.0196 - mape: 1330.9471 - val_loss: 9.2354e-04 - val_mae: 0.0387 - val_mape: 170.0493
# Epoch 56/100
# 5/5 [==============================] - 1s 167ms/step - loss: 5.4821e-04 - mae: 0.0196 - mape: 1590.0856 - val_loss: 2.2395e-04 - val_mae: 0.0163 - val_mape: 88.5881
# Epoch 57/100
# 5/5 [==============================] - 1s 193ms/step - loss: 5.7178e-04 - mae: 0.0199 - mape: 900.3529 - val_loss: 4.5424e-04 - val_mae: 0.0252 - val_mape: 123.0886
# Epoch 58/100
# 5/5 [==============================] - 1s 161ms/step - loss: 5.2765e-04 - mae: 0.0195 - mape: 1370.0460 - val_loss: 0.0010 - val_mae: 0.0410 - val_mape: 179.3641
# Epoch 59/100
# 5/5 [==============================] - 1s 153ms/step - loss: 5.3170e-04 - mae: 0.0202 - mape: 1421.4452 - val_loss: 1.7644e-04 - val_mae: 0.0144 - val_mape: 80.9454
# Epoch 60/100
# 5/5 [==============================] - 1s 158ms/step - loss: 5.5442e-04 - mae: 0.0200 - mape: 921.8676 - val_loss: 6.7007e-04 - val_mae: 0.0315 - val_mape: 143.3849
# Epoch 61/100
# 5/5 [==============================] - 1s 167ms/step - loss: 5.3160e-04 - mae: 0.0188 - mape: 1091.3175 - val_loss: 4.6938e-04 - val_mae: 0.0257 - val_mape: 124.5972
# Epoch 62/100
# 5/5 [==============================] - 1s 177ms/step - loss: 4.4622e-04 - mae: 0.0184 - mape: 993.6348 - val_loss: 7.4589e-04 - val_mae: 0.0340 - val_mape: 151.3929
# Epoch 63/100
# 5/5 [==============================] - 1s 177ms/step - loss: 4.9221e-04 - mae: 0.0188 - mape: 1033.2941 - val_loss: 2.8311e-04 - val_mae: 0.0187 - val_mape: 97.6900
# Epoch 64/100
# 5/5 [==============================] - 1s 222ms/step - loss: 5.0249e-04 - mae: 0.0191 - mape: 919.2968 - val_loss: 3.6350e-04 - val_mae: 0.0220 - val_mape: 109.9367
# Epoch 65/100
# 5/5 [==============================] - 1s 210ms/step - loss: 4.3479e-04 - mae: 0.0181 - mape: 1033.8264 - val_loss: 5.5202e-04 - val_mae: 0.0287 - val_mape: 135.1825
# Epoch 66/100
# 5/5 [==============================] - 1s 176ms/step - loss: 4.7672e-04 - mae: 0.0185 - mape: 1546.8896 - val_loss: 3.3216e-04 - val_mae: 0.0211 - val_mape: 109.2067
# Epoch 67/100
# 5/5 [==============================] - 1s 173ms/step - loss: 4.6637e-04 - mae: 0.0181 - mape: 1269.0260 - val_loss: 3.2672e-04 - val_mae: 0.0208 - val_mape: 108.3108
# Epoch 68/100
# 5/5 [==============================] - 1s 168ms/step - loss: 4.6060e-04 - mae: 0.0182 - mape: 1638.6749 - val_loss: 4.6187e-04 - val_mae: 0.0257 - val_mape: 124.8679
# ...
# Epoch 11/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0018 - mae: 0.0351 - mape: 1671.0789 - val_loss: 6.9303e-04 - val_mae: 0.0268 - val_mape: 75.5968
# Epoch 12/100
# 5/5 [==============================] - 1s 96ms/step - loss: 0.0011 - mae: 0.0315 - mape: 1379.1311 - val_loss: 6.8550e-04 - val_mae: 0.0316 - val_mape: 105.8085
# Epoch 13/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0012 - mae: 0.0313 - mape: 1613.5031 - val_loss: 4.8669e-04 - val_mae: 0.0238 - val_mape: 72.2174
# Epoch 14/100
# 5/5 [==============================] - 1s 156ms/step - loss: 9.3128e-04 - mae: 0.0262 - mape: 737.5714 - val_loss: 3.7574e-04 - val_mae: 0.0219 - val_mape: 71.3549
# Epoch 15/100
# 5/5 [==============================] - 1s 170ms/step - loss: 9.8751e-04 - mae: 0.0262 - mape: 1226.7505 - val_loss: 3.2996e-04 - val_mae: 0.0200 - val_mape: 62.2677
# Epoch 16/100
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0011 - mae: 0.0268 - mape: 129.1528 - val_loss: 3.6847e-04 - val_mae: 0.0209 - val_mape: 64.0721
# Epoch 17/100
# 5/5 [==============================] - 0s 97ms/step - loss: 9.8958e-04 - mae: 0.0270 - mape: 1148.5514 - val_loss: 3.7287e-04 - val_mae: 0.0223 - val_mape: 75.4859
# Epoch 18/100
# 5/5 [==============================] - 1s 114ms/step - loss: 9.5310e-04 - mae: 0.0258 - mape: 1195.9736 - val_loss: 3.8455e-04 - val_mae: 0.0213 - val_mape: 64.9432
# Epoch 19/100
# 5/5 [==============================] - 1s 130ms/step - loss: 8.7525e-04 - mae: 0.0249 - mape: 1084.8160 - val_loss: 3.5206e-04 - val_mae: 0.0216 - val_mape: 72.4000
# Epoch 20/100
# 5/5 [==============================] - 1s 141ms/step - loss: 7.7214e-04 - mae: 0.0238 - mape: 814.3633 - val_loss: 2.9928e-04 - val_mae: 0.0187 - val_mape: 56.5904
# Epoch 21/100
# 5/5 [==============================] - 1s 202ms/step - loss: 7.9341e-04 - mae: 0.0230 - mape: 820.8898 - val_loss: 2.8696e-04 - val_mae: 0.0188 - val_mape: 61.1343
# Epoch 22/100
# 5/5 [==============================] - 1s 201ms/step - loss: 7.4182e-04 - mae: 0.0226 - mape: 292.4939 - val_loss: 3.1040e-04 - val_mae: 0.0196 - val_mape: 63.3371
# Epoch 23/100
# 5/5 [==============================] - 1s 147ms/step - loss: 7.7079e-04 - mae: 0.0227 - mape: 1809.0419 - val_loss: 2.8835e-04 - val_mae: 0.0188 - val_mape: 61.1246
# Epoch 24/100
# 5/5 [==============================] - 1s 179ms/step - loss: 7.7950e-04 - mae: 0.0223 - mape: 1384.0103 - val_loss: 2.8680e-04 - val_mae: 0.0186 - val_mape: 59.5310
# Epoch 25/100
# 5/5 [==============================] - 1s 221ms/step - loss: 6.6885e-04 - mae: 0.0218 - mape: 1145.0032 - val_loss: 2.6803e-04 - val_mae: 0.0180 - val_mape: 57.7782
# Epoch 26/100
# 5/5 [==============================] - 1s 144ms/step - loss: 7.2802e-04 - mae: 0.0219 - mape: 904.5058 - val_loss: 2.7857e-04 - val_mae: 0.0185 - val_mape: 60.8152
# Epoch 27/100
# 5/5 [==============================] - 1s 195ms/step - loss: 7.4764e-04 - mae: 0.0219 - mape: 1329.2052 - val_loss: 2.7056e-04 - val_mae: 0.0180 - val_mape: 58.4487
# Epoch 28/100
# 5/5 [==============================] - 1s 177ms/step - loss: 6.7064e-04 - mae: 0.0215 - mape: 1069.5909 - val_loss: 3.0796e-04 - val_mae: 0.0199 - val_mape: 67.3689
# Epoch 29/100
# 5/5 [==============================] - 1s 136ms/step - loss: 7.4796e-04 - mae: 0.0225 - mape: 891.7679 - val_loss: 2.5068e-04 - val_mae: 0.0167 - val_mape: 48.7687
# Epoch 30/100
# 5/5 [==============================] - 1s 162ms/step - loss: 6.8662e-04 - mae: 0.0228 - mape: 2225.8584 - val_loss: 3.6770e-04 - val_mae: 0.0223 - val_mape: 77.2780
# Epoch 31/100
# 5/5 [==============================] - 1s 180ms/step - loss: 7.6156e-04 - mae: 0.0256 - mape: 1689.9639 - val_loss: 2.7442e-04 - val_mae: 0.0183 - val_mape: 59.9754
# Epoch 32/100
# 5/5 [==============================] - 1s 144ms/step - loss: 8.1576e-04 - mae: 0.0240 - mape: 1750.8876 - val_loss: 2.8475e-04 - val_mae: 0.0187 - val_mape: 60.5654
# Epoch 33/100
# 5/5 [==============================] - 1s 166ms/step - loss: 8.2485e-04 - mae: 0.0247 - mape: 1522.3940 - val_loss: 2.7991e-04 - val_mae: 0.0187 - val_mape: 61.4363
# Epoch 34/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0011 - mae: 0.0285 - mape: 646.3342 - val_loss: 4.0974e-04 - val_mae: 0.0222 - val_mape: 68.6153
# Epoch 35/100
# 5/5 [==============================] - 1s 137ms/step - loss: 8.2710e-04 - mae: 0.0285 - mape: 1630.8684 - val_loss: 4.3070e-04 - val_mae: 0.0247 - val_mape: 85.8731
# Epoch 36/100
# 5/5 [==============================] - 1s 177ms/step - loss: 7.8313e-04 - mae: 0.0253 - mape: 1126.6433 - val_loss: 3.0212e-04 - val_mae: 0.0180 - val_mape: 50.2598
# Epoch 37/100
# 5/5 [==============================] - 1s 161ms/step - loss: 7.5868e-04 - mae: 0.0229 - mape: 827.0164 - val_loss: 3.0226e-04 - val_mae: 0.0198 - val_mape: 67.4094
# Epoch 38/100
# 5/5 [==============================] - 1s 148ms/step - loss: 6.9110e-04 - mae: 0.0220 - mape: 509.1406 - val_loss: 3.2313e-04 - val_mae: 0.0194 - val_mape: 60.2815
# Epoch 39/100
# 5/5 [==============================] - 1s 154ms/step - loss: 6.3660e-04 - mae: 0.0209 - mape: 1104.2035 - val_loss: 3.2972e-04 - val_mae: 0.0207 - val_mape: 69.9368
# Epoch 40/100
# 5/5 [==============================] - 1s 165ms/step - loss: 5.9764e-04 - mae: 0.0213 - mape: 477.1453 - val_loss: 2.5298e-04 - val_mae: 0.0166 - val_mape: 46.7605
# Epoch 41/100
# 5/5 [==============================] - 1s 160ms/step - loss: 6.2827e-04 - mae: 0.0208 - mape: 844.0795 - val_loss: 2.7183e-04 - val_mae: 0.0181 - val_mape: 59.2157
# Epoch 42/100
# 5/5 [==============================] - 1s 137ms/step - loss: 6.3443e-04 - mae: 0.0201 - mape: 1378.5410 - val_loss: 3.0130e-04 - val_mae: 0.0195 - val_mape: 65.0177
# Epoch 43/100
# 5/5 [==============================] - 1s 164ms/step - loss: 5.4937e-04 - mae: 0.0196 - mape: 955.3466 - val_loss: 2.7113e-04 - val_mae: 0.0181 - val_mape: 59.3926
# Epoch 44/100
# 5/5 [==============================] - 1s 190ms/step - loss: 5.9090e-04 - mae: 0.0200 - mape: 857.8011 - val_loss: 2.4739e-04 - val_mae: 0.0170 - val_mape: 53.8765
# Epoch 45/100
# 5/5 [==============================] - 1s 150ms/step - loss: 6.2156e-04 - mae: 0.0199 - mape: 763.6605 - val_loss: 2.8315e-04 - val_mae: 0.0186 - val_mape: 61.2825
# Epoch 46/100
# 5/5 [==============================] - 1s 183ms/step - loss: 6.0084e-04 - mae: 0.0203 - mape: 1296.9423 - val_loss: 2.4904e-04 - val_mae: 0.0170 - val_mape: 53.9162
# Epoch 47/100
# 5/5 [==============================] - 1s 167ms/step - loss: 5.3925e-04 - mae: 0.0196 - mape: 143.8113 - val_loss: 2.6031e-04 - val_mae: 0.0175 - val_mape: 56.7874
# Epoch 48/100
# 5/5 [==============================] - 1s 137ms/step - loss: 5.9488e-04 - mae: 0.0194 - mape: 1823.6929 - val_loss: 2.8303e-04 - val_mae: 0.0186 - val_mape: 61.6774
# Epoch 49/100
# 5/5 [==============================] - 1s 166ms/step - loss: 5.1792e-04 - mae: 0.0191 - mape: 729.9794 - val_loss: 2.5218e-04 - val_mae: 0.0171 - val_mape: 54.1891
# Epoch 50/100
# 5/5 [==============================] - 1s 181ms/step - loss: 6.0461e-04 - mae: 0.0195 - mape: 1671.9823 - val_loss: 2.4281e-04 - val_mae: 0.0165 - val_mape: 50.7090
# Epoch 51/100
# 5/5 [==============================] - 1s 142ms/step - loss: 5.8899e-04 - mae: 0.0195 - mape: 784.4569 - val_loss: 3.1435e-04 - val_mae: 0.0199 - val_mape: 66.8176
# Epoch 52/100
# 5/5 [==============================] - 1s 165ms/step - loss: 4.8239e-04 - mae: 0.0195 - mape: 1288.4443 - val_loss: 2.5286e-04 - val_mae: 0.0169 - val_mape: 52.4712
# Epoch 53/100
# 5/5 [==============================] - 1s 178ms/step - loss: 5.4514e-04 - mae: 0.0194 - mape: 948.1851 - val_loss: 2.8532e-04 - val_mae: 0.0188 - val_mape: 62.4791
# Epoch 54/100
# 5/5 [==============================] - 1s 129ms/step - loss: 4.9372e-04 - mae: 0.0193 - mape: 906.9589 - val_loss: 2.4521e-04 - val_mae: 0.0167 - val_mape: 51.9752
# Epoch 55/100
# 5/5 [==============================] - 1s 175ms/step - loss: 5.0921e-04 - mae: 0.0192 - mape: 311.4781 - val_loss: 2.8125e-04 - val_mae: 0.0187 - val_mape: 62.9294
# Epoch 56/100
# 5/5 [==============================] - 1s 182ms/step - loss: 5.0532e-04 - mae: 0.0193 - mape: 1545.6238 - val_loss: 2.4291e-04 - val_mae: 0.0163 - val_mape: 46.9782
# Epoch 57/100
# 5/5 [==============================] - 1s 127ms/step - loss: 6.2542e-04 - mae: 0.0206 - mape: 1206.8342 - val_loss: 3.9559e-04 - val_mae: 0.0234 - val_mape: 80.9439
# Epoch 58/100
# 5/5 [==============================] - 1s 170ms/step - loss: 6.0248e-04 - mae: 0.0227 - mape: 1644.9595 - val_loss: 2.4205e-04 - val_mae: 0.0165 - val_mape: 50.0428
# Epoch 59/100
# 5/5 [==============================] - 1s 165ms/step - loss: 6.1289e-04 - mae: 0.0213 - mape: 1352.4983 - val_loss: 2.9895e-04 - val_mae: 0.0196 - val_mape: 66.0470
# Epoch 60/100
# 5/5 [==============================] - 1s 136ms/step - loss: 6.1203e-04 - mae: 0.0220 - mape: 1026.9132 - val_loss: 2.4494e-04 - val_mae: 0.0166 - val_mape: 50.6686
# Epoch 61/100
# 5/5 [==============================] - 1s 178ms/step - loss: 7.1278e-04 - mae: 0.0227 - mape: 1356.5820 - val_loss: 3.3116e-04 - val_mae: 0.0209 - val_mape: 71.6612
# Epoch 62/100
# 5/5 [==============================] - 1s 166ms/step - loss: 6.9920e-04 - mae: 0.0247 - mape: 2214.9744 - val_loss: 2.6059e-04 - val_mae: 0.0177 - val_mape: 57.8301
# Epoch 63/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0011 - mae: 0.0291 - mape: 384.8763 - val_loss: 4.2533e-04 - val_mae: 0.0230 - val_mape: 72.7821
# Epoch 64/100
# 5/5 [==============================] - 1s 130ms/step - loss: 8.6770e-04 - mae: 0.0291 - mape: 1761.8815 - val_loss: 4.5256e-04 - val_mae: 0.0255 - val_mape: 89.4718
# Epoch 65/100
# 5/5 [==============================] - 1s 182ms/step - loss: 9.8796e-04 - mae: 0.0277 - mape: 1006.3196 - val_loss: 3.7523e-04 - val_mae: 0.0196 - val_mape: 53.0980
# Epoch 66/100
# 5/5 [==============================] - 1s 165ms/step - loss: 6.9651e-04 - mae: 0.0223 - mape: 855.6057 - val_loss: 3.9308e-04 - val_mae: 0.0231 - val_mape: 79.2831
# Epoch 67/100
# 5/5 [==============================] - 1s 163ms/step - loss: 6.9063e-04 - mae: 0.0228 - mape: 2020.3284 - val_loss: 2.9354e-04 - val_mae: 0.0175 - val_mape: 46.3663
# Epoch 68/100
# 5/5 [==============================] - 1s 167ms/step - loss: 5.2659e-04 - mae: 0.0196 - mape: 1052.0968 - val_loss: 3.1854e-04 - val_mae: 0.0203 - val_mape: 69.5501
# Epoch 69/100
# 5/5 [==============================] - 1s 183ms/step - loss: 5.4323e-04 - mae: 0.0199 - mape: 996.4478 - val_loss: 2.6349e-04 - val_mae: 0.0175 - val_mape: 55.6929
# Epoch 70/100
# 5/5 [==============================] - 1s 156ms/step - loss: 6.2336e-04 - mae: 0.0202 - mape: 1633.4987 - val_loss: 2.9422e-04 - val_mae: 0.0191 - val_mape: 63.3669
# Epoch 71/100
# 5/5 [==============================] - 1s 172ms/step - loss: 5.2190e-04 - mae: 0.0197 - mape: 1508.2639 - val_loss: 2.9172e-04 - val_mae: 0.0191 - val_mape: 64.7701
# Epoch 72/100
# 5/5 [==============================] - 1s 177ms/step - loss: 5.1602e-04 - mae: 0.0195 - mape: 1749.0280 - val_loss: 2.6529e-04 - val_mae: 0.0174 - val_mape: 54.0224
# Epoch 73/100
# 5/5 [==============================] - 1s 134ms/step - loss: 4.5395e-04 - mae: 0.0182 - mape: 1697.4364 - val_loss: 2.9363e-04 - val_mae: 0.0192 - val_mape: 64.7357
# Epoch 74/100
# 5/5 [==============================] - 1s 186ms/step - loss: 5.1260e-04 - mae: 0.0187 - mape: 654.9713 - val_loss: 2.6989e-04 - val_mae: 0.0175 - val_mape: 54.2967
# Epoch 75/100
# 5/5 [==============================] - 1s 170ms/step - loss: 5.2167e-04 - mae: 0.0184 - mape: 670.2313 - val_loss: 2.7755e-04 - val_mae: 0.0183 - val_mape: 60.5872
# Epoch 76/100
# 5/5 [==============================] - 1s 136ms/step - loss: 4.6600e-04 - mae: 0.0182 - mape: 1011.7395 - val_loss: 2.4995e-04 - val_mae: 0.0167 - val_mape: 51.6957
# Epoch 77/100
# 5/5 [==============================] - 1s 198ms/step - loss: 5.1034e-04 - mae: 0.0186 - mape: 970.5790 - val_loss: 2.9085e-04 - val_mae: 0.0190 - val_mape: 63.6479
# Epoch 78/100
# 5/5 [==============================] - 1s 152ms/step - loss: 5.4613e-04 - mae: 0.0187 - mape: 1305.0311 - val_loss: 2.7755e-04 - val_mae: 0.0180 - val_mape: 57.5653
# Epoch 79/100
# 5/5 [==============================] - 1s 143ms/step - loss: 5.5701e-04 - mae: 0.0196 - mape: 1093.0493 - val_loss: 2.9575e-04 - val_mae: 0.0191 - val_mape: 63.1143
# Epoch 80/100
# 5/5 [==============================] - 1s 166ms/step - loss: 5.4613e-04 - mae: 0.0202 - mape: 1191.0360 - val_loss: 2.3600e-04 - val_mae: 0.0162 - val_mape: 47.2046
# Epoch 81/100
# 5/5 [==============================] - 1s 198ms/step - loss: 5.1739e-04 - mae: 0.0201 - mape: 837.7130 - val_loss: 3.0247e-04 - val_mae: 0.0195 - val_mape: 65.4410
# Epoch 82/100
# 5/5 [==============================] - 1s 126ms/step - loss: 5.2852e-04 - mae: 0.0199 - mape: 1485.8623 - val_loss: 2.8602e-04 - val_mae: 0.0189 - val_mape: 63.9833
# Epoch 83/100
# 5/5 [==============================] - 1s 174ms/step - loss: 5.2751e-04 - mae: 0.0191 - mape: 433.4341 - val_loss: 2.4272e-04 - val_mae: 0.0164 - val_mape: 49.9903
# Epoch 84/100
# 5/5 [==============================] - 1s 172ms/step - loss: 5.0389e-04 - mae: 0.0182 - mape: 1097.7367 - val_loss: 2.9478e-04 - val_mae: 0.0192 - val_mape: 65.2145
# Epoch 85/100
# 5/5 [==============================] - 1s 127ms/step - loss: 4.7221e-04 - mae: 0.0186 - mape: 986.0640 - val_loss: 2.6375e-04 - val_mae: 0.0175 - val_mape: 56.6674
# Epoch 86/100
# 5/5 [==============================] - 1s 155ms/step - loss: 4.6210e-04 - mae: 0.0182 - mape: 1977.4188 - val_loss: 2.3322e-04 - val_mae: 0.0161 - val_mape: 48.5309
# Epoch 87/100
# 5/5 [==============================] - 1s 183ms/step - loss: 5.1926e-04 - mae: 0.0194 - mape: 855.4690 - val_loss: 3.4576e-04 - val_mae: 0.0213 - val_mape: 72.7381
# Epoch 88/100
# 5/5 [==============================] - 1s 137ms/step - loss: 5.4822e-04 - mae: 0.0210 - mape: 1584.6963 - val_loss: 2.6210e-04 - val_mae: 0.0178 - val_mape: 58.5764
# Epoch 89/100
# 5/5 [==============================] - 1s 126ms/step - loss: 4.8875e-04 - mae: 0.0187 - mape: 924.6360 - val_loss: 2.5397e-04 - val_mae: 0.0171 - val_mape: 53.4020
# Epoch 90/100
# 5/5 [==============================] - 1s 174ms/step - loss: 4.2338e-04 - mae: 0.0178 - mape: 1059.0864 - val_loss: 2.8130e-04 - val_mae: 0.0185 - val_mape: 61.3681
# Epoch 91/100
# 5/5 [==============================] - 1s 177ms/step - loss: 5.1845e-04 - mae: 0.0184 - mape: 943.6266 - val_loss: 2.5207e-04 - val_mae: 0.0169 - val_mape: 52.5190
# Epoch 92/100
# 5/5 [==============================] - 1s 120ms/step - loss: 5.3001e-04 - mae: 0.0184 - mape: 1059.1780 - val_loss: 2.6170e-04 - val_mae: 0.0173 - val_mape: 54.1945
# Epoch 93/100
# 5/5 [==============================] - 1s 172ms/step - loss: 5.8989e-04 - mae: 0.0197 - mape: 1317.1101 - val_loss: 3.3258e-04 - val_mae: 0.0206 - val_mape: 68.9065
# Epoch 94/100
# 5/5 [==============================] - 1s 176ms/step - loss: 5.1958e-04 - mae: 0.0206 - mape: 1600.1766 - val_loss: 2.3881e-04 - val_mae: 0.0163 - val_mape: 45.5639
# Epoch 95/100
# 5/5 [==============================] - 1s 143ms/step - loss: 5.2524e-04 - mae: 0.0206 - mape: 1535.1234 - val_loss: 3.2933e-04 - val_mae: 0.0210 - val_mape: 72.8943
# Epoch 96/100
# 5/5 [==============================] - 1s 160ms/step - loss: 4.7013e-04 - mae: 0.0201 - mape: 1438.9868 - val_loss: 3.0470e-04 - val_mae: 0.0200 - val_mape: 68.1311
# Epoch 97/100
# 5/5 [==============================] - 1s 163ms/step - loss: 4.6246e-04 - mae: 0.0188 - mape: 1150.4717 - val_loss: 2.4503e-04 - val_mae: 0.0170 - val_mape: 54.2019
# Epoch 98/100
# 5/5 [==============================] - 1s 155ms/step - loss: 4.9203e-04 - mae: 0.0182 - mape: 1211.4436 - val_loss: 2.3564e-04 - val_mae: 0.0166 - val_mape: 52.8130
# Epoch 99/100
# 5/5 [==============================] - 1s 93ms/step - loss: 5.0554e-04 - mae: 0.0188 - mape: 970.6676 - val_loss: 2.5834e-04 - val_mae: 0.0174 - val_mape: 55.0637
# Epoch 100/100
# 5/5 [==============================] - 1s 116ms/step - loss: 5.0115e-04 - mae: 0.0186 - mape: 1293.3160 - val_loss: 2.4196e-04 - val_mae: 0.0164 - val_mape: 49.8685

# %% [markdown]
# #### Gráficas de entrenamiento modelo con ventanado

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='loss'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='mae'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,10))

metric='mape'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %% [markdown]
# ##### Evaluar modelo con ventanado

# %%
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xtr= x.numpy()
    Ytr=y.numpy()
    break

for idx,(x,y) in enumerate(val_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xval= x.numpy()
    Yval=y.numpy()
    break

for idx,(x,y) in enumerate(test_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xts= x.numpy()
    Yts=y.numpy()
    break
# Out:
# Example sample shapes
# x =  (256, 72, 7)
# y =  (256, 24, 1)
# x =  (256, 72, 7)
# y =  (256, 24, 1)
# x =  (256, 72, 7)
# y =  (256, 24, 1)

# %%
import pandas as pd
models=['dnn','lstm','gru','cnn_lstm']
# results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
results = []
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(1)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}

    results.append(data)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])

    resultsYtestP[mod]=listP
    listP=[]
df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
# Out:
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 83ms/step

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe_80_20_earlystop_kfolds-1.csv')
df.to_csv(file)

# %%
df
# Out:
#        Model   Tipo         MAE        MAPE      sMAPE        RMSE
# 0        dnn  Train   14.896415    7.950067   7.864310   16.937533
# 1        dnn    Val  154.192157  190.475427  94.146419  157.182438
# 2        dnn   Test   47.286528   32.580949  27.821952   48.960178
# 3       lstm  Train   26.261613   14.146017  15.592166   29.645324
# 4       lstm    Val   73.541669   93.208587  60.327239   77.611499
# 5       lstm   Test   16.815162   11.481393  10.676306   19.638883
# 6        gru  Train   23.880693   12.880979  14.138395   27.649873
# 7        gru    Val   72.677195   91.951001  59.863009   76.633478
# 8        gru   Test   15.573122   10.689643   9.984660   18.325364
# 9   cnn_lstm  Train   14.649276    7.931940   8.377166   18.563880
# 10  cnn_lstm    Val   54.653652   69.328412  48.979217   58.341200
# 11  cnn_lstm   Test   13.057580    9.208238   9.789414   14.978882

# %%
import pandas as pd
models=['dnn','lstm','gru','cnn_lstm']
# results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
results = []
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(3)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}

    results.append(data)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results.append(data)
    df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])

    resultsYtestP[mod]=listP
    listP=[]
df = pd.DataFrame(results, columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe_80_20_earlystop_kfolds-3.csv')
df.to_csv(file)
df
# Out:
#        Model   Tipo         MAE        MAPE      sMAPE        RMSE
# 0        dnn  Train   18.692687   10.374052   9.905557   21.366700
# 1        dnn    Val  104.818953  119.515632  67.836867  114.555557
# 2        dnn   Test   52.553728   37.672194  31.391880   54.643876
# 3       lstm  Train   19.090648   10.647609  11.633809   23.939366
# 4       lstm    Val   58.500349   67.951735  46.393455   65.026251
# 5       lstm   Test   22.063760   15.744086  14.309292   25.219931
# 6        gru  Train   17.343675    9.676848  10.520748   22.328348
# 7        gru    Val   58.107753   67.429725  46.158446   64.635113
# 8        gru   Test   20.676482   14.784515  13.508749   23.755024
# 9   cnn_lstm  Train   18.088856   10.220198  11.080492   22.415729
# 10  cnn_lstm    Val   39.402935   46.573150  34.640026   46.357559
# 11  cnn_lstm   Test   15.034631   11.025488  11.905498   17.269259

# %% [markdown]
# #### Gráfica del original y del pronóstico

# %%
listreg=[i for i in range(3)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.src.engine.sequential.Sequential object at 0x0000014892443210>, 'history': <keras.src.callbacks.History object at 0x0000014899083A90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 18ms/step
# lstm {'model': <keras.src.engine.sequential.Sequential object at 0x000001489C7AFA10>, 'history': <keras.src.callbacks.History object at 0x000001489C86BA90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 37ms/step
# gru {'model': <keras.src.engine.sequential.Sequential object at 0x000001489C7AE790>, 'history': <keras.src.callbacks.History object at 0x000001489C9F3190>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 16ms/step
# cnn_lstm {'model': <keras.src.engine.sequential.Sequential object at 0x000001489C2E2A50>, 'history': <keras.src.callbacks.History object at 0x00000148A3C66F90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 26ms/step

# %%
listreg=[i for i in range(1)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.src.engine.sequential.Sequential object at 0x0000014892443210>, 'history': <keras.src.callbacks.History object at 0x0000014899083A90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 16ms/step
# lstm {'model': <keras.src.engine.sequential.Sequential object at 0x000001489C7AFA10>, 'history': <keras.src.callbacks.History object at 0x000001489C86BA90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 19ms/step
# gru {'model': <keras.src.engine.sequential.Sequential object at 0x000001489C7AE790>, 'history': <keras.src.callbacks.History object at 0x000001489C9F3190>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 31ms/step
# cnn_lstm {'model': <keras.src.engine.sequential.Sequential object at 0x000001489C2E2A50>, 'history': <keras.src.callbacks.History object at 0x00000148A3C66F90>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 22ms/step
