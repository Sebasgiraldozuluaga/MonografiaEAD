# %% [markdown]
# #### Cargas las librerías

# %%
# Load Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from pathlib import Path
import os
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf

from evaluation._mae import MAE
from evaluation._smape import sMAPE
from evaluation._mape import MAPE
from evaluation._rmse import RMSE

# %% [markdown]
# #### Cargar dataset

# %%
s_path=Path.cwd()
s_prt_path=s_path.parent

file=os.path.join(s_prt_path,'datasets\XM_H_sinOfe.csv')
df_Data= pd.read_csv(file, index_col=0)
# df_Data.reset_index(inplace=True)

# %%
df_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52584 entries, 01/01/2013 0:00 to 31/12/2018 23:00
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PrecioB    52584 non-null  float64
#  1   Demanda    52584 non-null  float64
#  2   DispTer    52584 non-null  int64
#  3   DispNoTer  52584 non-null  int64
#  4   VolUtil    52584 non-null  int64
#  5   Aportes    52584 non-null  int64
#  6   day_cls    52584 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Funciones necesarias para las ejecuciones

# %% [markdown]
# ##### División de datos

# %%
# Dividir los datos en train, validación y test
def split_data(data, indexTotal, train_fraq, test_len=8760):

    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(data)-test_len

    test_data = data[test_slice:]
    indexTest=indexTotal[test_slice:]

    train_val_data = data[:test_slice]
    index_val_data=indexTotal[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    indexTrain=index_val_data[:train_size]

    val_data = train_val_data[train_size:]
    indexVal=index_val_data[train_size:]
    
    return train_data, val_data, test_data, indexTrain, indexVal, indexTest

# %% [markdown]
# ##### Construcción del dataset

# %%
# Crear los datos para entrar al modelo, definición de ventanas
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
    """ Create a windowed tensorflow dataset
    
    """

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
    
    #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    #ds = ds.shuffle(shuffle_buffer)
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    
    return ds

# Construcción del dataset usando las ventanas
def build_dataset(traindata,valdata,testdata,train_fraq=0.65, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
    """If multi variate then first column is always the column from which the target is contstructed.
    """
    
    tf.random.set_seed(23)
    
    
    train_ds = window_dataset(traindata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(valdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(testdata, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    
    
    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

# %% [markdown]
# ##### Parámetros y ejecución

# %%
# Definición de parámetros para la ejecución del modelo
def get_params(multivar=True):
    lr = 3e-4
    n_steps=24
    n_horizon=24
    if multivar:
        n_features=7
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

# Almacenamiento de los datos de las ejecuciones
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}

# Ejecuciones de los modelos con función de ventanado
def run_model(traindata,valdata,testdata,model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    
    train_ds, val_ds, test_ds = build_dataset(traindata,valdata,testdata,n_steps=n_steps, n_horizon=n_horizon, multi_var=True)

    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs)

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    
    return test_ds

# %% [markdown]
# #### Modelos

# %% [markdown]
# ##### DNN

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 168)               0
#
#  dense (Dense)               (None, 128)               21632
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 41,240
# Trainable params: 41,240
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### LSTM

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 72)            23040
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55,640
# Trainable params: 55,640
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### GRU

# %%
def gru_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.GRU(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.GRU(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='gru')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

gru = gru_model(*get_params(multivar=True))
gru.summary()
# Out:
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 24, 72)            17496
#
#  gru_1 (GRU)                 (None, 48)                17568
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 44,432
# Trainable params: 44,432
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### CNN_LSTM

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae','mape'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 19, 64)            2752
#
#  max_pooling1d (MaxPooling1D  (None, 9, 64)            0
#  )
#
#  conv1d_1 (Conv1D)           (None, 7, 64)             12352
#
#  max_pooling1d_1 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  lstm (LSTM)                 (None, 3, 72)             39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 87,160
# Trainable params: 87,160
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Escalamiento de los datos y división del dataset

# %%
#scale
scaler = MinMaxScaler(feature_range=(0, 1))
scalerP=MinMaxScaler(feature_range=(0, 1))

vec_precio=scalerP.fit_transform(df_Data.values[:,0].reshape(-1,1))

indexTotal=df_Data.index

multivar_df = scaler.fit_transform(df_Data)
train_multi, val_multi, test_multi, indexTrain, indexVal, indexTest = split_data(multivar_df,indexTotal, train_fraq=0.65, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
print('Precio',vec_precio.shape)
print('Todo',df_Data.shape)
# Out:
# Multivarate Datasets
# Train Data Shape: (28485, 7)
# Val Data Shape: (15339, 7)
# Test Data Shape: (8760, 7)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False
# Precio (52584, 1)
# Todo (52584, 7)

# %% [markdown]
# ##### Obtener dataset para el modelo utilizando la función de ventanado

# %%
n_steps=24
n_horizon=24

train_ds, val_ds, test_ds = build_dataset(train_multi, val_multi, test_multi,n_steps=n_steps, n_horizon=n_horizon,multi_var=True)
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Example sample shapes
# x =  (256, 24, 7)
# y =  (256, 24, 1)

# %% [markdown]
# ##### Ejecución de modelo con datos del ventanado

# %%
model_configs_v=dict()
nepochs=100

print('Ejecutando la dnn')
run_model(train_multi, val_multi, test_multi,"dnn", dnn_model, model_configs_v, epochs=nepochs)

print('Ejecutando la lstm')
run_model(train_multi, val_multi, test_multi,"lstm", lstm_model, model_configs_v, epochs=nepochs)

print('Ejecutando la gru')
run_model(train_multi, val_multi, test_multi,"gru", gru_model, model_configs_v, epochs=nepochs)

print('Ejecutando la cnn_lstm')
run_model(train_multi, val_multi, test_multi,"cnn_lstm", lstm_cnn_model, model_configs_v, epochs=nepochs)
# Out:
# Ejecutando la dnn
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 6s 608ms/step - loss: 0.0533 - mae: 0.2562 - mape: 15106.5000 - val_loss: 0.0072 - val_mae: 0.0931 - val_mape: 454.1885
# Epoch 2/100
# 5/5 [==============================] - 1s 289ms/step - loss: 0.0154 - mae: 0.1371 - mape: 1017.8020 - val_loss: 0.0039 - val_mae: 0.0716 - val_mape: 360.6321
# Epoch 3/100
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0091 - mae: 0.1018 - mape: 5986.8511 - val_loss: 0.0019 - val_mae: 0.0480 - val_mape: 245.6794
# Epoch 4/100
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0068 - mae: 0.0823 - mape: 3742.8147 - val_loss: 0.0014 - val_mae: 0.0416 - val_mape: 214.0862
# Epoch 5/100
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0057 - mae: 0.0719 - mape: 1480.5215 - val_loss: 0.0013 - val_mae: 0.0398 - val_mape: 205.3414
# Epoch 6/100
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0048 - mae: 0.0643 - mape: 2449.4678 - val_loss: 0.0012 - val_mae: 0.0384 - val_mape: 199.9846
# Epoch 7/100
# 5/5 [==============================] - 1s 292ms/step - loss: 0.0040 - mae: 0.0581 - mape: 1521.6646 - val_loss: 0.0012 - val_mae: 0.0394 - val_mape: 207.8547
# Epoch 8/100
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0035 - mae: 0.0556 - mape: 2613.5337 - val_loss: 0.0012 - val_mae: 0.0402 - val_mape: 213.7081
# Epoch 9/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0031 - mae: 0.0527 - mape: 3902.1199 - val_loss: 0.0010 - val_mae: 0.0374 - val_mape: 199.8392
# Epoch 10/100
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0026 - mae: 0.0488 - mape: 2136.4766 - val_loss: 8.3588e-04 - val_mae: 0.0329 - val_mape: 177.3407
# Epoch 11/100
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0022 - mae: 0.0439 - mape: 1722.1428 - val_loss: 7.2682e-04 - val_mae: 0.0304 - val_mape: 165.4432
# Epoch 12/100
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0020 - mae: 0.0403 - mape: 1890.6909 - val_loss: 6.6016e-04 - val_mae: 0.0289 - val_mape: 158.5115
# Epoch 13/100
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0017 - mae: 0.0371 - mape: 2154.7478 - val_loss: 5.8885e-04 - val_mae: 0.0273 - val_mape: 149.9233
# Epoch 14/100
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0017 - mae: 0.0355 - mape: 1651.7708 - val_loss: 5.3190e-04 - val_mae: 0.0260 - val_mape: 142.9431
# Epoch 15/100
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0014 - mae: 0.0333 - mape: 1901.1006 - val_loss: 5.1783e-04 - val_mae: 0.0260 - val_mape: 142.7618
# Epoch 16/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0015 - mae: 0.0322 - mape: 1438.6370 - val_loss: 4.8344e-04 - val_mae: 0.0251 - val_mape: 138.3093
# Epoch 17/100
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0014 - mae: 0.0311 - mape: 1231.7753 - val_loss: 5.0365e-04 - val_mae: 0.0258 - val_mape: 142.9633
# Epoch 18/100
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0014 - mae: 0.0308 - mape: 1202.4598 - val_loss: 4.9520e-04 - val_mae: 0.0258 - val_mape: 142.8255
# Epoch 19/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0013 - mae: 0.0297 - mape: 1239.3517 - val_loss: 4.8896e-04 - val_mae: 0.0258 - val_mape: 143.3084
# Epoch 20/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0013 - mae: 0.0294 - mape: 821.9199 - val_loss: 5.2258e-04 - val_mae: 0.0271 - val_mape: 150.4483
# Epoch 21/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0012 - mae: 0.0289 - mape: 1764.6030 - val_loss: 5.0990e-04 - val_mae: 0.0270 - val_mape: 149.8046
# Epoch 22/100
# 5/5 [==============================] - 1s 148ms/step - loss: 0.0012 - mae: 0.0283 - mape: 1859.6726 - val_loss: 5.4089e-04 - val_mae: 0.0282 - val_mape: 155.5043
# Epoch 23/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0012 - mae: 0.0287 - mape: 1641.7305 - val_loss: 5.3532e-04 - val_mae: 0.0281 - val_mape: 155.1332
# Epoch 24/100
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0011 - mae: 0.0278 - mape: 1707.9158 - val_loss: 5.4009e-04 - val_mae: 0.0283 - val_mape: 156.4102
# Epoch 25/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0012 - mae: 0.0291 - mape: 1932.6460 - val_loss: 6.0501e-04 - val_mae: 0.0302 - val_mape: 165.7229
# Epoch 26/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0013 - mae: 0.0289 - mape: 1633.7457 - val_loss: 5.5741e-04 - val_mae: 0.0290 - val_mape: 160.1267
# Epoch 27/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0011 - mae: 0.0277 - mape: 1784.8380 - val_loss: 5.6185e-04 - val_mae: 0.0293 - val_mape: 161.4267
# Epoch 28/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.0010 - mae: 0.0269 - mape: 2253.5488 - val_loss: 5.7030e-04 - val_mae: 0.0296 - val_mape: 162.4702
# Epoch 29/100
# 5/5 [==============================] - 1s 141ms/step - loss: 9.5698e-04 - mae: 0.0267 - mape: 1481.0420 - val_loss: 5.8458e-04 - val_mae: 0.0300 - val_mape: 164.1930
# Epoch 30/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0011 - mae: 0.0271 - mape: 1773.3270 - val_loss: 5.7084e-04 - val_mae: 0.0296 - val_mape: 162.3294
# Epoch 31/100
# 5/5 [==============================] - 1s 188ms/step - loss: 9.2518e-04 - mae: 0.0260 - mape: 1234.9756 - val_loss: 5.4954e-04 - val_mae: 0.0290 - val_mape: 159.5369
# Epoch 32/100
# 5/5 [==============================] - 1s 180ms/step - loss: 9.8634e-04 - mae: 0.0263 - mape: 1581.5800 - val_loss: 5.0788e-04 - val_mae: 0.0278 - val_mape: 154.0578
# Epoch 33/100
# 5/5 [==============================] - 1s 148ms/step - loss: 9.9676e-04 - mae: 0.0260 - mape: 1327.4764 - val_loss: 5.1415e-04 - val_mae: 0.0280 - val_mape: 155.1924
# Epoch 34/100
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0010 - mae: 0.0265 - mape: 1486.4872 - val_loss: 5.7821e-04 - val_mae: 0.0298 - val_mape: 163.3572
# Epoch 35/100
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0010 - mae: 0.0257 - mape: 1677.7268 - val_loss: 5.0703e-04 - val_mae: 0.0278 - val_mape: 153.5385
# Epoch 36/100
# 5/5 [==============================] - 1s 184ms/step - loss: 9.2617e-04 - mae: 0.0251 - mape: 1729.8491 - val_loss: 6.3159e-04 - val_mae: 0.0313 - val_mape: 170.0511
# Epoch 37/100
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0010 - mae: 0.0270 - mape: 1428.5785 - val_loss: 5.1036e-04 - val_mae: 0.0279 - val_mape: 154.0690
# Epoch 38/100
# 5/5 [==============================] - 1s 207ms/step - loss: 9.4825e-04 - mae: 0.0253 - mape: 1332.3295 - val_loss: 4.7234e-04 - val_mae: 0.0269 - val_mape: 149.1582
# Epoch 39/100
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0010 - mae: 0.0263 - mape: 1568.7427 - val_loss: 6.0609e-04 - val_mae: 0.0310 - val_mape: 167.1442
# Epoch 40/100
# 5/5 [==============================] - 1s 191ms/step - loss: 9.3698e-04 - mae: 0.0253 - mape: 1612.1378 - val_loss: 5.0229e-04 - val_mae: 0.0279 - val_mape: 153.0368
# Epoch 41/100
# 5/5 [==============================] - 1s 193ms/step - loss: 9.3833e-04 - mae: 0.0245 - mape: 1286.4297 - val_loss: 6.3161e-04 - val_mae: 0.0317 - val_mape: 169.7631
# Epoch 42/100
# 5/5 [==============================] - 1s 164ms/step - loss: 8.3191e-04 - mae: 0.0247 - mape: 1524.7562 - val_loss: 4.9812e-04 - val_mae: 0.0277 - val_mape: 152.2892
# Epoch 43/100
# 5/5 [==============================] - 1s 193ms/step - loss: 8.3981e-04 - mae: 0.0235 - mape: 1469.8989 - val_loss: 5.2496e-04 - val_mae: 0.0286 - val_mape: 156.1688
# Epoch 44/100
# 5/5 [==============================] - 1s 292ms/step - loss: 8.8444e-04 - mae: 0.0250 - mape: 1552.9214 - val_loss: 5.6792e-04 - val_mae: 0.0299 - val_mape: 161.4346
# Epoch 45/100
# 5/5 [==============================] - 1s 188ms/step - loss: 9.0499e-04 - mae: 0.0241 - mape: 1797.4211 - val_loss: 4.8922e-04 - val_mae: 0.0275 - val_mape: 150.1495
# Epoch 46/100
# 5/5 [==============================] - 1s 221ms/step - loss: 8.1423e-04 - mae: 0.0233 - mape: 1703.6351 - val_loss: 5.0140e-04 - val_mae: 0.0279 - val_mape: 152.0363
# Epoch 47/100
# 5/5 [==============================] - 1s 186ms/step - loss: 7.8520e-04 - mae: 0.0231 - mape: 1662.8245 - val_loss: 5.3987e-04 - val_mae: 0.0291 - val_mape: 157.8631
# Epoch 48/100
# 5/5 [==============================] - 1s 228ms/step - loss: 8.0738e-04 - mae: 0.0236 - mape: 1278.2125 - val_loss: 4.9739e-04 - val_mae: 0.0279 - val_mape: 151.7455
# Epoch 49/100
# 5/5 [==============================] - 1s 236ms/step - loss: 9.0431e-04 - mae: 0.0235 - mape: 1193.6459 - val_loss: 4.9220e-04 - val_mae: 0.0278 - val_mape: 150.8445
# Epoch 50/100
# 5/5 [==============================] - 1s 223ms/step - loss: 8.1400e-04 - mae: 0.0238 - mape: 1857.4578 - val_loss: 5.3376e-04 - val_mae: 0.0292 - val_mape: 155.7394
# Epoch 51/100
# 5/5 [==============================] - 1s 208ms/step - loss: 8.4680e-04 - mae: 0.0238 - mape: 1338.2006 - val_loss: 4.1645e-04 - val_mae: 0.0252 - val_mape: 139.7096
# Epoch 52/100
# 5/5 [==============================] - 1s 296ms/step - loss: 9.7433e-04 - mae: 0.0246 - mape: 1750.5089 - val_loss: 5.2587e-04 - val_mae: 0.0288 - val_mape: 155.6501
# Epoch 53/100
# 5/5 [==============================] - 1s 217ms/step - loss: 8.6544e-04 - mae: 0.0240 - mape: 1371.0020 - val_loss: 4.8935e-04 - val_mae: 0.0278 - val_mape: 150.6661
# Epoch 54/100
# 5/5 [==============================] - 1s 190ms/step - loss: 8.8479e-04 - mae: 0.0255 - mape: 1603.7036 - val_loss: 5.0591e-04 - val_mae: 0.0283 - val_mape: 151.4047
# Epoch 55/100
# 5/5 [==============================] - 1s 208ms/step - loss: 8.6477e-04 - mae: 0.0247 - mape: 1021.6079 - val_loss: 3.9392e-04 - val_mae: 0.0242 - val_mape: 135.2252
# Epoch 56/100
# 5/5 [==============================] - 1s 245ms/step - loss: 7.7678e-04 - mae: 0.0245 - mape: 1435.0829 - val_loss: 6.7618e-04 - val_mae: 0.0331 - val_mape: 174.1986
# Epoch 57/100
# 5/5 [==============================] - 1s 291ms/step - loss: 7.2894e-04 - mae: 0.0235 - mape: 1616.7709 - val_loss: 4.8521e-04 - val_mae: 0.0279 - val_mape: 149.5707
# Epoch 58/100
# 5/5 [==============================] - 1s 209ms/step - loss: 7.6215e-04 - mae: 0.0225 - mape: 1184.2449 - val_loss: 5.9317e-04 - val_mae: 0.0313 - val_mape: 164.8573
# Epoch 59/100
# 5/5 [==============================] - 1s 206ms/step - loss: 8.1985e-04 - mae: 0.0230 - mape: 1339.6858 - val_loss: 4.8004e-04 - val_mae: 0.0276 - val_mape: 150.3509
# Epoch 60/100
# 5/5 [==============================] - 2s 340ms/step - loss: 7.3313e-04 - mae: 0.0223 - mape: 1275.8101 - val_loss: 4.8536e-04 - val_mae: 0.0277 - val_mape: 150.7273
# Epoch 61/100
# 5/5 [==============================] - 1s 182ms/step - loss: 7.3802e-04 - mae: 0.0226 - mape: 1398.7175 - val_loss: 4.6002e-04 - val_mae: 0.0267 - val_mape: 144.8506
# Epoch 62/100
# 5/5 [==============================] - 1s 194ms/step - loss: 8.0047e-04 - mae: 0.0223 - mape: 1095.5248 - val_loss: 5.4469e-04 - val_mae: 0.0294 - val_mape: 156.0730
# Epoch 63/100
# 5/5 [==============================] - 1s 160ms/step - loss: 6.6948e-04 - mae: 0.0217 - mape: 1435.4351 - val_loss: 5.7328e-04 - val_mae: 0.0302 - val_mape: 160.1148
# Epoch 64/100
# 5/5 [==============================] - 1s 251ms/step - loss: 7.1337e-04 - mae: 0.0217 - mape: 1405.5363 - val_loss: 5.0922e-04 - val_mae: 0.0282 - val_mape: 151.7758
# Epoch 65/100
# 5/5 [==============================] - 1s 303ms/step - loss: 7.3194e-04 - mae: 0.0221 - mape: 1420.8173 - val_loss: 5.2870e-04 - val_mae: 0.0289 - val_mape: 154.2983
# Epoch 66/100
# 5/5 [==============================] - 1s 238ms/step - loss: 7.8663e-04 - mae: 0.0224 - mape: 749.0785 - val_loss: 4.7508e-04 - val_mae: 0.0274 - val_mape: 147.5489
# Epoch 67/100
# 5/5 [==============================] - 1s 298ms/step - loss: 6.5913e-04 - mae: 0.0211 - mape: 1725.0654 - val_loss: 5.7202e-04 - val_mae: 0.0306 - val_mape: 162.0367
# Epoch 68/100
# 5/5 [==============================] - 1s 303ms/step - loss: 6.9498e-04 - mae: 0.0220 - mape: 1194.0321 - val_loss: 5.4631e-04 - val_mae: 0.0296 - val_mape: 157.7264
# Epoch 69/100
# 5/5 [==============================] - 1s 238ms/step - loss: 7.3649e-04 - mae: 0.0215 - mape: 1394.4814 - val_loss: 4.4362e-04 - val_mae: 0.0260 - val_mape: 142.9789
# Epoch 70/100
# 5/5 [==============================] - 1s 234ms/step - loss: 7.1790e-04 - mae: 0.0220 - mape: 1049.7173 - val_loss: 4.9367e-04 - val_mae: 0.0278 - val_mape: 149.9228
# Epoch 71/100
# 5/5 [==============================] - 1s 228ms/step - loss: 6.9583e-04 - mae: 0.0213 - mape: 1389.6530 - val_loss: 4.9505e-04 - val_mae: 0.0280 - val_mape: 150.7777
# Epoch 72/100
# 5/5 [==============================] - 1s 247ms/step - loss: 6.9994e-04 - mae: 0.0219 - mape: 832.2345 - val_loss: 4.8235e-04 - val_mae: 0.0276 - val_mape: 148.8054
# Epoch 73/100
# 5/5 [==============================] - 1s 203ms/step - loss: 8.3364e-04 - mae: 0.0226 - mape: 1202.1365 - val_loss: 4.9010e-04 - val_mae: 0.0279 - val_mape: 151.0061
# Epoch 74/100
# 5/5 [==============================] - 1s 229ms/step - loss: 7.3614e-04 - mae: 0.0241 - mape: 1195.6777 - val_loss: 4.9618e-04 - val_mae: 0.0280 - val_mape: 150.1748
# Epoch 75/100
# 5/5 [==============================] - 1s 259ms/step - loss: 7.0373e-04 - mae: 0.0221 - mape: 916.4445 - val_loss: 4.0030e-04 - val_mae: 0.0247 - val_mape: 136.9498
# Epoch 76/100
# 5/5 [==============================] - 1s 241ms/step - loss: 8.3676e-04 - mae: 0.0240 - mape: 1314.7125 - val_loss: 4.9235e-04 - val_mae: 0.0280 - val_mape: 150.1563
# Epoch 77/100
# 5/5 [==============================] - 1s 270ms/step - loss: 8.1424e-04 - mae: 0.0232 - mape: 1501.5149 - val_loss: 3.9669e-04 - val_mae: 0.0246 - val_mape: 136.1878
# Epoch 78/100
# 5/5 [==============================] - 1s 225ms/step - loss: 7.0259e-04 - mae: 0.0225 - mape: 1166.6315 - val_loss: 6.6368e-04 - val_mae: 0.0332 - val_mape: 172.2161
# Epoch 79/100
# 5/5 [==============================] - 1s 268ms/step - loss: 7.0271e-04 - mae: 0.0221 - mape: 1444.9250 - val_loss: 4.5063e-04 - val_mae: 0.0264 - val_mape: 143.8063
# Epoch 80/100
# 5/5 [==============================] - 1s 186ms/step - loss: 6.6784e-04 - mae: 0.0224 - mape: 1482.6887 - val_loss: 5.6695e-04 - val_mae: 0.0302 - val_mape: 158.4338
# Epoch 81/100
# 5/5 [==============================] - 1s 250ms/step - loss: 6.0639e-04 - mae: 0.0206 - mape: 1475.9662 - val_loss: 3.8610e-04 - val_mae: 0.0241 - val_mape: 133.6136
# Epoch 82/100
# 5/5 [==============================] - 1s 259ms/step - loss: 6.6613e-04 - mae: 0.0204 - mape: 1406.5203 - val_loss: 6.2701e-04 - val_mae: 0.0319 - val_mape: 168.3394
# Epoch 83/100
# 5/5 [==============================] - 1s 196ms/step - loss: 7.1038e-04 - mae: 0.0216 - mape: 1461.8759 - val_loss: 5.9070e-04 - val_mae: 0.0310 - val_mape: 164.4660
# Epoch 84/100
# 5/5 [==============================] - 1s 297ms/step - loss: 6.0669e-04 - mae: 0.0204 - mape: 1399.1989 - val_loss: 5.2899e-04 - val_mae: 0.0291 - val_mape: 154.4940
# Epoch 85/100
# 5/5 [==============================] - 1s 228ms/step - loss: 6.3757e-04 - mae: 0.0209 - mape: 1012.7568 - val_loss: 4.8537e-04 - val_mae: 0.0277 - val_mape: 147.9937
# Epoch 86/100
# 5/5 [==============================] - 2s 404ms/step - loss: 6.5039e-04 - mae: 0.0215 - mape: 1101.0607 - val_loss: 4.6649e-04 - val_mae: 0.0271 - val_mape: 144.7706
# Epoch 87/100
# 5/5 [==============================] - 1s 315ms/step - loss: 5.6080e-04 - mae: 0.0195 - mape: 795.4544 - val_loss: 5.0438e-04 - val_mae: 0.0284 - val_mape: 150.4646
# Epoch 88/100
# 5/5 [==============================] - 2s 355ms/step - loss: 6.3511e-04 - mae: 0.0201 - mape: 1411.4336 - val_loss: 5.9756e-04 - val_mae: 0.0313 - val_mape: 165.1784
# Epoch 89/100
# 5/5 [==============================] - 2s 308ms/step - loss: 6.8506e-04 - mae: 0.0205 - mape: 1109.6565 - val_loss: 5.2424e-04 - val_mae: 0.0290 - val_mape: 155.7031
# Epoch 90/100
# 5/5 [==============================] - 1s 231ms/step - loss: 5.9947e-04 - mae: 0.0208 - mape: 1313.3079 - val_loss: 4.6850e-04 - val_mae: 0.0271 - val_mape: 146.1222
# Epoch 91/100
# 5/5 [==============================] - 2s 321ms/step - loss: 6.3597e-04 - mae: 0.0202 - mape: 1289.1440 - val_loss: 3.7803e-04 - val_mae: 0.0238 - val_mape: 133.2811
# Epoch 92/100
# 5/5 [==============================] - 1s 221ms/step - loss: 6.6286e-04 - mae: 0.0207 - mape: 1177.2323 - val_loss: 4.3432e-04 - val_mae: 0.0259 - val_mape: 142.2446
# Epoch 93/100
# 5/5 [==============================] - 2s 343ms/step - loss: 5.8145e-04 - mae: 0.0200 - mape: 1013.6769 - val_loss: 4.2310e-04 - val_mae: 0.0254 - val_mape: 140.0461
# Epoch 94/100
# 5/5 [==============================] - 3s 553ms/step - loss: 7.4054e-04 - mae: 0.0214 - mape: 1731.3593 - val_loss: 5.4076e-04 - val_mae: 0.0295 - val_mape: 156.8262
# Epoch 95/100
# 5/5 [==============================] - 1s 273ms/step - loss: 5.7028e-04 - mae: 0.0196 - mape: 1733.9707 - val_loss: 4.6067e-04 - val_mae: 0.0270 - val_mape: 145.8249
# Epoch 96/100
# 5/5 [==============================] - 1s 302ms/step - loss: 5.9729e-04 - mae: 0.0200 - mape: 1066.4596 - val_loss: 5.0515e-04 - val_mae: 0.0285 - val_mape: 151.8688
# Epoch 97/100
# 5/5 [==============================] - 2s 316ms/step - loss: 6.1448e-04 - mae: 0.0202 - mape: 1204.2638 - val_loss: 5.2122e-04 - val_mae: 0.0290 - val_mape: 155.3641
# Epoch 98/100
# 5/5 [==============================] - 1s 292ms/step - loss: 5.8817e-04 - mae: 0.0207 - mape: 1204.9672 - val_loss: 4.6907e-04 - val_mae: 0.0272 - val_mape: 146.8831
# Epoch 99/100
# 5/5 [==============================] - 2s 286ms/step - loss: 5.6899e-04 - mae: 0.0196 - mape: 1410.4923 - val_loss: 4.2951e-04 - val_mae: 0.0257 - val_mape: 141.6875
# Epoch 100/100
# 5/5 [==============================] - 1s 236ms/step - loss: 6.0771e-04 - mae: 0.0202 - mape: 1705.0676 - val_loss: 5.2255e-04 - val_mae: 0.0289 - val_mape: 154.7517
# Ejecutando la lstm
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 34s 1s/step - loss: 0.0079 - mae: 0.0875 - mape: 1764.4967 - val_loss: 6.2894e-04 - val_mae: 0.0255 - val_mape: 107.5147
# Epoch 2/100
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0059 - mae: 0.0666 - mape: 1227.6533 - val_loss: 8.9691e-04 - val_mae: 0.0332 - val_mape: 179.4879
# Epoch 3/100
# 5/5 [==============================] - 1s 301ms/step - loss: 0.0049 - mae: 0.0612 - mape: 2401.4697 - val_loss: 0.0018 - val_mae: 0.0530 - val_mape: 290.8627
# Epoch 4/100
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0047 - mae: 0.0654 - mape: 744.8209 - val_loss: 0.0023 - val_mae: 0.0625 - val_mape: 336.6743
# Epoch 5/100
# 5/5 [==============================] - 2s 349ms/step - loss: 0.0045 - mae: 0.0654 - mape: 4794.0913 - val_loss: 0.0020 - val_mae: 0.0592 - val_mape: 317.9619
# Epoch 6/100
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0041 - mae: 0.0617 - mape: 4195.5005 - val_loss: 0.0017 - val_mae: 0.0535 - val_mape: 287.4728
# Epoch 7/100
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0038 - mae: 0.0580 - mape: 3297.6970 - val_loss: 0.0015 - val_mae: 0.0508 - val_mape: 271.0969
# Epoch 8/100
# 5/5 [==============================] - 2s 397ms/step - loss: 0.0034 - mae: 0.0561 - mape: 2825.5740 - val_loss: 0.0013 - val_mae: 0.0459 - val_mape: 243.2528
# Epoch 9/100
# 5/5 [==============================] - 2s 327ms/step - loss: 0.0029 - mae: 0.0518 - mape: 1655.0950 - val_loss: 8.2913e-04 - val_mae: 0.0360 - val_mape: 192.7700
# Epoch 10/100
# 5/5 [==============================] - 2s 428ms/step - loss: 0.0024 - mae: 0.0452 - mape: 1162.5659 - val_loss: 5.4357e-04 - val_mae: 0.0277 - val_mape: 151.2695
# Epoch 11/100
# 5/5 [==============================] - 2s 347ms/step - loss: 0.0018 - mae: 0.0391 - mape: 1636.5728 - val_loss: 3.7073e-04 - val_mae: 0.0218 - val_mape: 120.9735
# Epoch 12/100
# 5/5 [==============================] - 2s 505ms/step - loss: 0.0016 - mae: 0.0349 - mape: 1244.5023 - val_loss: 3.1372e-04 - val_mae: 0.0187 - val_mape: 101.6782
# Epoch 13/100
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0013 - mae: 0.0316 - mape: 2197.2371 - val_loss: 2.9646e-04 - val_mae: 0.0187 - val_mape: 103.3175
# Epoch 14/100
# 5/5 [==============================] - 2s 361ms/step - loss: 0.0011 - mae: 0.0290 - mape: 2046.4772 - val_loss: 3.1864e-04 - val_mae: 0.0200 - val_mape: 111.9974
# Epoch 15/100
# 5/5 [==============================] - 1s 282ms/step - loss: 0.0014 - mae: 0.0318 - mape: 400.8607 - val_loss: 3.5169e-04 - val_mae: 0.0217 - val_mape: 121.9884
# Epoch 16/100
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0013 - mae: 0.0350 - mape: 1860.7728 - val_loss: 3.9416e-04 - val_mae: 0.0241 - val_mape: 133.3132
# Epoch 17/100
# 5/5 [==============================] - 2s 338ms/step - loss: 0.0014 - mae: 0.0325 - mape: 1569.4160 - val_loss: 2.9434e-04 - val_mae: 0.0188 - val_mape: 104.2638
# Epoch 18/100
# 5/5 [==============================] - 1s 291ms/step - loss: 0.0010 - mae: 0.0272 - mape: 392.4991 - val_loss: 3.5086e-04 - val_mae: 0.0227 - val_mape: 126.5184
# Epoch 19/100
# 5/5 [==============================] - 2s 416ms/step - loss: 9.5665e-04 - mae: 0.0285 - mape: 1351.0338 - val_loss: 2.5342e-04 - val_mae: 0.0180 - val_mape: 101.4758
# Epoch 20/100
# 5/5 [==============================] - 1s 283ms/step - loss: 8.8140e-04 - mae: 0.0252 - mape: 790.0941 - val_loss: 2.2661e-04 - val_mae: 0.0168 - val_mape: 94.1372
# Epoch 21/100
# 5/5 [==============================] - 2s 329ms/step - loss: 9.1831e-04 - mae: 0.0250 - mape: 1636.0770 - val_loss: 2.1421e-04 - val_mae: 0.0164 - val_mape: 92.0990
# Epoch 22/100
# 5/5 [==============================] - 1s 292ms/step - loss: 8.7206e-04 - mae: 0.0248 - mape: 934.7670 - val_loss: 2.2932e-04 - val_mae: 0.0171 - val_mape: 97.1665
# Epoch 23/100
# 5/5 [==============================] - 1s 275ms/step - loss: 7.3608e-04 - mae: 0.0248 - mape: 969.9199 - val_loss: 2.3995e-04 - val_mae: 0.0182 - val_mape: 104.9557
# Epoch 24/100
# 5/5 [==============================] - 2s 464ms/step - loss: 8.2000e-04 - mae: 0.0243 - mape: 910.4012 - val_loss: 2.0798e-04 - val_mae: 0.0162 - val_mape: 91.3908
# Epoch 25/100
# 5/5 [==============================] - 1s 254ms/step - loss: 7.5897e-04 - mae: 0.0237 - mape: 585.6229 - val_loss: 1.9720e-04 - val_mae: 0.0160 - val_mape: 91.7735
# Epoch 26/100
# 5/5 [==============================] - 2s 472ms/step - loss: 7.7237e-04 - mae: 0.0236 - mape: 1248.7997 - val_loss: 2.0218e-04 - val_mae: 0.0160 - val_mape: 90.3457
# Epoch 27/100
# 5/5 [==============================] - 2s 367ms/step - loss: 7.2853e-04 - mae: 0.0232 - mape: 1147.1388 - val_loss: 2.1406e-04 - val_mae: 0.0171 - val_mape: 99.3383
# Epoch 28/100
# 5/5 [==============================] - 2s 461ms/step - loss: 7.3358e-04 - mae: 0.0229 - mape: 894.8853 - val_loss: 1.8493e-04 - val_mae: 0.0152 - val_mape: 85.4890
# Epoch 29/100
# 5/5 [==============================] - 2s 317ms/step - loss: 6.8183e-04 - mae: 0.0216 - mape: 932.8881 - val_loss: 1.8216e-04 - val_mae: 0.0154 - val_mape: 88.7523
# Epoch 30/100
# 5/5 [==============================] - 2s 328ms/step - loss: 6.7438e-04 - mae: 0.0218 - mape: 1094.2115 - val_loss: 1.7890e-04 - val_mae: 0.0151 - val_mape: 86.1874
# Epoch 31/100
# 5/5 [==============================] - 3s 562ms/step - loss: 6.4919e-04 - mae: 0.0217 - mape: 1455.4437 - val_loss: 1.6938e-04 - val_mae: 0.0148 - val_mape: 85.7976
# Epoch 32/100
# 5/5 [==============================] - 3s 552ms/step - loss: 6.0828e-04 - mae: 0.0210 - mape: 984.9470 - val_loss: 1.6265e-04 - val_mae: 0.0142 - val_mape: 79.2391
# Epoch 33/100
# 5/5 [==============================] - 2s 463ms/step - loss: 6.1654e-04 - mae: 0.0205 - mape: 1246.4589 - val_loss: 1.7812e-04 - val_mae: 0.0153 - val_mape: 89.4624
# Epoch 34/100
# 5/5 [==============================] - 2s 504ms/step - loss: 6.1987e-04 - mae: 0.0210 - mape: 1178.8304 - val_loss: 1.8246e-04 - val_mae: 0.0155 - val_mape: 90.8484
# Epoch 35/100
# 5/5 [==============================] - 3s 425ms/step - loss: 5.6849e-04 - mae: 0.0204 - mape: 1059.9807 - val_loss: 1.6358e-04 - val_mae: 0.0145 - val_mape: 82.9407
# Epoch 36/100
# 5/5 [==============================] - 3s 421ms/step - loss: 5.8211e-04 - mae: 0.0203 - mape: 850.9478 - val_loss: 1.6720e-04 - val_mae: 0.0147 - val_mape: 85.0817
# Epoch 37/100
# 5/5 [==============================] - 1s 271ms/step - loss: 5.8686e-04 - mae: 0.0203 - mape: 1070.7831 - val_loss: 1.6765e-04 - val_mae: 0.0148 - val_mape: 86.4824
# Epoch 38/100
# 5/5 [==============================] - 3s 600ms/step - loss: 5.7403e-04 - mae: 0.0200 - mape: 1207.8521 - val_loss: 1.6549e-04 - val_mae: 0.0145 - val_mape: 82.0646
# Epoch 39/100
# 5/5 [==============================] - 2s 346ms/step - loss: 6.2024e-04 - mae: 0.0200 - mape: 1107.0249 - val_loss: 1.7749e-04 - val_mae: 0.0153 - val_mape: 89.8633
# Epoch 40/100
# 5/5 [==============================] - 1s 256ms/step - loss: 5.5310e-04 - mae: 0.0195 - mape: 1116.3617 - val_loss: 1.7863e-04 - val_mae: 0.0153 - val_mape: 90.4473
# Epoch 41/100
# 5/5 [==============================] - 3s 524ms/step - loss: 5.9394e-04 - mae: 0.0195 - mape: 1152.0199 - val_loss: 1.6559e-04 - val_mae: 0.0145 - val_mape: 82.8498
# Epoch 42/100
# 5/5 [==============================] - 2s 513ms/step - loss: 5.4025e-04 - mae: 0.0196 - mape: 781.5825 - val_loss: 1.6841e-04 - val_mae: 0.0147 - val_mape: 85.4226
# Epoch 43/100
# 5/5 [==============================] - 2s 473ms/step - loss: 5.1874e-04 - mae: 0.0191 - mape: 984.4637 - val_loss: 1.9192e-04 - val_mae: 0.0160 - val_mape: 95.6015
# Epoch 44/100
# 5/5 [==============================] - 3s 561ms/step - loss: 5.2853e-04 - mae: 0.0195 - mape: 1171.6664 - val_loss: 1.6711e-04 - val_mae: 0.0146 - val_mape: 84.0050
# Epoch 45/100
# 5/5 [==============================] - 2s 443ms/step - loss: 5.5133e-04 - mae: 0.0191 - mape: 1036.4883 - val_loss: 1.6966e-04 - val_mae: 0.0148 - val_mape: 86.0747
# Epoch 46/100
# 5/5 [==============================] - 3s 537ms/step - loss: 5.0848e-04 - mae: 0.0189 - mape: 1185.0452 - val_loss: 2.0237e-04 - val_mae: 0.0166 - val_mape: 99.0622
# Epoch 47/100
# 5/5 [==============================] - 2s 315ms/step - loss: 4.7770e-04 - mae: 0.0196 - mape: 1032.5094 - val_loss: 1.7579e-04 - val_mae: 0.0150 - val_mape: 85.3078
# Epoch 48/100
# 5/5 [==============================] - 2s 438ms/step - loss: 5.0802e-04 - mae: 0.0196 - mape: 942.0597 - val_loss: 1.7789e-04 - val_mae: 0.0153 - val_mape: 90.8612
# Epoch 49/100
# 5/5 [==============================] - 2s 461ms/step - loss: 5.2188e-04 - mae: 0.0191 - mape: 1305.5543 - val_loss: 1.8458e-04 - val_mae: 0.0156 - val_mape: 92.7742
# Epoch 50/100
# 5/5 [==============================] - 2s 437ms/step - loss: 4.8536e-04 - mae: 0.0185 - mape: 1038.0923 - val_loss: 1.8225e-04 - val_mae: 0.0156 - val_mape: 92.8892
# Epoch 51/100
# 5/5 [==============================] - 3s 487ms/step - loss: 5.3123e-04 - mae: 0.0189 - mape: 2471.3152 - val_loss: 1.7907e-04 - val_mae: 0.0152 - val_mape: 87.9846
# Epoch 52/100
# 5/5 [==============================] - 3s 621ms/step - loss: 5.0339e-04 - mae: 0.0192 - mape: 1178.8796 - val_loss: 1.8846e-04 - val_mae: 0.0158 - val_mape: 94.7383
# Epoch 53/100
# 5/5 [==============================] - 3s 546ms/step - loss: 4.8616e-04 - mae: 0.0189 - mape: 1318.0427 - val_loss: 1.9245e-04 - val_mae: 0.0160 - val_mape: 94.1173
# Epoch 54/100
# 5/5 [==============================] - 2s 549ms/step - loss: 5.7732e-04 - mae: 0.0193 - mape: 1212.5516 - val_loss: 2.0597e-04 - val_mae: 0.0168 - val_mape: 100.9186
# Epoch 55/100
# 5/5 [==============================] - 3s 671ms/step - loss: 5.4067e-04 - mae: 0.0201 - mape: 1231.4343 - val_loss: 1.9520e-04 - val_mae: 0.0159 - val_mape: 90.8857
# Epoch 56/100
# 5/5 [==============================] - 4s 784ms/step - loss: 6.6692e-04 - mae: 0.0219 - mape: 1035.4302 - val_loss: 1.9804e-04 - val_mae: 0.0163 - val_mape: 97.6152
# Epoch 57/100
# 5/5 [==============================] - 3s 582ms/step - loss: 6.5409e-04 - mae: 0.0223 - mape: 1612.3628 - val_loss: 2.1132e-04 - val_mae: 0.0166 - val_mape: 95.5622
# Epoch 58/100
# 5/5 [==============================] - 3s 726ms/step - loss: 0.0012 - mae: 0.0299 - mape: 1012.3730 - val_loss: 2.3025e-04 - val_mae: 0.0176 - val_mape: 102.9562
# Epoch 59/100
# 5/5 [==============================] - 4s 766ms/step - loss: 0.0012 - mae: 0.0330 - mape: 1261.2090 - val_loss: 2.4593e-04 - val_mae: 0.0183 - val_mape: 107.4080
# Epoch 60/100
# 5/5 [==============================] - 3s 698ms/step - loss: 0.0023 - mae: 0.0394 - mape: 1298.7545 - val_loss: 3.5458e-04 - val_mae: 0.0201 - val_mape: 112.4201
# Epoch 61/100
# 5/5 [==============================] - 2s 367ms/step - loss: 9.4964e-04 - mae: 0.0260 - mape: 1220.0198 - val_loss: 5.2961e-04 - val_mae: 0.0293 - val_mape: 165.2848
# Epoch 62/100
# 5/5 [==============================] - 2s 553ms/step - loss: 0.0012 - mae: 0.0380 - mape: 1686.5212 - val_loss: 4.9250e-04 - val_mae: 0.0281 - val_mape: 160.6094
# Epoch 63/100
# 5/5 [==============================] - 2s 383ms/step - loss: 9.0931e-04 - mae: 0.0278 - mape: 1700.4662 - val_loss: 3.5863e-04 - val_mae: 0.0223 - val_mape: 129.8511
# Epoch 64/100
# 5/5 [==============================] - 3s 660ms/step - loss: 6.7914e-04 - mae: 0.0228 - mape: 1348.6084 - val_loss: 3.1158e-04 - val_mae: 0.0212 - val_mape: 125.8258
# Epoch 65/100
# 5/5 [==============================] - 3s 719ms/step - loss: 7.1069e-04 - mae: 0.0228 - mape: 1590.4924 - val_loss: 2.8411e-04 - val_mae: 0.0202 - val_mape: 120.8100
# Epoch 66/100
# 5/5 [==============================] - 3s 632ms/step - loss: 5.4144e-04 - mae: 0.0205 - mape: 1123.5510 - val_loss: 2.6133e-04 - val_mae: 0.0189 - val_mape: 110.8252
# Epoch 67/100
# 5/5 [==============================] - 1s 295ms/step - loss: 5.3393e-04 - mae: 0.0197 - mape: 1505.8477 - val_loss: 2.4965e-04 - val_mae: 0.0187 - val_mape: 111.1811
# Epoch 68/100
# 5/5 [==============================] - 2s 372ms/step - loss: 5.5194e-04 - mae: 0.0204 - mape: 1299.6221 - val_loss: 2.4168e-04 - val_mae: 0.0184 - val_mape: 110.2419
# Epoch 69/100
# 5/5 [==============================] - 2s 405ms/step - loss: 5.0859e-04 - mae: 0.0194 - mape: 1170.6589 - val_loss: 2.3297e-04 - val_mae: 0.0177 - val_mape: 104.6420
# Epoch 70/100
# 5/5 [==============================] - 2s 422ms/step - loss: 4.2815e-04 - mae: 0.0182 - mape: 1359.0724 - val_loss: 2.2798e-04 - val_mae: 0.0176 - val_mape: 105.3076
# Epoch 71/100
# 5/5 [==============================] - 2s 308ms/step - loss: 4.4189e-04 - mae: 0.0182 - mape: 1236.9598 - val_loss: 2.2686e-04 - val_mae: 0.0177 - val_mape: 106.2632
# Epoch 72/100
# 5/5 [==============================] - 3s 539ms/step - loss: 4.5290e-04 - mae: 0.0183 - mape: 1390.3928 - val_loss: 2.2521e-04 - val_mae: 0.0175 - val_mape: 104.2178
# Epoch 73/100
# 5/5 [==============================] - 2s 329ms/step - loss: 4.5992e-04 - mae: 0.0175 - mape: 1511.0952 - val_loss: 2.2358e-04 - val_mae: 0.0175 - val_mape: 105.0701
# Epoch 74/100
# 5/5 [==============================] - 1s 299ms/step - loss: 4.4652e-04 - mae: 0.0180 - mape: 1192.6240 - val_loss: 2.2283e-04 - val_mae: 0.0175 - val_mape: 104.9627
# Epoch 75/100
# 5/5 [==============================] - 2s 477ms/step - loss: 4.0698e-04 - mae: 0.0171 - mape: 1549.9576 - val_loss: 2.2281e-04 - val_mae: 0.0174 - val_mape: 104.3194
# Epoch 76/100
# 5/5 [==============================] - 2s 328ms/step - loss: 3.9934e-04 - mae: 0.0172 - mape: 1074.5609 - val_loss: 2.2236e-04 - val_mae: 0.0174 - val_mape: 105.1561
# Epoch 77/100
# 5/5 [==============================] - 2s 371ms/step - loss: 4.2502e-04 - mae: 0.0176 - mape: 1059.8328 - val_loss: 2.2140e-04 - val_mae: 0.0174 - val_mape: 104.6860
# Epoch 78/100
# 5/5 [==============================] - 2s 273ms/step - loss: 4.4300e-04 - mae: 0.0173 - mape: 1206.9675 - val_loss: 2.2387e-04 - val_mae: 0.0175 - val_mape: 104.8054
# Epoch 79/100
# 5/5 [==============================] - 2s 362ms/step - loss: 4.9540e-04 - mae: 0.0177 - mape: 1195.6362 - val_loss: 2.2411e-04 - val_mae: 0.0175 - val_mape: 105.9277
# Epoch 80/100
# 5/5 [==============================] - 2s 407ms/step - loss: 4.5081e-04 - mae: 0.0175 - mape: 1239.3119 - val_loss: 2.2624e-04 - val_mae: 0.0176 - val_mape: 105.9809
# Epoch 81/100
# 5/5 [==============================] - 3s 642ms/step - loss: 4.4475e-04 - mae: 0.0174 - mape: 1216.2721 - val_loss: 2.2843e-04 - val_mae: 0.0177 - val_mape: 106.3723
# Epoch 82/100
# 5/5 [==============================] - 2s 398ms/step - loss: 4.5859e-04 - mae: 0.0172 - mape: 1214.1859 - val_loss: 2.2925e-04 - val_mae: 0.0178 - val_mape: 107.9700
# Epoch 83/100
# 5/5 [==============================] - 3s 535ms/step - loss: 4.1686e-04 - mae: 0.0170 - mape: 1224.1315 - val_loss: 2.2740e-04 - val_mae: 0.0176 - val_mape: 107.0596
# Epoch 84/100
# 5/5 [==============================] - 3s 561ms/step - loss: 4.2670e-04 - mae: 0.0172 - mape: 1067.5134 - val_loss: 2.2526e-04 - val_mae: 0.0175 - val_mape: 105.9482
# Epoch 85/100
# 5/5 [==============================] - 2s 481ms/step - loss: 4.3185e-04 - mae: 0.0170 - mape: 1178.4615 - val_loss: 2.3195e-04 - val_mae: 0.0178 - val_mape: 107.7208
# Epoch 86/100
# 5/5 [==============================] - 2s 370ms/step - loss: 3.5945e-04 - mae: 0.0163 - mape: 1236.1150 - val_loss: 2.3489e-04 - val_mae: 0.0180 - val_mape: 109.1279
# Epoch 87/100
# 5/5 [==============================] - 2s 478ms/step - loss: 3.9204e-04 - mae: 0.0167 - mape: 1183.1060 - val_loss: 2.3775e-04 - val_mae: 0.0181 - val_mape: 109.5587
# Epoch 88/100
# 5/5 [==============================] - 3s 697ms/step - loss: 4.2334e-04 - mae: 0.0169 - mape: 1272.7440 - val_loss: 2.3884e-04 - val_mae: 0.0182 - val_mape: 109.9860
# Epoch 89/100
# 5/5 [==============================] - 2s 434ms/step - loss: 3.6342e-04 - mae: 0.0165 - mape: 1243.8547 - val_loss: 2.3858e-04 - val_mae: 0.0182 - val_mape: 110.5599
# Epoch 90/100
# 5/5 [==============================] - 2s 396ms/step - loss: 4.1470e-04 - mae: 0.0164 - mape: 1180.7753 - val_loss: 2.4036e-04 - val_mae: 0.0182 - val_mape: 110.3684
# Epoch 91/100
# 5/5 [==============================] - 2s 517ms/step - loss: 4.7725e-04 - mae: 0.0172 - mape: 1250.6700 - val_loss: 2.3894e-04 - val_mae: 0.0182 - val_mape: 109.9987
# Epoch 92/100
# 5/5 [==============================] - 3s 514ms/step - loss: 3.9683e-04 - mae: 0.0167 - mape: 1272.8995 - val_loss: 2.4162e-04 - val_mae: 0.0183 - val_mape: 111.2260
# Epoch 93/100
# 5/5 [==============================] - 2s 448ms/step - loss: 4.4917e-04 - mae: 0.0169 - mape: 1026.8892 - val_loss: 2.4257e-04 - val_mae: 0.0183 - val_mape: 111.0471
# Epoch 94/100
# 5/5 [==============================] - 4s 913ms/step - loss: 4.1818e-04 - mae: 0.0165 - mape: 1830.7766 - val_loss: 2.4385e-04 - val_mae: 0.0184 - val_mape: 111.0788
# Epoch 95/100
# 5/5 [==============================] - 2s 449ms/step - loss: 3.8413e-04 - mae: 0.0165 - mape: 1168.0424 - val_loss: 2.4625e-04 - val_mae: 0.0185 - val_mape: 112.6628
# Epoch 96/100
# 5/5 [==============================] - 2s 333ms/step - loss: 4.0694e-04 - mae: 0.0166 - mape: 1326.6400 - val_loss: 2.4221e-04 - val_mae: 0.0183 - val_mape: 111.2490
# Epoch 97/100
# 5/5 [==============================] - 2s 349ms/step - loss: 4.4118e-04 - mae: 0.0169 - mape: 1070.6577 - val_loss: 2.3604e-04 - val_mae: 0.0180 - val_mape: 109.4742
# Epoch 98/100
# 5/5 [==============================] - 4s 741ms/step - loss: 3.7940e-04 - mae: 0.0163 - mape: 1147.7494 - val_loss: 2.3006e-04 - val_mae: 0.0178 - val_mape: 107.2470
# Epoch 99/100
# 5/5 [==============================] - 3s 617ms/step - loss: 4.0617e-04 - mae: 0.0167 - mape: 1267.3597 - val_loss: 2.3830e-04 - val_mae: 0.0181 - val_mape: 110.0805
# Epoch 100/100
# 5/5 [==============================] - 3s 669ms/step - loss: 3.9886e-04 - mae: 0.0170 - mape: 1287.7084 - val_loss: 2.4526e-04 - val_mae: 0.0185 - val_mape: 111.9642
# Ejecutando la gru
# Prediction lookback (n_steps): 24
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/100
# 5/5 [==============================] - 62s 2s/step - loss: 0.0080 - mae: 0.0886 - mape: 376.2693 - val_loss: 6.5829e-04 - val_mae: 0.0271 - val_mape: 118.3805
# Epoch 2/100
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0058 - mae: 0.0674 - mape: 1301.1165 - val_loss: 8.9423e-04 - val_mae: 0.0344 - val_mape: 181.7012
# Epoch 3/100
# 5/5 [==============================] - 3s 490ms/step - loss: 0.0048 - mae: 0.0629 - mape: 1974.4998 - val_loss: 0.0017 - val_mae: 0.0516 - val_mape: 276.4017
# Epoch 4/100
# 5/5 [==============================] - 2s 360ms/step - loss: 0.0046 - mae: 0.0653 - mape: 1590.9406 - val_loss: 0.0024 - val_mae: 0.0639 - val_mape: 337.9241
# Epoch 5/100
# 5/5 [==============================] - 2s 433ms/step - loss: 0.0046 - mae: 0.0675 - mape: 2207.4702 - val_loss: 0.0024 - val_mae: 0.0652 - val_mape: 344.1698
# Epoch 6/100
# 5/5 [==============================] - 2s 409ms/step - loss: 0.0041 - mae: 0.0641 - mape: 1645.8385 - val_loss: 0.0022 - val_mae: 0.0618 - val_mape: 326.6275
# Epoch 7/100
# 5/5 [==============================] - 2s 333ms/step - loss: 0.0038 - mae: 0.0610 - mape: 2605.4668 - val_loss: 0.0020 - val_mae: 0.0591 - val_mape: 312.0335
# Epoch 8/100
# 5/5 [==============================] - 1s 293ms/step - loss: 0.0035 - mae: 0.0577 - mape: 3587.8176 - val_loss: 0.0018 - val_mae: 0.0569 - val_mape: 299.6011
# Epoch 9/100
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0031 - mae: 0.0539 - mape: 3125.7725 - val_loss: 0.0017 - val_mae: 0.0548 - val_mape: 286.9620
# Epoch 10/100
# 5/5 [==============================] - 3s 527ms/step - loss: 0.0025 - mae: 0.0499 - mape: 2994.2986 - val_loss: 0.0015 - val_mae: 0.0508 - val_mape: 265.2858
# Epoch 11/100
# 5/5 [==============================] - 2s 289ms/step - loss: 0.0021 - mae: 0.0446 - mape: 1636.5881 - val_loss: 0.0011 - val_mae: 0.0433 - val_mape: 228.2144
# Epoch 12/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.0016 - mae: 0.0382 - mape: 809.1317 - val_loss: 7.2469e-04 - val_mae: 0.0338 - val_mape: 182.8876
# Epoch 13/100
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0012 - mae: 0.0321 - mape: 2102.1343 - val_loss: 4.8719e-04 - val_mae: 0.0264 - val_mape: 147.2058
# Epoch 14/100
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0010 - mae: 0.0285 - mape: 1539.7949 - val_loss: 3.3592e-04 - val_mae: 0.0211 - val_mape: 120.2851
# Epoch 15/100
# 5/5 [==============================] - 3s 769ms/step - loss: 0.0011 - mae: 0.0283 - mape: 1305.8226 - val_loss: 3.0987e-04 - val_mae: 0.0203 - val_mape: 116.9925
# Epoch 16/100
# 5/5 [==============================] - 2s 382ms/step - loss: 9.6937e-04 - mae: 0.0267 - mape: 1428.6185 - val_loss: 3.5436e-04 - val_mae: 0.0223 - val_mape: 128.2570
# Epoch 17/100
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0011 - mae: 0.0286 - mape: 1611.3303 - val_loss: 3.3002e-04 - val_mae: 0.0216 - val_mape: 125.4040
# Epoch 18/100
# 5/5 [==============================] - 3s 525ms/step - loss: 0.0010 - mae: 0.0276 - mape: 1629.1035 - val_loss: 5.0215e-04 - val_mae: 0.0279 - val_mape: 152.7946
# Epoch 19/100
# 5/5 [==============================] - 2s 240ms/step - loss: 9.5289e-04 - mae: 0.0272 - mape: 2045.6790 - val_loss: 2.9910e-04 - val_mae: 0.0204 - val_mape: 119.7694
# Epoch 20/100
# 5/5 [==============================] - 2s 570ms/step - loss: 8.9189e-04 - mae: 0.0250 - mape: 1689.4569 - val_loss: 4.0164e-04 - val_mae: 0.0245 - val_mape: 137.5018
# Epoch 21/100
# 5/5 [==============================] - 2s 393ms/step - loss: 9.1435e-04 - mae: 0.0260 - mape: 1422.1215 - val_loss: 2.5778e-04 - val_mae: 0.0186 - val_mape: 109.8403
# Epoch 22/100
# 5/5 [==============================] - 3s 757ms/step - loss: 8.1664e-04 - mae: 0.0240 - mape: 1658.2360 - val_loss: 2.5360e-04 - val_mae: 0.0185 - val_mape: 109.5041
# Epoch 23/100
# 5/5 [==============================] - 2s 455ms/step - loss: 8.5566e-04 - mae: 0.0242 - mape: 1861.4861 - val_loss: 2.8394e-04 - val_mae: 0.0200 - val_mape: 117.1029
# Epoch 24/100
# 5/5 [==============================] - 2s 250ms/step - loss: 8.1613e-04 - mae: 0.0240 - mape: 1363.0011 - val_loss: 2.4473e-04 - val_mae: 0.0184 - val_mape: 109.2878
# Epoch 25/100
# 5/5 [==============================] - 1s 257ms/step - loss: 6.9675e-04 - mae: 0.0228 - mape: 1308.3188 - val_loss: 3.0169e-04 - val_mae: 0.0210 - val_mape: 122.0786
# Epoch 26/100
# 5/5 [==============================] - 2s 406ms/step - loss: 8.1436e-04 - mae: 0.0241 - mape: 1449.0533 - val_loss: 2.1603e-04 - val_mae: 0.0171 - val_mape: 102.5997
# Epoch 27/100
# 5/5 [==============================] - 4s 852ms/step - loss: 7.3955e-04 - mae: 0.0227 - mape: 1324.8177 - val_loss: 2.9926e-04 - val_mae: 0.0210 - val_mape: 120.5481
# Epoch 28/100
# 5/5 [==============================] - 2s 518ms/step - loss: 8.0925e-04 - mae: 0.0236 - mape: 1213.7900 - val_loss: 1.9082e-04 - val_mae: 0.0158 - val_mape: 94.3097
# Epoch 29/100
# 5/5 [==============================] - 3s 548ms/step - loss: 6.9463e-04 - mae: 0.0215 - mape: 1732.8629 - val_loss: 3.0150e-04 - val_mae: 0.0211 - val_mape: 122.4573
# Epoch 30/100
# 5/5 [==============================] - 1s 271ms/step - loss: 7.4165e-04 - mae: 0.0227 - mape: 1245.9293 - val_loss: 2.1080e-04 - val_mae: 0.0169 - val_mape: 101.9462
# Epoch 31/100
# 5/5 [==============================] - 2s 470ms/step - loss: 6.7604e-04 - mae: 0.0217 - mape: 1254.9575 - val_loss: 2.0587e-04 - val_mae: 0.0167 - val_mape: 100.7802
# Epoch 32/100
# 5/5 [==============================] - 2s 390ms/step - loss: 6.7205e-04 - mae: 0.0214 - mape: 1240.1219 - val_loss: 2.2874e-04 - val_mae: 0.0179 - val_mape: 106.4999
# Epoch 33/100
# 5/5 [==============================] - 2s 523ms/step - loss: 6.9395e-04 - mae: 0.0216 - mape: 1399.3436 - val_loss: 1.9756e-04 - val_mae: 0.0163 - val_mape: 98.7405
# Epoch 34/100
# 5/5 [==============================] - 2s 368ms/step - loss: 6.6412e-04 - mae: 0.0213 - mape: 1007.5007 - val_loss: 2.3501e-04 - val_mae: 0.0182 - val_mape: 108.3623
# Epoch 35/100
# 5/5 [==============================] - 2s 317ms/step - loss: 6.8009e-04 - mae: 0.0216 - mape: 1160.3901 - val_loss: 2.0486e-04 - val_mae: 0.0167 - val_mape: 101.1712
# Epoch 36/100
# 5/5 [==============================] - 2s 333ms/step - loss: 7.0128e-04 - mae: 0.0210 - mape: 1391.3833 - val_loss: 2.2168e-04 - val_mae: 0.0175 - val_mape: 105.2204
# Epoch 37/100
# 5/5 [==============================] - 1s 272ms/step - loss: 6.0327e-04 - mae: 0.0209 - mape: 1274.5896 - val_loss: 1.9788e-04 - val_mae: 0.0163 - val_mape: 99.1613
# Epoch 38/100
# 5/5 [==============================] - 1s 163ms/step - loss: 6.8614e-04 - mae: 0.0211 - mape: 1616.5695 - val_loss: 2.1099e-04 - val_mae: 0.0170 - val_mape: 102.6410
# Epoch 39/100
# 5/5 [==============================] - 1s 220ms/step - loss: 7.0340e-04 - mae: 0.0217 - mape: 1429.4285 - val_loss: 1.9249e-04 - val_mae: 0.0161 - val_mape: 97.5747
# Epoch 40/100
# 5/5 [==============================] - 3s 696ms/step - loss: 6.7184e-04 - mae: 0.0216 - mape: 1434.8888 - val_loss: 1.9641e-04 - val_mae: 0.0163 - val_mape: 98.7450
# Epoch 41/100
# 5/5 [==============================] - 2s 327ms/step - loss: 7.6323e-04 - mae: 0.0230 - mape: 1157.8872 - val_loss: 1.8832e-04 - val_mae: 0.0158 - val_mape: 96.0821
# Epoch 42/100
# 5/5 [==============================] - 2s 449ms/step - loss: 7.1507e-04 - mae: 0.0228 - mape: 1371.7599 - val_loss: 2.1525e-04 - val_mae: 0.0172 - val_mape: 103.4647
# Epoch 43/100
# 5/5 [==============================] - 2s 395ms/step - loss: 7.2476e-04 - mae: 0.0230 - mape: 1380.7018 - val_loss: 1.8970e-04 - val_mae: 0.0157 - val_mape: 93.4063
# Epoch 44/100
# 5/5 [==============================] - 3s 603ms/step - loss: 6.1360e-04 - mae: 0.0213 - mape: 1662.4574 - val_loss: 2.6813e-04 - val_mae: 0.0197 - val_mape: 114.9980
# Epoch 45/100
# 5/5 [==============================] - 2s 405ms/step - loss: 6.8975e-04 - mae: 0.0222 - mape: 1304.8868 - val_loss: 1.9499e-04 - val_mae: 0.0159 - val_mape: 95.1236
# Epoch 46/100
# 5/5 [==============================] - 2s 345ms/step - loss: 5.5488e-04 - mae: 0.0195 - mape: 1387.2877 - val_loss: 3.1440e-04 - val_mae: 0.0217 - val_mape: 123.6135
# Epoch 47/100
# 5/5 [==============================] - 1s 154ms/step - loss: 5.7420e-04 - mae: 0.0214 - mape: 1256.6469 - val_loss: 1.9562e-04 - val_mae: 0.0160 - val_mape: 96.2913
# Epoch 48/100
# 5/5 [==============================] - 1s 315ms/step - loss: 5.6116e-04 - mae: 0.0200 - mape: 1519.6913 - val_loss: 2.0792e-04 - val_mae: 0.0167 - val_mape: 101.7570
# Epoch 49/100
# 5/5 [==============================] - 1s 262ms/step - loss: 5.3003e-04 - mae: 0.0192 - mape: 2192.0381 - val_loss: 2.4291e-04 - val_mae: 0.0185 - val_mape: 111.3460
# Epoch 50/100
# 5/5 [==============================] - 2s 491ms/step - loss: 5.0304e-04 - mae: 0.0193 - mape: 1609.7909 - val_loss: 2.2113e-04 - val_mae: 0.0174 - val_mape: 106.2312
# Epoch 51/100
# 5/5 [==============================] - 2s 408ms/step - loss: 5.6867e-04 - mae: 0.0193 - mape: 1558.4080 - val_loss: 2.1529e-04 - val_mae: 0.0171 - val_mape: 104.3356
# Epoch 52/100
# 5/5 [==============================] - 3s 584ms/step - loss: 5.2220e-04 - mae: 0.0193 - mape: 1454.1907 - val_loss: 1.9756e-04 - val_mae: 0.0163 - val_mape: 99.2865
# Epoch 53/100
# 5/5 [==============================] - 3s 532ms/step - loss: 5.1574e-04 - mae: 0.0186 - mape: 1176.1876 - val_loss: 2.1278e-04 - val_mae: 0.0171 - val_mape: 103.7055
# Epoch 54/100
# 5/5 [==============================] - 3s 459ms/step - loss: 5.8436e-04 - mae: 0.0191 - mape: 1673.7712 - val_loss: 2.0403e-04 - val_mae: 0.0167 - val_mape: 101.4831
# Epoch 55/100
# 5/5 [==============================] - 2s 499ms/step - loss: 5.2461e-04 - mae: 0.0188 - mape: 1476.0956 - val_loss: 2.0879e-04 - val_mae: 0.0169 - val_mape: 102.1887
# Epoch 56/100
# 5/5 [==============================] - 2s 434ms/step - loss: 5.0054e-04 - mae: 0.0187 - mape: 1195.7063 - val_loss: 1.8678e-04 - val_mae: 0.0157 - val_mape: 95.6336
# Epoch 57/100
# 5/5 [==============================] - 1s 223ms/step - loss: 5.3857e-04 - mae: 0.0186 - mape: 1399.6962 - val_loss: 1.9339e-04 - val_mae: 0.0160 - val_mape: 97.3038
# Epoch 58/100
# 5/5 [==============================] - 2s 500ms/step - loss: 4.9150e-04 - mae: 0.0184 - mape: 1171.9691 - val_loss: 1.9170e-04 - val_mae: 0.0159 - val_mape: 97.2210
# Epoch 59/100
# 5/5 [==============================] - 4s 705ms/step - loss: 5.0647e-04 - mae: 0.0184 - mape: 1145.3510 - val_loss: 2.1261e-04 - val_mae: 0.0171 - val_mape: 103.5108
# Epoch 60/100
# 5/5 [==============================] - 2s 492ms/step - loss: 5.2677e-04 - mae: 0.0189 - mape: 1258.8286 - val_loss: 2.0887e-04 - val_mae: 0.0169 - val_mape: 102.7584
# Epoch 61/100
# 5/5 [==============================] - 2s 411ms/step - loss: 5.0470e-04 - mae: 0.0189 - mape: 1218.0424 - val_loss: 1.8782e-04 - val_mae: 0.0157 - val_mape: 95.8564
# Epoch 62/100
# 5/5 [==============================] - 2s 388ms/step - loss: 5.2536e-04 - mae: 0.0194 - mape: 1348.8636 - val_loss: 1.9605e-04 - val_mae: 0.0162 - val_mape: 98.9689
# Epoch 63/100
# 5/5 [==============================] - 3s 450ms/step - loss: 5.2069e-04 - mae: 0.0186 - mape: 1722.6937 - val_loss: 2.1742e-04 - val_mae: 0.0173 - val_mape: 105.2089
# Epoch 64/100
# 5/5 [==============================] - 3s 550ms/step - loss: 5.0666e-04 - mae: 0.0187 - mape: 1376.4274 - val_loss: 2.0836e-04 - val_mae: 0.0168 - val_mape: 102.5759
# Epoch 65/100
# 5/5 [==============================] - 2s 437ms/step - loss: 4.6787e-04 - mae: 0.0185 - mape: 1250.5237 - val_loss: 2.1469e-04 - val_mae: 0.0171 - val_mape: 104.3931
# Epoch 66/100
# 5/5 [==============================] - 4s 563ms/step - loss: 4.6845e-04 - mae: 0.0187 - mape: 1193.9386 - val_loss: 2.0644e-04 - val_mae: 0.0167 - val_mape: 102.0692
# Epoch 67/100
# ...
# Epoch 12/100
# 5/5 [==============================] - 3s 706ms/step - loss: 0.0021 - mae: 0.0471 - mape: 2470.5212 - val_loss: 8.2975e-04 - val_mae: 0.0361 - val_mape: 195.4367
# Epoch 13/100
# 5/5 [==============================] - 2s 472ms/step - loss: 0.0014 - mae: 0.0374 - mape: 1224.7543 - val_loss: 5.1169e-04 - val_mae: 0.0261 - val_mape: 143.0153
# Epoch 14/100
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0013 - mae: 0.0310 - mape: 501.6084 - val_loss: 3.8113e-04 - val_mae: 0.0213 - val_mape: 113.1339
# Epoch 15/100
# 5/5 [==============================] - 4s 657ms/step - loss: 0.0013 - mae: 0.0325 - mape: 1005.6398 - val_loss: 4.0398e-04 - val_mae: 0.0236 - val_mape: 132.2991
# Epoch 16/100
# 5/5 [==============================] - 3s 613ms/step - loss: 0.0015 - mae: 0.0354 - mape: 1474.9486 - val_loss: 4.6218e-04 - val_mae: 0.0264 - val_mape: 150.2202
# Epoch 17/100
# 5/5 [==============================] - 5s 994ms/step - loss: 0.0022 - mae: 0.0399 - mape: 1420.3014 - val_loss: 4.6239e-04 - val_mae: 0.0246 - val_mape: 137.4893
# Epoch 18/100
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0014 - mae: 0.0322 - mape: 1296.9296 - val_loss: 6.9836e-04 - val_mae: 0.0339 - val_mape: 190.0531
# Epoch 19/100
# 5/5 [==============================] - 3s 658ms/step - loss: 0.0013 - mae: 0.0392 - mape: 2081.1399 - val_loss: 8.7472e-04 - val_mae: 0.0389 - val_mape: 212.4287
# Epoch 20/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0011 - mae: 0.0346 - mape: 1211.7148 - val_loss: 5.2202e-04 - val_mae: 0.0282 - val_mape: 158.7263
# Epoch 21/100
# 5/5 [==============================] - 2s 319ms/step - loss: 9.4302e-04 - mae: 0.0272 - mape: 1576.8320 - val_loss: 4.0326e-04 - val_mae: 0.0242 - val_mape: 136.2762
# Epoch 22/100
# 5/5 [==============================] - 1s 220ms/step - loss: 8.7883e-04 - mae: 0.0258 - mape: 1056.5554 - val_loss: 3.2660e-04 - val_mae: 0.0216 - val_mape: 123.4367
# Epoch 23/100
# 5/5 [==============================] - 3s 626ms/step - loss: 7.4371e-04 - mae: 0.0242 - mape: 1279.0826 - val_loss: 2.6014e-04 - val_mae: 0.0183 - val_mape: 100.6277
# Epoch 24/100
# 5/5 [==============================] - 3s 696ms/step - loss: 6.8657e-04 - mae: 0.0231 - mape: 1038.0288 - val_loss: 2.7990e-04 - val_mae: 0.0199 - val_mape: 113.8457
# Epoch 25/100
# 5/5 [==============================] - 1s 283ms/step - loss: 7.1103e-04 - mae: 0.0234 - mape: 1635.4655 - val_loss: 2.7243e-04 - val_mae: 0.0197 - val_mape: 114.0097
# Epoch 26/100
# 5/5 [==============================] - 3s 719ms/step - loss: 7.3645e-04 - mae: 0.0230 - mape: 1084.5361 - val_loss: 2.2110e-04 - val_mae: 0.0172 - val_mape: 96.8720
# Epoch 27/100
# 5/5 [==============================] - 3s 605ms/step - loss: 6.7586e-04 - mae: 0.0219 - mape: 1792.8401 - val_loss: 2.1407e-04 - val_mae: 0.0171 - val_mape: 97.7096
# Epoch 28/100
# 5/5 [==============================] - 4s 872ms/step - loss: 6.8886e-04 - mae: 0.0219 - mape: 1572.0758 - val_loss: 1.9443e-04 - val_mae: 0.0160 - val_mape: 90.3608
# Epoch 29/100
# 5/5 [==============================] - 4s 893ms/step - loss: 6.9527e-04 - mae: 0.0218 - mape: 1358.8323 - val_loss: 2.0026e-04 - val_mae: 0.0164 - val_mape: 93.2475
# Epoch 30/100
# 5/5 [==============================] - 2s 312ms/step - loss: 6.3271e-04 - mae: 0.0208 - mape: 927.4647 - val_loss: 2.0491e-04 - val_mae: 0.0167 - val_mape: 96.4497
# Epoch 31/100
# 5/5 [==============================] - 3s 678ms/step - loss: 6.1128e-04 - mae: 0.0212 - mape: 1587.9048 - val_loss: 1.8400e-04 - val_mae: 0.0157 - val_mape: 89.0872
# Epoch 32/100
# 5/5 [==============================] - 3s 562ms/step - loss: 5.7314e-04 - mae: 0.0207 - mape: 798.1066 - val_loss: 1.6493e-04 - val_mae: 0.0147 - val_mape: 82.0975
# Epoch 33/100
# 5/5 [==============================] - 2s 434ms/step - loss: 6.1598e-04 - mae: 0.0206 - mape: 912.5709 - val_loss: 1.7072e-04 - val_mae: 0.0149 - val_mape: 84.0146
# Epoch 34/100
# 5/5 [==============================] - 4s 808ms/step - loss: 6.0689e-04 - mae: 0.0206 - mape: 352.3737 - val_loss: 1.9235e-04 - val_mae: 0.0162 - val_mape: 93.7448
# Epoch 35/100
# 5/5 [==============================] - 4s 885ms/step - loss: 5.8960e-04 - mae: 0.0205 - mape: 1227.3245 - val_loss: 1.6146e-04 - val_mae: 0.0144 - val_mape: 79.3431
# Epoch 36/100
# 5/5 [==============================] - 2s 311ms/step - loss: 5.9343e-04 - mae: 0.0208 - mape: 884.8162 - val_loss: 1.8723e-04 - val_mae: 0.0159 - val_mape: 91.2173
# Epoch 37/100
# 5/5 [==============================] - 1s 182ms/step - loss: 5.6893e-04 - mae: 0.0205 - mape: 1336.6526 - val_loss: 1.7316e-04 - val_mae: 0.0151 - val_mape: 85.9075
# Epoch 38/100
# 5/5 [==============================] - 3s 470ms/step - loss: 6.4097e-04 - mae: 0.0208 - mape: 1303.5404 - val_loss: 1.6772e-04 - val_mae: 0.0147 - val_mape: 82.3559
# Epoch 39/100
# 5/5 [==============================] - 2s 451ms/step - loss: 6.4105e-04 - mae: 0.0209 - mape: 1533.5590 - val_loss: 1.9057e-04 - val_mae: 0.0162 - val_mape: 93.6088
# Epoch 40/100
# 5/5 [==============================] - 3s 514ms/step - loss: 5.6564e-04 - mae: 0.0202 - mape: 972.7393 - val_loss: 1.5456e-04 - val_mae: 0.0140 - val_mape: 77.1152
# Epoch 41/100
# 5/5 [==============================] - 3s 720ms/step - loss: 6.1311e-04 - mae: 0.0201 - mape: 1294.8342 - val_loss: 1.7003e-04 - val_mae: 0.0150 - val_mape: 85.6951
# Epoch 42/100
# 5/5 [==============================] - 4s 726ms/step - loss: 5.2224e-04 - mae: 0.0195 - mape: 998.7327 - val_loss: 1.6279e-04 - val_mae: 0.0145 - val_mape: 81.2948
# Epoch 43/100
# 5/5 [==============================] - 3s 746ms/step - loss: 5.1455e-04 - mae: 0.0192 - mape: 1450.5110 - val_loss: 1.8889e-04 - val_mae: 0.0160 - val_mape: 92.1473
# Epoch 44/100
# 5/5 [==============================] - 4s 813ms/step - loss: 4.8918e-04 - mae: 0.0194 - mape: 1043.1804 - val_loss: 1.6189e-04 - val_mae: 0.0145 - val_mape: 81.8906
# Epoch 45/100
# 5/5 [==============================] - 2s 429ms/step - loss: 5.5914e-04 - mae: 0.0197 - mape: 1748.8821 - val_loss: 1.5279e-04 - val_mae: 0.0140 - val_mape: 77.4873
# Epoch 46/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.2410e-04 - mae: 0.0192 - mape: 784.0538 - val_loss: 1.6301e-04 - val_mae: 0.0146 - val_mape: 83.3325
# Epoch 47/100
# 5/5 [==============================] - 3s 634ms/step - loss: 5.4495e-04 - mae: 0.0191 - mape: 1150.4298 - val_loss: 1.4447e-04 - val_mae: 0.0135 - val_mape: 74.2637
# Epoch 48/100
# 5/5 [==============================] - 3s 614ms/step - loss: 5.3035e-04 - mae: 0.0190 - mape: 1181.5789 - val_loss: 1.5793e-04 - val_mae: 0.0143 - val_mape: 81.1830
# Epoch 49/100
# 5/5 [==============================] - 4s 950ms/step - loss: 5.2009e-04 - mae: 0.0194 - mape: 588.1237 - val_loss: 1.7065e-04 - val_mae: 0.0150 - val_mape: 85.9590
# Epoch 50/100
# 5/5 [==============================] - 3s 696ms/step - loss: 5.0579e-04 - mae: 0.0188 - mape: 753.3616 - val_loss: 1.5405e-04 - val_mae: 0.0141 - val_mape: 79.5959
# Epoch 51/100
# 5/5 [==============================] - 5s 1s/step - loss: 5.5450e-04 - mae: 0.0191 - mape: 873.6919 - val_loss: 1.5264e-04 - val_mae: 0.0140 - val_mape: 78.9401
# Epoch 52/100
# 5/5 [==============================] - 3s 644ms/step - loss: 5.1693e-04 - mae: 0.0190 - mape: 1082.4166 - val_loss: 1.4913e-04 - val_mae: 0.0138 - val_mape: 76.7451
# Epoch 53/100
# 5/5 [==============================] - 4s 776ms/step - loss: 4.8047e-04 - mae: 0.0189 - mape: 982.0363 - val_loss: 1.8488e-04 - val_mae: 0.0158 - val_mape: 91.2216
# Epoch 54/100
# 5/5 [==============================] - 3s 525ms/step - loss: 5.9265e-04 - mae: 0.0196 - mape: 1145.1820 - val_loss: 1.6145e-04 - val_mae: 0.0145 - val_mape: 82.4922
# Epoch 55/100
# 5/5 [==============================] - 4s 803ms/step - loss: 5.7034e-04 - mae: 0.0194 - mape: 1103.3527 - val_loss: 1.5551e-04 - val_mae: 0.0142 - val_mape: 80.1526
# Epoch 56/100
# 5/5 [==============================] - 2s 349ms/step - loss: 5.2762e-04 - mae: 0.0196 - mape: 1315.0006 - val_loss: 1.2981e-04 - val_mae: 0.0126 - val_mape: 66.3670
# Epoch 57/100
# 5/5 [==============================] - 2s 396ms/step - loss: 5.1407e-04 - mae: 0.0192 - mape: 1228.7074 - val_loss: 1.8353e-04 - val_mae: 0.0157 - val_mape: 91.0256
# Epoch 58/100
# 5/5 [==============================] - 4s 770ms/step - loss: 4.6956e-04 - mae: 0.0190 - mape: 998.8511 - val_loss: 1.7694e-04 - val_mae: 0.0153 - val_mape: 87.6478
# Epoch 59/100
# 5/5 [==============================] - 2s 347ms/step - loss: 4.9982e-04 - mae: 0.0192 - mape: 665.6764 - val_loss: 1.9371e-04 - val_mae: 0.0162 - val_mape: 94.0359
# Epoch 60/100
# 5/5 [==============================] - 2s 414ms/step - loss: 5.3956e-04 - mae: 0.0197 - mape: 1110.3885 - val_loss: 1.5446e-04 - val_mae: 0.0141 - val_mape: 79.9185
# Epoch 61/100
# 5/5 [==============================] - 2s 395ms/step - loss: 5.4771e-04 - mae: 0.0202 - mape: 1234.9927 - val_loss: 1.7770e-04 - val_mae: 0.0154 - val_mape: 88.9956
# Epoch 62/100
# 5/5 [==============================] - 2s 391ms/step - loss: 5.2531e-04 - mae: 0.0205 - mape: 1736.6270 - val_loss: 1.5096e-04 - val_mae: 0.0138 - val_mape: 76.9841
# Epoch 63/100
# 5/5 [==============================] - 1s 300ms/step - loss: 7.1352e-04 - mae: 0.0226 - mape: 1245.5226 - val_loss: 2.2045e-04 - val_mae: 0.0175 - val_mape: 101.6263
# Epoch 64/100
# 5/5 [==============================] - 2s 443ms/step - loss: 6.5388e-04 - mae: 0.0238 - mape: 1463.5946 - val_loss: 2.2035e-04 - val_mae: 0.0176 - val_mape: 102.4832
# Epoch 65/100
# 5/5 [==============================] - 1s 303ms/step - loss: 8.6136e-04 - mae: 0.0262 - mape: 1050.8677 - val_loss: 2.1912e-04 - val_mae: 0.0171 - val_mape: 97.4816
# Epoch 66/100
# 5/5 [==============================] - 2s 420ms/step - loss: 6.9698e-04 - mae: 0.0248 - mape: 1197.0457 - val_loss: 3.4572e-04 - val_mae: 0.0231 - val_mape: 133.8461
# Epoch 67/100
# 5/5 [==============================] - 2s 449ms/step - loss: 8.3632e-04 - mae: 0.0254 - mape: 1795.8156 - val_loss: 1.8326e-04 - val_mae: 0.0150 - val_mape: 81.1639
# Epoch 68/100
# 5/5 [==============================] - 1s 318ms/step - loss: 5.9455e-04 - mae: 0.0210 - mape: 899.4212 - val_loss: 3.2887e-04 - val_mae: 0.0224 - val_mape: 129.7256
# Epoch 69/100
# 5/5 [==============================] - 1s 271ms/step - loss: 6.3901e-04 - mae: 0.0215 - mape: 1048.7233 - val_loss: 1.4196e-04 - val_mae: 0.0130 - val_mape: 66.1889
# Epoch 70/100
# 5/5 [==============================] - 1s 190ms/step - loss: 4.7347e-04 - mae: 0.0189 - mape: 679.2719 - val_loss: 2.0264e-04 - val_mae: 0.0167 - val_mape: 98.0027
# Epoch 71/100
# 5/5 [==============================] - 1s 177ms/step - loss: 4.7604e-04 - mae: 0.0188 - mape: 1224.3646 - val_loss: 1.8094e-04 - val_mae: 0.0155 - val_mape: 89.4258
# Epoch 72/100
# 5/5 [==============================] - 1s 257ms/step - loss: 5.3251e-04 - mae: 0.0194 - mape: 652.8088 - val_loss: 2.0649e-04 - val_mae: 0.0168 - val_mape: 97.4812
# Epoch 73/100
# 5/5 [==============================] - 2s 309ms/step - loss: 5.1844e-04 - mae: 0.0189 - mape: 1802.7257 - val_loss: 2.4526e-04 - val_mae: 0.0187 - val_mape: 110.5639
# Epoch 74/100
# 5/5 [==============================] - 1s 310ms/step - loss: 4.4330e-04 - mae: 0.0183 - mape: 848.2793 - val_loss: 1.6492e-04 - val_mae: 0.0146 - val_mape: 82.7683
# Epoch 75/100
# 5/5 [==============================] - 1s 301ms/step - loss: 4.7567e-04 - mae: 0.0181 - mape: 1475.8262 - val_loss: 1.8031e-04 - val_mae: 0.0156 - val_mape: 90.9316
# Epoch 76/100
# 5/5 [==============================] - 3s 437ms/step - loss: 4.4284e-04 - mae: 0.0175 - mape: 1360.4409 - val_loss: 1.6298e-04 - val_mae: 0.0146 - val_mape: 84.0236
# Epoch 77/100
# 5/5 [==============================] - 2s 424ms/step - loss: 4.7115e-04 - mae: 0.0176 - mape: 1312.9983 - val_loss: 1.6495e-04 - val_mae: 0.0147 - val_mape: 84.7694
# Epoch 78/100
# 5/5 [==============================] - 1s 290ms/step - loss: 4.7496e-04 - mae: 0.0177 - mape: 966.4064 - val_loss: 1.7741e-04 - val_mae: 0.0154 - val_mape: 89.6286
# Epoch 79/100
# 5/5 [==============================] - 3s 625ms/step - loss: 5.2823e-04 - mae: 0.0181 - mape: 796.2067 - val_loss: 1.6276e-04 - val_mae: 0.0146 - val_mape: 83.9208
# Epoch 80/100
# 5/5 [==============================] - 3s 534ms/step - loss: 4.5913e-04 - mae: 0.0176 - mape: 656.5045 - val_loss: 1.7012e-04 - val_mae: 0.0150 - val_mape: 86.4197
# Epoch 81/100
# 5/5 [==============================] - 1s 267ms/step - loss: 4.1674e-04 - mae: 0.0170 - mape: 795.5604 - val_loss: 1.8171e-04 - val_mae: 0.0156 - val_mape: 91.3109
# Epoch 82/100
# 5/5 [==============================] - 1s 233ms/step - loss: 4.0184e-04 - mae: 0.0171 - mape: 1448.4398 - val_loss: 1.6298e-04 - val_mae: 0.0146 - val_mape: 84.0856
# Epoch 83/100
# 5/5 [==============================] - 1s 307ms/step - loss: 4.6823e-04 - mae: 0.0173 - mape: 956.8287 - val_loss: 1.6363e-04 - val_mae: 0.0146 - val_mape: 84.6762
# Epoch 84/100
# 5/5 [==============================] - 2s 436ms/step - loss: 4.5181e-04 - mae: 0.0175 - mape: 1460.0610 - val_loss: 1.5904e-04 - val_mae: 0.0143 - val_mape: 81.8178
# Epoch 85/100
# 5/5 [==============================] - 2s 473ms/step - loss: 4.1498e-04 - mae: 0.0170 - mape: 1618.1810 - val_loss: 1.8688e-04 - val_mae: 0.0159 - val_mape: 93.0243
# Epoch 86/100
# 5/5 [==============================] - 2s 389ms/step - loss: 4.2204e-04 - mae: 0.0174 - mape: 1055.5747 - val_loss: 1.4393e-04 - val_mae: 0.0135 - val_mape: 75.1141
# Epoch 87/100
# 5/5 [==============================] - 3s 617ms/step - loss: 4.6642e-04 - mae: 0.0176 - mape: 1582.3920 - val_loss: 1.5164e-04 - val_mae: 0.0140 - val_mape: 79.0268
# Epoch 88/100
# 5/5 [==============================] - 1s 242ms/step - loss: 4.2282e-04 - mae: 0.0171 - mape: 936.3309 - val_loss: 1.8946e-04 - val_mae: 0.0160 - val_mape: 93.8881
# Epoch 89/100
# 5/5 [==============================] - 3s 518ms/step - loss: 4.2133e-04 - mae: 0.0172 - mape: 970.4761 - val_loss: 1.6830e-04 - val_mae: 0.0149 - val_mape: 86.4445
# Epoch 90/100
# 5/5 [==============================] - 1s 201ms/step - loss: 4.5282e-04 - mae: 0.0172 - mape: 1078.5040 - val_loss: 1.4096e-04 - val_mae: 0.0134 - val_mape: 74.5080
# Epoch 91/100
# 5/5 [==============================] - 1s 216ms/step - loss: 4.5160e-04 - mae: 0.0171 - mape: 995.4677 - val_loss: 1.5607e-04 - val_mae: 0.0143 - val_mape: 82.0146
# Epoch 92/100
# 5/5 [==============================] - 2s 441ms/step - loss: 4.4596e-04 - mae: 0.0170 - mape: 966.1699 - val_loss: 1.5521e-04 - val_mae: 0.0142 - val_mape: 81.5342
# Epoch 93/100
# 5/5 [==============================] - 2s 324ms/step - loss: 4.4642e-04 - mae: 0.0174 - mape: 1814.0956 - val_loss: 1.5373e-04 - val_mae: 0.0141 - val_mape: 80.7293
# Epoch 94/100
# 5/5 [==============================] - 1s 203ms/step - loss: 4.3207e-04 - mae: 0.0171 - mape: 641.2390 - val_loss: 1.4272e-04 - val_mae: 0.0134 - val_mape: 73.8464
# Epoch 95/100
# 5/5 [==============================] - 2s 377ms/step - loss: 4.0584e-04 - mae: 0.0171 - mape: 887.3282 - val_loss: 2.3869e-04 - val_mae: 0.0185 - val_mape: 108.7517
# Epoch 96/100
# 5/5 [==============================] - 2s 463ms/step - loss: 4.1283e-04 - mae: 0.0184 - mape: 1602.7291 - val_loss: 1.3545e-04 - val_mae: 0.0130 - val_mape: 71.1219
# Epoch 97/100
# 5/5 [==============================] - 2s 404ms/step - loss: 4.7570e-04 - mae: 0.0183 - mape: 1322.6302 - val_loss: 1.7605e-04 - val_mae: 0.0154 - val_mape: 89.7709
# Epoch 98/100
# 5/5 [==============================] - 2s 323ms/step - loss: 4.2734e-04 - mae: 0.0176 - mape: 1274.3564 - val_loss: 1.6760e-04 - val_mae: 0.0149 - val_mape: 85.9497
# Epoch 99/100
# 5/5 [==============================] - 3s 611ms/step - loss: 4.7049e-04 - mae: 0.0180 - mape: 1420.5963 - val_loss: 2.0217e-04 - val_mae: 0.0167 - val_mape: 98.1148
# Epoch 100/100
# 5/5 [==============================] - 2s 376ms/step - loss: 4.7863e-04 - mae: 0.0192 - mape: 1141.3735 - val_loss: 1.3194e-04 - val_mae: 0.0126 - val_mape: 63.9579
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>

# %%
# from tensorflow import keras
# for key, value in model_configs.items():
#     print(key, value)
#     model=value['model']
#     # file_data=os.path.join(s_prt_path,'experimental_files\DataModel_' + key + '_72l_24a_' + dt.datetime.now().strftime("%Y-%m-%d"))
#     file_data=os.path.join(s_prt_path,'experimental_files\\')
#     print(file_data)
#     # keras.experimental.export_saved_model(model, file_data)
#     model.save(file_data,save_format='tf')
#     break

# %%
# import pickle
# import datetime as dt
# file_data=os.path.join(s_prt_path,'experimental_files\DataModel_72l_24a_' + dt.datetime.now().strftime("%Y-%m-%d") + '.plk')

# #Save Data
# with open(file_data, 'wb') as file:
#     pickle.dump(model_configs, file)

# with open('tensor_data.pkl', 'rb') as file:
#     loaded_dict = pickle.load(file)

# print(loaded_dict)

# %%
# from tensorflow import keras
# import datetime as dt
# model_configs=dict()
# models=['dnn','lstm','gru','lstm_cnn']
# for i in range(4):
#     print(i)
#     file_data=os.path.join(s_prt_path,'experimental_files\\DataModel_' + models[i] + '_72l_24a_' + (dt.datetime.now()-dt.timedelta(days=1)).strftime("%Y-%m-%d") + '.h5')
#     print(file_data)
#     model = keras.models.load_model(file_data, compile=False, encoding='utf-8')
#     model_configs[models[i]]=model

# %% [markdown]
# #### Gráficas de entrenamiento modelo con ventanado

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,5))

metric='loss'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, figsize=(25,5))

metric='mae'

i=0
i1=0
for (key, val) in model_configs_v.items():
    # sns.lineplot(val['history'].history[metric],ax=axs[i1,i])
    # sns.lineplot(val['history'].history[f'val_{metric}'],ax=axs[i1,i])
    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].set_facecolor('white')
    axs[i1,i].plot(val['history'].history[metric])
    axs[i1,i].plot(val['history'].history[f'val_{metric}'])
    axs[i1,i].set_title(key)
    axs[i1,i].legend([metric, f"val_{metric}"],facecolor='white')
    axs[i1,i].set_xlabel('epochs')
    axs[i1,i].set_ylabel(metric)
    # axs[i1,i].set_ylim([0, 0.1])
    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()

# %% [markdown]
# ##### Evaluar modelo con ventanado

# %%
print('Example sample shapes')
for idx,(x,y) in enumerate(train_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xtr= x.numpy()
    Ytr=y.numpy()
    break

for idx,(x,y) in enumerate(val_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xval= x.numpy()
    Yval=y.numpy()
    break

for idx,(x,y) in enumerate(test_ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    Xts= x.numpy()
    Yts=y.numpy()
    break
# Out:
# Example sample shapes
# x =  (256, 24, 7)
# y =  (256, 24, 1)
# x =  (256, 24, 7)
# y =  (256, 24, 1)
# x =  (256, 24, 7)
# y =  (256, 24, 1)

# %%
models=['dnn','lstm','gru','cnn_lstm']
results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
resultsYtestP={}
listP=[]

# fechaIni=
# FechaFin=

listreg=[i for i in range(3)]


Xtrm=Xtr[listreg]
Ytrm=Ytr[listreg]
Xvalm=Xval[listreg]
Yvalm=Yval[listreg]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtrm)
    Ye=scalerP.inverse_transform(Ytrm.reshape(Ytrm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    #Evaluación de las X en validación
    Yp=model.predict(Xvalm)
    Ye=scalerP.inverse_transform(Yvalm.reshape(Yvalm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    # Hacer pedicciones con el Xtest
    # Xts=tipomodelo['Xts']
    # Yts=tipomodelo['Yts'].reshape(Yts.shape[0],24)
    Yp=model.predict(Xtsm)
    Ye=scalerP.inverse_transform(Ytsm.reshape(Ytsm.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 1/1 [==============================] - 1s 1s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 0s 311ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 624ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 8s 8s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 0s 257ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 0s 187ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 9s 9s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 659ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 768ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# WARNING:tensorflow:5 out of the last 125 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002C4EB2C6AC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 5s 5s/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 1s 588ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\1700758202.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)

# %%
file=os.path.join(s_prt_path,'datasets\Results_' + str(n_steps) + '_' + str(n_horizon) + '_sinOfe.csv')
results.to_csv(file)

# %%
results
# Out:
#        Model   Tipo         MAE       MAPE      sMAPE        RMSE
# 0        dnn  Train   12.384511   6.706978   6.710855   16.032150
# 1        dnn    Val  123.107259  21.626521  21.418730  138.311020
# 2        dnn   Test   29.553921  22.178172  19.563182   31.808790
# 3       lstm  Train   20.673383  11.052563  11.947278   24.173355
# 4       lstm    Val  103.511788  19.409321  17.983272  126.341330
# 5       lstm   Test   22.433887  17.066139  15.356947   24.724439
# 6        gru  Train   25.395462  13.629295  14.867131   27.972424
# 7        gru    Val   97.898061  19.342120  16.910704  129.104877
# 8        gru   Test   18.674354  14.231320  12.953412   21.337963
# 9   cnn_lstm  Train   23.763524  12.722503  13.939553   27.928190
# 10  cnn_lstm    Val  147.085492  25.580747  25.808256  164.051806
# 11  cnn_lstm   Test   25.325603  17.886317  20.503035   30.785287

# %%
models=['dnn','lstm','gru','cnn_lstm']
results=pd.DataFrame(columns=['Model','Tipo','MAE','MAPE','sMAPE','RMSE'])
resultsYtestP={}
listP=[]
for mod in models:
    #Obtener el modelo
    tipomodelo=model_configs_v[mod]
    model=tipomodelo['model']

    #Evaluación de los X de entrenamiento
    Yp=model.predict(Xtr)
    Ye=scalerP.inverse_transform(Ytr.reshape(Ytr.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Train','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    #Evaluación de las X en validación
    Yp=model.predict(Xval)
    Ye=scalerP.inverse_transform(Yval.reshape(Yval.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Val','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    # Hacer pedicciones con el Xtest
    Yp=model.predict(Xts)
    Ye=scalerP.inverse_transform(Yts.reshape(Yts.shape[0],n_horizon))
    Yp=scalerP.inverse_transform(Yp)
    listP.append(Ye)
    listP.append(Yp)

    mae_validation = np.mean(MAE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))
    mape_validation= np.mean(MAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    smape_validation = np.mean(sMAPE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1))) * 100
    rmse_validation = np.mean(RMSE(Ye.flatten().reshape(-1,1), Yp.flatten().reshape(-1,1)))

    data={'Model':mod,'Tipo':'Test','MAE':mae_validation,'MAPE':mape_validation,
        'sMAPE':smape_validation,'RMSE':rmse_validation}
    results=results.append(data, ignore_index=True)

    resultsYtestP[mod]=listP
    listP=[]
# Out:
# 8/8 [==============================] - 0s 4ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 4ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 4ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 19ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 17ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 22ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 1s 14ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 16ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 22ms/step
# 1/8 [==>...........................] - ETA: 0s
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 6ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 8ms/step
# 1/8 [==>...........................] - ETA: 0s
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)
# 8/8 [==============================] - 0s 9ms/step
# C:\Users\alejo\AppData\Local\Temp\ipykernel_8844\488922259.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results=results.append(data, ignore_index=True)

# %%
results
# Out:
#        Model   Tipo        MAE       MAPE      sMAPE       RMSE
# 0        dnn  Train  31.808170  25.247945  19.670174  41.221883
# 1        dnn    Val  70.136318  53.390403  37.664795  82.302106
# 2        dnn   Test  60.436144  73.123955  48.027447  69.005466
# 3       lstm  Train  30.900958  23.359779  19.224692  41.206364
# 4       lstm    Val  40.104221  29.331836  24.310984  51.581359
# 5       lstm   Test  57.485737  70.291068  46.633623  66.201186
# 6        gru  Train  30.430496  22.650726  19.134089  40.134139
# 7        gru    Val  38.743492  28.684529  23.464710  50.501955
# 8        gru   Test  54.703157  66.967376  44.981362  63.475568
# 9   cnn_lstm  Train  29.458241  18.747018  18.391380  39.548633
# 10  cnn_lstm    Val  39.181277  24.062976  23.984746  52.947916
# 11  cnn_lstm   Test  31.589137  35.203499  29.063860  37.370892

# %% [markdown]
# #### Gráfica del original y del pronóstico

# %%
listreg=[i for i in range(3)]
Xtsm=Xts[listreg]
Ytsm=Yts[listreg]

fig, axs = plt.subplots(2,2,figsize=(25,10))  # create a new figure with a default 111 subplot

i=0
i1=0
for (key, val) in model_configs_v.items():

    print(key,val)

    preds = val['model'].predict(Xtsm)

    Ye=Ytsm.reshape(-1,1)
    Ye=scalerP.inverse_transform(Ye)

    Yp=preds[listreg].reshape(-1,1)
    Yp=scalerP.inverse_transform(Yp)

    sns.set(font_scale=1.5,rc={'font.size': 12, 'axes.titlesize': 16})
    axs[i1,i].plot(Ye, label='Original')
    axs[i1,i].plot(Yp, label='Predicción')
    axs[i1,i].set_title(key)
    axs[i1,i].set_xlabel("Hora")
    axs[i1,i].set_ylabel("Precio de Bolsa [$/kWh-día]")
    axs[i1,i].legend(['Original','Predicción'],facecolor='white')
    axs[i1,i].set_facecolor('white')

    i=i+1
    if i==2:
        i1=1
        i=0

plt.tight_layout()
# Out:
# dnn {'model': <keras.engine.sequential.Sequential object at 0x000002C4EB66DB10>, 'history': <keras.callbacks.History object at 0x000002C4EC425AD0>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 1s 1s/step
# lstm {'model': <keras.engine.sequential.Sequential object at 0x000002C4D9BC9590>, 'history': <keras.callbacks.History object at 0x000002C4DA4C10D0>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 489ms/step
# gru {'model': <keras.engine.sequential.Sequential object at 0x000002C4DA73EA10>, 'history': <keras.callbacks.History object at 0x000002C4DA45CA10>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 293ms/step
# cnn_lstm {'model': <keras.engine.sequential.Sequential object at 0x000002C4E8CEE950>, 'history': <keras.callbacks.History object at 0x000002C4E8A1F290>, 'test_ds': <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 7), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>}
# 1/1 [==============================] - 0s 58ms/step
